# %% [markdown]
# # MongoDB
#
# [MongoDB](https://www.mongodb.com/) es un sistema gestor de ase de datos no relacional (no tabular) orientada a documentos. Cuando hablamos de documentos, hablamos de información estructurada y anotada tal y como suele ser habitual en el contexto web.
#
# Las bases de datos orientadas a objetos usaban originalmente documentos XML:
#
# ```xml
# <books>
#     <book>
#         <title>The three body problem</title>
#         <author>Cixin Liu</author>
#     </book>
#     <book>
#         <title>Foundation</title>
#         <author>Isaac Asimov</author>
#     </book>
# </books>
# ```
#
# pero MongoDB pertenece a la nueva generación donde las estructuras de objetos Javascript (JSON) son las predominantes, siendo esa la estructura de los documentos que nos encontraremos.
#
# ```json
# {
#     'books' : [
#         {
#             'title' : "The three body problem",
#             'author' : "Cixin Liu"
#         },
#         {
#             'title' : "Foundation",
#             'author' : "Isaac Asimov"
#         }
#     ]
# }
# ```
#
# Disponer de una base de datos MongoDB resultaría algo más complejo de instalar pero hoy día nos podemos beneficiar de la oferta nube gratuita de MongoDB Atlas: https://www.mongodb.com/cloud/atlas/register
#
# Una vez registrados podréis ver la pantalla central donde crear vuestra primera base de datos:
#
# ![home](./img/atlas-home.png)
#
# **NOTA: Prestad atención a seleccionar la capacidad M0 que es la gratuita**
#
# ![m0](./img/atlas-free.png)

# %% [markdown]
# Cread vuestro usuario y contraseña y veréis que os habilita la opción para poder conectaros desde vuestra conexión actual (habilitar IP).
#
# ![auth](./img/mongo-auth.png)

# %% [markdown]
# Con esto ya os indica distintas formas de conectarnos, nosotros seleccionaremos la opción de drivers:
#
# ![driver](./img/mongo-drivers.png)
#
# Y si hemos indicado Python como nuestra lenguaje de preferencia, nos mostrará directamente la información relevante para realizar la conexión.
#
# ![python](./img/mongo-python.png)

# %%
pip install "pymongo[srv]"
# Out:
# Collecting pymongo[srv]
#   Downloading pymongo-4.7.3-cp312-cp312-win_amd64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo[srv])
#   Downloading dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#    ---------------------------------------- 0.0/307.7 kB ? eta -:--:--
#    ----- --------------------------------- 41.0/307.7 kB 991.0 kB/s eta 0:00:01
#    ------------------ --------------------- 143.4/307.7 kB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 307.7/307.7 kB 2.4 MB/s eta 0:00:00
# Downloading pymongo-4.7.3-cp312-cp312-win_amd64.whl (484 kB)
#    ---------------------------------------- 0.0/484.2 kB ? eta -:--:--
#    -------- ------------------------------- 102.4/484.2 kB 5.8 MB/s eta 0:00:01
#    ------------------ --------------------- 225.3/484.2 kB 2.8 MB/s eta 0:00:01
#    ------------------------------ --------- 368.6/484.2 kB 2.9 MB/s eta 0:00:01
#    -------------------------------- ------- 399.4/484.2 kB 2.1 MB/s eta 0:00:01
#    -------------------------------- ------- 399.4/484.2 kB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 484.2/484.2 kB 1.8 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.6.1 pymongo-4.7.3
# Note: you may need to restart the kernel to use updated packages.

# %%
connection_string = "mongodb+srv://rodrigomezaortiz:TAwhpuAmtG8LBym6  @cluster0.rmvbjey.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
from pymongo import MongoClient

client = MongoClient(connection_string)

# %% [markdown]
# Una vez conectados, podemos acceder a ciertos datos de prueba que nos deja ver MongoDB:
#
# * Base de datos: sample_mflix
# * Colección: movies

# %%
sample_mflix = client.get_database("sample_mflix")

# %%
movies = sample_mflix.get_collection("movies")

# %% [markdown]
# En gran medida las operaciones que realizaremos con MongoDB son de búsqueda y filtrado de documentos.

# %%
data = collection.find()

for row in data:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[16], line 3
#       1 data = collection.find()
# ----> 3 for row in data:
#       4     print(row)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\cursor.py:1243, in Cursor.next(self)
#    1241 if self.__empty:
#    1242     raise StopIteration
# -> 1243 if len(self.__data) or self._refresh():
#    1244     return self.__data.popleft()
#    1245 else:
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\cursor.py:1160, in Cursor._refresh(self)
#    1138         raise InvalidOperation(
#    1139             "Passing a 'hint' is required when using the min/max query"
#    1140             " option to ensure the query utilizes the correct index"
#    1141         )
#    1142     q = self._query_class(
#    1143         self.__query_flags,
#    1144         self.__collection.database.name,
#    (...)
#    1158         self.__exhaust,
#    1159     )
# -> 1160     self.__send_message(q)
#    1161 elif self.__id:  # Get More
#    1162     if self.__limit:
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\cursor.py:1039, in Cursor.__send_message(self, operation)
#    1036     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1038 try:
# -> 1039     response = client._run_operation(
#    1040         operation, self._unpack_response, address=self.__address
#    1041     )
#    1042 except OperationFailure as exc:
#    1043     if exc.code in _CURSOR_CLOSED_ERRORS or self.__exhaust:
#    1044         # Don't send killCursors because the cursor is already closed.
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1425, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1415     operation.reset()  # Reset op in case of retry.
#    1416     return server.run_operation(
#    1417         conn,
#    1418         operation,
#    (...)
#    1422         self,
#    1423     )
# -> 1425 return self._retryable_read(
#    1426     _cmd,
#    1427     operation.read_preference,
#    1428     operation.session,
#    1429     address=address,
#    1430     retryable=isinstance(operation, message._Query),
#    1431     operation=operation.name,
#    1432 )
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1534, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    1529 # Ensure that the client supports retrying on reads and there is no session in
#    1530 # transaction, otherwise, we will not support retry behavior for this call.
#    1531 retryable = bool(
#    1532     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    1533 )
# -> 1534 return self._retry_internal(
#    1535     func,
#    1536     session,
#    1537     None,
#    1538     operation,
#    1539     is_read=True,
#    1540     address=address,
#    1541     read_pref=read_pref,
#    1542     retryable=retryable,
#    1543     operation_id=operation_id,
#    1544 )
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1501, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1464 @_csot.apply
#    1465 def _retry_internal(
#    1466     self,
#    (...)
#    1475     operation_id: Optional[int] = None,
#    1476 ) -> T:
#    1477     """Internal retryable helper for all client transactions.
#    1478
#    1479     :param func: Callback function we want to retry
#    (...)
#    1488     :return: Output of the calling func()
#    1489     """
#    1490     return _ClientConnectionRetryable(
#    1491         mongo_client=self,
#    1492         func=func,
#    1493         bulk=bulk,
#    1494         operation=operation,
#    1495         is_read=is_read,
#    1496         session=session,
#    1497         read_pref=read_pref,
#    1498         address=address,
#    1499         retryable=retryable,
#    1500         operation_id=operation_id,
# -> 1501     ).run()
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:2347, in _ClientConnectionRetryable.run(self)
#    2345 self._check_last_error(check_csot=True)
#    2346 try:
# -> 2347     return self._read() if self._is_read else self._write()
#    2348 except ServerSelectionTimeoutError:
#    2349     # The application may think the write was never attempted
#    2350     # if we raise ServerSelectionTimeoutError on the retry
#    2351     # attempt. Raise the original exception instead.
#    2352     self._check_last_error()
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:2479, in _ClientConnectionRetryable._read(self)
#    2477 self._server = self._get_server()
#    2478 assert self._read_pref is not None, "Read Preference required on read calls"
# -> 2479 with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#    2480     conn,
#    2481     read_pref,
#    2482 ):
#    2483     if self._retrying and not self._retryable:
#    2484         self._check_last_error()
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1351, in MongoClient._conn_from_server(self, read_preference, server, session)
#    1341 # Get a connection for a server matching the read preference, and yield
#    1342 # conn with the effective read preference. The Server Selection
#    1343 # Spec says not to send any $readPreference to standalones and to
#    (...)
#    1347 # NOTE: We already opened the Topology when selecting a server so there's no need
#    1348 # to call _get_topology() again.
#    1349 single = self._topology.description.topology_type == TOPOLOGY_TYPE.Single
# -> 1351 with self._checkout(server, session) as conn:
#    1352     if single:
#    1353         if conn.is_repl and not (session and session.in_transaction):
#    1354             # Use primary preferred to ensure any repl set member
#    1355             # can handle the request.
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1260, in MongoClient._checkout(self, server, session)
#    1258     yield session._pinned_connection
#    1259     return
# -> 1260 with server.checkout(handler=err_handler) as conn:
#    1261     # Pin this session to the selected server or connection.
#    1262     if (
#    1263         in_txn
#    1264         and session
#    (...)
#    1269         )
#    1270     ):
#    1271         session._pin(server, conn)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:1763, in Pool.checkout(self, handler)
#    1754     if _CONNECTION_LOGGER.isEnabledFor(logging.DEBUG):
#    1755         _debug_log(
#    1756             _CONNECTION_LOGGER,
#    1757             clientId=self._client_id,
#    (...)
#    1760             serverPort=self.address[1],
#    1761         )
# -> 1763 conn = self._get_conn(checkout_started_time, handler=handler)
#    1765 if self.enabled_for_cmap:
#    1766     assert listeners is not None
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:1921, in Pool._get_conn(self, checkout_started_time, handler)
#    1919 else:  # We need to create a new connection
#    1920     try:
# -> 1921         conn = self.connect(handler=handler)
#    1922     finally:
#    1923         with self._max_connecting_cond:
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:1725, in Pool.connect(self, handler)
#    1722     if handler:
#    1723         handler.contribute_socket(conn, completed_handshake=False)
# -> 1725     conn.authenticate()
#    1726 except BaseException:
#    1727     conn.close_conn(ConnectionClosedReason.ERROR)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:1098, in Connection.authenticate(self, reauthenticate)
#    1095 if creds:
#    1096     from pymongo import auth
# -> 1098     auth.authenticate(creds, self, reauthenticate=reauthenticate)
#    1099 self.ready = True
#    1100 if self.enabled_for_cmap:
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\auth.py:656, in authenticate(credentials, conn, reauthenticate)
#     654     _authenticate_oidc(credentials, conn, reauthenticate)
#     655 else:
# --> 656     auth_func(credentials, conn)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\auth.py:560, in _authenticate_default(credentials, conn)
#     558         return _authenticate_scram(credentials, conn, "SCRAM-SHA-256")
#     559     else:
# --> 560         return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#     561 else:
#     562     return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\auth.py:338, in _authenticate_scram(credentials, conn, mechanism)
#     331 server_sig = standard_b64encode(_hmac(server_key, auth_msg, digestmod).digest())
#     333 cmd = {
#     334     "saslContinue": 1,
#     335     "conversationId": res["conversationId"],
#     336     "payload": Binary(client_final),
#     337 }
# --> 338 res = conn.command(source, cmd)
#     340 parsed = _parse_scram_response(res["payload"])
#     341 if not hmac.compare_digest(parsed[b"v"], server_sig):
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\helpers.py:342, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     339 from pymongo.pool import Connection
#     341 try:
# --> 342     return func(*args, **kwargs)
#     343 except OperationFailure as exc:
#     344     if no_reauth:
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:988, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     986     self._raise_if_not_writable(unacknowledged)
#     987 try:
# --> 988     return command(
#     989         self,
#     990         dbname,
#     991         spec,
#     992         self.is_mongos,
#     993         read_preference,
#     994         codec_options,
#     995         session,
#     996         client,
#     997         check,
#     998         allowable_errors,
#     999         self.address,
#    1000         listeners,
#    1001         self.max_bson_size,
#    1002         read_concern,
#    1003         parse_write_concern_error=parse_write_concern_error,
#    1004         collation=collation,
#    1005         compression_ctx=self.compression_context,
#    1006         use_op_msg=self.op_msg_enabled,
#    1007         unacknowledged=unacknowledged,
#    1008         user_fields=user_fields,
#    1009         exhaust_allowed=exhaust_allowed,
#    1010         write_concern=write_concern,
#    1011     )
#    1012 except (OperationFailure, NotPrimaryError):
#    1013     raise
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\network.py:212, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     210             client._process_response(response_doc, session)
#     211         if check:
# --> 212             helpers._check_command_response(
#     213                 response_doc,
#     214                 conn.max_wire_version,
#     215                 allowable_errors,
#     216                 parse_write_concern_error=parse_write_concern_error,
#     217             )
#     218 except Exception as exc:
#     219     duration = datetime.datetime.now() - start
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\helpers.py:248, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     245 elif code == 43:
#     246     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 248 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: bad auth : authentication failed, full error: {'ok': 0, 'errmsg': 'bad auth : authentication failed', 'code': 8000, 'codeName': 'AtlasError'}

# %% [markdown]
# Por defecto, las preguntas nos devuelven un cursor. Una especie de apuntador a los datos que nos irá dando los datos según los vayamos pidiendo para no desbordar nuestra máquina.

# %%
type(movies_data)
# Out:
# pymongo.cursor.Cursor

# %% [markdown]
# Si conocemos algún campo de los documentos, podemos pedir aquellos que por ejemplo tengan como título _Back to the future_

# %%
from pprint import pprint

# Query for a movie that has the title 'Back to the Future'
query = { "title": "Back to the Future" }

movies_data = movies.find(query)

for movie in movies_data:
    pprint(movie)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[18], line 8
#       4 query = { "title": "Back to the Future" }
#       6 movies_data = movies.find(query)
# ----> 8 for movie in movies_data:
#       9     pprint(movie)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\cursor.py:1243, in Cursor.next(self)
#    1241 if self.__empty:
#    1242     raise StopIteration
# -> 1243 if len(self.__data) or self._refresh():
#    1244     return self.__data.popleft()
#    1245 else:
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\cursor.py:1160, in Cursor._refresh(self)
#    1138         raise InvalidOperation(
#    1139             "Passing a 'hint' is required when using the min/max query"
#    1140             " option to ensure the query utilizes the correct index"
#    1141         )
#    1142     q = self._query_class(
#    1143         self.__query_flags,
#    1144         self.__collection.database.name,
#    (...)
#    1158         self.__exhaust,
#    1159     )
# -> 1160     self.__send_message(q)
#    1161 elif self.__id:  # Get More
#    1162     if self.__limit:
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\cursor.py:1039, in Cursor.__send_message(self, operation)
#    1036     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1038 try:
# -> 1039     response = client._run_operation(
#    1040         operation, self._unpack_response, address=self.__address
#    1041     )
#    1042 except OperationFailure as exc:
#    1043     if exc.code in _CURSOR_CLOSED_ERRORS or self.__exhaust:
#    1044         # Don't send killCursors because the cursor is already closed.
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1425, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1415     operation.reset()  # Reset op in case of retry.
#    1416     return server.run_operation(
#    1417         conn,
#    1418         operation,
#    (...)
#    1422         self,
#    1423     )
# -> 1425 return self._retryable_read(
#    1426     _cmd,
#    1427     operation.read_preference,
#    1428     operation.session,
#    1429     address=address,
#    1430     retryable=isinstance(operation, message._Query),
#    1431     operation=operation.name,
#    1432 )
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1534, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    1529 # Ensure that the client supports retrying on reads and there is no session in
#    1530 # transaction, otherwise, we will not support retry behavior for this call.
#    1531 retryable = bool(
#    1532     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    1533 )
# -> 1534 return self._retry_internal(
#    1535     func,
#    1536     session,
#    1537     None,
#    1538     operation,
#    1539     is_read=True,
#    1540     address=address,
#    1541     read_pref=read_pref,
#    1542     retryable=retryable,
#    1543     operation_id=operation_id,
#    1544 )
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1501, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1464 @_csot.apply
#    1465 def _retry_internal(
#    1466     self,
#    (...)
#    1475     operation_id: Optional[int] = None,
#    1476 ) -> T:
#    1477     """Internal retryable helper for all client transactions.
#    1478
#    1479     :param func: Callback function we want to retry
#    (...)
#    1488     :return: Output of the calling func()
#    1489     """
#    1490     return _ClientConnectionRetryable(
#    1491         mongo_client=self,
#    1492         func=func,
#    1493         bulk=bulk,
#    1494         operation=operation,
#    1495         is_read=is_read,
#    1496         session=session,
#    1497         read_pref=read_pref,
#    1498         address=address,
#    1499         retryable=retryable,
#    1500         operation_id=operation_id,
# -> 1501     ).run()
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:2347, in _ClientConnectionRetryable.run(self)
#    2345 self._check_last_error(check_csot=True)
#    2346 try:
# -> 2347     return self._read() if self._is_read else self._write()
#    2348 except ServerSelectionTimeoutError:
#    2349     # The application may think the write was never attempted
#    2350     # if we raise ServerSelectionTimeoutError on the retry
#    2351     # attempt. Raise the original exception instead.
#    2352     self._check_last_error()
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:2479, in _ClientConnectionRetryable._read(self)
#    2477 self._server = self._get_server()
#    2478 assert self._read_pref is not None, "Read Preference required on read calls"
# -> 2479 with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#    2480     conn,
#    2481     read_pref,
#    2482 ):
#    2483     if self._retrying and not self._retryable:
#    2484         self._check_last_error()
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1351, in MongoClient._conn_from_server(self, read_preference, server, session)
#    1341 # Get a connection for a server matching the read preference, and yield
#    1342 # conn with the effective read preference. The Server Selection
#    1343 # Spec says not to send any $readPreference to standalones and to
#    (...)
#    1347 # NOTE: We already opened the Topology when selecting a server so there's no need
#    1348 # to call _get_topology() again.
#    1349 single = self._topology.description.topology_type == TOPOLOGY_TYPE.Single
# -> 1351 with self._checkout(server, session) as conn:
#    1352     if single:
#    1353         if conn.is_repl and not (session and session.in_transaction):
#    1354             # Use primary preferred to ensure any repl set member
#    1355             # can handle the request.
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1260, in MongoClient._checkout(self, server, session)
#    1258     yield session._pinned_connection
#    1259     return
# -> 1260 with server.checkout(handler=err_handler) as conn:
#    1261     # Pin this session to the selected server or connection.
#    1262     if (
#    1263         in_txn
#    1264         and session
#    (...)
#    1269         )
#    1270     ):
#    1271         session._pin(server, conn)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:1763, in Pool.checkout(self, handler)
#    1754     if _CONNECTION_LOGGER.isEnabledFor(logging.DEBUG):
#    1755         _debug_log(
#    1756             _CONNECTION_LOGGER,
#    1757             clientId=self._client_id,
#    (...)
#    1760             serverPort=self.address[1],
#    1761         )
# -> 1763 conn = self._get_conn(checkout_started_time, handler=handler)
#    1765 if self.enabled_for_cmap:
#    1766     assert listeners is not None
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:1921, in Pool._get_conn(self, checkout_started_time, handler)
#    1919 else:  # We need to create a new connection
#    1920     try:
# -> 1921         conn = self.connect(handler=handler)
#    1922     finally:
#    1923         with self._max_connecting_cond:
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:1725, in Pool.connect(self, handler)
#    1722     if handler:
#    1723         handler.contribute_socket(conn, completed_handshake=False)
# -> 1725     conn.authenticate()
#    1726 except BaseException:
#    1727     conn.close_conn(ConnectionClosedReason.ERROR)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:1098, in Connection.authenticate(self, reauthenticate)
#    1095 if creds:
#    1096     from pymongo import auth
# -> 1098     auth.authenticate(creds, self, reauthenticate=reauthenticate)
#    1099 self.ready = True
#    1100 if self.enabled_for_cmap:
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\auth.py:656, in authenticate(credentials, conn, reauthenticate)
#     654     _authenticate_oidc(credentials, conn, reauthenticate)
#     655 else:
# --> 656     auth_func(credentials, conn)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\auth.py:560, in _authenticate_default(credentials, conn)
#     558         return _authenticate_scram(credentials, conn, "SCRAM-SHA-256")
#     559     else:
# --> 560         return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#     561 else:
#     562     return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\auth.py:338, in _authenticate_scram(credentials, conn, mechanism)
#     331 server_sig = standard_b64encode(_hmac(server_key, auth_msg, digestmod).digest())
#     333 cmd = {
#     334     "saslContinue": 1,
#     335     "conversationId": res["conversationId"],
#     336     "payload": Binary(client_final),
#     337 }
# --> 338 res = conn.command(source, cmd)
#     340 parsed = _parse_scram_response(res["payload"])
#     341 if not hmac.compare_digest(parsed[b"v"], server_sig):
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\helpers.py:342, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     339 from pymongo.pool import Connection
#     341 try:
# --> 342     return func(*args, **kwargs)
#     343 except OperationFailure as exc:
#     344     if no_reauth:
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:988, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     986     self._raise_if_not_writable(unacknowledged)
#     987 try:
# --> 988     return command(
#     989         self,
#     990         dbname,
#     991         spec,
#     992         self.is_mongos,
#     993         read_preference,
#     994         codec_options,
#     995         session,
#     996         client,
#     997         check,
#     998         allowable_errors,
#     999         self.address,
#    1000         listeners,
#    1001         self.max_bson_size,
#    1002         read_concern,
#    1003         parse_write_concern_error=parse_write_concern_error,
#    1004         collation=collation,
#    1005         compression_ctx=self.compression_context,
#    1006         use_op_msg=self.op_msg_enabled,
#    1007         unacknowledged=unacknowledged,
#    1008         user_fields=user_fields,
#    1009         exhaust_allowed=exhaust_allowed,
#    1010         write_concern=write_concern,
#    1011     )
#    1012 except (OperationFailure, NotPrimaryError):
#    1013     raise
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\network.py:212, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     210             client._process_response(response_doc, session)
#     211         if check:
# --> 212             helpers._check_command_response(
#     213                 response_doc,
#     214                 conn.max_wire_version,
#     215                 allowable_errors,
#     216                 parse_write_concern_error=parse_write_concern_error,
#     217             )
#     218 except Exception as exc:
#     219     duration = datetime.datetime.now() - start
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\helpers.py:248, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     245 elif code == 43:
#     246     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 248 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: bad auth : authentication failed, full error: {'ok': 0, 'errmsg': 'bad auth : authentication failed', 'code': 8000, 'codeName': 'AtlasError'}

# %% [markdown]
# ## CRUD
#
# Operaciones de creación, actualización y borrado (CUD). Veremos la lectura (filtrado) más en detalle, que será la versión mongodb de las _SELECT FROM WHERE_ que veníamos usando en bases de datos SQL.

# %%
database = client.get_database("thebridge")
collection = database.get_collection("datascience")
collection.insert_one({"nombre": "Rodrigo", "apellido" : "Meza"})
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[20], line 3
#       1 database = client.get_database("thebridge")
#       2 collection = database.get_collection("datascience")
# ----> 3 collection.insert_one({"nombre": "Rodrigo", "apellido" : "Meza"})
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\collection.py:658, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     654     document["_id"] = ObjectId()  # type: ignore[index]
#     656 write_concern = self._write_concern_for(session)
#     657 return InsertOneResult(
# --> 658     self._insert_one(
#     659         document,
#     660         ordered=True,
#     661         write_concern=write_concern,
#     662         op_id=None,
#     663         bypass_doc_val=bypass_document_validation,
#     664         session=session,
#     665         comment=comment,
#     666     ),
#     667     write_concern.acknowledged,
#     668 )
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\collection.py:598, in Collection._insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     586     result = conn.command(
#     587         self.__database.name,
#     588         command,
#    (...)
#     593         retryable_write=retryable_write,
#     594     )
#     596     _check_write_command_response(result)
# --> 598 self.__database.client._retryable_write(
#     599     acknowledged, _insert_command, session, operation=_Op.INSERT
#     600 )
#     602 if not isinstance(doc, RawBSONDocument):
#     603     return doc.get("_id")
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1569, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    1555 """Execute an operation with consecutive retries if possible
#    1556
#    1557 Returns func()'s return value on success. On error retries the same
#    (...)
#    1566 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    1567 """
#    1568 with self._tmp_session(session) as s:
# -> 1569     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1455, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1450 # Ensure that the options supports retry_writes and there is a valid session not in
#    1451 # transaction, otherwise, we will not support retry behavior for this txn.
#    1452 retryable = bool(
#    1453     retryable and self.options.retry_writes and session and not session.in_transaction
#    1454 )
# -> 1455 return self._retry_internal(
#    1456     func=func,
#    1457     session=session,
#    1458     bulk=bulk,
#    1459     operation=operation,
#    1460     retryable=retryable,
#    1461     operation_id=operation_id,
#    1462 )
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1501, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1464 @_csot.apply
#    1465 def _retry_internal(
#    1466     self,
#    (...)
#    1475     operation_id: Optional[int] = None,
#    1476 ) -> T:
#    1477     """Internal retryable helper for all client transactions.
#    1478
#    1479     :param func: Callback function we want to retry
#    (...)
#    1488     :return: Output of the calling func()
#    1489     """
#    1490     return _ClientConnectionRetryable(
#    1491         mongo_client=self,
#    1492         func=func,
#    1493         bulk=bulk,
#    1494         operation=operation,
#    1495         is_read=is_read,
#    1496         session=session,
#    1497         read_pref=read_pref,
#    1498         address=address,
#    1499         retryable=retryable,
#    1500         operation_id=operation_id,
# -> 1501     ).run()
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:2347, in _ClientConnectionRetryable.run(self)
#    2345 self._check_last_error(check_csot=True)
#    2346 try:
# -> 2347     return self._read() if self._is_read else self._write()
#    2348 except ServerSelectionTimeoutError:
#    2349     # The application may think the write was never attempted
#    2350     # if we raise ServerSelectionTimeoutError on the retry
#    2351     # attempt. Raise the original exception instead.
#    2352     self._check_last_error()
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:2451, in _ClientConnectionRetryable._write(self)
#    2449 is_mongos = False
#    2450 self._server = self._get_server()
# -> 2451 with self._client._checkout(self._server, self._session) as conn:
#    2452     max_wire_version = conn.max_wire_version
#    2453     sessions_supported = (
#    2454         self._session
#    2455         and self._server.description.retryable_writes_supported
#    2456         and conn.supports_sessions
#    2457     )
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1260, in MongoClient._checkout(self, server, session)
#    1258     yield session._pinned_connection
#    1259     return
# -> 1260 with server.checkout(handler=err_handler) as conn:
#    1261     # Pin this session to the selected server or connection.
#    1262     if (
#    1263         in_txn
#    1264         and session
#    (...)
#    1269         )
#    1270     ):
#    1271         session._pin(server, conn)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:1763, in Pool.checkout(self, handler)
#    1754     if _CONNECTION_LOGGER.isEnabledFor(logging.DEBUG):
#    1755         _debug_log(
#    1756             _CONNECTION_LOGGER,
#    1757             clientId=self._client_id,
#    (...)
#    1760             serverPort=self.address[1],
#    1761         )
# -> 1763 conn = self._get_conn(checkout_started_time, handler=handler)
#    1765 if self.enabled_for_cmap:
#    1766     assert listeners is not None
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:1921, in Pool._get_conn(self, checkout_started_time, handler)
#    1919 else:  # We need to create a new connection
#    1920     try:
# -> 1921         conn = self.connect(handler=handler)
#    1922     finally:
#    1923         with self._max_connecting_cond:
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:1725, in Pool.connect(self, handler)
#    1722     if handler:
#    1723         handler.contribute_socket(conn, completed_handshake=False)
# -> 1725     conn.authenticate()
#    1726 except BaseException:
#    1727     conn.close_conn(ConnectionClosedReason.ERROR)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:1098, in Connection.authenticate(self, reauthenticate)
#    1095 if creds:
#    1096     from pymongo import auth
# -> 1098     auth.authenticate(creds, self, reauthenticate=reauthenticate)
#    1099 self.ready = True
#    1100 if self.enabled_for_cmap:
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\auth.py:656, in authenticate(credentials, conn, reauthenticate)
#     654     _authenticate_oidc(credentials, conn, reauthenticate)
#     655 else:
# --> 656     auth_func(credentials, conn)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\auth.py:560, in _authenticate_default(credentials, conn)
#     558         return _authenticate_scram(credentials, conn, "SCRAM-SHA-256")
#     559     else:
# --> 560         return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#     561 else:
#     562     return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\auth.py:338, in _authenticate_scram(credentials, conn, mechanism)
#     331 server_sig = standard_b64encode(_hmac(server_key, auth_msg, digestmod).digest())
#     333 cmd = {
#     334     "saslContinue": 1,
#     335     "conversationId": res["conversationId"],
#     336     "payload": Binary(client_final),
#     337 }
# --> 338 res = conn.command(source, cmd)
#     340 parsed = _parse_scram_response(res["payload"])
#     341 if not hmac.compare_digest(parsed[b"v"], server_sig):
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\helpers.py:342, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     339 from pymongo.pool import Connection
#     341 try:
# --> 342     return func(*args, **kwargs)
#     343 except OperationFailure as exc:
#     344     if no_reauth:
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:988, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     986     self._raise_if_not_writable(unacknowledged)
#     987 try:
# --> 988     return command(
#     989         self,
#     990         dbname,
#     991         spec,
#     992         self.is_mongos,
#     993         read_preference,
#     994         codec_options,
#     995         session,
#     996         client,
#     997         check,
#     998         allowable_errors,
#     999         self.address,
#    1000         listeners,
#    1001         self.max_bson_size,
#    1002         read_concern,
#    1003         parse_write_concern_error=parse_write_concern_error,
#    1004         collation=collation,
#    1005         compression_ctx=self.compression_context,
#    1006         use_op_msg=self.op_msg_enabled,
#    1007         unacknowledged=unacknowledged,
#    1008         user_fields=user_fields,
#    1009         exhaust_allowed=exhaust_allowed,
#    1010         write_concern=write_concern,
#    1011     )
#    1012 except (OperationFailure, NotPrimaryError):
#    1013     raise
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\network.py:212, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     210             client._process_response(response_doc, session)
#     211         if check:
# --> 212             helpers._check_command_response(
#     213                 response_doc,
#     214                 conn.max_wire_version,
#     215                 allowable_errors,
#     216                 parse_write_concern_error=parse_write_concern_error,
#     217             )
#     218 except Exception as exc:
#     219     duration = datetime.datetime.now() - start
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\helpers.py:248, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     245 elif code == 43:
#     246     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 248 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: bad auth : authentication failed, full error: {'ok': 0, 'errmsg': 'bad auth : authentication failed', 'code': 8000, 'codeName': 'AtlasError'}

# %% [markdown]
# No existe la base de datos, no existe la colección y hemos podido insertar el dato ¿Cómo puede ser?

# %%
data = collection.find()

for row in data:
    pprint(row)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[19], line 3
#       1 data = collection.find()
# ----> 3 for row in data:
#       4     pprint(row)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\cursor.py:1243, in Cursor.next(self)
#    1241 if self.__empty:
#    1242     raise StopIteration
# -> 1243 if len(self.__data) or self._refresh():
#    1244     return self.__data.popleft()
#    1245 else:
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\cursor.py:1160, in Cursor._refresh(self)
#    1138         raise InvalidOperation(
#    1139             "Passing a 'hint' is required when using the min/max query"
#    1140             " option to ensure the query utilizes the correct index"
#    1141         )
#    1142     q = self._query_class(
#    1143         self.__query_flags,
#    1144         self.__collection.database.name,
#    (...)
#    1158         self.__exhaust,
#    1159     )
# -> 1160     self.__send_message(q)
#    1161 elif self.__id:  # Get More
#    1162     if self.__limit:
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\cursor.py:1039, in Cursor.__send_message(self, operation)
#    1036     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1038 try:
# -> 1039     response = client._run_operation(
#    1040         operation, self._unpack_response, address=self.__address
#    1041     )
#    1042 except OperationFailure as exc:
#    1043     if exc.code in _CURSOR_CLOSED_ERRORS or self.__exhaust:
#    1044         # Don't send killCursors because the cursor is already closed.
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1425, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1415     operation.reset()  # Reset op in case of retry.
#    1416     return server.run_operation(
#    1417         conn,
#    1418         operation,
#    (...)
#    1422         self,
#    1423     )
# -> 1425 return self._retryable_read(
#    1426     _cmd,
#    1427     operation.read_preference,
#    1428     operation.session,
#    1429     address=address,
#    1430     retryable=isinstance(operation, message._Query),
#    1431     operation=operation.name,
#    1432 )
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1534, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    1529 # Ensure that the client supports retrying on reads and there is no session in
#    1530 # transaction, otherwise, we will not support retry behavior for this call.
#    1531 retryable = bool(
#    1532     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    1533 )
# -> 1534 return self._retry_internal(
#    1535     func,
#    1536     session,
#    1537     None,
#    1538     operation,
#    1539     is_read=True,
#    1540     address=address,
#    1541     read_pref=read_pref,
#    1542     retryable=retryable,
#    1543     operation_id=operation_id,
#    1544 )
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1501, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1464 @_csot.apply
#    1465 def _retry_internal(
#    1466     self,
#    (...)
#    1475     operation_id: Optional[int] = None,
#    1476 ) -> T:
#    1477     """Internal retryable helper for all client transactions.
#    1478
#    1479     :param func: Callback function we want to retry
#    (...)
#    1488     :return: Output of the calling func()
#    1489     """
#    1490     return _ClientConnectionRetryable(
#    1491         mongo_client=self,
#    1492         func=func,
#    1493         bulk=bulk,
#    1494         operation=operation,
#    1495         is_read=is_read,
#    1496         session=session,
#    1497         read_pref=read_pref,
#    1498         address=address,
#    1499         retryable=retryable,
#    1500         operation_id=operation_id,
# -> 1501     ).run()
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:2347, in _ClientConnectionRetryable.run(self)
#    2345 self._check_last_error(check_csot=True)
#    2346 try:
# -> 2347     return self._read() if self._is_read else self._write()
#    2348 except ServerSelectionTimeoutError:
#    2349     # The application may think the write was never attempted
#    2350     # if we raise ServerSelectionTimeoutError on the retry
#    2351     # attempt. Raise the original exception instead.
#    2352     self._check_last_error()
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:2479, in _ClientConnectionRetryable._read(self)
#    2477 self._server = self._get_server()
#    2478 assert self._read_pref is not None, "Read Preference required on read calls"
# -> 2479 with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#    2480     conn,
#    2481     read_pref,
#    2482 ):
#    2483     if self._retrying and not self._retryable:
#    2484         self._check_last_error()
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1351, in MongoClient._conn_from_server(self, read_preference, server, session)
#    1341 # Get a connection for a server matching the read preference, and yield
#    1342 # conn with the effective read preference. The Server Selection
#    1343 # Spec says not to send any $readPreference to standalones and to
#    (...)
#    1347 # NOTE: We already opened the Topology when selecting a server so there's no need
#    1348 # to call _get_topology() again.
#    1349 single = self._topology.description.topology_type == TOPOLOGY_TYPE.Single
# -> 1351 with self._checkout(server, session) as conn:
#    1352     if single:
#    1353         if conn.is_repl and not (session and session.in_transaction):
#    1354             # Use primary preferred to ensure any repl set member
#    1355             # can handle the request.
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1260, in MongoClient._checkout(self, server, session)
#    1258     yield session._pinned_connection
#    1259     return
# -> 1260 with server.checkout(handler=err_handler) as conn:
#    1261     # Pin this session to the selected server or connection.
#    1262     if (
#    1263         in_txn
#    1264         and session
#    (...)
#    1269         )
#    1270     ):
#    1271         session._pin(server, conn)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:1763, in Pool.checkout(self, handler)
#    1754     if _CONNECTION_LOGGER.isEnabledFor(logging.DEBUG):
#    1755         _debug_log(
#    1756             _CONNECTION_LOGGER,
#    1757             clientId=self._client_id,
#    (...)
#    1760             serverPort=self.address[1],
#    1761         )
# -> 1763 conn = self._get_conn(checkout_started_time, handler=handler)
#    1765 if self.enabled_for_cmap:
#    1766     assert listeners is not None
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:1921, in Pool._get_conn(self, checkout_started_time, handler)
#    1919 else:  # We need to create a new connection
#    1920     try:
# -> 1921         conn = self.connect(handler=handler)
#    1922     finally:
#    1923         with self._max_connecting_cond:
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:1725, in Pool.connect(self, handler)
#    1722     if handler:
#    1723         handler.contribute_socket(conn, completed_handshake=False)
# -> 1725     conn.authenticate()
#    1726 except BaseException:
#    1727     conn.close_conn(ConnectionClosedReason.ERROR)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:1098, in Connection.authenticate(self, reauthenticate)
#    1095 if creds:
#    1096     from pymongo import auth
# -> 1098     auth.authenticate(creds, self, reauthenticate=reauthenticate)
#    1099 self.ready = True
#    1100 if self.enabled_for_cmap:
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\auth.py:656, in authenticate(credentials, conn, reauthenticate)
#     654     _authenticate_oidc(credentials, conn, reauthenticate)
#     655 else:
# --> 656     auth_func(credentials, conn)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\auth.py:560, in _authenticate_default(credentials, conn)
#     558         return _authenticate_scram(credentials, conn, "SCRAM-SHA-256")
#     559     else:
# --> 560         return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#     561 else:
#     562     return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\auth.py:338, in _authenticate_scram(credentials, conn, mechanism)
#     331 server_sig = standard_b64encode(_hmac(server_key, auth_msg, digestmod).digest())
#     333 cmd = {
#     334     "saslContinue": 1,
#     335     "conversationId": res["conversationId"],
#     336     "payload": Binary(client_final),
#     337 }
# --> 338 res = conn.command(source, cmd)
#     340 parsed = _parse_scram_response(res["payload"])
#     341 if not hmac.compare_digest(parsed[b"v"], server_sig):
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\helpers.py:342, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     339 from pymongo.pool import Connection
#     341 try:
# --> 342     return func(*args, **kwargs)
#     343 except OperationFailure as exc:
#     344     if no_reauth:
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:988, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     986     self._raise_if_not_writable(unacknowledged)
#     987 try:
# --> 988     return command(
#     989         self,
#     990         dbname,
#     991         spec,
#     992         self.is_mongos,
#     993         read_preference,
#     994         codec_options,
#     995         session,
#     996         client,
#     997         check,
#     998         allowable_errors,
#     999         self.address,
#    1000         listeners,
#    1001         self.max_bson_size,
#    1002         read_concern,
#    1003         parse_write_concern_error=parse_write_concern_error,
#    1004         collation=collation,
#    1005         compression_ctx=self.compression_context,
#    1006         use_op_msg=self.op_msg_enabled,
#    1007         unacknowledged=unacknowledged,
#    1008         user_fields=user_fields,
#    1009         exhaust_allowed=exhaust_allowed,
#    1010         write_concern=write_concern,
#    1011     )
#    1012 except (OperationFailure, NotPrimaryError):
#    1013     raise
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\network.py:212, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     210             client._process_response(response_doc, session)
#     211         if check:
# --> 212             helpers._check_command_response(
#     213                 response_doc,
#     214                 conn.max_wire_version,
#     215                 allowable_errors,
#     216                 parse_write_concern_error=parse_write_concern_error,
#     217             )
#     218 except Exception as exc:
#     219     duration = datetime.datetime.now() - start
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\helpers.py:248, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     245 elif code == 43:
#     246     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 248 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: bad auth : authentication failed, full error: {'ok': 0, 'errmsg': 'bad auth : authentication failed', 'code': 8000, 'codeName': 'AtlasError'}

# %% [markdown]
# Para actualizar deberemos seleccionar en base al filtrado (primer campo) a qué documentos les queremos aplicar la actualización. Las funciones disponen de dos versiones:
#
# * Insertar: `insert_one` o `insert_many`
# * Actualizar: `update_one` o `update_many`
# * Borrado: `delete_one`o `delete_many`

# %%
collection.update_one({}, {'$set' : {"apellido": "Montalbán"}})
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 collection.update_one({}, {'$set' : {"apellido": "Montalbán"}})
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\collection.py:1077, in Collection.update_one(self, filter, update, upsert, bypass_document_validation, collation, array_filters, hint, session, let, comment)
#    1073 common.validate_list_or_none("array_filters", array_filters)
#    1075 write_concern = self._write_concern_for(session)
#    1076 return UpdateResult(
# -> 1077     self._update_retryable(
#    1078         filter,
#    1079         update,
#    1080         _Op.UPDATE,
#    1081         upsert,
#    1082         write_concern=write_concern,
#    1083         bypass_doc_val=bypass_document_validation,
#    1084         collation=collation,
#    1085         array_filters=array_filters,
#    1086         hint=hint,
#    1087         session=session,
#    1088         let=let,
#    1089         comment=comment,
#    1090     ),
#    1091     write_concern.acknowledged,
#    1092 )
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\collection.py:872, in Collection._update_retryable(self, criteria, document, operation, upsert, multi, write_concern, op_id, ordered, bypass_doc_val, collation, array_filters, hint, session, let, comment)
#     850 def _update(
#     851     session: Optional[ClientSession], conn: Connection, retryable_write: bool
#     852 ) -> Optional[Mapping[str, Any]]:
#     853     return self._update(
#     854         conn,
#     855         criteria,
#    (...)
#     869         comment=comment,
#     870     )
# --> 872 return self.__database.client._retryable_write(
#     873     (write_concern or self.write_concern).acknowledged and not multi,
#     874     _update,
#     875     session,
#     876     operation,
#     877 )
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1569, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    1555 """Execute an operation with consecutive retries if possible
#    1556
#    1557 Returns func()'s return value on success. On error retries the same
#    (...)
#    1566 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    1567 """
#    1568 with self._tmp_session(session) as s:
# -> 1569     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1455, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1450 # Ensure that the options supports retry_writes and there is a valid session not in
#    1451 # transaction, otherwise, we will not support retry behavior for this txn.
#    1452 retryable = bool(
#    1453     retryable and self.options.retry_writes and session and not session.in_transaction
#    1454 )
# -> 1455 return self._retry_internal(
#    1456     func=func,
#    1457     session=session,
#    1458     bulk=bulk,
#    1459     operation=operation,
#    1460     retryable=retryable,
#    1461     operation_id=operation_id,
#    1462 )
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1501, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1464 @_csot.apply
#    1465 def _retry_internal(
#    1466     self,
#    (...)
#    1475     operation_id: Optional[int] = None,
#    1476 ) -> T:
#    1477     """Internal retryable helper for all client transactions.
#    1478
#    1479     :param func: Callback function we want to retry
#    (...)
#    1488     :return: Output of the calling func()
#    1489     """
#    1490     return _ClientConnectionRetryable(
#    1491         mongo_client=self,
#    1492         func=func,
#    1493         bulk=bulk,
#    1494         operation=operation,
#    1495         is_read=is_read,
#    1496         session=session,
#    1497         read_pref=read_pref,
#    1498         address=address,
#    1499         retryable=retryable,
#    1500         operation_id=operation_id,
# -> 1501     ).run()
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:2347, in _ClientConnectionRetryable.run(self)
#    2345 self._check_last_error(check_csot=True)
#    2346 try:
# -> 2347     return self._read() if self._is_read else self._write()
#    2348 except ServerSelectionTimeoutError:
#    2349     # The application may think the write was never attempted
#    2350     # if we raise ServerSelectionTimeoutError on the retry
#    2351     # attempt. Raise the original exception instead.
#    2352     self._check_last_error()
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:2451, in _ClientConnectionRetryable._write(self)
#    2449 is_mongos = False
#    2450 self._server = self._get_server()
# -> 2451 with self._client._checkout(self._server, self._session) as conn:
#    2452     max_wire_version = conn.max_wire_version
#    2453     sessions_supported = (
#    2454         self._session
#    2455         and self._server.description.retryable_writes_supported
#    2456         and conn.supports_sessions
#    2457     )
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1260, in MongoClient._checkout(self, server, session)
#    1258     yield session._pinned_connection
#    1259     return
# -> 1260 with server.checkout(handler=err_handler) as conn:
#    1261     # Pin this session to the selected server or connection.
#    1262     if (
#    1263         in_txn
#    1264         and session
#    (...)
#    1269         )
#    1270     ):
#    1271         session._pin(server, conn)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:1763, in Pool.checkout(self, handler)
#    1754     if _CONNECTION_LOGGER.isEnabledFor(logging.DEBUG):
#    1755         _debug_log(
#    1756             _CONNECTION_LOGGER,
#    1757             clientId=self._client_id,
#    (...)
#    1760             serverPort=self.address[1],
#    1761         )
# -> 1763 conn = self._get_conn(checkout_started_time, handler=handler)
#    1765 if self.enabled_for_cmap:
#    1766     assert listeners is not None
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:1921, in Pool._get_conn(self, checkout_started_time, handler)
#    1919 else:  # We need to create a new connection
#    1920     try:
# -> 1921         conn = self.connect(handler=handler)
#    1922     finally:
#    1923         with self._max_connecting_cond:
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:1725, in Pool.connect(self, handler)
#    1722     if handler:
#    1723         handler.contribute_socket(conn, completed_handshake=False)
# -> 1725     conn.authenticate()
#    1726 except BaseException:
#    1727     conn.close_conn(ConnectionClosedReason.ERROR)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:1098, in Connection.authenticate(self, reauthenticate)
#    1095 if creds:
#    1096     from pymongo import auth
# -> 1098     auth.authenticate(creds, self, reauthenticate=reauthenticate)
#    1099 self.ready = True
#    1100 if self.enabled_for_cmap:
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\auth.py:656, in authenticate(credentials, conn, reauthenticate)
#     654     _authenticate_oidc(credentials, conn, reauthenticate)
#     655 else:
# --> 656     auth_func(credentials, conn)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\auth.py:560, in _authenticate_default(credentials, conn)
#     558         return _authenticate_scram(credentials, conn, "SCRAM-SHA-256")
#     559     else:
# --> 560         return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#     561 else:
#     562     return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\auth.py:338, in _authenticate_scram(credentials, conn, mechanism)
#     331 server_sig = standard_b64encode(_hmac(server_key, auth_msg, digestmod).digest())
#     333 cmd = {
#     334     "saslContinue": 1,
#     335     "conversationId": res["conversationId"],
#     336     "payload": Binary(client_final),
#     337 }
# --> 338 res = conn.command(source, cmd)
#     340 parsed = _parse_scram_response(res["payload"])
#     341 if not hmac.compare_digest(parsed[b"v"], server_sig):
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\helpers.py:342, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     339 from pymongo.pool import Connection
#     341 try:
# --> 342     return func(*args, **kwargs)
#     343 except OperationFailure as exc:
#     344     if no_reauth:
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:988, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     986     self._raise_if_not_writable(unacknowledged)
#     987 try:
# --> 988     return command(
#     989         self,
#     990         dbname,
#     991         spec,
#     992         self.is_mongos,
#     993         read_preference,
#     994         codec_options,
#     995         session,
#     996         client,
#     997         check,
#     998         allowable_errors,
#     999         self.address,
#    1000         listeners,
#    1001         self.max_bson_size,
#    1002         read_concern,
#    1003         parse_write_concern_error=parse_write_concern_error,
#    1004         collation=collation,
#    1005         compression_ctx=self.compression_context,
#    1006         use_op_msg=self.op_msg_enabled,
#    1007         unacknowledged=unacknowledged,
#    1008         user_fields=user_fields,
#    1009         exhaust_allowed=exhaust_allowed,
#    1010         write_concern=write_concern,
#    1011     )
#    1012 except (OperationFailure, NotPrimaryError):
#    1013     raise
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\network.py:212, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     210             client._process_response(response_doc, session)
#     211         if check:
# --> 212             helpers._check_command_response(
#     213                 response_doc,
#     214                 conn.max_wire_version,
#     215                 allowable_errors,
#     216                 parse_write_concern_error=parse_write_concern_error,
#     217             )
#     218 except Exception as exc:
#     219     duration = datetime.datetime.now() - start
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\helpers.py:248, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     245 elif code == 43:
#     246     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 248 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: bad auth : authentication failed, full error: {'ok': 0, 'errmsg': 'bad auth : authentication failed', 'code': 8000, 'codeName': 'AtlasError'}

# %%
collection.delete_one({"nombre" : "Iraitz"})
# Out:
# DeleteResult({'n': 1, 'electionId': ObjectId('7fffffff0000000000000012'), 'opTime': {'ts': Timestamp(1718529640, 5), 't': 18}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1718529640, 5), 'signature': {'hash': b':\x99\xbdcL\x87\x89\x84a \x92mQ\x19\xbfU\x84z"\xa6', 'keyId': 7322183778070167558}}, 'operationTime': Timestamp(1718529640, 5)}, acknowledged=True)

# %%
collection.delete_many({"nombre" : "Iraitz"})
# Out:
# DeleteResult({'n': 0, 'electionId': ObjectId('7fffffff0000000000000012'), 'opTime': {'ts': Timestamp(1718529640, 6), 't': 18}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1718529640, 6), 'signature': {'hash': b':\x99\xbdcL\x87\x89\x84a \x92mQ\x19\xbfU\x84z"\xa6', 'keyId': 7322183778070167558}}, 'operationTime': Timestamp(1718529640, 6)}, acknowledged=True)

# %% [markdown]
# ### Filtrado
#
# Es la función primordial de MongoDB, poder filtrar el contenido en base a criterios que nos sean relevantes. Por defecto MongoDB busca la igualdad en los campos.

# %%
query = { "title": "Back to the Future" }

movies_data = movies.find(query)

for movie in movies_data:
    pprint(movie)
# Out:
# {'_id': ObjectId('573a1398f29313caabce9682'),
#  'awards': {'nominations': 24,
#             'text': 'Won 1 Oscar. Another 18 wins & 24 nominations.',
#             'wins': 19},
#  'cast': ['Michael J. Fox',
#           'Christopher Lloyd',
#           'Lea Thompson',
#           'Crispin Glover'],
#  'countries': ['USA'],
#  'directors': ['Robert Zemeckis'],
#  'fullplot': 'Marty McFly, a typical American teenager of the Eighties, is '
#              'accidentally sent back to 1955 in a plutonium-powered DeLorean '
#              '"time machine" invented by slightly mad scientist. During his '
#              'often hysterical, always amazing trip back in time, Marty must '
#              'make certain his teenage parents-to-be meet and fall in love - '
#              'so he can get back to the future.',
#  'genres': ['Adventure', 'Comedy', 'Sci-Fi'],
#  'imdb': {'id': 88763, 'rating': 8.5, 'votes': 636511},
#  'languages': ['English'],
#  'lastupdated': '2015-09-12 00:29:36.890000000',
#  'metacritic': 86,
#  'num_mflix_comments': 0,
#  'plot': 'A young man is accidentally sent 30 years into the past in a '
#          'time-traveling DeLorean invented by his friend, Dr. Emmett Brown, '
#          'and must make sure his high-school-age parents unite in order to '
#          'save his own existence.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZmU0M2Y1OGUtZjIxNi00ZjBkLTg1MjgtOWIyNThiZWIwYjRiXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG',
#  'released': datetime.datetime(1985, 7, 3, 0, 0),
#  'runtime': 116,
#  'title': 'Back to the Future',
#  'type': 'movie',
#  'writers': ['Robert Zemeckis', 'Bob Gale'],
#  'year': 1985}

# %% [markdown]
# Aunque cuando el campo contiene una lista, veréis que hace algo distinto.

# %%
query = { "writers": "Robert Zemeckis" }

movies_data = []

for movie in movies.find(query):
    movies_data.append(movie)

for movie in movies_data:
    print(movie["title"])
# Out:
# Used Cars
# Back to the Future

# %%
pprint(movies_data[0])
# Out:
# {'_id': ObjectId('573a1397f29313caabce7bd2'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Kurt Russell', 'Jack Warden', 'Gerrit Graham', 'Frank McRae'],
#  'countries': ['USA'],
#  'directors': ['Robert Zemeckis'],
#  'fullplot': 'Used car salesman Rudy Russo needs money to run for State '
#              'Senate, so he approaches his boss Luke. Luke agrees to front him '
#              'the $10,000 he needs, but then encounters an "accident" '
#              'orchestrated by his brother Roy, who runs the car lot across the '
#              "street. Roy is hoping to claim title to his brother's property "
#              "because Roy's paying off the mayor to put the new interstate "
#              "through the area. After Luke disappears, it's all out war "
#              'between the competing car shops, and no nasty trick is off '
#              "limits as Rudy and his gang fight to keep Roy from taking Luke's "
#              "property. Then Luke's daughter shows up.",
#  'genres': ['Comedy'],
#  'imdb': {'id': 81698, 'rating': 6.8, 'votes': 9919},
#  'languages': ['English'],
#  'lastupdated': '2015-09-16 08:12:35.890000000',
#  'num_mflix_comments': 1,
#  'plot': "When the owner of a struggling used car lot is killed, it's up to "
#          "the lot's hot-shot salesman to save the property from falling into "
#          "the hands of the owner's ruthless brother and used-car rival.",
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTAzOTBhNTAtMzY5MS00YjcwLWIzYWItNWI1NzQ4YjcxY2E2XkEyXkFqcGdeQXVyNTI4MjkwNjA@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(1980, 7, 11, 0, 0),
#  'runtime': 113,
#  'title': 'Used Cars',
#  'tomatoes': {'critic': {'meter': 78, 'numReviews': 18, 'rating': 6.6},
#               'dvd': datetime.datetime(2002, 2, 5, 0, 0),
#               'fresh': 14,
#               'lastUpdated': datetime.datetime(2015, 9, 1, 18, 25, 59),
#               'production': 'Sony Pictures Home Entertainment',
#               'rotten': 4,
#               'viewer': {'meter': 70, 'numReviews': 7665, 'rating': 3.4}},
#  'type': 'movie',
#  'writers': ['Robert Zemeckis', 'Bob Gale'],
#  'year': 1980}

# %%
query = { "directors": "Robert Zemeckis" }

movies_data = []

for movie in movies.find(query):
    movies_data.append(movie)

for movie in movies_data:
    print(movie["title"])
# Out:
# Used Cars
# Romancing the Stone
# Back to the Future
# Who Framed Roger Rabbit
# Back to the Future Part II
# Back to the Future Part III
# Death Becomes Her
# Forrest Gump
# Contact
# What Lies Beneath
# Cast Away
# Cast Away
# The Polar Express
# Beowulf
# A Christmas Carol
# Flight

# %% [markdown]
# Las proyecciones nos permiten obtener solo la parte de la información que nos interesa de los documentos (es como el `SELECT campo1, campo2`).

# %%
query = { "directors": "Robert Zemeckis" }
proyeccion = {"title": True}

for movie in movies.find(query, proyeccion):
    pprint(movie)
# Out:
# {'_id': ObjectId('573a1397f29313caabce7bd2'), 'title': 'Used Cars'}
# {'_id': ObjectId('573a1398f29313caabce93b5'), 'title': 'Romancing the Stone'}
# {'_id': ObjectId('573a1398f29313caabce9682'), 'title': 'Back to the Future'}
# {'_id': ObjectId('573a1398f29313caabceb35c'),
#  'title': 'Who Framed Roger Rabbit'}
# {'_id': ObjectId('573a1398f29313caabceb500'),
#  'title': 'Back to the Future Part II'}
# {'_id': ObjectId('573a1398f29313caabcebd41'),
#  'title': 'Back to the Future Part III'}
# {'_id': ObjectId('573a1399f29313caabced02d'), 'title': 'Death Becomes Her'}
# {'_id': ObjectId('573a1399f29313caabcee607'), 'title': 'Forrest Gump'}
# {'_id': ObjectId('573a139af29313caabcf082a'), 'title': 'Contact'}
# {'_id': ObjectId('573a139df29313caabcfa665'), 'title': 'What Lies Beneath'}
# {'_id': ObjectId('573a139df29313caabcfaaab'), 'title': 'Cast Away'}
# {'_id': ObjectId('573a13a0f29313caabd04333'), 'title': 'Cast Away'}
# {'_id': ObjectId('573a13abf29313caabd2418b'), 'title': 'The Polar Express'}
# {'_id': ObjectId('573a13b3f29313caabd3c719'), 'title': 'Beowulf'}
# {'_id': ObjectId('573a13bef29313caabd5c293'), 'title': 'A Christmas Carol'}
# {'_id': ObjectId('573a13d3f29313caabd95e4b'), 'title': 'Flight'}

# %% [markdown]
# Si no queremos ver el `_id` del documento tendremos que expresarlo estrictamente.

# %%
query = { "directors": "Robert Zemeckis" }
proyeccion = {"_id": 0 }

for movie in movies.find(query, proyeccion):
    pprint(movie)
# Out:
# {'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Kurt Russell', 'Jack Warden', 'Gerrit Graham', 'Frank McRae'],
#  'countries': ['USA'],
#  'directors': ['Robert Zemeckis'],
#  'fullplot': 'Used car salesman Rudy Russo needs money to run for State '
#              'Senate, so he approaches his boss Luke. Luke agrees to front him '
#              'the $10,000 he needs, but then encounters an "accident" '
#              'orchestrated by his brother Roy, who runs the car lot across the '
#              "street. Roy is hoping to claim title to his brother's property "
#              "because Roy's paying off the mayor to put the new interstate "
#              "through the area. After Luke disappears, it's all out war "
#              'between the competing car shops, and no nasty trick is off '
#              "limits as Rudy and his gang fight to keep Roy from taking Luke's "
#              "property. Then Luke's daughter shows up.",
#  'genres': ['Comedy'],
#  'imdb': {'id': 81698, 'rating': 6.8, 'votes': 9919},
#  'languages': ['English'],
#  'lastupdated': '2015-09-16 08:12:35.890000000',
#  'num_mflix_comments': 1,
#  'plot': "When the owner of a struggling used car lot is killed, it's up to "
#          "the lot's hot-shot salesman to save the property from falling into "
#          "the hands of the owner's ruthless brother and used-car rival.",
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTAzOTBhNTAtMzY5MS00YjcwLWIzYWItNWI1NzQ4YjcxY2E2XkEyXkFqcGdeQXVyNTI4MjkwNjA@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(1980, 7, 11, 0, 0),
#  'runtime': 113,
#  'title': 'Used Cars',
#  'tomatoes': {'critic': {'meter': 78, 'numReviews': 18, 'rating': 6.6},
#               'dvd': datetime.datetime(2002, 2, 5, 0, 0),
#               'fresh': 14,
#               'lastUpdated': datetime.datetime(2015, 9, 1, 18, 25, 59),
#               'production': 'Sony Pictures Home Entertainment',
#               'rotten': 4,
#               'viewer': {'meter': 70, 'numReviews': 7665, 'rating': 3.4}},
#  'type': 'movie',
#  'writers': ['Robert Zemeckis', 'Bob Gale'],
#  'year': 1980}
# {'awards': {'nominations': 2,
#             'text': 'Nominated for 1 Oscar. Another 6 wins & 2 nominations.',
#             'wins': 7},
#  'cast': ['Michael Douglas', 'Kathleen Turner', 'Danny DeVito', 'Zack Norman'],
#  'countries': ['USA', 'Mexico'],
#  'directors': ['Robert Zemeckis'],
#  'fullplot': 'Joan Wilder, a mousy romance novelist, receives a treasure map '
#              'in the mail from her recently murdered brother-in-law. '
#              'Meanwhile, her sister Elaine is kidnapped in Colombia and the '
#              'two criminals responsible demand that she travel to Colombia to '
#              'exchange the map for her sister. Joan does, and quickly becomes '
#              'lost in the jungle after being waylayed by Zolo, a vicious and '
#              'corrupt Colombian cop who will stop at nothing to obtain the '
#              'map. There, she meets an irreverent soldier-of-fortune named '
#              'Jack Colton who agrees to bring her back to civilization. '
#              'Together, they embark upon an adventure that could be straight '
#              "out of Joan's novels.",
#  'genres': ['Action', 'Adventure', 'Comedy'],
#  'imdb': {'id': 88011, 'rating': 6.9, 'votes': 59403},
#  'languages': ['English', 'Spanish', 'French'],
#  'lastupdated': '2015-09-07 00:22:35.767000000',
#  'num_mflix_comments': 0,
#  'plot': 'A romance writer sets off to Colombia to ransom her kidnapped '
#          'sister, and soon finds herself in the middle of a dangerous '
#          'adventure.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMDAwNjljMzEtMTc3Yy00NDg2LThjNDAtNjc0NGYyYjM2M2I1XkEyXkFqcGdeQXVyNDE5MTU2MDE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG',
#  'released': datetime.datetime(1984, 3, 30, 0, 0),
#  'runtime': 106,
#  'title': 'Romancing the Stone',
#  'type': 'movie',
#  'writers': ['Diane Thomas'],
#  'year': 1984}
# {'awards': {'nominations': 24,
#             'text': 'Won 1 Oscar. Another 18 wins & 24 nominations.',
#             'wins': 19},
#  'cast': ['Michael J. Fox',
#           'Christopher Lloyd',
#           'Lea Thompson',
#           'Crispin Glover'],
#  'countries': ['USA'],
#  'directors': ['Robert Zemeckis'],
#  'fullplot': 'Marty McFly, a typical American teenager of the Eighties, is '
#              'accidentally sent back to 1955 in a plutonium-powered DeLorean '
#              '"time machine" invented by slightly mad scientist. During his '
#              'often hysterical, always amazing trip back in time, Marty must '
#              'make certain his teenage parents-to-be meet and fall in love - '
#              'so he can get back to the future.',
#  'genres': ['Adventure', 'Comedy', 'Sci-Fi'],
#  'imdb': {'id': 88763, 'rating': 8.5, 'votes': 636511},
#  'languages': ['English'],
#  'lastupdated': '2015-09-12 00:29:36.890000000',
#  'metacritic': 86,
#  'num_mflix_comments': 0,
#  'plot': 'A young man is accidentally sent 30 years into the past in a '
#          'time-traveling DeLorean invented by his friend, Dr. Emmett Brown, '
#          'and must make sure his high-school-age parents unite in order to '
#          'save his own existence.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZmU0M2Y1OGUtZjIxNi00ZjBkLTg1MjgtOWIyNThiZWIwYjRiXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG',
#  'released': datetime.datetime(1985, 7, 3, 0, 0),
#  'runtime': 116,
#  'title': 'Back to the Future',
#  'type': 'movie',
#  'writers': ['Robert Zemeckis', 'Bob Gale'],
#  'year': 1985}
# {'awards': {'nominations': 21,
#             'text': 'Won 3 Oscars. Another 19 wins & 21 nominations.',
#             'wins': 22},
#  'cast': ['Bob Hoskins',
#           'Christopher Lloyd',
#           'Joanna Cassidy',
#           'Charles Fleischer'],
#  'countries': ['USA'],
#  'directors': ['Robert Zemeckis'],
#  'fullplot': "'Toon star Roger is worried that his wife Jessica is playing "
#              'pattycake with someone else, so the studio hires detective Eddie '
#              'Valiant to snoop on her. But the stakes are quickly raised when '
#              'Marvin Acme is found dead and Roger is the prime suspect. '
#              'Groundbreaking interaction between the live and animated '
#              'characters, and lots of references to classic animation.',
#  'genres': ['Animation', 'Comedy', 'Crime'],
#  'imdb': {'id': 96438, 'rating': 7.7, 'votes': 127268},
#  'languages': ['English'],
#  'lastupdated': '2015-09-13 00:26:06.120000000',
#  'metacritic': 83,
#  'num_mflix_comments': 0,
#  'plot': "A toon hating detective is a cartoon rabbit's only hope to prove his "
#          'innocence when he is accused of murder.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMDhiOTM2OTctODk3Ny00NWI4LThhZDgtNGQ4NjRiYjFkZGQzXkEyXkFqcGdeQXVyMTA0MjU0Ng@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG',
#  'released': datetime.datetime(1988, 6, 22, 0, 0),
#  'runtime': 104,
#  'title': 'Who Framed Roger Rabbit',
#  'tomatoes': {'consensus': 'Who Framed Roger Rabbit is an innovative and '
#                            'entertaining film that features a groundbreaking '
#                            'mix of live action and animation, with a touching '
#                            'and original story to boot.',
#               'critic': {'meter': 97, 'numReviews': 61, 'rating': 8.4},
#               'dvd': datetime.datetime(1999, 9, 28, 0, 0),
#               'fresh': 59,
#               'lastUpdated': datetime.datetime(2015, 9, 13, 9, 55, 20),
#               'production': 'Buena Vista Distribution Compa',
#               'rotten': 2,
#               'viewer': {'meter': 84, 'numReviews': 440357, 'rating': 3.5}},
#  'type': 'movie',
#  'writers': ['Gary K. Wolf (novel)',
#              'Jeffrey Price (screenplay)',
#              'Peter S. Seaman (screenplay)'],
#  'year': 1988}
# {'awards': {'nominations': 5,
#             'text': 'Nominated for 1 Oscar. Another 9 wins & 5 nominations.',
#             'wins': 10},
#  'cast': ['Michael J. Fox',
#           'Christopher Lloyd',
#           'Lea Thompson',
#           'Thomas F. Wilson'],
#  'countries': ['USA'],
#  'directors': ['Robert Zemeckis'],
#  'fullplot': 'Marty McFly has only just gotten back from the past, when he is '
#              'once again picked up by Dr. Emmett Brown and sent through time '
#              "to the future. Marty's job in the future is to pose as his own "
#              'son to prevent him from being thrown in prison. Unfortunately, '
#              'things get worse when the future changes the present.',
#  'genres': ['Action', 'Adventure', 'Comedy'],
#  'imdb': {'id': 96874, 'rating': 7.8, 'votes': 292539},
#  'languages': ['English'],
#  'lastupdated': '2015-09-14 10:39:00.767000000',
#  'metacritic': 57,
#  'num_mflix_comments': 142,
#  'plot': 'After visiting 2015, Marty McFly must repeat his visit to 1955 to '
#          'prevent disastrous changes to 1985... without interfering with his '
#          'first trip.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZTMxMGM5MjItNDJhNy00MWI2LWJlZWMtOWFhMjI5ZTQwMWM3XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG',
#  'released': datetime.datetime(1989, 11, 22, 0, 0),
#  'runtime': 108,
#  'title': 'Back to the Future Part II',
#  'tomatoes': {'consensus': 'Back to the Future II is far more uneven than its '
#                            'predecessor, but its madcap highs outweigh the '
#                            'occasionally cluttered machinations of an '
#                            'overstuffed plot.',
#               'critic': {'meter': 61, 'numReviews': 54, 'rating': 6.1},
#               'dvd': datetime.datetime(2002, 12, 17, 0, 0),
#               'fresh': 33,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 18, 16, 45),
#               'production': 'Universal Pictures',
#               'rotten': 21,
#               'viewer': {'meter': 85, 'numReviews': 746856, 'rating': 3.5}},
#  'type': 'movie',
#  'writers': ['Robert Zemeckis (characters)',
#              'Bob Gale (characters)',
#              'Robert Zemeckis (story)',
#              'Bob Gale (story)',
#              'Bob Gale (screenplay)'],
#  'year': 1989}
# {'awards': {'nominations': 8, 'text': '5 wins & 8 nominations.', 'wins': 5},
#  'cast': ['Michael J. Fox',
#           'Christopher Lloyd',
#           'Mary Steenburgen',
#           'Thomas F. Wilson'],
#  'countries': ['USA'],
#  'directors': ['Robert Zemeckis'],
#  'fullplot': 'Stranded in 1955, Marty McFly receives written word from his '
#              'friend, Doctor Emmett Brown, as to where can be found the '
#              'DeLorean time machine. However, an unfortunate discovery prompts '
#              "Marty to go to his friend's aid. Using the time machine, Marty "
#              'travels to the old west where his friend has run afoul of a gang '
#              'of thugs and has fallen in love with a local schoolteacher. '
#              'Using the technology from the time, Marty and Emmett devise one '
#              'last chance to send the two of them back to the future.',
#  'genres': ['Action', 'Adventure', 'Comedy'],
#  'imdb': {'id': 99088, 'rating': 7.4, 'votes': 242390},
#  'languages': ['English'],
#  'lastupdated': '2015-09-12 00:02:49.817000000',
#  'metacritic': 55,
#  'num_mflix_comments': 140,
#  'plot': 'Enjoying a peaceable existence in 1885, Doctor Emmet Brown is about '
#          'to be killed by Buford "Mad Dog" Tannen. Marty McFly travels back in '
#          'time to save his friend.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYjhlMGYxNmMtOWFmMi00Y2M2LWE5NWYtZTdlMDRlMGEzMDA3XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG',
#  'released': datetime.datetime(1990, 5, 25, 0, 0),
#  'runtime': 118,
#  'title': 'Back to the Future Part III',
#  'tomatoes': {'critic': {'meter': 73, 'numReviews': 41, 'rating': 6.5},
#               'dvd': datetime.datetime(2002, 12, 17, 0, 0),
#               'fresh': 30,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 18, 5, 50),
#               'production': 'MCA Universal Home Video',
#               'rotten': 11,
#               'viewer': {'meter': 78, 'numReviews': 691791, 'rating': 3.4}},
#  'type': 'movie',
#  'writers': ['Robert Zemeckis (characters)',
#              'Bob Gale (characters)',
#              'Robert Zemeckis (story)',
#              'Bob Gale (story)',
#              'Bob Gale (screenplay)'],
#  'year': 1990}
# {'awards': {'nominations': 11,
#             'text': 'Won 1 Oscar. Another 4 wins & 11 nominations.',
#             'wins': 5},
#  'cast': ['Meryl Streep', 'Bruce Willis', 'Goldie Hawn', 'Isabella Rossellini'],
#  'countries': ['USA'],
#  'directors': ['Robert Zemeckis'],
#  'fullplot': 'Helen, a writer, and Madeline, an actress, have hated each other '
#              "for years. Madeline is married to Ernest, who was once Helen's "
#              'fiance. After she recovers from a mental breakdown, Helen vows '
#              'revenge by stealing back Ernest and plotting to kill Madeline. '
#              'Both rivals have secretly drunk a miracle cure for aging; they '
#              'accidentally discover, when each tries to eliminate the other, '
#              'that they have become immortal and that "life" will never be the '
#              'same again.',
#  'genres': ['Comedy', 'Fantasy'],
#  'imdb': {'id': 104070, 'rating': 6.4, 'votes': 72504},
#  'languages': ['English'],
#  'lastupdated': '2015-09-02 00:06:46.600000000',
#  'num_mflix_comments': 0,
#  'plot': 'When a woman learns of an immortality treatment, she sees it as a '
#          'way to outdo her long-time rival.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNzM2YjIwMzgtZTg4Yy00NmJlLWIzOTYtYTQ0Zjc3NjIyZDcyXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(1992, 7, 31, 0, 0),
#  'runtime': 104,
#  'title': 'Death Becomes Her',
#  'tomatoes': {'dvd': datetime.datetime(2008, 12, 9, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 9, 11, 17, 21, 48),
#               'viewer': {'numReviews': 67, 'rating': 3.3}},
#  'type': 'movie',
#  'writers': ['Martin Donovan', 'David Koepp'],
#  'year': 1992}
# {'awards': {'nominations': 47,
#             'text': 'Won 6 Oscars. Another 40 wins & 47 nominations.',
#             'wins': 46},
#  'cast': ['Tom Hanks',
#           'Rebecca Williams',
#           'Sally Field',
#           'Michael Conner Humphreys'],
#  'countries': ['USA'],
#  'directors': ['Robert Zemeckis'],
#  'fullplot': 'Forrest Gump is a simple man with a low I.Q. but good '
#              'intentions. He is running through childhood with his best and '
#              "only friend Jenny. His 'mama' teaches him the ways of life and "
#              'leaves him to choose his destiny. Forrest joins the army for '
#              'service in Vietnam, finding new friends called Dan and Bubba, he '
#              'wins medals, creates a famous shrimp fishing fleet, inspires '
#              'people to jog, starts a ping-pong craze, create the smiley, '
#              'write bumper stickers and songs, donating to people and meeting '
#              'the president several times. However, this is all irrelevant to '
#              'Forrest who can only think of his childhood sweetheart Jenny '
#              'Curran. Who has messed up her life. Although in the end all he '
#              'wants to prove is that anyone can love anyone.',
#  'genres': ['Drama', 'Romance'],
#  'imdb': {'id': 109830, 'rating': 8.8, 'votes': 1087227},
#  'languages': ['English'],
#  'lastupdated': '2015-08-22 00:15:05.593000000',
#  'metacritic': 82,
#  'num_mflix_comments': 136,
#  'plot': 'Forrest Gump, while not intelligent, has accidentally been present '
#          'at many historic moments, but his true love, Jenny Curran, eludes '
#          'him.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNWIwODRlZTUtY2U3ZS00Yzg1LWJhNzYtMmZiYmEyNmU1NjMzXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(1994, 7, 6, 0, 0),
#  'runtime': 142,
#  'title': 'Forrest Gump',
#  'tomatoes': {'boxOffice': '$0.4M',
#               'consensus': 'Forrest Gump may be an overly sentimental film '
#                            'with a somewhat problematic message, but its '
#                            'sweetness and charm are usually enough to '
#                            'approximate true depth and grace.',
#               'critic': {'meter': 72, 'numReviews': 81, 'rating': 7.2},
#               'dvd': datetime.datetime(2001, 8, 28, 0, 0),
#               'fresh': 58,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 18, 18, 31),
#               'production': 'Paramount Pictures',
#               'rotten': 23,
#               'viewer': {'meter': 95, 'numReviews': 1238843, 'rating': 4.1},
#               'website': 'http://www.paramount.com/movies/forrest-gump/'},
#  'type': 'movie',
#  'writers': ['Winston Groom (novel)', 'Eric Roth (screenplay)'],
#  'year': 1994}
# {'awards': {'nominations': 25,
#             'text': 'Nominated for 1 Oscar. Another 14 wins & 25 nominations.',
#             'wins': 15},
#  'cast': ['Jena Malone', 'David Morse', 'Jodie Foster', 'Geoffrey Blake'],
#  'countries': ['USA'],
#  'directors': ['Robert Zemeckis'],
#  'fullplot': 'Astronomer Dr. Ellie Arroway has long been interested in contact '
#              'to faraway lands, a love fostered in her childhood by her '
#              'father, Ted Arroway, who passed away when she was nine years old '
#              'leaving her then orphaned. Her current work in monitoring for '
#              'extraterrestrial life is based on that love and is in part an '
#              'homage to her father. Ever since funding from the National '
#              'Science Foundation (NSF) was pulled on her work, which is '
#              'referred to some, including her NSF superior David Drumlin, as '
#              'more science fiction than science, Ellie, with a few of her '
#              'rogue scientist colleagues, have looked for funding from where '
#              'ever they could get it to continue their work. When Ellie and '
#              'her colleagues hear chatter originating from the vicinity of the '
#              'star Vega, Ellie feels vindicated. But that vindication is short '
#              'lived when others, including politicians, the military, '
#              'religious leaders and other scientists such as Drumlin, try to '
#              'take over her work. When the messages received from space are '
#              'decoded, the project takes on a whole new dimension, which '
#              'strengthens for Ellie the quest for the truth. Thrown into the '
#              'mix are the unknown person who has up until now funded most of '
#              "Ellie's work and what his motivations are, and Palmer Joss, a "
#              'renowned author and theologian, who despite their fundamental '
#              'differences in outlook, is mutually attracted to Ellie, that '
#              'attraction based in part on intellect and their common goal of '
#              'wanting to know the truth.',
#  'genres': ['Drama', 'Mystery', 'Sci-Fi'],
#  'imdb': {'id': 118884, 'rating': 7.4, 'votes': 184196},
#  'languages': ['English', 'Spanish', 'German', 'Russian'],
#  'lastupdated': '2015-09-07 00:22:08.887000000',
#  'metacritic': 62,
#  'num_mflix_comments': 0,
#  'plot': 'Dr. Ellie Arroway, after years of searching, finds conclusive radio '
#          'proof of intelligent aliens, who send plans for a mysterious '
#          'machine.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYWNkYmFiZjUtYmI3Ni00NzIwLTkxZjktN2ZkMjdhMzlkMDc3XkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG',
#  'released': datetime.datetime(1997, 7, 11, 0, 0),
#  'runtime': 150,
#  'title': 'Contact',
#  'tomatoes': {'critic': {'meter': 63, 'numReviews': 62, 'rating': 6.8},
#               'dvd': datetime.datetime(1997, 12, 16, 0, 0),
#               'fresh': 39,
#               'lastUpdated': datetime.datetime(2015, 9, 16, 18, 2, 13),
#               'production': 'Warner Home Video',
#               'rotten': 23,
#               'viewer': {'meter': 78, 'numReviews': 202348, 'rating': 3.2}},
#  'type': 'movie',
#  'writers': ['Carl Sagan (novel)',
#              'Carl Sagan (story)',
#              'Ann Druyan (story)',
#              'James V. Hart (screenplay)',
#              'Michael Goldenberg (screenplay)'],
#  'year': 1997}
# {'awards': {'nominations': 5, 'text': '4 wins & 5 nominations.', 'wins': 4},
#  'cast': ['Michelle Pfeiffer',
#           'Katharine Towne',
#           'Miranda Otto',
#           'James Remar'],
#  'countries': ['USA'],
#  'directors': ['Robert Zemeckis'],
#  'fullplot': 'Norman Spencer, a university research scientist, is growing more '
#              'and more concerned about his wife, Claire, a retired concert '
#              'cellist who a year ago was involved in a serious auto accident, '
#              "and who has just sent off her daughter Caitlin (Norman's "
#              'stepdaughter) to college. Now, Claire reports hearing voices and '
#              'witnessing eerie occurrences in and around their lakeside '
#              'Vermont home, including seeing the face of a young woman '
#              'reflected in water. An increasingly frightened Claire thinks the '
#              'phenomena have something to do with the couple living next door, '
#              'especially since the wife has disappeared without apparent '
#              "explanation. At her husband's urging, Claire starts to see a "
#              'therapist; she tells him she thinks the house is being haunted '
#              'by a ghost. His advice? Try to make contact. Enlisting the help '
#              'of her best friend, Jody, and a ouija board, Claire seeks to '
#              'find out the truth of What Lies Beneath.',
#  'genres': ['Drama', 'Horror', 'Mystery'],
#  'imdb': {'id': 161081, 'rating': 6.6, 'votes': 93122},
#  'languages': ['English'],
#  'lastupdated': '2015-08-23 00:06:16.547000000',
#  'metacritic': 51,
#  'num_mflix_comments': 2,
#  'plot': 'The wife of a university research scientist believes that her '
#          'lakeside Vermont home is haunted by a ghost - or that she is losing '
#          'her mind.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNTY4NjNkMTMtNTEyOC00NDBiLWFkZjMtZDkwYzU3OTFjOTkzXkEyXkFqcGdeQXVyNTUyMzE4Mzg@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2000, 7, 21, 0, 0),
#  'runtime': 130,
#  'title': 'What Lies Beneath',
#  'tomatoes': {'boxOffice': '$155.0M',
#               'consensus': 'Robert Zemeckis is unable to salvage an '
#                            'uncompelling and unoriginal film.',
#               'critic': {'meter': 46, 'numReviews': 124, 'rating': 5.5},
#               'dvd': datetime.datetime(2001, 1, 30, 0, 0),
#               'fresh': 57,
#               'lastUpdated': datetime.datetime(2015, 9, 16, 17, 10, 11),
#               'production': 'DreamWorks SKG',
#               'rotten': 67,
#               'viewer': {'meter': 59, 'numReviews': 278520, 'rating': 3.1}},
#  'type': 'movie',
#  'writers': ['Clark Gregg (screenplay)',
#              'Sarah Kernochan (story)',
#              'Clark Gregg (story)'],
#  'year': 2000}
# {'awards': {'nominations': 28,
#             'text': 'Nominated for 2 Oscars. Another 19 wins & 28 nominations.',
#             'wins': 21},
#  'cast': ['Paul Sanchez', 'Lari White', 'Leonid Citer', 'David Allen Brooks'],
#  'countries': ['USA'],
#  'directors': ['Robert Zemeckis'],
#  'fullplot': 'A man is marooned on an island after his plane crashes into the '
#              'ocean. Far away from home, his girlfriend, and any human '
#              'contact, he engages in a battle of wits with himself as he is '
#              'tested mentally, physically, and emotionally in order to '
#              'survive.',
#  'genres': ['Adventure', 'Drama'],
#  'imdb': {'id': 162222, 'rating': 7.7, 'votes': 353894},
#  'languages': ['English', 'Russian'],
#  'lastupdated': '2015-08-26 00:45:54.790000000',
#  'metacritic': 73,
#  'num_mflix_comments': 145,
#  'plot': 'A FedEx executive must transform himself physically and emotionally '
#          'to survive a crash landing on a deserted island.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BN2Y5ZTU4YjctMDRmMC00MTg4LWE1M2MtMjk4MzVmOTE4YjkzXkEyXkFqcGdeQXVyNTc1NTQxODI@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2000, 12, 22, 0, 0),
#  'runtime': 143,
#  'title': 'Cast Away',
#  'tomatoes': {'consensus': 'Flawed but fascinating, Cast Away offers an '
#                            "intelligent script, some of Robert Zemeckis' most "
#                            'mature directing, and a showcase performance from '
#                            'Tom Hanks.',
#               'critic': {'meter': 90, 'numReviews': 154, 'rating': 7.4},
#               'dvd': datetime.datetime(2001, 6, 12, 0, 0),
#               'fresh': 138,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 18, 52, 6),
#               'production': '20th Century Fox',
#               'rotten': 16,
#               'viewer': {'meter': 83, 'numReviews': 741268, 'rating': 3.5},
#               'website': 'http://www.castawaymovie.com'},
#  'type': 'movie',
#  'writers': ['William Broyles Jr.'],
#  'year': 2000}
# {'awards': {'nominations': 28,
#             'text': 'Nominated for 2 Oscars. Another 19 wins & 28 nominations.',
#             'wins': 21},
#  'cast': ['Paul Sanchez', 'Lari White', 'Leonid Citer', 'David Allen Brooks'],
#  'countries': ['USA'],
#  'directors': ['Robert Zemeckis'],
#  'fullplot': 'A man is marooned on an island after his plane crashes into the '
#              'ocean. Far away from home, his girlfriend, and any human '
#              'contact, he engages in a battle of wits with himself as he is '
#              'tested mentally, physically, and emotionally in order to '
#              'survive.',
#  'genres': ['Adventure', 'Drama'],
#  'imdb': {'id': 162222, 'rating': 7.7, 'votes': 354554},
#  'languages': ['English', 'Russian'],
#  'lastupdated': '2015-08-30 04:40:27.240000000',
#  'metacritic': 73,
#  'num_mflix_comments': 136,
#  'plot': 'A FedEx executive must transform himself physically and emotionally '
#          'to survive a crash landing on a deserted island.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BN2Y5ZTU4YjctMDRmMC00MTg4LWE1M2MtMjk4MzVmOTE4YjkzXkEyXkFqcGdeQXVyNTc1NTQxODI@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2000, 12, 22, 0, 0),
#  'runtime': 143,
#  'title': 'Cast Away',
#  'tomatoes': {'consensus': 'Flawed but fascinating, Cast Away offers an '
#                            "intelligent script, some of Robert Zemeckis' most "
#                            'mature directing, and a showcase performance from '
#                            'Tom Hanks.',
#               'critic': {'meter': 90, 'numReviews': 154, 'rating': 7.4},
#               'dvd': datetime.datetime(2001, 6, 12, 0, 0),
#               'fresh': 138,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 18, 52, 6),
#               'production': '20th Century Fox',
#               'rotten': 16,
#               'viewer': {'meter': 83, 'numReviews': 741268, 'rating': 3.5},
#               'website': 'http://www.castawaymovie.com'},
#  'type': 'movie',
#  'writers': ['William Broyles Jr.'],
#  'year': 2000}
# {'awards': {'nominations': 19,
#             'text': 'Nominated for 3 Oscars. Another 5 wins & 19 nominations.',
#             'wins': 8},
#  'cast': ['Tom Hanks', 'Leslie Zemeckis', 'Eddie Deezen', 'Nona Gaye'],
#  'countries': ['USA'],
#  'directors': ['Robert Zemeckis'],
#  'fullplot': 'This is the story of a young hero boy on Christmas Eve who '
#              "boards on a powerful magical train that's headed to the North "
#              "Pole and Santa Claus's home. What unfolds is an an adventure "
#              'which follows a doubting boy, who takes an extraordinary train '
#              'ride to the North Pole; during this ride, he embarks on a '
#              'journey of self-discovery which shows him that the wonder of '
#              'life never fades for those who believe.',
#  'genres': ['Animation', 'Adventure', 'Family'],
#  'imdb': {'id': 338348, 'rating': 6.6, 'votes': 107277},
#  'languages': ['English'],
#  'lastupdated': '2015-08-25 00:22:58.180000000',
#  'metacritic': 61,
#  'num_mflix_comments': 0,
#  'plot': 'A young boy embarks on a magical adventure to the North Pole on the '
#          'Polar Express. During his adventure he learns about friendship, '
#          'bravery, and the spirit of Christmas.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTM1NTU0NTE4MV5BMl5BanBnXkFtZTcwMTQ0MjEzMw@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'G',
#  'released': datetime.datetime(2004, 11, 10, 0, 0),
#  'runtime': 100,
#  'title': 'The Polar Express',
#  'tomatoes': {'boxOffice': '$0.5M',
#               'consensus': 'Though the movie is visually stunning overall, the '
#                            "animation for the human characters isn't lifelike "
#                            'enough, and the story is padded.',
#               'critic': {'meter': 55, 'numReviews': 199, 'rating': 6.4},
#               'dvd': datetime.datetime(2005, 11, 22, 0, 0),
#               'fresh': 110,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 54, 49),
#               'production': 'Warner Bros. Pictures',
#               'rotten': 89,
#               'viewer': {'meter': 63, 'numReviews': 240019, 'rating': 3.2},
#               'website': 'http://polarexpressmovie.warnerbros.com/'},
#  'type': 'movie',
#  'writers': ['Chris Van Allsburg (book)',
#              'Robert Zemeckis (screenplay)',
#              'William Broyles Jr. (screenplay)'],
#  'year': 2004}
# {'awards': {'nominations': 16, 'text': '2 wins & 16 nominations.', 'wins': 2},
#  'cast': ['Robin Wright', 'Anthony Hopkins', 'Paul Baker', 'John Bilezikjian'],
#  'countries': ['USA'],
#  'directors': ['Robert Zemeckis'],
#  'fullplot': 'Set against the coming of Christianity, this is the story of the '
#              'last hero: in 507, a monstrous troll wreaks havoc in the mead '
#              'hall of the Danish king, Hrothgar. He offers rewards for the '
#              'death of Grendel, so Beowulf, a great and boastful Geat warrior, '
#              'arrives with his thanes. Beowulf sets aside his armor and awaits '
#              "the monster; a fierce battle ensues that leads to Beowolf's "
#              "entering the watery lair of Grendel's mother, where a devil's "
#              'bargain awaits. Beowulf returns to Herot, the castle, and '
#              'becomes king. Jump ahead many years, and the sins of the father '
#              'are visited upon Beowulf and his kingdom. The hero must face his '
#              'weakness and be heroic once again. Is the age of demons over?',
#  'genres': ['Animation', 'Action', 'Adventure'],
#  'imdb': {'id': 442933, 'rating': 6.3, 'votes': 135898},
#  'languages': ['English', 'Old English'],
#  'lastupdated': '2015-09-06 00:03:11.213000000',
#  'metacritic': 59,
#  'num_mflix_comments': 0,
#  'plot': 'The warrior Beowulf must fight and defeat the monster Grendel who is '
#          "terrorizing towns, and later, Grendel's mother, who begins killing "
#          'out of revenge.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTUzMjM0MTc3MF5BMl5BanBnXkFtZTcwNzU0ODMyMw@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2007, 11, 16, 0, 0),
#  'runtime': 115,
#  'title': 'Beowulf',
#  'tomatoes': {'boxOffice': '$82.2M',
#               'consensus': 'Featuring groundbreaking animation, stunning '
#                            'visuals, and a talented cast, Beowulf has in '
#                            'spades what more faithful book adaptations forget '
#                            'to bring: pure cinematic entertainment.',
#               'critic': {'meter': 71, 'numReviews': 194, 'rating': 6.6},
#               'dvd': datetime.datetime(2007, 2, 13, 0, 0),
#               'fresh': 137,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 18, 50, 3),
#               'production': 'Paramount Pictures',
#               'rotten': 57,
#               'viewer': {'meter': 50, 'numReviews': 338556, 'rating': 3.1},
#               'website': 'http://www.beowulfmovie.com/'},
#  'type': 'movie',
#  'writers': ['Neil Gaiman (screenplay)',
#              'Roger Avary (screenplay)',
#              'Anonymous (epic poem "Beowulf")'],
#  'year': 2007}
# {'awards': {'nominations': 4, 'text': '3 wins & 4 nominations.', 'wins': 3},
#  'cast': ['Jim Carrey', 'Steve Valentine', 'Daryl Sabara', 'Sage Ryan'],
#  'countries': ['USA'],
#  'directors': ['Robert Zemeckis'],
#  'fullplot': 'Miser Ebenezer Scrooge is awakened on Christmas Eve by spirits '
#              'who reveal to him his own miserable existence, what '
#              'opportunities he wasted in his youth, his current cruelties, and '
#              'the dire fate that awaits him if he does not change his ways. '
#              'Scrooge is faced with his own story of growing bitterness and '
#              'meanness, and must decide what his own future will hold: death '
#              'or redemption.',
#  'genres': ['Animation', 'Drama', 'Family'],
#  'imdb': {'id': 1067106, 'rating': 6.8, 'votes': 64556},
#  'languages': ['English'],
#  'lastupdated': '2015-09-05 00:29:12.033000000',
#  'metacritic': 55,
#  'num_mflix_comments': 138,
#  'plot': "An animated retelling of Charles Dickens' classic novel about a "
#          'Victorian-era miser taken on a journey of self-redemption, courtesy '
#          'of several mysterious Christmas apparitions.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTM1MTI5ODU4MV5BMl5BanBnXkFtZTcwNTYyNTU4Mg@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG',
#  'released': datetime.datetime(2009, 11, 6, 0, 0),
#  'runtime': 96,
#  'title': 'A Christmas Carol',
#  'tomatoes': {'boxOffice': '$137.8M',
#               'consensus': "Robert Zemeckis' 3-D animated take on the Dickens "
#                            'classic tries hard, but its dazzling special '
#                            'effects distract from an array of fine '
#                            'performances from Jim Carrey and Gary Oldman.',
#               'critic': {'meter': 54, 'numReviews': 188, 'rating': 5.9},
#               'dvd': datetime.datetime(2010, 11, 16, 0, 0),
#               'fresh': 102,
#               'lastUpdated': datetime.datetime(2015, 9, 13, 17, 0, 46),
#               'production': 'Walt Disney Studios',
#               'rotten': 86,
#               'viewer': {'meter': 58, 'numReviews': 775448, 'rating': 3.2},
#               'website': 'http://Disney.com/ChristmasCarol'},
#  'type': 'movie',
#  'writers': ['Charles Dickens (novel)', 'Robert Zemeckis (screenplay)'],
#  'year': 2009}
# {'awards': {'nominations': 38,
#             'text': 'Nominated for 2 Oscars. Another 14 wins & 38 nominations.',
#             'wins': 16},
#  'cast': ['Nadine Velazquez',
#           'Denzel Washington',
#           'Carter Cabassa',
#           'Adam C. Edwards'],
#  'countries': ['USA'],
#  'directors': ['Robert Zemeckis'],
#  'fullplot': 'Whip Whitaker is a commuter airline pilot. While on a flight '
#              'from Orlando to Atlanta something goes wrong and the plane '
#              'starts to fly erratically. With little choice Whip crashes the '
#              'plane and saves almost all on board. When he wakes up in the '
#              'hospital, his friend from the airline union introduces him to a '
#              "lawyer who tells him there's a chance he could face criminal "
#              'charges because his blood test reveals that he was intoxicated '
#              'with alcohol and cocaine. He denies being impaired, so while an '
#              'investigation is underway, he is told to keep his act together. '
#              'However, letting go of his addiction is not as easy as it '
#              'seems...',
#  'genres': ['Drama', 'Thriller'],
#  'imdb': {'id': 1907668, 'rating': 7.3, 'votes': 244269},
#  'languages': ['English'],
#  'lastupdated': '2015-09-02 00:29:07.570000000',
#  'metacritic': 76,
#  'num_mflix_comments': 1,
#  'plot': 'An airline pilot saves almost all his passengers on his '
#          'malfunctioning airliner which eventually crashed, but an '
#          'investigation into the accident reveals something troubling.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTUxMjI1OTMxNl5BMl5BanBnXkFtZTcwNjc3NTY1OA@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2012, 11, 2, 0, 0),
#  'runtime': 138,
#  'title': 'Flight',
#  'tomatoes': {'boxOffice': '$93.7M',
#               'consensus': 'Robert Zemeckis makes a triumphant return to '
#                            'live-action cinema with Flight, a thoughtful and '
#                            'provocative character study propelled by a '
#                            'compelling performance from Denzel Washington.',
#               'critic': {'meter': 77, 'numReviews': 220, 'rating': 7.0},
#               'dvd': datetime.datetime(2013, 2, 5, 0, 0),
#               'fresh': 170,
#               'lastUpdated': datetime.datetime(2015, 9, 11, 17, 7, 4),
#               'production': 'Paramount Pictures',
#               'rotten': 50,
#               'viewer': {'meter': 75, 'numReviews': 152079, 'rating': 3.8},
#               'website': 'http://www.paramount.com/flight/'},
#  'type': 'movie',
#  'writers': ['John Gatins'],
#  'year': 2012}

# %%
query = { "directors": "Robert Zemeckis" }
proyeccion = {"_id": 0, "title" : True }

for movie in movies.find(query, proyeccion):
    pprint(movie)
# Out:
# {'title': 'Used Cars'}
# {'title': 'Romancing the Stone'}
# {'title': 'Back to the Future'}
# {'title': 'Who Framed Roger Rabbit'}
# {'title': 'Back to the Future Part II'}
# {'title': 'Back to the Future Part III'}
# {'title': 'Death Becomes Her'}
# {'title': 'Forrest Gump'}
# {'title': 'Contact'}
# {'title': 'What Lies Beneath'}
# {'title': 'Cast Away'}
# {'title': 'Cast Away'}
# {'title': 'The Polar Express'}
# {'title': 'Beowulf'}
# {'title': 'A Christmas Carol'}
# {'title': 'Flight'}

# %% [markdown]
# ### Comparadores
#
# Si quisiéramos rangos o desigualdades a la hora de filtrar deberemos utilizar operadores:
#
# * Comparación: https://www.mongodb.com/docs/manual/reference/operator/query-comparison/
# * Lógicos: https://www.mongodb.com/docs/manual/reference/operator/query-logical/
# * Elementos: https://www.mongodb.com/docs/manual/reference/operator/query-element/
# * Texto y evaluaciones: https://www.mongodb.com/docs/manual/reference/operator/query-evaluation/

# %%
query = { "directors": "Robert Zemeckis", "year" : {"$gt" : 2008 }}
proyeccion = {"_id": 0, "title" : True, "year": 1}

for movie in movies.find(query, proyeccion):
    pprint(movie)
# Out:
# {'title': 'A Christmas Carol', 'year': 2009}
# {'title': 'Flight', 'year': 2012}

# %%
query = { "$and" : [{"directors": "Robert Zemeckis"},{"year" : {"$gt" : 2008 }}]}
proyeccion = {"_id": 0, "title" : True, "year": 1}

for movie in movies.find(query, proyeccion):
    pprint(movie)
# Out:
# {'title': 'A Christmas Carol', 'year': 2009}
# {'title': 'Flight', 'year': 2012}

# %%
query = { "$or" : [{"directors": "Robert Zemeckis"},{"year" : {"$gt" : 2008 }}]}
proyeccion = {"_id": 0, "title" : True, "year": 1}

for movie in movies.find(query, proyeccion):
    pprint(movie)
# Out:
# {'title': 'Used Cars', 'year': 1980}
# {'title': 'Romancing the Stone', 'year': 1984}
# {'title': 'Back to the Future', 'year': 1985}
# {'title': 'Who Framed Roger Rabbit', 'year': 1988}
# {'title': 'Back to the Future Part II', 'year': 1989}
# {'title': 'Back to the Future Part III', 'year': 1990}
# {'title': 'Death Becomes Her', 'year': 1992}
# {'title': 'Forrest Gump', 'year': 1994}
# {'title': 'Contact', 'year': 1997}
# {'title': 'Pèl Adrienn', 'year': 2010}
# {'title': 'What Lies Beneath', 'year': 2000}
# {'title': 'Cast Away', 'year': 2000}
# {'title': 'Cast Away', 'year': 2000}
# {'title': 'In My Sleep', 'year': 2010}
# {'title': 'Coraline', 'year': 2009}
# {'title': 'On the Road', 'year': 2012}
# {'title': 'The Polar Express', 'year': 2004}
# {'title': 'The Secret Life of Walter Mitty', 'year': 2013}
# {'title': 'Inglourious Basterds', 'year': 2009}
# {'title': 'The Box', 'year': 2009}
# {'title': 'Jurassic World', 'year': 2015}
# {'title': 'The Pacific', 'year': 2010}
# {'title': 'Astro Boy', 'year': 2009}
# {'title': 'The Rum Diary', 'year': 2011}
# {'title': 'Gnomeo & Juliet', 'year': 2011}
# {'title': 'The Lovely Bones', 'year': 2009}
# {'title': 'Cargo', 'year': 2009}
# {'title': 'Skellig: The Owl Man', 'year': 2009}
# {'title': 'The Three Stooges', 'year': 2012}
# {'title': 'The Crimson Petal and the White', 'year': 2011}
# {'title': 'Where the Wild Things Are', 'year': 2009}
# {'title': 'Tangled', 'year': 2010}
# {'title': 'John Carter', 'year': 2012}
# {'title': 'Utomlyonnye solntsem 2: Predstoyanie', 'year': 2010}
# {'title': 'Youth in Revolt', 'year': 2009}
# {'title': 'Action Jackson', 'year': 2014}
# {'title': 'In Secret', 'year': 2013}
# {'title': 'Watchmen', 'year': 2009}
# {'title': 'Cowboys & Aliens', 'year': 2011}
# {'title': 'Harry Potter and the Half-Blood Prince', 'year': 2009}
# {'title': 'The Stanford Prison Experiment', 'year': 2015}
# {'title': 'Hemingway & Gellhorn', 'year': 2012}
# {'title': 'Dinner for Schmucks', 'year': 2010}
# {'title': 'The A-Team', 'year': 2010}
# {'title': 'The Possession', 'year': 2012}
# {'title': 'Fantastic Mr. Fox', 'year': 2009}
# {'title': 'Leningrad', 'year': 2009}
# {'title': 'Real Steel', 'year': 2011}
# {'title': 'Daybreakers', 'year': 2009}
# {'title': 'The Giver', 'year': 2014}
# {'title': 'Toy Story 3', 'year': 2010}
# {'title': 'G-Force', 'year': 2009}
# {'title': 'Terminator Salvation', 'year': 2009}
# {'title': 'Beowulf', 'year': 2007}
# {'title': 'Lincoln', 'year': 2012}
# {'title': '7 Days', 'year': 2010}
# {'title': 'Scott Pilgrim vs. the World', 'year': 2010}
# {'title': 'Knowing', 'year': 2009}
# {'title': 'Puss in Boots', 'year': 2011}
# {'title': "Cirque du Freak: The Vampire's Assistant", 'year': 2009}
# {'title': 'Party Crashers', 'year': 2012}
# {'title': "The Time Traveler's Wife", 'year': 2009}
# {'title': 'Life of Pi', 'year': 2012}
# {'title': 'The Crazies', 'year': 2010}
# {'title': 'The Equalizer', 'year': 2014}
# {'title': 'Land of the Lost', 'year': 2009}
# {'title': 'Captain America: The First Avenger', 'year': 2011}
# {'title': 'Pope Joan', 'year': 2009}
# {'title': 'Sin City: A Dame to Kill For', 'year': 2014}
# {'title': 'X-Men Origins: Wolverine', 'year': 2009}
# {'title': 'Generation P', 'year': 2011}
# {'title': 'Piranha 3D', 'year': 2010}
# {'title': 'Push', 'year': 2009}
# {'title': 'Margaret', 'year': 2011}
# {'title': 'Alan Partridge', 'year': 2013}
# {'title': 'Ex Machina', 'year': 2015}
# {'title': 'Tower Heist', 'year': 2011}
# {'title': '9', 'year': 2009}
# {'title': 'The Smurfs', 'year': 2011}
# {'title': 'Notorious', 'year': 2009}
# {'title': 'The Mechanic', 'year': 2011}
# {'title': 'Prince of Persia: The Sands of Time', 'year': 2010}
# {'title': 'On the Road', 'year': 2012}
# {'title': 'State of Play', 'year': 2009}
# {'title': 'Unstoppable', 'year': 2010}
# {'title': 'Extremely Loud & Incredibly Close', 'year': 2011}
# {'title': 'The Tree of Life', 'year': 2011}
# {'title': 'Ant-Man', 'year': 2015}
# {'title': 'Season of the Witch', 'year': 2011}
# {'title': 'Atlas Shrugged: Part I', 'year': 2011}
# {'title': 'The Losers', 'year': 2010}
# {'title': 'The Croods', 'year': 2013}
# {'title': 'Bandage', 'year': 2010}
# {'title': 'Barry Munday', 'year': 2010}
# {'title': 'U Want Me 2 Kill Him?', 'year': 2013}
# {'title': 'Mr. Nobody', 'year': 2009}
# {'title': 'Red Tails', 'year': 2012}
# {'title': 'Which Way Home', 'year': 2009}
# {'title': 'Something Borrowed', 'year': 2011}
# {'title': 'The Haunting in Connecticut', 'year': 2009}
# {'title': 'Furry Vengeance', 'year': 2010}
# {'title': 'The Wild Stallion', 'year': 2009}
# {'title': "Archie's Final Project", 'year': 2009}
# {'title': 'Ramona and Beezus', 'year': 2010}
# {'title': 'Severe Clear', 'year': 2009}
# {'title': 'Calvin Marshall', 'year': 2009}
# {'title': 'Avatar', 'year': 2009}
# {'title': "Who Is Harry Nilsson (And Why Is Everybody Talkin' About Him?)",
#  'year': 2010}
# {'title': 'Friday the 13th', 'year': 2009}
# {'title': 'Grey Gardens', 'year': 2009}
# {'title': 'Love & Other Drugs', 'year': 2010}
# {'title': "Don't Let Me Drown", 'year': 2009}
# {'title': 'Thirst', 'year': 2009}
# {'title': 'Planet 51', 'year': 2009}
# {'title': 'A Thousand Words', 'year': 2012}
# {'title': 'Brothers', 'year': 2009}
# {'title': 'Oceans', 'year': 2009}
# {'title': 'Escape from Planet Earth', 'year': 2013}
# {'title': 'Thirst', 'year': 2009}
# {'title': 'Storm', 'year': 2009}
# {'title': 'Samsara', 'year': 2011}
# {'title': 'Man of Steel', 'year': 2013}
# {'title': "Who Is Harry Nilsson (And Why Is Everybody Talkin' About Him?)",
#  'year': 2010}
# {'title': 'The Illusionist', 'year': 2010}
# {'title': 'Aliens in the Attic', 'year': 2009}
# {'title': 'Night Catches Us', 'year': 2010}
# {'title': 'Drive', 'year': 2011}
# {'title': 'The Princess and the Frog', 'year': 2009}
# {'title': "Everybody's Fine", 'year': 2009}
# {'title': 'Imagine That', 'year': 2009}
# {'title': 'Official Rejection', 'year': 2009}
# {'title': 'The Wolfman', 'year': 2010}
# {'title': 'You Will Be Mine', 'year': 2009}
# {'title': 'Hotel for Dogs', 'year': 2009}
# {'title': 'The Attack', 'year': 2012}
# {'title': 'The Boxtrolls', 'year': 2014}
# {'title': 'The Incredible Burt Wonderstone', 'year': 2013}
# {'title': 'Dallas Buyers Club', 'year': 2013}
# {'title': 'Elliot Loves', 'year': 2012}
# {'title': 'Brief Interviews with Hideous Men', 'year': 2009}
# {'title': 'The First Grader', 'year': 2010}
# {'title': 'Jack Reacher', 'year': 2012}
# {'title': 'The Messenger', 'year': 2009}
# {'title': 'Case 39', 'year': 2009}
# {'title': 'Not Easily Broken', 'year': 2009}
# {'title': 'Scary Movie 5', 'year': 2013}
# {'title': 'Star Trek', 'year': 2009}
# {'title': '13', 'year': 2010}
# {'title': 'Clash of the Titans', 'year': 2010}
# {'title': 'Thor', 'year': 2011}
# {'title': 'Red Dog', 'year': 2011}
# {'title': "It's Kind of a Funny Story", 'year': 2010}
# {'title': 'Carriers', 'year': 2009}
# {'title': 'Angels & Demons', 'year': 2009}
# {'title': 'A Letter to Elia', 'year': 2010}
# {'title': 'The Good Heart', 'year': 2009}
# {'title': 'Life During Wartime', 'year': 2009}
# {'title': 'Tooth Fairy', 'year': 2010}
# {'title': 'Hilde', 'year': 2009}
# {'title': 'The Belgrade Phantom', 'year': 2009}
# {'title': 'Bright Star', 'year': 2009}
# {'title': 'The Danish Girl', 'year': 2015}
# {'title': 'Jack and Jill', 'year': 2011}
# {'title': 'Take Me Home Tonight', 'year': 2011}
# {'title': 'The Do-Deca-Pentathlon', 'year': 2012}
# {'title': 'Percy Jackson & the Olympians: The Lightning Thief', 'year': 2010}
# {'title': 'The Stepfather', 'year': 2009}
# {'title': 'The Uninvited', 'year': 2009}
# {'title': "She's Out of My League", 'year': 2010}
# {'title': 'The Book Thief', 'year': 2013}
# {'title': 'Conan the Barbarian', 'year': 2011}
# {'title': 'Interstellar', 'year': 2014}
# {'title': 'Flipped', 'year': 2010}
# {'title': 'World War Z', 'year': 2013}
# {'title': "Valentine's Day", 'year': 2010}
# {'title': 'Dreamkiller', 'year': 2010}
# {'title': 'Ghosts of Girlfriends Past', 'year': 2009}
# {'title': 'The Soloist', 'year': 2009}
# {'title': 'Priest', 'year': 2011}
# {'title': 'Sex, Party and Lies', 'year': 2009}
# {'title': 'The Last Station', 'year': 2009}
# {'title': 'Dracula Untold', 'year': 2014}
# {'title': 'Godzilla', 'year': 2014}
# {'title': 'What Goes Up', 'year': 2009}
# {'title': 'The Babymakers', 'year': 2012}
# {'title': 'Hotel Transylvania', 'year': 2012}
# {'title': 'The Pink Panther 2', 'year': 2009}
# {'title': 'After.Life', 'year': 2009}
# {'title': 'Bhopal: A Prayer for Rain', 'year': 2014}
# {'title': 'The Town', 'year': 2010}
# {'title': 'Everyday Sunshine: The Story of Fishbone', 'year': 2010}
# {'title': 'The Kids Are All Right', 'year': 2010}
# {'title': 'My Dog Tulip', 'year': 2009}
# {'title': 'Cloudy with a Chance of Meatballs', 'year': 2009}
# {'title': 'The Last House on the Left', 'year': 2009}
# {'title': 'Hoodwinked Too! Hood vs. Evil', 'year': 2011}
# {'title': 'The Avengers', 'year': 2012}
# {'title': 'Epic', 'year': 2013}
# {'title': 'Jack & Diane', 'year': 2012}
# {'title': 'Silver Medallist', 'year': 2009}
# {'title': 'The Lodger', 'year': 2009}
# {'title': 'The Sweeney', 'year': 2012}
# {'title': 'Evangelion: 3.0 You Can (Not) Redo', 'year': 2012}
# {'title': 'Evangelion: 2.0 You Can (Not) Advance', 'year': 2009}
# {'title': 'Lupin III', 'year': 2014}
# {'title': 'Mr. Peabody & Sherman', 'year': 2014}
# {'title': 'My Life in Ruins', 'year': 2009}
# {'title': '6 Month Rule', 'year': 2011}
# {'title': "All Tomorrow's Parties", 'year': 2009}
# {'title': 'My Soul to Take', 'year': 2010}
# {'title': 'Red State', 'year': 2011}
# {'title': 'Nine', 'year': 2009}
# {'title': 'The Blind Side', 'year': 2009}
# {'title': 'Please Give', 'year': 2010}
# {'title': 'Eat Pray Love', 'year': 2010}
# {'title': 'The Ministers', 'year': 2009}
# {'title': 'Sanctum', 'year': 2011}
# {'title': 'All About Steve', 'year': 2009}
# {'title': 'Snitch', 'year': 2013}
# {'title': 'Mr Hockey: The Gordie Howe Story', 'year': 2013}
# {'title': "Legends of Oz: Dorothy's Return", 'year': 2013}
# {'title': 'The Wedding Ringer', 'year': 2015}
# {'title': 'Luck by Chance', 'year': 2009}
# {'title': 'The Switch', 'year': 2010}
# {'title': 'Brèno', 'year': 2009}
# {'title': 'Letters to Juliet', 'year': 2010}
# {'title': 'How to Train Your Dragon', 'year': 2010}
# {'title': 'Monsters vs. Aliens', 'year': 2009}
# {'title': 'Shrek Forever After', 'year': 2010}
# {'title': 'White on Rice', 'year': 2009}
# {'title': 'From Prada to Nada', 'year': 2011}
# {'title': 'Kill Theory', 'year': 2009}
# {'title': 'Cairo Time', 'year': 2009}
# {'title': 'The Whistleblower', 'year': 2010}
# {'title': 'The City of Your Final Destination', 'year': 2009}
# {'title': 'The Road', 'year': 2009}
# {'title': 'Bride Wars', 'year': 2009}
# {'title': 'Life Is Hot in Cracktown', 'year': 2009}
# {'title': 'The Hobbit: An Unexpected Journey', 'year': 2012}
# {'title': 'Love & Mercy', 'year': 2014}
# {'title': 'The Thing', 'year': 2011}
# {'title': 'St. George Shoots the Dragon', 'year': 2009}
# {'title': 'Prey', 'year': 2010}
# {'title': 'The Hills Run Red', 'year': 2009}
# {'title': 'In the Electric Mist', 'year': 2009}
# {'title': 'Hilde', 'year': 2009}
# {'title': 'Broken Embraces', 'year': 2009}
# {'title': '44 Inch Chest', 'year': 2009}
# {'title': 'Jackboots on Whitehall', 'year': 2010}
# {'title': 'Carriers', 'year': 2009}
# {'title': 'Public Sex', 'year': 2009}
# {'title': 'Harry Potter and the Deathly Hallows: Part 1', 'year': 2010}
# {'title': 'The Boys Are Back', 'year': 2009}
# {'title': 'Precious', 'year': 2009}
# {'title': 'Rabbit Hole', 'year': 2010}
# {'title': 'The Last Airbender', 'year': 2010}
# {'title': 'Silent Hill: Revelation 3D', 'year': 2012}
# {'title': 'Arthur 3: The War of the Two Worlds', 'year': 2010}
# {'title': 'Salt', 'year': 2010}
# {'title': 'Source Code', 'year': 2011}
# {'title': 'Green Zone', 'year': 2010}
# {'title': 'Black Swan', 'year': 2010}
# {'title': 'The Amazing Spider-Man', 'year': 2012}
# {'title': 'The Killer Inside Me', 'year': 2010}
# {'title': 'Robin Hood', 'year': 2010}
# {'title': 'Big River Man', 'year': 2009}
# {'title': 'Big River Man', 'year': 2009}
# {'title': 'A Monster in Paris', 'year': 2011}
# {'title': 'The Young Victoria', 'year': 2009}
# {'title': 'The International', 'year': 2009}
# {'title': 'Redland', 'year': 2009}
# {'title': "The Sorcerer's Apprentice", 'year': 2010}
# {'title': 'Tetro', 'year': 2009}
# {'title': 'The Fighter', 'year': 2010}
# {'title': 'The Conspirator', 'year': 2010}
# {'title': 'Tetro', 'year': 2009}
# {'title': 'Hugo', 'year': 2011}
# {'title': 'Solomon Kane', 'year': 2009}
# {'title': 'Little Fockers', 'year': 2010}
# {'title': 'A Perfect Getaway', 'year': 2009}
# {'title': 'Obitaemyy ostrov', 'year': 2009}
# {'title': 'Creation', 'year': 2009}
# {'title': '17 Again', 'year': 2009}
# {'title': 'The Velveteen Rabbit', 'year': 2009}
# {'title': 'Hitchcock', 'year': 2012}
# {'title': 'Creation', 'year': 2009}
# {'title': 'Little New York', 'year': 2009}
# {'title': 'Old Dogs', 'year': 2009}
# {'title': 'Fair Game', 'year': 2010}
# {'title': 'Sucker Punch', 'year': 2011}
# {'title': 'The Chronicles of Narnia: The Voyage of the Dawn Treader',
#  'year': 2010}
# {'title': 'Like Dandelion Dust', 'year': 2009}
# {'title': 'Funkytown', 'year': 2011}
# {'title': 'The Adventures of Tintin', 'year': 2011}
# {'title': 'Metropia', 'year': 2009}
# {'title': 'Machete', 'year': 2010}
# {'title': 'Sherlock Holmes', 'year': 2009}
# {'title': 'Jean Charles', 'year': 2009}
# {'title': 'Dear John', 'year': 2010}
# {'title': 'The Green Hornet', 'year': 2011}
# {'title': 'Ingenious', 'year': 2009}
# {'title': 'Into the Storm', 'year': 2009}
# {'title': 'The Wolf of Wall Street', 'year': 2013}
# {'title': 'Hanna', 'year': 2011}
# {'title': 'In Her Skin', 'year': 2009}
# {'title': 'An Englishman in New York', 'year': 2009}
# {'title': 'Unmade Beds', 'year': 2009}
# {'title': 'Straw Dogs', 'year': 2011}
# {'title': "He's Just Not That Into You", 'year': 2009}
# {'title': 'Megamind', 'year': 2010}
# {'title': "Perrier's Bounty", 'year': 2009}
# {'title': 'The Iron Lady', 'year': 2011}
# {'title': 'Yatterman', 'year': 2009}
# {'title': 'The Courageous Heart of Irena Sendler', 'year': 2009}
# {'title': 'Helen', 'year': 2009}
# {'title': 'Knight and Day', 'year': 2010}
# {'title': 'Fast & Furious', 'year': 2009}
# {'title': 'Dylan Dog: Dead of Night', 'year': 2010}
# {'title': 'Alice in Wonderland', 'year': 2010}
# {'title': 'A Shine of Rainbows', 'year': 2009}
# {'title': 'The Sisterhood of Night', 'year': 2014}
# {'title': 'Legally Blondes', 'year': 2009}
# {'title': 'Fame', 'year': 2009}
# {'title': 'Percy Jackson & the Olympians: The Lightning Thief', 'year': 2010}
# {'title': 'Adrift', 'year': 2009}
# {'title': 'The Runaways', 'year': 2010}
# {'title': 'Splice', 'year': 2009}
# {'title': 'Taking Chance', 'year': 2009}
# {'title': 'A Serious Man', 'year': 2009}
# {'title': 'Selma', 'year': 2014}
# {'title': 'Centurion', 'year': 2010}
# {'title': 'Infestation', 'year': 2009}
# {'title': 'Under the Sea 3D', 'year': 2009}
# {'title': 'Vampire Killers', 'year': 2009}
# {'title': 'Babies', 'year': 2010}
# {'title': 'The Scouting Book for Boys', 'year': 2009}
# {'title': '(500) Days of Summer', 'year': 2009}
# {'title': 'The Way Back', 'year': 2010}
# {'title': 'Coco Chanel & Igor Stravinsky', 'year': 2009}
# {'title': 'Brothers', 'year': 2009}
# {'title': 'Argo', 'year': 2012}
# {'title': 'Wall Street: Money Never Sleeps', 'year': 2010}
# {'title': 'Secretariat', 'year': 2010}
# {'title': "Love N' Dancing", 'year': 2009}
# {'title': 'Krrish 3', 'year': 2013}
# {'title': 'From Time to Time', 'year': 2009}
# {'title': 'I Love You, Beth Cooper', 'year': 2009}
# {'title': 'The Butterfly Tattoo', 'year': 2009}
# {'title': 'Inseparable', 'year': 2011}
# {'title': 'The Descendants', 'year': 2011}
# {'title': 'Gamer', 'year': 2009}
# {'title': 'Iron Sky', 'year': 2012}
# {'title': 'The Eagle', 'year': 2011}
# {'title': "White Lightnin'", 'year': 2009}
# {'title': 'All About Actresses', 'year': 2009}
# {'title': 'Coco Before Chanel', 'year': 2009}
# {'title': 'The Time that Remains', 'year': 2009}
# {'title': 'Everyday', 'year': 2012}
# {'title': 'The Book of Eli', 'year': 2010}
# {'title': 'The Book of Eli', 'year': 2010}
# {'title': 'Mammoth', 'year': 2009}
# {'title': 'The Story of Luke', 'year': 2012}
# {'title': 'The Bounty Hunter', 'year': 2010}
# {'title': 'The Immaculate Conception of Little Dizzle', 'year': 2009}
# {'title': 'The Nutcracker in 3D', 'year': 2010}
# {'title': 'The Proposal', 'year': 2009}
# {'title': 'Delhi-6', 'year': 2009}
# {'title': 'The Legend of Hercules', 'year': 2014}
# {'title': 'For the Good of Others', 'year': 2010}
# {'title': 'Lascars', 'year': 2009}
# {'title': 'Eyeborgs', 'year': 2009}
# {'title': 'Silver Linings Playbook', 'year': 2012}
# {'title': 'I Love You Phillip Morris', 'year': 2009}
# {'title': 'Year One', 'year': 2009}
# {'title': 'G.I. Joe: The Rise of Cobra', 'year': 2009}
# {'title': 'Unfinished Song', 'year': 2012}
# {'title': 'Lo', 'year': 2009}
# {'title': 'Parental Guidance', 'year': 2012}
# {'title': 'Outrage', 'year': 2009}
# {'title': 'Howl', 'year': 2010}
# {'title': 'Up', 'year': 2009}
# {'title': 'Repo Men', 'year': 2010}
# {'title': 'One Lucky Elephant', 'year': 2010}
# {'title': 'Imago mortis', 'year': 2009}
# {'title': 'Goemon', 'year': 2009}
# {'title': 'Futurama: Into the Wild Green Yonder', 'year': 2009}
# {'title': 'Desert Flower', 'year': 2009}
# {'title': 'The Imaginarium of Doctor Parnassus', 'year': 2009}
# {'title': 'Life as We Know It', 'year': 2010}
# {'title': 'The Best Things in the World', 'year': 2010}
# {'title': 'Transformers: Revenge of the Fallen', 'year': 2009}
# {'title': 'Invictus', 'year': 2009}
# {'title': 'The Invention of Lying', 'year': 2009}
# {'title': 'The Strength of Water', 'year': 2009}
# {'title': 'The Lodger', 'year': 2009}
# {'title': 'Bare Knuckles', 'year': 2010}
# {'title': 'Boyhood', 'year': 2014}
# {'title': 'A Christmas Carol', 'year': 2009}
# {'title': 'Water for Elephants', 'year': 2011}
# {'title': 'Adult World', 'year': 2013}
# {'title': 'Game of Assassins', 'year': 2013}
# {'title': 'Monte Carlo', 'year': 2011}
# {'title': 'Footloose', 'year': 2011}
# {'title': 'Midnight Son', 'year': 2011}
# {'title': 'Elvis & Madona', 'year': 2010}
# {'title': "Mao's Last Dancer", 'year': 2009}
# {'title': 'Ink', 'year': 2009}
# {'title': 'Ghost Rider: Spirit of Vengeance', 'year': 2011}
# {'title': "Mao's Last Dancer", 'year': 2009}
# {'title': 'Prayers for Bobby', 'year': 2009}
# {'title': 'William Kunstler: Disturbing the Universe', 'year': 2009}
# {'title': 'Skyfall', 'year': 2012}
# {'title': "Don't Look Back", 'year': 2009}
# {'title': 'The Misfortunates', 'year': 2009}
# {'title': 'Shinjuku Incident', 'year': 2009}
# {'title': 'Race to Witch Mountain', 'year': 2009}
# {'title': 'Reykjavik Whale Watching Massacre', 'year': 2009}
# {'title': 'Jonah Hex', 'year': 2010}
# {'title': 'Ajami', 'year': 2009}
# {'title': 'Dark Shadows', 'year': 2012}
# {'title': "My Sister's Keeper", 'year': 2009}
# {'title': 'Night at the Museum: Battle of the Smithsonian', 'year': 2009}
# {'title': 'The Girl from the Naked Eye', 'year': 2012}
# {'title': 'Couples Retreat', 'year': 2009}
# {'title': 'Happiness Runs', 'year': 2010}
# {'title': 'Jack and the Beanstalk', 'year': 2010}
# {'title': 'Ice Age: Dawn of the Dinosaurs', 'year': 2009}
# {'title': 'Dr. Dolittle: Million Dollar Mutts', 'year': 2009}
# {'title': 'Baarèa', 'year': 2009}
# {'title': 'Dirty Mind', 'year': 2009}
# {'title': 'Richness of Internal Space', 'year': 2012}
# {'title': 'Italians', 'year': 2009}
# {'title': 'Fighting', 'year': 2009}
# {'title': 'A Princess for Christmas', 'year': 2011}
# {'title': 'Fired Up!', 'year': 2009}
# {'title': 'Off and Running', 'year': 2009}
# {'title': 'Wanted', 'year': 2009}
# {'title': 'Chicago Overcoat', 'year': 2009}
# {'title': 'The Prince', 'year': 2014}
# {'title': 'Weather Girl', 'year': 2009}
# {'title': 'The Hole', 'year': 2009}
# {'title': 'Blended', 'year': 2014}
# {'title': 'Once Fallen', 'year': 2010}
# {'title': 'Megan Is Missing', 'year': 2011}
# {'title': 'The Soloist', 'year': 2009}
# {'title': 'The Diplomat', 'year': 2009}
# {'title': 'Lone Survivor', 'year': 2013}
# {'title': 'Chandni Chowk to China', 'year': 2009}
# {'title': 'Adventureland', 'year': 2009}
# {'title': 'With Great Power: The Stan Lee Story', 'year': 2010}
# {'title': 'Paul', 'year': 2011}
# {'title': 'The Darkest Hour', 'year': 2011}
# {'title': 'Confessions of a Shopaholic', 'year': 2009}
# {'title': 'The Hammer', 'year': 2010}
# {'title': 'Bad Lieutenant: Port of Call New Orleans', 'year': 2009}
# {'title': 'Dragonball: Evolution', 'year': 2009}
# {'title': 'If I Were You 2', 'year': 2009}
# {'title': 'Bereavement', 'year': 2010}
# {'title': 'Tormented', 'year': 2009}
# {'title': 'Foxcatcher', 'year': 2014}
# {'title': 'Shorts', 'year': 2009}
# {'title': 'Thirst', 'year': 2010}
# {'title': 'Killers', 'year': 2010}
# {'title': 'Red Sands', 'year': 2009}
# {'title': 'TRON: Legacy', 'year': 2010}
# {'title': 'The Girlfriend Experience', 'year': 2009}
# {'title': 'TRON: Legacy', 'year': 2010}
# {'title': 'Coffin Rock', 'year': 2009}
# {'title': "Good Ol' Boy", 'year': 2015}
# {'title': 'The Missing Person', 'year': 2009}
# {'title': '8 x 10 Tasveer', 'year': 2009}
# {'title': 'Eva', 'year': 2010}
# {'title': 'Giallo', 'year': 2009}
# {'title': 'Mars', 'year': 2010}
# {'title': 'Between Us', 'year': 2012}
# {'title': 'Paddington', 'year': 2014}
# {'title': 'The Elephant in the Living Room', 'year': 2010}
# {'title': 'The Taking of Pelham 1 2 3', 'year': 2009}
# {'title': 'Balibo', 'year': 2009}
# {'title': 'George Harrison: Living in the Material World', 'year': 2011}
# {'title': 'Hannah Montana: The Movie', 'year': 2009}
# {'title': 'That Evening Sun', 'year': 2009}
# {'title': 'Paul Blart: Mall Cop', 'year': 2009}
# {'title': 'Jackass 3D', 'year': 2010}
# {'title': 'Strigoi', 'year': 2009}
# {'title': 'The Special Relationship', 'year': 2010}
# {'title': 'The Town', 'year': 2010}
# {'title': 'Here and There', 'year': 2009}
# {'title': 'A Thousand Words', 'year': 2012}
# {'title': 'Accidents Happen', 'year': 2009}
# {'title': 'The Killing Room', 'year': 2009}
# {'title': 'The Hangover', 'year': 2009}
# {'title': 'Formosa Betrayed', 'year': 2009}
# {'title': 'Crank: High Voltage', 'year': 2009}
# {'title': 'Mother and Child', 'year': 2009}
# {'title': 'Rosencrantz and Guildenstern Are Undead', 'year': 2009}
# {'title': 'Alien Trespass', 'year': 2009}
# {'title': 'Detective Dee: Mystery of the Phantom Flame', 'year': 2010}
# {'title': 'Detective Dee: Mystery of the Phantom Flame', 'year': 2010}
# {'title': 'Phantom Pain', 'year': 2009}
# {'title': 'The Ides of March', 'year': 2011}
# {'title': 'St. Nick', 'year': 2009}
# {'title': 'City of Life and Death', 'year': 2009}
# {'title': 'City of War: The Story of John Rabe', 'year': 2009}
# {'title': 'Play the Game', 'year': 2009}
# {'title': "See What I'm Saying: The Deaf Entertainers Documentary",
#  'year': 2009}
# {'title': 'Love Ranch', 'year': 2010}
# {'title': 'Big Eyes', 'year': 2014}
# {'title': 'Burlesque', 'year': 2010}
# {'title': 'Morning Glory', 'year': 2010}
# {'title': 'Drag Me to Hell', 'year': 2009}
# {'title': 'The Diary of Anne Frank', 'year': 2009}
# {'title': 'Sin Nombre', 'year': 2009}
# {'title': 'The Girl', 'year': 2012}
# {'title': 'Taking Woodstock', 'year': 2009}
# {'title': 'Cold Souls', 'year': 2009}
# {'title': 'Another Harvest Moon', 'year': 2010}
# {'title': 'Miss Nobody', 'year': 2010}
# {'title': 'Amelia', 'year': 2009}
# {'title': 'The Informant!', 'year': 2009}
# {'title': '16 to Life', 'year': 2009}
# {'title': 'Shutter Island', 'year': 2010}
# {'title': "Jennifer's Body", 'year': 2009}
# {'title': 'Against the Current', 'year': 2009}
# {'title': 'Pirate Radio', 'year': 2009}
# {'title': '(Untitled)', 'year': 2009}
# {'title': 'Can Go Through Skin', 'year': 2009}
# {'title': 'A Ted Named Gooby', 'year': 2009}
# {'title': "You Don't Know Jack", 'year': 2010}
# {'title': 'The Girl with the Dragon Tattoo', 'year': 2009}
# {'title': 'Green Lantern', 'year': 2011}
# {'title': 'The Private Lives of Pippa Lee', 'year': 2009}
# {'title': 'Precious', 'year': 2009}
# {'title': 'Survival of the Dead', 'year': 2009}
# {'title': 'Tell Tale', 'year': 2009}
# {'title': 'Takers', 'year': 2010}
# {'title': 'Trader Games', 'year': 2010}
# {'title': 'Duplicity', 'year': 2009}
# {'title': 'Julie & Julia', 'year': 2009}
# {'title': 'A Tale of Love and Darkness', 'year': 2015}
# {'title': 'District 9', 'year': 2009}
# {'title': 'Awaydays', 'year': 2009}
# {'title': 'Blood River', 'year': 2009}
# {'title': 'Sonny Boy', 'year': 2011}
# {'title': 'How to Draw a Perfect Circle', 'year': 2009}
# {'title': 'Personal Effects', 'year': 2009}
# {'title': 'The Ghost Writer', 'year': 2010}
# {'title': 'Calvin Marshall', 'year': 2009}
# {'title': 'The Unborn', 'year': 2009}
# {'title': 'I Believe in Unicorns', 'year': 2014}
# {'title': 'Madea Goes to Jail', 'year': 2009}
# {'title': 'Dragonball: Evolution', 'year': 2009}
# {'title': 'Frankenweenie', 'year': 2012}
# {'title': 'The Ugly Truth', 'year': 2009}
# {'title': 'High Life', 'year': 2009}
# {'title': 'Holy Rollers', 'year': 2010}
# {'title': 'Peter and Vandy', 'year': 2009}
# {'title': 'The Final Destination', 'year': 2009}
# {'title': 'Overseas and Under Your Skin', 'year': 2009}
# {'title': 'Under the North Star', 'year': 2009}
# {'title': 'Bran Nue Dae', 'year': 2009}
# {'title': 'Orphan', 'year': 2009}
# {'title': 'Blue', 'year': 2009}
# {'title': 'Micmacs', 'year': 2009}
# {'title': 'The White Ribbon', 'year': 2009}
# {'title': 'Raging Sun, Raging Sky', 'year': 2009}
# {'title': 'Spy(ies)', 'year': 2009}
# {'title': 'Leaves of Grass', 'year': 2009}
# {'title': 'Rage', 'year': 2009}
# {'title': 'Cornered!', 'year': 2009}
# {'title': 'Miss March', 'year': 2009}
# {'title': 'Beastly', 'year': 2011}
# {'title': 'Freakonomics', 'year': 2010}
# {'title': 'Racing Dreams', 'year': 2009}
# {'title': 'Public Enemies', 'year': 2009}
# {'title': 'Tidal Wave', 'year': 2009}
# {'title': 'Broken Kingdom', 'year': 2012}
# {'title': 'I Love You, Man', 'year': 2009}
# {'title': 'The Karate Kid', 'year': 2010}
# {'title': 'A Dangerous Place', 'year': 2012}
# {'title': 'The Lightkeepers', 'year': 2009}
# {'title': "The Hell of '63", 'year': 2009}
# {'title': 'Wild Grass', 'year': 2009}
# {'title': 'Zombieland', 'year': 2009}
# {'title': 'Undisputed 3: Redemption', 'year': 2010}
# {'title': 'Silent Sonata', 'year': 2010}
# {'title': 'The Happiest Girl in the World', 'year': 2009}
# {'title': 'Huacho', 'year': 2009}
# {'title': 'Waking Sleeping Beauty', 'year': 2009}
# {'title': 'The Colony', 'year': 2013}
# {'title': 'Playground', 'year': 2009}
# {'title': 'Super Capers: The Origins of Ed and the Missing Bullion',
#  'year': 2009}
# {'title': 'Gentlemen Broncos', 'year': 2009}
# {'title': 'Friend Zone', 'year': 2009}
# {'title': 'The Rite', 'year': 2011}
# {'title': 'Biutiful', 'year': 2010}
# {'title': 'Seven Minutes', 'year': 2009}
# {'title': 'Fat People', 'year': 2009}
# {'title': 'Mississippi Damned', 'year': 2009}
# {'title': 'The Hobbit: The Desolation of Smaug', 'year': 2013}
# {'title': 'Beautiful', 'year': 2009}
# {'title': 'Baggage Claim', 'year': 2013}
# {'title': 'Whip It', 'year': 2009}
# {'title': 'Delhi Safari', 'year': 2012}
# {'title': 'The House of the Devil', 'year': 2009}
# {'title': 'The Company Men', 'year': 2010}
# {'title': 'Babysitters Beware', 'year': 2009}
# {'title': 'The Bang Bang Club', 'year': 2010}
# {'title': 'City Island', 'year': 2009}
# {'title': 'An Education', 'year': 2009}
# {'title': 'All Good Things', 'year': 2010}
# {'title': 'Tetsuo: The Bullet Man', 'year': 2009}
# {'title': 'Away We Go', 'year': 2009}
# {'title': 'Away We Go', 'year': 2009}
# {'title': 'The Good Herbs', 'year': 2010}
# {'title': 'Whatever Works', 'year': 2009}
# {'title': 'The Extraordinary Adventures of Adèle Blanc-Sec', 'year': 2010}
# {'title': 'Cold in July', 'year': 2014}
# {'title': 'A Nightmare on Elm Street', 'year': 2010}
# {'title': 'Chèri', 'year': 2009}
# {'title': 'Buddies', 'year': 2012}
# {'title': 'TiMER', 'year': 2009}
# {'title': 'My Bloody Valentine', 'year': 2009}
# {'title': 'American: The Bill Hicks Story', 'year': 2009}
# {'title': 'Kimjongilia', 'year': 2009}
# {'title': 'Black Death', 'year': 2010}
# {'title': 'Jack and the Cuckoo-Clock Heart', 'year': 2013}
# {'title': '20th Century Boys 3: Redemption', 'year': 2009}
# {'title': '20th Century Boys 2: The Last Hope', 'year': 2009}
# {'title': 'The Bone Man', 'year': 2009}
# {'title': 'Jack and the Cuckoo-Clock Heart', 'year': 2013}
# {'title': 'You Will Meet a Tall Dark Stranger', 'year': 2010}
# {'title': 'Moon', 'year': 2009}
# {'title': 'Cracks', 'year': 2009}
# {'title': 'Mr. Nice', 'year': 2010}
# {'title': 'The Vicious Kind', 'year': 2009}
# {'title': 'Welcome to the Rileys', 'year': 2010}
# {'title': 'Marley', 'year': 2012}
# {'title': 'The Lika Cinema', 'year': 2009}
# {'title': 'Princess Kaiulani', 'year': 2009}
# {'title': 'Stan Helsing', 'year': 2009}
# {'title': "Corman's World: Exploits of a Hollywood Rebel", 'year': 2011}
# {'title': 'Map of the Sounds of Tokyo', 'year': 2009}
# {'title': 'My One and Only', 'year': 2009}
# {'title': 'When in Rome', 'year': 2010}
# {'title': 'Adam', 'year': 2009}
# {'title': 'The Outlaw', 'year': 2010}
# {'title': 'My Soul to Take', 'year': 2010}
# {'title': 'Storm Warriors', 'year': 2009}
# {'title': 'Agora', 'year': 2009}
# {'title': '3 Idiots', 'year': 2009}
# {'title': 'The Answer Man', 'year': 2009}
# {'title': 'The Maid', 'year': 2009}
# {'title': 'Triangle', 'year': 2009}
# {'title': 'Ex', 'year': 2009}
# {'title': 'Forbidden Fruit', 'year': 2009}
# {'title': 'The House of Branching Love', 'year': 2009}
# {'title': 'My Name Is Khan', 'year': 2010}
# {'title': 'The Skin I Live In', 'year': 2011}
# {'title': 'Ricky', 'year': 2009}
# {'title': 'The Lincoln Lawyer', 'year': 2011}
# {'title': 'The Hunter', 'year': 2010}
# {'title': '2012', 'year': 2009}
# {'title': 'Black Dynamite', 'year': 2009}
# {'title': 'Amreeka', 'year': 2009}
# {'title': 'Road, Movie', 'year': 2009}
# {'title': 'Punching the Clown', 'year': 2009}
# {'title': 'Rango', 'year': 2011}
# {'title': 'Up in the Air', 'year': 2009}
# {'title': 'Step Up 3D', 'year': 2010}
# {'title': 'The Bourne Legacy', 'year': 2012}
# {'title': 'Get Low', 'year': 2009}
# {'title': 'Casino Jack', 'year': 2010}
# {'title': 'Into Eternity: A Film for the Future', 'year': 2010}
# {'title': 'The Sniper', 'year': 2009}
# {'title': 'Chelovek, kotoryy znal vsyo', 'year': 2009}
# {'title': 'The Five-Year Engagement', 'year': 2012}
# {'title': 'Harmony and Me', 'year': 2009}
# {'title': 'Cemetery Junction', 'year': 2010}
# {'title': 'Diary of a Wimpy Kid', 'year': 2010}
# {'title': 'Princess Protection Program', 'year': 2009}
# {'title': 'Charlie Countryman', 'year': 2013}
# {'title': 'One Chance', 'year': 2013}
# {'title': 'The Last Templar', 'year': 2009}
# {'title': 'Law Abiding Citizen', 'year': 2009}
# {'title': 'Observe and Report', 'year': 2009}
# {'title': 'The Miracle', 'year': 2009}
# {'title': 'Obsessed', 'year': 2009}
# {'title': 'About Sunny', 'year': 2011}
# {'title': 'In the Beginning', 'year': 2009}
# {'title': 'La mission', 'year': 2009}
# {'title': 'Spooner', 'year': 2009}
# {'title': 'Barking Water', 'year': 2009}
# {'title': 'Funny People', 'year': 2009}
# {'title': 'Harry Potter and the Deathly Hallows: Part 2', 'year': 2011}
# {'title': 'By the People: The Election of Barack Obama', 'year': 2009}
# {'title': 'Accident', 'year': 2009}
# {'title': 'The Escape', 'year': 2009}
# {'title': 'The Muppets', 'year': 2011}
# {'title': 'Everyone Else', 'year': 2009}
# {'title': 'Ouija', 'year': 2014}
# {'title': 'Last Vegas', 'year': 2013}
# {'title': 'Paintball', 'year': 2009}
# {'title': 'I Know a Woman Like That', 'year': 2009}
# {'title': 'Without Bias', 'year': 2009}
# {'title': 'Jack Ryan: Shadow Recruit', 'year': 2014}
# {'title': 'Of Love and Other Demons', 'year': 2009}
# {'title': 'Die Perlmutterfarbe', 'year': 2009}
# {'title': 'The Milk of Sorrow', 'year': 2009}
# {'title': 'Out of the Furnace', 'year': 2013}
# {'title': 'Bomber', 'year': 2009}
# {'title': 'The Angel', 'year': 2009}
# {'title': 'Last Cowboy Standing', 'year': 2009}
# {'title': 'Toe to Toe', 'year': 2009}
# {'title': 'Beautiful Kate', 'year': 2009}
# {'title': 'Blood Done Sign My Name', 'year': 2010}
# {'title': "Brooklyn's Finest", 'year': 2009}
# {'title': 'Moneyball', 'year': 2011}
# {'title': 'Pinprick', 'year': 2009}
# {'title': 'The Lone Ranger', 'year': 2013}
# {'title': 'Middle of Nowhere', 'year': 2012}
# {'title': 'Escape Plan', 'year': 2013}
# {'title': 'Hereafter', 'year': 2010}
# {'title': 'The Back-up Plan', 'year': 2010}
# {'title': 'Lawless', 'year': 2012}
# {'title': 'An Invisible Sign', 'year': 2010}
# {'title': 'Broken Hill', 'year': 2009}
# {'title': 'Entre nos', 'year': 2009}
# {'title': 'Alpha and Omega', 'year': 2010}
# {'title': 'Good Hair', 'year': 2009}
# {'title': "The World's End", 'year': 2013}
# {'title': 'London Boulevard', 'year': 2010}
# {'title': 'Love Hurts', 'year': 2009}
# {'title': 'White Wedding', 'year': 2009}
# {'title': 'White Wedding', 'year': 2009}
# {'title': 'Love & Savagery', 'year': 2009}
# {'title': 'Seeking Justice', 'year': 2011}
# {'title': 'Seeking Justice', 'year': 2011}
# {'title': 'Sea Wolf', 'year': 2009}
# {'title': 'Cars 2', 'year': 2011}
# {'title': 'Kill the Messenger', 'year': 2014}
# {'title': 'The Girl Who Played with Fire', 'year': 2009}
# {'title': 'Starring Maja', 'year': 2009}
# {'title': 'Mother', 'year': 2009}
# {'title': 'Tinker Bell and the Great Fairy Rescue', 'year': 2010}
# {'title': 'Tinker Bell and the Lost Treasure', 'year': 2009}
# {'title': 'Triage', 'year': 2009}
# {'title': 'Brave', 'year': 2012}
# {'title': 'Secret of the Wings', 'year': 2012}
# {'title': 'Battle Los Angeles', 'year': 2011}
# {'title': 'Endgame', 'year': 2009}
# {'title': 'Limitless', 'year': 2011}
# {'title': "Legend of the Guardians: The Owls of Ga'Hoole", 'year': 2010}
# {'title': 'Going Postal', 'year': 2010}
# {'title': 'Happy Tears', 'year': 2009}
# {'title': 'Grace', 'year': 2009}
# {'title': 'The Fourth Kind', 'year': 2009}
# {'title': 'Heartless', 'year': 2009}
# {'title': 'Motherhood', 'year': 2009}
# {'title': 'Resident Evil: Afterlife', 'year': 2010}
# {'title': 'Frankie & Alice', 'year': 2010}
# {'title': 'Wild Cherry', 'year': 2009}
# {'title': 'Chimpanzee', 'year': 2012}
# {'title': 'Zookeeper', 'year': 2011}
# {'title': 'Oy Vey! My Son Is Gay!!', 'year': 2009}
# {'title': 'African Cats', 'year': 2011}
# {'title': 'Time of Peace', 'year': 2009}
# {'title': 'The Door', 'year': 2009}
# {'title': 'A Call Girl', 'year': 2009}
# {'title': 'Made in Hungaria', 'year': 2009}
# {'title': 'The Greatest', 'year': 2009}
# {'title': 'Get Him to the Greek', 'year': 2010}
# {'title': 'I Am Love', 'year': 2009}
# {'title': 'The Damned United', 'year': 2009}
# {'title': 'Edge of Darkness', 'year': 2010}
# {'title': 'The Debt', 'year': 2010}
# {'title': 'Passenger Side', 'year': 2009}
# {'title': 'Hellsinki', 'year': 2009}
# {'title': 'Impact', 'year': 2009}
# {'title': 'Aladin', 'year': 2009}
# {'title': 'Iron Man 2', 'year': 2010}
# {'title': 'Laid to Rest', 'year': 2009}
# {'title': 'Bikini Girls on Ice', 'year': 2009}
# {'title': 'Big Fan', 'year': 2009}
# {'title': 'Let Me In', 'year': 2010}
# {'title': 'Mission: Impossible - Ghost Protocol', 'year': 2011}
# {'title': 'Anchorman 2: The Legend Continues', 'year': 2013}
# {'title': 'Road, Movie', 'year': 2009}
# {'title': 'Jane Eyre', 'year': 2011}
# {'title': 'Jonas Brothers: The 3D Concert Experience', 'year': 2009}
# {'title': 'Earth Days', 'year': 2009}
# {'title': 'Margaret', 'year': 2009}
# {'title': 'Minor Details', 'year': 2009}
# {'title': "A Turtle's Tale: Sammy's Adventures", 'year': 2010}
# {'title': 'Newsmakers', 'year': 2009}
# {'title': 'Not Fade Away', 'year': 2012}
# {'title': 'The Job', 'year': 2009}
# {'title': 'The Yellow Sea', 'year': 2010}
# {'title': "It's Complicated", 'year': 2009}
# {'title': 'Alvin and the Chipmunks: The Squeakquel', 'year': 2009}
# {'title': 'Due Date', 'year': 2010}
# {'title': 'Hot Tub Time Machine', 'year': 2010}
# {'title': "That's My Boy", 'year': 2012}
# {'title': 'Teenage Paparazzo', 'year': 2010}
# {'title': 'Capitalism: A Love Story', 'year': 2009}
# {'title': 'Sorority Row', 'year': 2009}
# {'title': '21 Jump Street', 'year': 2012}
# {'title': 'Drones', 'year': 2010}
# {'title': 'Brighton Rock', 'year': 2010}
# {'title': 'My Son, My Son, What Have Ye Done', 'year': 2009}
# {'title': 'Saw VI', 'year': 2009}
# {'title': 'Captain Thunder', 'year': 2011}
# {'title': 'Pariah', 'year': 2011}
# {'title': 'Rage', 'year': 2009}
# {'title': 'Chico Xavier', 'year': 2010}
# {'title': 'The Men Who Stare at Goats', 'year': 2009}
# {'title': 'Greenberg', 'year': 2010}
# {'title': 'Red Dawn', 'year': 2012}
# {'title': 'RoboCop', 'year': 2014}
# {'title': 'Dorian Gray', 'year': 2009}
# {'title': 'The Future', 'year': 2011}
# {'title': 'A Prophet', 'year': 2009}
# {'title': 'The Thaw', 'year': 2009}
# {'title': 'Greenberg', 'year': 2010}
# {'title': 'VIPs', 'year': 2010}
# {'title': 'Mahler on the Couch', 'year': 2010}
# {'title': 'Ondine', 'year': 2009}
# {'title': 'The Fish Child', 'year': 2009}
# {'title': 'Boogie', 'year': 2009}
# {'title': 'Sidewalls', 'year': 2011}
# {'title': 'Mysteries of Lisbon', 'year': 2010}
# {'title': 'A Mulher Invisèvel', 'year': 2009}
# {'title': 'Lemmy', 'year': 2010}
# {'title': 'Drop', 'year': 2009}
# {'title': 'Five Minutes of Heaven', 'year': 2009}
# {'title': 'Mariachi Gringo', 'year': 2012}
# {'title': 'Brothers at War', 'year': 2009}
# {'title': 'The Last Days of Emma Blank', 'year': 2009}
# {'title': 'Amazonia', 'year': 2013}
# {'title': 'Your Highness', 'year': 2011}
# {'title': 'Dare', 'year': 2009}
# {'title': 'Road Kill', 'year': 2010}
# {'title': 'The River Why', 'year': 2010}
# {'title': 'Cell 211', 'year': 2009}
# {'title': 'Dear Lemon Lima', 'year': 2009}
# {'title': 'I Spit on Your Grave', 'year': 2010}
# {'title': 'Taras Bulba', 'year': 2009}
# {'title': "At World's End", 'year': 2009}
# {'title': 'Father, Son & Holy Cow', 'year': 2011}
# {'title': 'We Need to Talk About Kevin', 'year': 2011}
# {'title': 'Oscar and the Lady in Pink', 'year': 2009}
# {'title': 'Looking for Eric', 'year': 2009}
# {'title': 'Bellflower', 'year': 2011}
# {'title': 'Godspeed', 'year': 2009}
# {'title': 'Rebellion', 'year': 2011}
# {'title': 'Judas Kiss', 'year': 2011}
# {'title': 'Through the Mist', 'year': 2009}
# {'title': 'Snow White and Russian Red', 'year': 2009}
# {'title': 'The Tourist', 'year': 2010}
# {'title': 'Dirt! The Movie', 'year': 2009}
# {'title': 'Aloha', 'year': 2015}
# {'title': 'The Dancer and the Thief', 'year': 2009}
# {'title': 'Soul Kitchen', 'year': 2009}
# {'title': 'Fish Story', 'year': 2009}
# {'title': 'Conviction', 'year': 2010}
# {'title': '[Rec] 2', 'year': 2009}
# {'title': 'This Is the End', 'year': 2013}
# {'title': 'RED', 'year': 2010}
# {'title': 'Interceptor', 'year': 2009}
# {'title': 'Knerten', 'year': 2009}
# {'title': 'The Carter', 'year': 2009}
# {'title': 'Friendship!', 'year': 2010}
# {'title': 'Breaking Upwards', 'year': 2009}
# {'title': 'The Temptation of St. Tony', 'year': 2009}
# {'title': 'Norman', 'year': 2010}
# {'title': 'Shrink', 'year': 2009}
# {'title': 'Cherrybomb', 'year': 2009}
# {'title': 'Kick-Ass', 'year': 2010}
# {'title': 'Under the Boardwalk: The Monopoly Story', 'year': 2010}
# {'title': 'Moonshot', 'year': 2009}
# {'title': 'Bunny and the Bull', 'year': 2009}
# {'title': 'Camp Rock 2: The Final Jam', 'year': 2010}
# {'title': 'Ajab Prem Ki Ghazab Kahani', 'year': 2009}
# {'title': 'North', 'year': 2009}
# {'title': '300: Rise of an Empire', 'year': 2014}
# {'title': 'Immortals', 'year': 2011}
# {'title': 'Splinterheads', 'year': 2009}
# {'title': 'De Dana Dan', 'year': 2009}
# {'title': 'Incendies', 'year': 2010}
# {'title': 'Men in the City', 'year': 2009}
# {'title': 'Hadewijch', 'year': 2009}
# {'title': 'Army of Crime', 'year': 2009}
# {'title': 'Father and Guns', 'year': 2009}
# {'title': 'A Matter of Size', 'year': 2009}
# {'title': "Je l'aimais", 'year': 2009}
# {'title': 'Scooby-Doo! The Mystery Begins', 'year': 2009}
# {'title': 'Hello Lonesome', 'year': 2010}
# {'title': 'The Man with the Iron Fists', 'year': 2012}
# {'title': 'SoulBoy', 'year': 2010}
# {'title': 'The Cabin in the Woods', 'year': 2012}
# {'title': 'Bon appètit', 'year': 2010}
# {'title': 'The Twilight Saga: New Moon', 'year': 2009}
# {'title': 'Dark House', 'year': 2009}
# {'title': 'The Scenesters', 'year': 2009}
# {'title': "Giulia Doesn't Date at Night", 'year': 2009}
# {'title': 'Questione di cuore', 'year': 2009}
# {'title': 'El Estudiante', 'year': 2009}
# {'title': 'Gulaal', 'year': 2009}
# {'title': 'Take Me Home', 'year': 2011}
# {'title': 'Sex and the City 2', 'year': 2010}
# {'title': 'Pig', 'year': 2011}
# {'title': 'Face', 'year': 2009}
# {'title': 'Scream 4', 'year': 2011}
# {'title': 'A Small Act', 'year': 2010}
# {'title': "World's Greatest Dad", 'year': 2009}
# {'title': 'Crazy Heart', 'year': 2009}
# {'title': 'Knights of Bloodsteel', 'year': 2009}
# {'title': 'Little Nicholas', 'year': 2009}
# {'title': 'The Roommate', 'year': 2011}
# {'title': 'Nowhere Boy', 'year': 2009}
# {'title': 'Afro Samurai: Resurrection', 'year': 2009}
# {'title': 'Quartier lointain', 'year': 2010}
# {'title': 'Hercules', 'year': 2014}
# {'title': 'The Friends at the Margherita Cafe', 'year': 2009}
# {'title': 'Waste Land', 'year': 2010}
# {'title': 'Night of the Demons', 'year': 2009}
# {'title': 'A Very Harold & Kumar 3D Christmas', 'year': 2011}
# {'title': 'The Last Rites of Ransom Pride', 'year': 2010}
# {'title': 'The Unloved', 'year': 2009}
# {'title': 'Love Takes Wing', 'year': 2009}
# {'title': 'Dark Frontier', 'year': 2009}
# {'title': 'Angel of Death', 'year': 2009}
# {'title': 'Mein Leben - Marcel Reich-Ranicki', 'year': 2009}
# {'title': 'Transfer', 'year': 2010}
# {'title': 'Saints and Soldiers: The Void', 'year': 2014}
# {'title': "The Devil's Double", 'year': 2011}
# {'title': 'To Save a Life', 'year': 2009}
# {'title': 'Sympathy for Delicious', 'year': 2010}
# {'title': "Don't Be Afraid of the Dark", 'year': 2010}
# {'title': 'X-Men: First Class', 'year': 2011}
# {'title': 'Hatchet II', 'year': 2010}
# {'title': 'The Waiting City', 'year': 2009}
# {'title': 'Deliver Us from Evil', 'year': 2009}
# {'title': 'Besa', 'year': 2009}
# {'title': 'Brain Drain', 'year': 2009}
# {'title': 'Generazione mille euro', 'year': 2009}
# {'title': 'My Queen Karo', 'year': 2009}
# {'title': '2 Guns', 'year': 2013}
# {'title': 'Small Apartments', 'year': 2012}
# {'title': 'Deadheads', 'year': 2011}
# {'title': 'Brotherhood', 'year': 2010}
# {'title': 'The Spy Next Door', 'year': 2010}
# {'title': 'Listen to Your Heart', 'year': 2010}
# {'title': 'Woochi', 'year': 2009}
# {'title': 'The Tempest', 'year': 2010}
# {'title': 'Kaminey: The Scoundrels', 'year': 2009}
# {'title': 'USS Seaviper', 'year': 2012}
# {'title': 'Father', 'year': 2010}
# {'title': 'The Mosquito Net', 'year': 2010}
# {'title': 'Questo piccolo grande amore', 'year': 2009}
# {'title': 'Under the Mountain', 'year': 2009}
# {'title': 'Like You Know It All', 'year': 2009}
# {'title': 'Help Gone Mad', 'year': 2009}
# {'title': 'Looper', 'year': 2012}
# {'title': 'Charlie & Boots', 'year': 2009}
# {'title': 'Who Killed Chea Vichea?', 'year': 2011}
# {'title': 'A Royal Affair', 'year': 2012}
# {'title': 'How to Make Money Selling Drugs', 'year': 2012}
# {'title': "Madagascar 3: Europe's Most Wanted", 'year': 2012}
# {'title': 'In Therapy', 'year': 2009}
# {'title': 'Jack Goes Boating', 'year': 2010}
# {'title': 'Sound of Noise', 'year': 2010}
# {'title': 'Temple Grandin', 'year': 2010}
# {'title': 'Zombie Girl: The Movie', 'year': 2009}
# {'title': 'Date Night', 'year': 2010}
# {'title': 'Smash His Camera', 'year': 2010}
# {'title': "Anton Chekhov's The Duel", 'year': 2010}
# {'title': 'Fort McCoy', 'year': 2011}
# {'title': 'Easy A', 'year': 2010}
# {'title': 'Sweet Evil', 'year': 2010}
# {'title': 'Bad Teacher', 'year': 2011}
# {'title': 'The Social Network', 'year': 2010}
# {'title': 'Due partite', 'year': 2009}
# {'title': 'Lahore', 'year': 2010}
# {'title': 'Mademoiselle Chambon', 'year': 2009}
# {'title': 'The Joneses', 'year': 2009}
# {'title': 'Battlestar Galactica: The Plan', 'year': 2009}
# {'title': '1981', 'year': 2009}
# {'title': 'I taket lyser stjèrnorna', 'year': 2009}
# {'title': 'Dossier K.', 'year': 2009}
# {'title': 'Cats & Dogs: The Revenge of Kitty Galore', 'year': 2010}
# {'title': 'A Brand New Life', 'year': 2009}
# {'title': 'Evil Dead', 'year': 2013}
# {'title': 'Hangtime', 'year': 2009}
# {'title': 'Shank', 'year': 2009}
# {'title': 'Guts', 'year': 2009}
# {'title': 'The Forbidden Door', 'year': 2009}
# {'title': 'Harry Brown', 'year': 2009}
# {'title': 'Me Too', 'year': 2009}
# {'title': 'Lebanon, Pa.', 'year': 2010}
# {'title': 'Au revoir Taipei', 'year': 2010}
# {'title': 'Teenage Mutant Ninja Turtles', 'year': 2014}
# {'title': 'Raajneeti', 'year': 2010}
# {'title': 'Meet Monica Velour', 'year': 2010}
# {'title': 'Tomorrow at Dawn', 'year': 2009}
# {'title': 'Behind the Candelabra', 'year': 2013}
# {'title': 'Warrior', 'year': 2011}
# {'title': 'Easy Money', 'year': 2010}
# {'title': 'Railways', 'year': 2010}
# {'title': 'Plastic Planet', 'year': 2009}
# {'title': 'Artois the Goat', 'year': 2009}
# {'title': 'Accomplices', 'year': 2009}
# {'title': 'Casting By', 'year': 2012}
# {'title': 'Solitary Man', 'year': 2009}
# {'title': 'Shit Year', 'year': 2010}
# {'title': 'The Last Song', 'year': 2010}
# {'title': 'Last Night', 'year': 2010}
# {'title': 'The Trotsky', 'year': 2009}
# {'title': 'Gifted Hands: The Ben Carson Story', 'year': 2009}
# {'title': 'Sennentuntschi: Curse of the Alps', 'year': 2010}
# {'title': 'The FP', 'year': 2011}
# {'title': 'Sons of Perdition', 'year': 2010}
# {'title': 'Waiting for Forever', 'year': 2010}
# {'title': 'Wake Wood', 'year': 2010}
# {'title': 'Salvage', 'year': 2009}
# {'title': "Berlin '36", 'year': 2009}
# {'title': 'Animals', 'year': 2012}
# {'title': 'Eva', 'year': 2011}
# {'title': 'The Presence', 'year': 2010}
# {'title': 'The Watch', 'year': 2012}
# {'title': 'Pirates of the Caribbean: On Stranger Tides', 'year': 2011}
# {'title': 'Oldboys', 'year': 2009}
# {'title': 'Alabama Moon', 'year': 2009}
# {'title': 'The Age of Stupid', 'year': 2009}
# {'title': 'Iron Man 3', 'year': 2013}
# {'title': 'Harvest', 'year': 2010}
# {'title': 'Kung Fu Panda 2', 'year': 2011}
# {'title': 'Yogi Bear', 'year': 2010}
# {'title': 'Diverted', 'year': 2009}
# {'title': 'Defendor', 'year': 2009}
# {'title': "Sophie's Revenge", 'year': 2009}
# {'title': 'Our Family Wedding', 'year': 2010}
# {'title': 'Mars Needs Moms', 'year': 2011}
# {'title': 'Fred & Vinnie', 'year': 2011}
# {'title': 'Make the Yuletide Gay', 'year': 2009}
# {'title': 'Enthiran', 'year': 2010}
# {'title': 'The Secret in Their Eyes', 'year': 2009}
# {'title': 'Ingrid', 'year': 2009}
# {'title': '50/50', 'year': 2011}
# {'title': 'Seeking a Friend for the End of the World', 'year': 2012}
# {'title': 'All Stars 2: Old Stars', 'year': 2011}
# {'title': 'Turn the Beat Around', 'year': 2010}
# {'title': 'Go for It!', 'year': 2011}
# {'title': 'Mulan: Rise of a Warrior', 'year': 2009}
# {'title': 'Bullet to the Head', 'year': 2012}
# {'title': "Don't Stop Believin': Everyman's Journey", 'year': 2012}
# {'title': 'Our Grand Despair', 'year': 2011}
# {'title': 'Sam', 'year': 2015}
# {'title': 'Halloween II', 'year': 2009}
# {'title': 'Kill Your Darlings', 'year': 2013}
# {'title': 'A.C.O.D.', 'year': 2013}
# {'title': 'The Scientist', 'year': 2010}
# {'title': 'The Human Resources Manager', 'year': 2010}
# {'title': 'Skateland', 'year': 2010}
# {'title': 'Animal Kingdom', 'year': 2010}
# {'title': 'The Cove', 'year': 2009}
# {'title': 'The Invisible Eye', 'year': 2010}
# {'title': '3 Backyards', 'year': 2010}
# {'title': 'Did You Hear About the Morgans?', 'year': 2009}
# {'title': 'The French Kissers', 'year': 2009}
# {'title': 'Applause', 'year': 2009}
# {'title': 'Welcome', 'year': 2009}
# {'title': 'Oto-na-ri', 'year': 2009}
# {'title': 'Devil', 'year': 2010}
# {'title': 'Small Island', 'year': 2009}
# {'title': 'Cherry', 'year': 2010}
# {'title': 'A Single Man', 'year': 2009}
# {'title': 'The Loved Ones', 'year': 2009}
# {'title': 'There Be Dragons', 'year': 2011}
# {'title': 'Handsome Harry', 'year': 2009}
# {'title': 'Altiplano', 'year': 2009}
# {'title': 'Just Between Us', 'year': 2010}
# {'title': 'Hierro', 'year': 2009}
# {'title': 'Rise of the Planet of the Apes', 'year': 2011}
# {'title': 'Chatroom', 'year': 2010}
# {'title': "It's a Wonderful Afterlife", 'year': 2010}
# {'title': 'A Little Help', 'year': 2010}
# {'title': 'The Most Dangerous Man in America: Daniel Ellsberg and the Pentagon '
#           'Papers',
#  'year': 2009}
# {'title': 'The Concert', 'year': 2009}
# {'title': 'The Last Exorcism', 'year': 2010}
# {'title': 'The Expendables', 'year': 2010}
# {'title': "Gulliver's Travels", 'year': 2010}
# {'title': '30 Days of Night: Dark Days', 'year': 2010}
# {'title': 'Nothing Personal', 'year': 2009}
# {'title': 'Oldboy', 'year': 2013}
# {'title': 'Death at a Funeral', 'year': 2010}
# {'title': 'Gangster Squad', 'year': 2013}
# {'title': 'Oldboy', 'year': 2013}
# {'title': 'The Beaver', 'year': 2011}
# {'title': 'The Dry Land', 'year': 2010}
# {'title': 'August: Osage County', 'year': 2013}
# {'title': 'The Assailant', 'year': 2009}
# {'title': 'Sunshine Superman', 'year': 2014}
# {'title': 'Headhunter', 'year': 2009}
# {'title': 'The Burma Conspiracy', 'year': 2011}
# {'title': 'Miss Kicki', 'year': 2009}
# {'title': 'Submarino', 'year': 2010}
# {'title': 'Frozen', 'year': 2010}
# ...
# {'title': 'The Great Hypnotist', 'year': 2014}
# {'title': '3 AM: A Paranormal Experience', 'year': 2014}
# {'title': 'Das Ende der Geduld', 'year': 2014}
# {'title': 'The Disappearance of Eleanor Rigby: Her', 'year': 2013}
# {'title': 'Requisitos para ser una persona normal', 'year': 2015}
# {'title': 'One Christmas Eve', 'year': 2014}
# {'title': 'Die Fischerin', 'year': 2014}
# {'title': 'Last Chance', 'year': 2014}
# {'title': "Ava's Possessions", 'year': 2015}
# {'title': 'The Disappearance of Eleanor Rigby: Them', 'year': 2014}
# {'title': 'Sailing to Paradise', 'year': 2014}
# {'title': 'Hill of Freedom', 'year': 2014}
# {'title': 'Body', 'year': 2015}
# {'title': 'A Brave Heart: The Lizzie Velasquez Story', 'year': 2015}
# {'title': 'Latin Lover', 'year': 2015}
# {'title': 'Tetarti 04:45', 'year': 2015}
# {'title': 'Mountains May Depart', 'year': 2015}
# {'title': 'The Second Mother', 'year': 2015}
# {'title': 'Bogowie', 'year': 2014}
# {'title': 'Sherpa', 'year': 2015}
# {'title': 'Hitchcock/Truffaut', 'year': 2015}
# {'title': 'Flocken', 'year': 2015}
# {'title': 'Wire Cutters', 'year': 2014}
# {'title': 'Whitney', 'year': 2015}
# {'title': 'Self Made', 'year': 2014}
# {'title': 'Elephant Song', 'year': 2014}
# {'title': 'Our Little Sister', 'year': 2015}
# {'title': 'Asterix and Obelix: Mansion of the Gods', 'year': 2014}
# {'title': 'Summer Nights', 'year': 2014}
# {'title': "Warsaw '44", 'year': 2014}
# {'title': 'Hello, My Name Is Doris', 'year': 2015}
# {'title': 'Iron Ivan', 'year': 2014}
# {'title': 'Love', 'year': 2015}
# {'title': 'Ashby', 'year': 2015}
# {'title': 'Afterlife', 'year': 2014}
# {'title': 'Sindrom Petrushki', 'year': 2015}
# {'title': 'Cherry Tobacco', 'year': 2014}
# {'title': 'Wir sind die Neuen', 'year': 2014}
# {'title': 'Sleeping Giant', 'year': 2015}
# {'title': 'War Pigs', 'year': 2015}
# {'title': "I'm the One You Want", 'year': 2014}
# {'title': 'Cèdigo Paz', 'year': 2014}
# {'title': 'Valley Uprising', 'year': 2014}
# {'title': 'Paulina', 'year': 2015}
# {'title': 'Corner Gas: The Movie', 'year': 2014}
# {'title': 'The Swimmers', 'year': 2014}
# {'title': 'The Brand New Testament', 'year': 2015}
# {'title': 'The Escort', 'year': 2015}
# {'title': 'Roar', 'year': 2014}
# {'title': 'Chronicle of a Blood Merchant', 'year': 2015}
# {'title': 'Brand: A Second Coming', 'year': 2015}
# {'title': '6 Years', 'year': 2015}
# {'title': 'Drone', 'year': 2014}
# {'title': 'Son of Saul', 'year': 2015}
# {'title': 'Noi e la Giulia', 'year': 2015}
# {'title': 'Ode to My Father', 'year': 2014}
# {'title': 'Cop Car', 'year': 2015}
# {'title': 'Bloed, Zweet & Tranen', 'year': 2015}
# {'title': 'A Blast', 'year': 2014}
# {'title': 'The Unauthorized Saved by the Bell Story', 'year': 2014}
# {'title': 'The Girl Who Talked to Dolphins', 'year': 2014}
# {'title': 'Naked Among Wolves', 'year': 2015}
# {'title': 'Monster High: Freaky Fusion', 'year': 2014}
# {'title': 'Lava', 'year': 2014}
# {'title': 'Results', 'year': 2015}
# {'title': 'Tangerine', 'year': 2015}
# {'title': 'Labyrinth of Lies', 'year': 2014}
# {'title': 'Scusate se esisto!', 'year': 2014}
# {'title': 'The Tree', 'year': 2014}
# {'title': 'A War', 'year': 2015}
# {'title': 'The Visit', 'year': 2015}
# {'title': 'Ratter', 'year': 2015}
# {'title': 'Thread of Lies', 'year': 2013}
# {'title': 'Bang Gang (A Modern Love Story)', 'year': 2015}
# {'title': 'Felices 140', 'year': 2015}
# {'title': 'The Overnight', 'year': 2015}
# {'title': 'Dope', 'year': 2015}
# {'title': 'Chronic', 'year': 2015}
# {'title': 'Homies', 'year': 2015}
# {'title': 'Assassination Classroom', 'year': 2015}
# {'title': 'Clean Hands', 'year': 2015}
# {'title': 'A Fool', 'year': 2014}
# {'title': 'Mune, le gardien de la lune', 'year': 2014}
# {'title': 'The Bronze', 'year': 2015}
# {'title': 'Ogni maledetto Natale', 'year': 2014}
# {'title': 'Tiny Times 3.0', 'year': 2014}
# {'title': 'King Jack', 'year': 2015}
# {'title': 'My Lonely Me', 'year': 2015}
# {'title': '11 Minutes', 'year': 2015}
# {'title': 'The Missing', 'year': 2014}
# {'title': 'Men & Chicken', 'year': 2015}
# {'title': 'Tokyo Fiancèe', 'year': 2014}
# {'title': 'Kept Woman', 'year': 2015}
# {'title': 'Batkid Begins', 'year': 2015}
# {'title': 'Chuang ru zhe', 'year': 2014}
# {'title': 'Sonyeogoedam', 'year': 2014}
# {'title': 'Fires on the Plain', 'year': 2014}
# {'title': 'That Sugar Film', 'year': 2014}
# {'title': 'The State-Mafia Pact', 'year': 2014}
# {'title': 'Christmas, Again', 'year': 2014}
# {'title': 'Black Souls', 'year': 2014}
# {'title': 'The Continent', 'year': 2014}
# {'title': 'Gayby Baby', 'year': 2015}
# {'title': 'Those People', 'year': 2015}
# {'title': 'Call Me Lucky', 'year': 2015}
# {'title': 'Loreak', 'year': 2014}
# {'title': 'The Birth of Sakè', 'year': 2015}
# {'title': 'Tales of the Grim Sleeper', 'year': 2014}
# {'title': 'The Princess of France', 'year': 2014}
# {'title': 'August Winds', 'year': 2014}
# {'title': 'Songs from the North', 'year': 2014}
# {'title': 'Salad Days', 'year': 2014}
# {'title': 'But Always', 'year': 2014}
# {'title': 'Horse Money', 'year': 2014}
# {'title': 'The Iron Ministry', 'year': 2014}
# {'title': 'Remake, Remix, Rip-Off: About Copy Culture & Turkish Pop Cinema',
#  'year': 2014}
# {'title': 'Si accettano miracoli', 'year': 2015}
# {'title': 'Sei mai stata sulla luna?', 'year': 2015}
# {'title': 'From Caligari to Hitler: German Cinema in the Age of the Masses',
#  'year': 2014}
# {'title': 'Lamb', 'year': 2015}
# {'title': 'With This Ring', 'year': 2015}
# {'title': 'Iron Man and Captain America: Heroes United', 'year': 2014}
# {'title': 'Hector', 'year': 2015}
# {'title': 'Pokèmon the Movie: Diancie and the Cocoon of Destruction',
#  'year': 2014}
# {'title': 'Bill Maher: Live from D.C.', 'year': 2014}
# {'title': 'Scooby-Doo! Frankencreepy', 'year': 2014}
# {'title': 'Butterfly', 'year': 2015}
# {'title': 'The Price We Pay', 'year': 2014}
# {'title': 'Out of My Hand', 'year': 2015}
# {'title': 'The Daughter', 'year': 2015}
# {'title': 'OzLand', 'year': 2015}
# {'title': 'Zvezda', 'year': 2014}
# {'title': 'Corbo', 'year': 2014}
# {'title': 'The Taking of Tiger Mountain', 'year': 2014}
# {'title': 'Scherzo Diabolico', 'year': 2015}
# {'title': 'A Country Called Home', 'year': 2015}
# {'title': 'My Old Classmate', 'year': 2014}
# {'title': 'Confession', 'year': 2014}
# {'title': 'Along Came a Nanny', 'year': 2014}
# {'title': 'In the Basement', 'year': 2014}
# {'title': 'Welcome to Leith', 'year': 2015}
# {'title': "We Can't Live Without Cosmos", 'year': 2014}
# {'title': 'Mustang', 'year': 2015}
# {'title': 'The President', 'year': 2014}
# {'title': 'From Caligari to Hitler: German Cinema in the Age of the Masses',
#  'year': 2014}
# {'title': 'The Perfect Dictatorship', 'year': 2014}
# {'title': 'Peter Pan Live!', 'year': 2014}
# {'title': 'Kaakkaa Muttai', 'year': 2014}
# {'title': 'Cafè. Waiting. Love', 'year': 2014}
# {'title': 'One and Two', 'year': 2015}
# {'title': 'Jackrabbit', 'year': 2015}
# {'title': 'Fourth Man Out', 'year': 2015}
# {'title': 'Aanmodderfakker', 'year': 2014}
# {'title': 'Capital C', 'year': 2014}
# {'title': 'III', 'year': 2015}
# {'title': 'Queen of Earth', 'year': 2015}
# {'title': "What's Between Us", 'year': 2015}
# {'title': 'Do I Sound Gay?', 'year': 2014}
# {'title': 'Foreign Body', 'year': 2014}
# {'title': 'Looking for Grace', 'year': 2015}
# {'title': 'Tom and Jerry: The Lost Dragon', 'year': 2014}
# {'title': 'Terror at the Mall', 'year': 2014}
# {'title': 'Hockney', 'year': 2014}
# {'title': 'I Am Ali', 'year': 2014}
# {'title': 'Shut In', 'year': 2015}
# {'title': 'Saving Christmas', 'year': 2014}
# {'title': 'Xiu chun dao', 'year': 2014}
# {'title': 'The Royal Tailor', 'year': 2014}
# {'title': 'Home Care', 'year': 2015}
# {'title': 'Underdog', 'year': 2014}
# {'title': 'Radiator', 'year': 2014}
# {'title': 'Bag Man', 'year': 2014}
# {'title': 'The Man in the Wall', 'year': 2015}
# {'title': 'Whistle Blower', 'year': 2014}
# {'title': 'Cosmos', 'year': 2015}
# {'title': 'Gold Coast', 'year': 2015}
# {'title': 'Citizenfour', 'year': 2014}
# {'title': 'Fiddlesticks', 'year': 2014}
# {'title': 'Encounters', 'year': 2014}
# {'title': 'My Golden Days', 'year': 2015}
# {'title': 'The Chinese Mayor', 'year': 2015}
# {'title': "India's Daughter", 'year': 2015}
# {'title': 'Green Room', 'year': 2015}
# {'title': "My Love, Don't Cross That River", 'year': 2014}
# {'title': 'Andiamo a quel paese', 'year': 2014}
# {'title': 'Best Christmas Party Ever', 'year': 2014}
# {'title': 'Killswitch', 'year': 2014}
# {'title': 'Pervert Park', 'year': 2014}
# {'title': "Dark Star: H.R. Giger's World", 'year': 2014}
# {'title': 'Cemetery of Splendour', 'year': 2015}
# {'title': 'Somewhere Only We Know', 'year': 2015}
# {'title': 'We Are Young. We Are Strong.', 'year': 2014}
# {'title': 'Life Is Sacred', 'year': 2014}
# {'title': 'Being Evel', 'year': 2015}
# {'title': 'Peace Officer', 'year': 2015}
# {'title': 'Dheepan', 'year': 2015}
# {'title': 'The Russian Woodpecker', 'year': 2015}
# {'title': 'Bitva za Sevastopol', 'year': 2015}
# {'title': 'Disorder', 'year': 2015}
# {'title': 'Frankenstein', 'year': 2015}
# {'title': 'Dhanak', 'year': 2015}
# {'title': 'Packed In A Trunk: The Lost Art of Edith Lake Wilkinson',
#  'year': 2015}
# {'title': 'My Skinny Sister', 'year': 2015}
# {'title': 'Beyond the Fear', 'year': 2015}
# {'title': 'In the Grayscale', 'year': 2015}
# {'title': 'Dream Driven', 'year': 2014}
# {'title': 'People Places Things', 'year': 2015}
# {'title': 'War', 'year': 2014}
# {'title': 'They Look Like People', 'year': 2015}
# {'title': 'Miedzy nami dobrze jest', 'year': 2014}
# {'title': 'Whisper If I Forget', 'year': 2014}
# {'title': 'Those Who Feel the Fire Burning', 'year': 2014}
# {'title': 'Solnechnyy udar', 'year': 2014}
# {'title': '1989', 'year': 2014}
# {'title': 'Valley of Love', 'year': 2015}
# {'title': 'Day One', 'year': 2015}
# {'title': 'For Grace', 'year': 2015}
# {'title': 'Cartel Land', 'year': 2015}
# {'title': '3 1/2 Minutes, Ten Bullets', 'year': 2015}
# {'title': 'Ambition', 'year': 2014}
# {'title': 'Lucifer', 'year': 2014}
# {'title': 'Test', 'year': 2014}
# {'title': 'Tired Moonlight', 'year': 2015}
# {'title': 'The Seven Five', 'year': 2014}
# {'title': 'Ixcanul Volcano', 'year': 2015}
# {'title': 'Magician: The Astonishing Life and Work of Orson Welles',
#  'year': 2014}
# {'title': 'Dark Horse', 'year': 2015}
# {'title': 'Italiano medio', 'year': 2015}
# {'title': 'How to Change the World', 'year': 2015}
# {'title': 'Listen to Me Marlon', 'year': 2015}
# {'title': 'Unexpected', 'year': 2015}
# {'title': 'Crush the Skull', 'year': 2015}
# {'title': 'The Here After', 'year': 2015}
# {'title': 'Iris', 'year': 2014}
# {'title': 'Olmo & the Seagull', 'year': 2014}
# {'title': 'Prince', 'year': 2015}
# {'title': 'Angels of Revolution', 'year': 2014}
# {'title': 'Homme Less', 'year': 2014}
# {'title': 'That Thing Called Tadhana', 'year': 2014}
# {'title': 'World of Tomorrow', 'year': 2015}
# {'title': 'Journey to the Shore', 'year': 2015}
# {'title': 'Two Friends', 'year': 2015}
# {'title': 'Bridgend', 'year': 2015}
# {'title': 'The Hunting Ground', 'year': 2015}
# {'title': 'The Ecstasy of Wilko Johnson', 'year': 2015}
# {'title': 'Thank You for Playing', 'year': 2015}
# {'title': 'Limonata', 'year': 2015}
# {'title': 'Socialphobia', 'year': 2014}
# {'title': 'Elizabeth Ekadashi', 'year': 2014}
# {'title': 'Boj za', 'year': 2014}
# {'title': 'Western', 'year': 2015}
# {'title': 'The Shaman', 'year': 2015}
# {'title': 'Courted', 'year': 2015}
# {'title': 'Frau Mèller muss weg!', 'year': 2015}
# {'title': 'Top Spin', 'year': 2014}
# {'title': 'TransFatty Lives', 'year': 2015}
# {'title': 'Black Mountain Poets', 'year': 2015}
# {'title': 'Victoria', 'year': 2015}
# {'title': 'Uncle Kent 2', 'year': 2015}
# {'title': 'Les cowboys', 'year': 2015}
# {'title': 'Zid', 'year': 2014}
# {'title': 'Cobain: Montage of Heck', 'year': 2015}
# {'title': 'Tanna', 'year': 2015}
# {'title': 'Forever', 'year': 2014}
# {'title': 'Tyke Elephant Outlaw', 'year': 2015}
# {'title': 'In Transit', 'year': 2015}
# {'title': 'The Witch', 'year': 2015}
# {'title': 'Krisha', 'year': 2015}
# {'title': 'Most Likely to Succeed', 'year': 2015}
# {'title': 'Applesauce', 'year': 2015}
# {'title': 'Caught', 'year': 2015}
# {'title': 'The Boy and the Beast', 'year': 2015}
# {'title': 'Breaking a Monster', 'year': 2015}
# {'title': 'Under Electric Clouds', 'year': 2015}
# {'title': 'Embrace of the Serpent', 'year': 2015}
# {'title': 'White Out, Black In', 'year': 2015}
# {'title': 'James White', 'year': 2015}
# {'title': 'B-Movie: Lust & Sound in West-Berlin 1979-1989', 'year': 2015}
# {'title': 'Evolution', 'year': 2015}
# {'title': 'Genetic Me', 'year': 2014}
# {'title': 'An', 'year': 2015}
# {'title': 'The Jinx: The Life and Deaths of Robert Durst', 'year': 2015}
# {'title': 'Insanity', 'year': 2014}
# {'title': 'Ivy', 'year': 2015}
# {'title': 'Ch/B', 'year': 2014}
# {'title': 'The Black Panthers: Vanguard of the Revolution', 'year': 2015}
# {'title': "It's Me, Hilary: The Man Who Drew Eloise", 'year': 2015}
# {'title': 'Larry Kramer in Love and Anger', 'year': 2015}
# {'title': 'Carte Blanche', 'year': 2015}
# {'title': 'The Mysterious Death of Pèrola', 'year': 2014}
# {'title': 'Frame by Frame', 'year': 2015}
# {'title': 'The Break-In', 'year': 2015}
# {'title': 'Live from New York!', 'year': 2015}
# {'title': 'Body', 'year': 2015}
# {'title': 'Taxi', 'year': 2015}
# {'title': 'Crumbs', 'year': 2015}
# {'title': 'Petting Zoo', 'year': 2015}
# {'title': 'Louis C.K.: Live at the Comedy Store', 'year': 2015}
# {'title': 'How to Win at Checkers (Every Time)', 'year': 2015}
# {'title': '(T)ERROR', 'year': 2015}
# {'title': 'Aferim!', 'year': 2015}
# {'title': 'The Club', 'year': 2015}
# {'title': 'The Pearl Button', 'year': 2015}
# {'title': 'Hot Girls Wanted', 'year': 2015}
# {'title': 'Pionery-geroi', 'year': 2015}
# {'title': 'Adam Curtis: Bitter Lake', 'year': 2015}
# {'title': 'Everything Before Us', 'year': 2015}
# {'title': 'The Clan', 'year': 2015}
# {'title': 'Homeland (Iraq Year Zero)', 'year': 2015}
# {'title': 'Port of Call', 'year': 2015}
# {'title': 'Ave Maria', 'year': 2015}
# {'title': 'The Wakhan Front', 'year': 2015}
# {'title': 'Marguerite & Julien', 'year': 2015}
# {'title': 'Marguerite', 'year': 2015}
# {'title': 'The Measure of a Man', 'year': 2015}
# {'title': 'Dègradè', 'year': 2015}
# {'title': 'Song of Lahore', 'year': 2015}
# {'title': 'The Corpse of Anna Fritz', 'year': 2015}
# {'title': 'Ayanda and the Mechanic', 'year': 2015}
# {'title': 'Ice and the Sky', 'year': 2015}
# {'title': 'Tikkun', 'year': 2015}
# {'title': 'Tom Swift and His Electric Rifle', 'year': 2015}
# {'title': 'Emelie', 'year': 2015}
# {'title': 'Thought Crimes: The Case of the Cannibal Cop', 'year': 2015}
# {'title': 'The Treasure', 'year': 2015}
# {'title': 'Hallway', 'year': 2015}
# {'title': 'The Blue Hour', 'year': 2015}
# {'title': 'Viaje', 'year': 2015}
# {'title': 'Les oiseaux de passage', 'year': 2015}
# {'title': 'Jeruzalem', 'year': 2015}
# {'title': 'Un monstruo de mil cabezas', 'year': 2015}
# {'title': 'Ho ucciso Napoleone', 'year': 2015}
# {'title': 'Techo y comida', 'year': 2015}
# {'title': 'The High Sun', 'year': 2015}
# {'title': "Dennis Rodman's Big Bang in PyongYang", 'year': 2015}
# {'title': 'Men Go to Battle', 'year': 2015}
# {'title': 'The Other Side', 'year': 2015}
# {'title': 'Kaili Blues', 'year': 2015}
# {'title': 'One Floor Below', 'year': 2015}
# {'title': 'Ingrid Bergman in Her Own Words', 'year': 2015}
# {'title': 'Fly Away Solo', 'year': 2015}
# {'title': 'Nahid', 'year': 2015}
# {'title': 'Manoman', 'year': 2015}
# {'title': 'Se Dio vuole', 'year': 2015}
# {'title': 'Monkey King: Hero Is Back', 'year': 2015}
# {'title': 'Coin Locker Girl', 'year': 2015}
# {'title': 'Bitcoin: The End of Money as We Know It', 'year': 2015}
# {'title': 'Land and Shade', 'year': 2015}
# {'title': 'A Sinner in Mecca', 'year': 2015}
# {'title': 'Very Semi-Serious', 'year': 2015}
# {'title': 'Office', 'year': 2015}
# {'title': 'Much Loved', 'year': 2015}
# {'title': 'The Magic Mountain', 'year': 2015}
# {'title': 'Alice in Earnestland', 'year': 2015}
# {'title': 'Heil', 'year': 2015}
# {'title': 'Desde allè', 'year': 2015}
# {'title': 'Babai', 'year': 2015}
# {'title': 'Paren s nashego kladbishcha', 'year': 2015}
# {'title': 'Tryapichnyy soyuz', 'year': 2015}
# {'title': 'Right Now, Wrong Then', 'year': 2015}
# {'title': 'The Laundryman', 'year': 2015}
# {'title': 'The Red Spider', 'year': 2015}
# {'title': 'Our Loved Ones', 'year': 2015}
# {'title': 'No Home Movie', 'year': 2015}

# %%
query = { "directors" : {"$exists" : False}} # No tienen director informado.. "exists" ES UN OPERADOR QUE SE UTILIZA PARA FILTRAR LA EXISTENCIA DE UN CAMPO 

proyeccion = {"_id": 0, "title" : True, "year": 1, "directors" : True}

for movie in movies.find(query, proyeccion):
    pprint(movie)
# Out:
# {'title': 'The Forsyte Saga', 'year': 1967}
# {'title': 'Scenes from a Marriage', 'year': 1973}
# {'title': 'Ironiya sudby, ili S legkim parom!', 'year': 1975}
# {'title': 'Sybil', 'year': 1976}
# {'title': 'Jesus of Nazareth', 'year': 1977}
# {'title': 'Roots', 'year': 1977}
# {'title': 'Centennial', 'year': 1978}
# {'title': 'Holocaust', 'year': 1978}
# {'title': 'Pennies from Heaven', 'year': 1978}
# {'title': 'Pride and Prejudice', 'year': 1980}
# {'title': 'Hollywood', 'year': 1980}
# {'title': 'Tinker Tailor Soldier Spy', 'year': 1979}
# {'title': 'Cosmos', 'year': 1980}
# {'title': 'The Hitch Hikers Guide to the Galaxy', 'year': '1981è'}
# {'title': 'The Blue and the Gray', 'year': 1982}
# {'title': "Smiley's People", 'year': 1982}
# {'title': 'Jane Eyre', 'year': 1983}
# {'title': 'Reilly: Ace of Spies', 'year': 1983}
# {'title': 'The Thorn Birds', 'year': 1983}
# {'title': 'The Barchester Chronicles', 'year': 1982}
# {'title': 'The Far Pavilions', 'year': 1984}
# {'title': 'The First Olympics: Athens 1896', 'year': 1984}
# {'title': 'V: The Final Battle', 'year': 1984}
# {'title': 'Heimat: A Chronicle of Germany', 'year': 1984}
# {'title': 'North and South', 'year': 1985}
# {'title': 'Space', 'year': 1985}
# {'title': 'Anne of Green Gables', 'year': 1985}
# {'title': 'Manuel on the Island of Wonders', 'year': 1984}
# {'title': 'A Little Princess', 'year': 1986}
# {'title': 'North and South, Book II', 'year': 1986}
# {'title': 'All Passion Spent', 'year': '1986è'}
# {'title': 'The Decalogue', 'year': 1989}
# {'title': 'The Storyteller', 'year': '1987è'}
# {'title': 'Anne of Avonlea', 'year': 1987}
# {'title': 'Out on a Limb', 'year': 1987}
# {'title': 'Jack the Ripper', 'year': '1988è'}
# {'title': 'Around the World in 80 Days', 'year': 1989}
# {'title': 'Bangkok Hilton', 'year': 1989}
# {'title': 'Lonesome Dove', 'year': 1989}
# {'title': 'The Civil War', 'year': 1990}
# {'title': 'Prime Suspect', 'year': 1991}
# {'title': 'Conspiracy of Silence', 'year': 1991}
# {'title': 'Prime Suspect 2', 'year': 1992}
# {'title': 'Babylon 5', 'year': '1994è1998'}
# {'title': 'Hotel Room', 'year': 1993}
# {'title': 'Return to Lonesome Dove', 'year': 1993}
# {'title': 'Prime Suspect 3', 'year': 1993}
# {'title': 'Wild Palms', 'year': 1993}
# {'title': 'Baseball', 'year': 1994}
# {'title': 'The Kingdom', 'year': 1994}
# {'title': 'Scarlett', 'year': 1994}
# {'title': 'Abraham', 'year': 1993}
# {'title': 'Macross Plus', 'year': 1994}
# {'title': 'Streets of Laredo', 'year': 1995}
# {'title': 'The Langoliers', 'year': 1995}
# {'title': 'Pride and Prejudice', 'year': 1995}
# {'title': "L'allèe du roi", 'year': 1996}
# {'title': "Gulliver's Travels", 'year': 1996}
# {'title': "Dead Man's Walk", 'year': 1996}
# {'title': 'Prime Suspect 5: Errors of Judgement', 'year': 1996}
# {'title': 'The Tenant of Wildfell Hall', 'year': 1996}
# {'title': 'Titanic', 'year': 1996}
# {'title': 'The West', 'year': '1996è'}
# {'title': 'Scarlett', 'year': 1994}
# {'title': 'The Odyssey', 'year': '1997è'}
# {'title': 'The Ice House', 'year': '1997è'}
# {'title': 'From the Earth to the Moon', 'year': 1998}
# {'title': 'The Private Life of Plants', 'year': '1995è'}
# {'title': 'The Kingdom', 'year': 1994}
# {'title': 'Storm of the Century', 'year': 1999}
# {'title': 'Eight Deadly Shots', 'year': 1972}
# {'title': 'Days of Hope', 'year': 1975}
# {'title': 'The Count of Monte Cristo', 'year': 1998}
# {'title': 'Arabian Nights', 'year': '2000è'}
# {'title': 'Band of Brothers', 'year': 2001}
# {'title': 'The First Olympics: Athens 1896', 'year': 1984}
# {'title': 'The Nazis: A Warning from History', 'year': 1997}
# {'title': 'Nuremberg', 'year': 2000}
# {'title': 'Jason and the Argonauts', 'year': 2000}
# {'title': 'New York: A Documentary Film', 'year': '1999è'}
# {'title': 'Jazz', 'year': 2001}
# {'title': 'Oliver Twist', 'year': 1999}
# {'title': 'Dinotopia', 'year': 2002}
# {'title': 'The Beach Boys: An American Family', 'year': 2000}
# {'title': 'The Civil War', 'year': 1990}
# {'title': 'Rose Red', 'year': 2002}
# {'title': 'Ostrov pogibshikh korabley', 'year': 1987}
# {'title': 'Do You Believe in Miracles? The Story of the 1980 U.S. Hockey Team',
#  'year': 2001}
# {'title': 'FLCL', 'year': 2000}
# {'title': 'Walking with Prehistoric Beasts', 'year': 2001}
# {'title': 'Taken', 'year': 2002}
# {'title': 'The Blue Planet', 'year': 2001}
# {'title': 'The Way We Live Now', 'year': 2001}
# {'title': 'Rose Red', 'year': 2002}
# {'title': 'Battlestar Galactica', 'year': 2003}
# {'title': 'Angels in America', 'year': 2003}
# {'title': 'Daniel Deronda', 'year': 2002}
# {'title': 'Tipping the Velvet', 'year': 2002}
# {'title': 'The Nazis: A Warning from History', 'year': 1997}
# {'title': 'Helen of Troy', 'year': 2003}
# {'title': 'Angels in America', 'year': 2003}
# {'title': 'Cambridge Spies', 'year': 2003}
# {'title': 'Hitler: The Rise of Evil', 'year': 2003}
# {'title': 'State of Play', 'year': 2003}
# {'title': 'Prime Suspect 6: The Last Witness', 'year': 2003}
# {'title': 'Idiot', 'year': 2003}
# {'title': 'Frankenstein', 'year': 2004}
# {'title': 'The Pacific', 'year': 2010}
# {'title': 'Empire Falls', 'year': 2005}
# {'title': 'Yukikaze', 'year': '2002è'}
# {'title': 'MythBusters', 'year': '2003è'}
# {'title': 'The Crimson Petal and the White', 'year': 2011}
# {'title': '5ive Days to Midnight', 'year': 2004}
# {'title': 'Farscape: The Peacekeeper Wars', 'year': 2004}
# {'title': 'Death on the Staircase', 'year': 2004}
# {'title': 'Island at War', 'year': 2004}
# {'title': 'Earthsea', 'year': 2004}
# {'title': 'Into the West', 'year': 2005}
# {'title': 'North & South', 'year': 2004}
# {'title': 'Fingersmith', 'year': 2005}
# {'title': 'The Andromeda Strain', 'year': 2008}
# {'title': 'We Can Be Heroes', 'year': '2005è'}
# {'title': 'Casanova', 'year': 2005}
# {'title': 'The Power of Nightmares: The Rise of the Politics of Fear',
#  'year': 2004}
# {'title': 'To the Ends of the Earth', 'year': 2005}
# {'title': 'Bleak House', 'year': 2005}
# {'title': 'Thief', 'year': 2006}
# {'title': 'Human Trafficking', 'year': 2005}
# {'title': 'Elizabeth I', 'year': 2005}
# {'title': 'John Adams', 'year': 2008}
# {'title': 'John Adams', 'year': 2008}
# {'title': 'Broken Trail', 'year': 2006}
# {'title': 'Walking with Monsters', 'year': '2005è'}
# {'title': 'H2O: Just Add Water', 'year': '2006è'}
# {'title': 'War and Peace', 'year': 2007}
# {'title': 'Hellsing Ultimate', 'year': '2006è2012'}
# {'title': 'Jekyll', 'year': 2007}
# {'title': 'Jane Eyre', 'year': 2006}
# {'title': 'Comanche Moon', 'year': 2008}
# {'title': 'When the Levees Broke: A Requiem in Four Acts', 'year': 2006}
# {'title': 'Planet Earth', 'year': 2006}
# {'title': 'Prime Suspect 7: The Final Act', 'year': 2006}
# {'title': 'Race to Mars', 'year': 2007}
# {'title': 'The Lost Room', 'year': 2006}
# {'title': 'Sense & Sensibility', 'year': 2008}
# {'title': 'Death Note', 'year': '2006è2007'}
# {'title': 'Wild China', 'year': 2008}
# {'title': 'Tin Man', 'year': 2007}
# {'title': 'Summer Heights High', 'year': '2007è'}
# {'title': 'Cranford', 'year': '2007è'}
# {'title': 'Generation Kill', 'year': 2008}
# {'title': 'The War', 'year': 2007}
# {'title': 'Hellsing Ultimate', 'year': '2006è2012'}
# {'title': 'Liquidation', 'year': '2007è'}
# {'title': 'Fanny Hill', 'year': 2007}
# {'title': 'Brooklyn Dodgers: The Ghosts of Flatbush', 'year': 2007}
# {'title': 'Serrallonga', 'year': 2008}
# {'title': 'The Capture of the Green River Killer', 'year': 2008}
# {'title': 'XIII: The Conspiracy', 'year': 2008}
# {'title': 'The Diary of Anne Frank', 'year': 2009}
# {'title': 'The Capture of the Green River Killer', 'year': 2008}
# {'title': 'Little Dorrit', 'year': 2008}
# {'title': "Tess of the D'Urbervilles", 'year': 2008}
# {'title': 'The Last Templar', 'year': 2009}
# {'title': 'Sea Wolf', 'year': 2009}
# {'title': 'Going Postal', 'year': 2010}
# {'title': 'Impact', 'year': 2009}
# {'title': "Dr. Horrible's Sing-Along Blog", 'year': 2008}
# {'title': 'Aftermath: Population Zero', 'year': 2008}
# {'title': 'Knights of Bloodsteel', 'year': 2009}
# {'title': 'Dead Set', 'year': 2008}
# {'title': 'Stephen Fry in America', 'year': 2008}
# {'title': '1066: The Battle for Middle Earth', 'year': 2009}
# {'title': 'The Day of the Triffids', 'year': 2009}
# {'title': 'The Pig Farm', 'year': 2011}
# {'title': 'Emma', 'year': 2009}
# {'title': 'The Take', 'year': 2009}
# {'title': 'Boys Over Flowers', 'year': '2009è'}
# {'title': 'Charles Darwin and the Tree of Life', 'year': 2009}
# {'title': "Nature's Most Amazing Events", 'year': 2009}
# {'title': 'The Phantom', 'year': 2009}
# {'title': 'The Pillars of the Earth', 'year': 2010}
# {'title': 'Alice', 'year': 2009}
# {'title': 'Falling Skies', 'year': '2011è'}
# {'title': 'WWII in HD', 'year': 2009}
# {'title': 'Mildred Pierce', 'year': 2011}
# {'title': 'The Sinking of the Laconia', 'year': 2010}
# {'title': 'Life', 'year': 2009}
# {'title': 'Latin Music USA', 'year': '2009è'}
# {'title': 'The Kennedys', 'year': 2011}
# {'title': "If God Is Willing and da Creek Don't Rise", 'year': '2010è'}
# {'title': "Stephen Hawking's Universe", 'year': '2010è'}
# {'title': 'Dreileben', 'year': 2011}
# {'title': 'Neverland', 'year': 2011}
# {'title': 'First Ascent', 'year': '2010è'}
# {'title': 'Great Migrations', 'year': 2010}
# {'title': 'Great Migrations', 'year': 2010}
# {'title': 'Human Planet', 'year': 2011}
# {'title': 'Appropriate Adult', 'year': 2011}
# {'title': 'Madagascar', 'year': 2011}
# {'title': 'Third Reich: The Rise & Fall', 'year': '2010è'}
# {'title': 'World Without End', 'year': 2012}
# {'title': 'Unsere Mètter, unsere Vèter', 'year': 2013}
# {'title': 'Prohibition', 'year': 2011}
# {'title': 'All Watched Over by Machines of Loving Grace', 'year': 2011}
# {'title': 'Hatfields & McCoys', 'year': 2012}
# {'title': 'Penance', 'year': '2012è'}
# {'title': 'The Story of Film: An Odyssey', 'year': 2011}
# {'title': 'Frozen Planet', 'year': 2011}
# {'title': 'Vietnam in HD', 'year': '2011è'}
# {'title': 'Dancing on the Edge', 'year': 2013}
# {'title': 'The Men Who Built America', 'year': 2012}
# {'title': 'Hit & Miss', 'year': '2012è'}
# {'title': 'Political Animals', 'year': 2012}
# {'title': 'The Bible', 'year': 2013}
# {'title': 'Halo 4: Forward Unto Dawn', 'year': 2012}
# {'title': 'The Hollow Crown', 'year': 2012}
# {'title': 'The Weight of the Nation', 'year': '2012è'}
# {'title': 'The Dust Bowl', 'year': 2012}
# {'title': 'The Casual Vacancy', 'year': 2015}
# {'title': 'The Escape Artist', 'year': 2013}
# {'title': 'Bonnie and Clyde', 'year': 2013}
# {'title': 'The Spoils of Babylon', 'year': 2014}
# {'title': 'The 2013 Rock and Roll Hall of Fame Induction Ceremony',
#  'year': 2013}
# {'title': 'Motylki', 'year': 2013}
# {'title': 'Death Comes to Pemberley', 'year': 2013}
# {'title': 'Olive Kitteridge', 'year': 2014}
# {'title': 'The Honourable Woman', 'year': 2014}
# {'title': "Li'l Quinquin", 'year': 2014}
# {'title': "Rosemary's Baby", 'year': 2014}
# {'title': 'Houdini', 'year': 2014}
# {'title': 'Never Tear Us Apart: The Untold Story of INXS', 'year': 2014}
# {'title': 'The Sixties', 'year': 2013}
# {'title': 'The Saboteurs', 'year': 2015}
# {'title': 'The Roosevelts: An Intimate History', 'year': '2014è'}
# {'title': 'The Lost Honour of Christopher Jefferies', 'year': 2014}
# {'title': 'Wolf Hall', 'year': 2015}
# {'title': 'Over the Garden Wall', 'year': 2014}
# {'title': 'Halo: Nightfall', 'year': '2014è'}
# {'title': 'The Missing', 'year': 2014}
# {'title': 'Beyond the Fear', 'year': 2015}
# {'title': 'The Jinx: The Life and Deaths of Robert Durst', 'year': 2015}

# %% [markdown]
# ### Indices

# %% [markdown]
# Para hacer búsquedas más complejas podemos utilizar expresiones regulares mediante el operador `$expr` o crear un índice de texto para así poder usar el operador `$text`. En nuestro caso ya contamos con uno creado.

# %%
pprint(movies.index_information())
# Out:
# {'_id_': {'key': [('_id', 1)], 'v': 2},
#  'cast_text_fullplot_text_genres_text_title_text': {'default_language': 'english',
#                                                     'key': [('_fts', 'text'),
#                                                             ('_ftsx', 1)],
#                                                     'language_override': 'language',
#                                                     'textIndexVersion': 3,
#                                                     'v': 2,
#                                                     'weights': SON([('cast', 1), ('fullplot', 1), ('genres', 1), ('title', 1)])}}

# %%
query = { "$text" : { "$search": "future", "$caseSensitive": False }} # Que contengan la palabra future, "$caseSensitive" ES UN OPERADOR 
     # UTILIZADO PARA ESPECIFICAR SI LA PALABRA QUE TIENE QUE BUSCAR SE DEBE AJUSTAR O NO A COMO ESTÁ ESCRITA (MAY, MINUS, ETC ...)
proyeccion = {"_id": 0, "title" : True, "year": 1, "plot" : 1}

for movie in movies.find(query, proyeccion):
    pprint(movie)
# Out:
# {'plot': 'After visiting 2015, Marty McFly must repeat his visit to 1955 to '
#          'prevent disastrous changes to 1985... without interfering with his '
#          'first trip.',
#  'title': 'Back to the Future Part II',
#  'year': 1989}
# {'plot': 'A young man is accidentally sent 30 years into the past in a '
#          'time-traveling DeLorean invented by his friend, Dr. Emmett Brown, '
#          'and must make sure his high-school-age parents unite in order to '
#          'save his own existence.',
#  'title': 'Back to the Future',
#  'year': 1985}
# {'plot': 'The possibly exaggerated origin story of the real life alien '
#          'bluegrass band, Future Folk, that has been playing for NYC audiences '
#          'for the better part of a decade.',
#  'title': 'The History of Future Folk',
#  'year': 2012}
# {'plot': 'Enjoying a peaceable existence in 1885, Doctor Emmet Brown is about '
#          'to be killed by Buford "Mad Dog" Tannen. Marty McFly travels back in '
#          'time to save his friend.',
#  'title': 'Back to the Future Part III',
#  'year': 1990}
# {'plot': 'Lewis is a brilliant inventor who meets mysterious stranger named '
#          'Wilbur Robinson, whisking Lewis away in a time machine and together '
#          'they team up to track down Bowler Hat Guy in a showdown that ends '
#          'with an unexpected twist of fate.',
#  'title': 'Meet the Robinsons',
#  'year': 2007}
# {'plot': 'When a couple decides to adopt a stray cat their perspective on life '
#          'changes radically, literally altering the course of time and space '
#          'and testing their faith in each other and themselves.',
#  'title': 'The Future',
#  'year': 2011}
# {'plot': 'A small-time hood struggles to succeed on the "mean streets" of '
#          'Little Italy.',
#  'title': 'Mean Streets',
#  'year': 1973}
# {'plot': 'When college professor J.T. Neumeyer discovers a police file that '
#          'outlines the details of his murder - which is to take place five '
#          'days in the future - he wastes no time trying to save his own life.',
#  'title': '5ive Days to Midnight',
#  'year': 2004}
# {'plot': 'After Dexter is confronted with robots who wish to "destroy the one '
#          'who saved the future," he uses his time machine to see how he saved '
#          'it.',
#  'title': "Dexter's Laboratory: Ego Trip",
#  'year': 1999}
# {'plot': 'A cybernetic warrior from a post-apocalyptic future travels back in '
#          'time to protect a 19-year old drifter and his future wife from a '
#          'most advanced robotic assassin and to ensure they both survive a '
#          'nuclear attack.',
#  'title': 'Terminator 3: Rise of the Machines',
#  'year': 2003}
# {'plot': 'Chris is a psychic who lives his life out of order - experiencing '
#          'past, present and future as a jigsaw puzzle. But when he commits a '
#          'murder in the future, he has to change his past and present in order '
#          'to prevent it from happening.',
#  'title': 'Found in Time',
#  'year': 2012}
# {'plot': 'The film is set in a terrorizing world of the future, where '
#          'technology commands the movements of individuals, supervised by the '
#          'doctors, carrying out a program to improve the human race. ...',
#  'title': 'Golem',
#  'year': 1980}
# {'plot': 'A rich father in a fisher village plans to take on the project of '
#          'writing his life story. But first he has to take on his own family, '
#          'and everybody wants something...',
#  'title': 'The Sea',
#  'year': 2002}
# {'plot': 'A reporter, learning of time travelers visiting 20th century '
#          'disasters, tries to change the history they know by averting '
#          'upcoming disasters.',
#  'title': 'Thrill Seekers',
#  'year': 1999}
# {'plot': 'A human-looking indestructible cyborg is sent from 2029 to 1984 to '
#          'assassinate a waitress, whose unborn son will lead humanity in a war '
#          'against the machines, while a soldier from that war is sent to '
#          'protect her at all costs.',
#  'title': 'The Terminator',
#  'year': 1984}
# {'plot': 'A young man who thought himself already in love with a nice girl is '
#          'drawn into a literary drama when he is captured by a deep and '
#          'stimulating love affair.',
#  'title': 'Reconstruction',
#  'year': 2003}
# {'plot': 'Teens encounter people, who, after being used as guinea pigs for the '
#          'experimental testing of a virus can live forever in a post '
#          'apocalyptic world.',
#  'title': 'Teenage Caveman',
#  'year': 2002}
# {'plot': "It's All About Love is the story of two lovers and their attempts to "
#          'save their relationship in a near-future world on the brink of '
#          'cosmic collapse. John, and world-famous ice skating star,...',
#  'title': "It's All About Love",
#  'year': 2003}
# {'plot': 'When John Connor, leader of the human resistance, sends Sgt. Kyle '
#          'Reese back to 1984 to protect Sarah Connor and safeguard the future, '
#          'an unexpected turn of events creates a fractured timeline.',
#  'title': 'Terminator Genisys',
#  'year': 2015}
# {'plot': 'An inventor comes up with a time machine, but must prevent its abuse '
#          'at the hands of an evil C.E.O.',
#  'title': 'Time Chasers',
#  'year': 1994}
# {'plot': 'Three freedom fighters attack a large corporation to prevent a '
#          'future apocalypse.',
#  'title': 'T2 3-D: Battle Across Time',
#  'year': 1996}
# {'plot': 'In this suburban drama, a widower (played by Anthony LaPaglia) '
#          "confronts his older son's (played by Aaron Stanford) decision to "
#          "leave home and his younger son's self-destructive behavior.",
#  'title': 'Winter Solstice',
#  'year': 2004}
# {'plot': 'Terrorists with an indestructible robot take over a high-rise '
#          "hospital in order to kidnap the president's daughter.",
#  'title': 'Shadowchaser',
#  'year': 1992}
# {'plot': 'A team of explorers travel through a wormhole in space in an attempt '
#          "to ensure humanity's survival.",
#  'title': 'Interstellar',
#  'year': 2014}
# {'plot': "A hard-partying high school senior's philosophy on life changes when "
#          'he meets the not-so-typical "nice girl."',
#  'title': 'The Spectacular Now',
#  'year': 2013}
# {'plot': 'Gina and Marco are living in the suburbs of Rome. The two meet on a '
#          'very special day: their first day at work. They have a future that '
#          'awaits them and really seems at hand. Gina is about to...',
#  'title': 'A Special Day',
#  'year': 2012}
# {'plot': 'The study of a youth on the edge of adulthood and his aunt, ten '
#          'years older. Fabrizio is passionate, idealistic, influenced by '
#          'Cesare, a teacher and Marxist, engaged to the lovely but ...',
#  'title': 'Before the Revolution',
#  'year': 1964}
# {'plot': 'An eccentric Belgian inventor travels to Quèbec to search for his '
#          'family, which uncovers a secret history between two seemingly '
#          'unrelated people.',
#  'title': 'Congorama',
#  'year': 2006}
# {'plot': 'Unless a comet can be destroyed before colliding with Earth, only '
#          'those allowed into shelters will survive. Which people will survive?',
#  'title': 'Deep Impact',
#  'year': 1998}
# {'plot': 'He may have just graduated but Nick has it all figured out - '
#          'marriage, a lucrative career and a totally different lifestyle from '
#          'that of his West Coast hippy parents. When he discovers that...',
#  'title': 'Going the Distance',
#  'year': 2004}
# {'plot': 'Lorrpu, Botj and Milika are three Yolngu (Aboriginal) teenagers who '
#          'once shared a childhood dream of becoming great hunters together. '
#          'But as teenagers they changed: Botj did bad things ...',
#  'title': 'Yolngu Boy',
#  'year': 2001}
# {'plot': 'Uno is a story from inner-city Oslo about David, a '
#          'twentyfive-year-old with few prospects for the future. His days are '
#          'spent hanging around with petty criminals at an inner-city gym. '
#          'Still,...',
#  'title': 'Uno',
#  'year': 2004}
# {'plot': 'Two seemingly dumb teens struggle to prepare a historical '
#          'presentation with the help of a time machine.',
#  'title': "Bill & Ted's Excellent Adventure",
#  'year': 1989}
# {'plot': "What will happen to Nobita's life after Doraemon leaves?",
#  'title': 'Stand by Me Doraemon',
#  'year': 2014}
# {'plot': 'Nick is a feckless television salesman who gets fired and '
#          'impulsively decides that he and his girlfriend, Beth, will move to '
#          'Butte, MT, which he\'s read is "the city of the future." "I read ...',
#  'title': 'Bodies, Rest & Motion',
#  'year': 1993}
# {'plot': 'Two siblings begin to develop special talents after they find a '
#          'mysterious box of toys. Soon the kids, their parents, and even their '
#          'teacher are drawn into a strange new world and find a task ahead of '
#          'them that is far more important than any of them could imagine!',
#  'title': 'The Last Mimzy',
#  'year': 2007}
# {'plot': 'At Pacific Palisades High, a poor Latino falls hard for a troubled '
#          'girl from the affluent neighborhood.',
#  'title': 'Crazy/Beautiful',
#  'year': 2001}
# {'plot': 'Professional sports is known as a true meritocracy, a field in which '
#          "the cream really does rise to the top, as there's simply too much "
#          'money at stake to operate in any other fashion. In ...',
#  'title': 'Lenny Cooke',
#  'year': 2013}
# {'plot': 'With the help of his uncle, a man travels to the future to try and '
#          'bring his girlfriend back to life.',
#  'title': 'Love Story 2050',
#  'year': 2008}
# {'plot': 'Kristoffer is a billboard hanger, 24 years old and carefree. When '
#          'his girlfriend Elisabeth dumps him for the boss of her trend bureau, '
#          'his life falls into pieces. He feels like a loser. By ...',
#  'title': 'Buddy',
#  'year': 2003}
# {'plot': 'O Contador de Histèrias (The Story of Me), a Luiz Villaèa;a movie '
#          'based on the life of Roberto Carlos Ramos, is a story about how '
#          'affection can change reality. The youngest of 10 brothers, ...',
#  'title': 'The Story of Me',
#  'year': 2009}
# {'plot': '"The Trials of Darryl Hunt" is a feature documentary about a brutal '
#          'rape/murder case and a wrongly convicted man, Darryl Hunt, who spent '
#          'nearly twenty years in prison for a crime he did not...',
#  'title': 'The Trials of Darryl Hunt',
#  'year': 2006}
# {'plot': 'Zero (Wagner Moura) is a brilliant scientist, but unfortunate '
#          'because 20 years ago was publicly humiliated and lost in college '
#          'Helena (Alinne Moraes) the love of his life. One day, an ...',
#  'title': 'The Man from the Future',
#  'year': 2011}
# {'plot': 'When her single mom runs off to California, Lauduree, a passionate '
#          'environmentalist, clings to her rural home and a carbon '
#          'sequestration experiment. But her grandmother Greta, a caustic ...',
#  'title': 'Future Weather',
#  'year': 2012}
# {'plot': 'A film about love and utopia.',
#  'title': 'Future My Love',
#  'year': 2012}
# {'plot': 'Two young guys work in a plant that manufactures oshibori (those '
#          'moist hand-towels found in some Japanese restaurants). Their weird '
#          'bond is based on uncontrollable rage--something neither ...',
#  'title': 'Bright Future',
#  'year': 2003}
# {'title': 'The Future Is Woman', 'year': 1984}
# {'plot': 'A documentary on the safety of nuclear storage.',
#  'title': 'Into Eternity: A Film for the Future',
#  'year': 2010}
# {'plot': 'Two college friends get together and reminisce on the woman they '
#          'both fell in love with at different times in their past, and are '
#          'thus propelled to find her.',
#  'title': 'Woman Is the Future of Man',
#  'year': 2004}
# {'plot': 'A warrior seeks his true origins in a seemingly prehistoric '
#          'wasteland.',
#  'title': 'Yor, the Hunter from the Future',
#  'year': 1983}
# {'plot': "Documentary covering the highs and lows of 2000AD's history, from "
#          'its inception after the demise of Action to the present day.',
#  'title': 'Future Shock! The Story of 2000AD',
#  'year': 2014}
# {'plot': 'The X-Men send Wolverine to the past in a desperate effort to change '
#          'history and prevent an event that results in doom for both humans '
#          'and mutants.',
#  'title': 'X-Men: Days of Future Past',
#  'year': 2014}
# {'plot': 'A little girl is taken on a mind-bending tour of her distant future.',
#  'title': 'World of Tomorrow',
#  'year': 2015}
# {'plot': 'In the not too distant future, people struggle to survive their '
#          'greatest enemy, the sun.',
#  'title': 'Hell',
#  'year': 2011}
# {'plot': 'Two documentary filmmakers attempt to penetrate a cult who worships '
#          'a woman who claims to be from the future.',
#  'title': 'Sound of My Voice',
#  'year': 2011}
# {'plot': 'A sci-fi film about Africa in the future, 35 years after World War '
#          'III, the water war.',
#  'title': 'Pumzi',
#  'year': 2009}
# {'plot': "Cynical look at a 50's rebellious Rocker who has to confront his "
#          'future, thugs with knives, and the crooked town sheriff.',
#  'title': 'Roadracers',
#  'year': 1994}
# {'plot': 'A soldier, brought back to life as a cyborg, fights alongside a band '
#          'of adventurers against demon hordes in a dystopian future.',
#  'title': 'Manborg',
#  'year': 2011}
# {'plot': 'A son longs to escape from his stifling home, where his genteel '
#          'mother worries about the future prospects of his lame, shy sister.',
#  'title': 'The Glass Menagerie',
#  'year': 1987}
# {'plot': 'A series of uncanny dèjè vu events force a man to re-examine his '
#          'tragic past, memory, instinct, and future.',
#  'title': "Donovan's Echo",
#  'year': 2011}
# {'plot': 'A Polish-Jewish family comes to the USA at the beginning of the '
#          'Twentieth Century. There, the family and their children try to make '
#          'themselves a better future in the so-called promised land.',
#  'title': 'Avalon',
#  'year': 1990}
# {'plot': 'A team of genius-but-broke grad students invent mind-reading '
#          'technology that destroys their lives and threatens the future of '
#          'free-will itself.',
#  'title': 'Listening',
#  'year': 2014}
# {'plot': 'In near future Brooklyn, an ad executive uses a new Augmented '
#          "Reality technology to conduct an affair with his best friend's "
#          'girlfriend...sort of.',
#  'title': 'Creative Control',
#  'year': 2015}
# {'plot': 'Karri, Pete, Andrè, Akseli and Joni are dealing with same issues as '
#          'every other young man; fears and hopes for future, disillusions and '
#          'problems with parents.',
#  'title': 'Almost 18',
#  'year': 2012}
# {'plot': 'In a near future society a man claims that his dreams physically '
#          'change reality. His therapist is confused at first but soon decides '
#          'to use him for his own gain.',
#  'title': 'Lathe of Heaven',
#  'year': 2002}
# {'plot': "London: The Modern Babylon is legendary director Julien Temple's "
#          '(Joe Strummer - The Future is Unwritten) epic time-traveling voyage '
#          'to the heart of his hometown.',
#  'title': 'London - The Modern Babylon',
#  'year': 2012}
# {'plot': 'Captures the past, present, and future of the remarkable Epstein '
#          'brothers - Max, Julie and Willie - Klezmer music legends on a joyous '
#          'international comeback tour.',
#  'title': 'A Tickle in the Heart',
#  'year': 1996}
# {'plot': 'A young couple bound by a seemingly ideal love, begins to unravel as '
#          'unexpected opportunities spin them down a volatile and violent path '
#          'and threaten the future they had always imagined.',
#  'title': '6 Years',
#  'year': 2015}
# {'plot': 'Three friends discover a mysterious machine that takes pictures '
#          '24hrs into the future and conspire to use it for personal gain, '
#          'until disturbing and dangerous images begin to develop.',
#  'title': 'Time Lapse',
#  'year': 2014}
# {'plot': 'Traveling in 11-minute increments, a time-tumbler from 48-years in '
#          'the future spends two years of his life weaving through a two-hour '
#          'wedding reception.',
#  'title': '11 Minutes Ago',
#  'year': 2007}
# {'plot': 'A group of a run-down Tokyo high school students face the struggles '
#          'of growing up, growing apart from their friends and worrying about '
#          'their future, while living in a highly violent environment.',
#  'title': 'Blue Spring',
#  'year': 2001}
# {'plot': 'A group of a run-down Tokyo high school students face the struggles '
#          'of growing up, growing apart from their friends and worrying about '
#          'their future, while living in a highly violent environment.',
#  'title': 'Blue Spring',
#  'year': 2001}
# {'plot': "A 21-year-old reformed gangster's devotion to his family and his "
#          'future is put to the test when he is released from prison and '
#          'returns to his old stomping grounds in Watts, Los Angeles.',
#  'title': 'Imperial Dreams',
#  'year': 2014}
# {'plot': 'Two people in love, two apartments - one in Barcelona and another on '
#          'in Los Angeles - and the images of their past, present and future. '
#          'Can love survive 10,000km?',
#  'title': '10.000 Km',
#  'year': 2014}
# {'plot': 'In a near-future city where soaring opulence overshadows economic '
#          'hardship, Gwen and her daughter Jules do all they can to hold on to '
#          'their joy together, despite the instability surfacing in their '
#          'world.',
#  'title': 'Advantageous',
#  'year': 2015}
# {'plot': 'Vincent is about to become a father. At a meeting with childhood '
#          'friends he announces the name for his future son. The scandalous '
#          'name ignites a discussion which surfaces unpleasant matters from the '
#          'past of the group.',
#  'title': "What's in a Name?",
#  'year': 2012}
# {'plot': 'When the plans for the future change, new bonds are created between '
#          'Danilo, Lucas and Marcos. in between video-games and milk cups, pain '
#          'and disappointment, they need to learn how to live together.',
#  'title': 'Cafè com Leite',
#  'year': 2007}
# {'plot': 'In a future where energy is made from fecal matter, the government '
#          'rewards defecation with "juicybars". Small-time hustlers try to get '
#          'rich while fending off the mutated Diaper Gang.',
#  'title': 'Aachi and Ssipak',
#  'year': 2006}
# {'plot': 'Sci-Fi mystery. In the future the world has apparently reached '
#          'complete perfection, but when Dale suffers a car accident he begins '
#          'noticing disturbing glitches in the fabric of reality.',
#  'title': 'Virtual Nightmare',
#  'year': 2000}
# {'plot': 'In an alternate futuristic society, a tough female police detective '
#          'is paired with a talking dinosaur to find the killer of dinosaurs '
#          'and other prehistoric animals leading them to a mad scientist bent '
#          'on creating a new Armageddon.',
#  'title': 'Theodore Rex',
#  'year': 1995}
# {'plot': 'The Muppet characters tell their version of the classic tale of an '
#          "old and bitter miser's redemption on Christmas Eve.",
#  'title': 'The Muppet Christmas Carol',
#  'year': 1992}
# {'plot': 'A mercenary with a three-bladed sword rediscovers his royal '
#          "heritage's dangerous future when he is recruited to help a princess "
#          'foil the designs of a brutal tyrant and a powerful sorcerer in '
#          'conquering a land.',
#  'title': 'The Sword and the Sorcerer',
#  'year': 1982}
# {'plot': 'Shots at a black music party in the outskirts of Brasilia injure two '
#          'men that get scarred for life. A third man comes from the future to '
#          "investigate what happened and to prove that it is all the society's "
#          'fault.',
#  'title': 'White Out, Black In',
#  'year': 2015}
# {'plot': 'Following the conclusion of the storyline in the "Fight For Your '
#          'Right" music video, the Beasties break into a liquor store, drop '
#          'acid with groupies, and get into a breakdance competition with '
#          'time-traveling future versions of themselves.',
#  'title': 'Fight for Your Right Revisited',
#  'year': 2011}
# {'plot': 'In the near future, a police officer specializes in malfunctioning '
#          'robots. When a robot turns out to have been programmed to kill, he '
#          'begins to uncover a homicidal plot to create killer robots... and '
#          'his son becomes a target.',
#  'title': 'Runaway',
#  'year': 1984}
# {'plot': 'A simple immigration issue spins wildly out of control for those '
#          'involved, ranging from the President of the United States, to a news '
#          'producer.',
#  'title': 'The Second Civil War',
#  'year': 1997}
# {'plot': 'A mercenary goes after his ex-girlfriend, a singer who has been '
#          'kidnapped by a gang.',
#  'title': 'Streets of Fire',
#  'year': 1984}
# {'plot': 'In a dystopian near future, single people are obliged to find a '
#          'matching mate in 45 days or are transformed into animals and '
#          'released into the woods.',
#  'title': 'The Lobster',
#  'year': 2015}
# {'plot': 'The seven-year-old Kid, his brother Billy and there mother living on '
#          "a farm. The mother of the children's is always sad. One day, "
#          'something painful happened for the poor family and the kids have to '
#          'make a future by themselves.',
#  'title': 'Kid',
#  'year': 2012}
# {'plot': 'Sunny gives up a promising future to return to her hometown to care '
#          'for her ailing father and finds herself working at a bowling alley. '
#          'When a charming high school rival returns for the holidays, Sunny is '
#          'forced to reexamine her life.',
#  'title': 'The New Year',
#  'year': 2010}
# {'plot': 'Humans in a fascistic, militaristic future do battle with giant '
#          'alien bugs in a fight for survival.',
#  'title': 'Starship Troopers',
#  'year': 1997}
# {'plot': 'Featuring music instead of any dialogue and set in a near Kafkaesque '
#          'future, this loose remake of The Cabinet of Dr. Caligari follows a '
#          'bureaucrat whom mysterious Dr. Ramirez and his hideous sidekick want '
#          'as their latest victim.',
#  'title': 'The Cabinet of Dr. Ramirez',
#  'year': 1991}
# {'plot': 'The life of the poor Tucker family, that worked as cotton pluggers '
#          'and decided to get their own ground, but nature is against them.',
#  'title': 'The Southerner',
#  'year': 1945}
# {'plot': 'Between fear of success and a tricky break-up, Ludovic is beyond all '
#          "hope as he is getting close to the 30's stage. His unexpected "
#          'meeting with a sick child, Raphael, shakes up his daily life and his '
#          'future approach. Together, they go after their dreams...',
#  'title': "Le monde doit m'arriver?",
#  'year': 2012}
# {'plot': 'When their parents die, Bianca starts to smoke and Tomas is still a '
#          'virgin. The orphans explore the dangerous streets of adulthood until '
#          'Bianca finds Maciste, a retired Mr. Universe, and enters his dark '
#          'mansion in search of a future.',
#  'title': 'Il Futuro',
#  'year': 2013}
# {'plot': 'A couple embarks on a journey home for Chinese new year along with '
#          '130 million other migrant workers, to reunite with their children '
#          'and struggle for a future. Their unseen story plays out as China '
#          'soars towards being a world superpower.',
#  'title': 'Last Train Home',
#  'year': 2009}
# {'plot': 'In an old-time dance hall (the "gafieira") in Sèo Paulo, one evening '
#          'is all it takes to meet different characters as they remember the '
#          'past, live the present, wonder about the future, have fun, flirt, '
#          'fight and, naturally, dance.',
#  'title': 'Chega de Saudade',
#  'year': 2007}
# {'plot': 'The near future. Like tomorrow. In a world marked by closed borders, '
#          'corporate warriors, and a global computer network, three strangers '
#          'risk their lives to connect, break through the barriers of '
#          'technology, and unseal their fates.',
#  'title': 'Sleep Dealer',
#  'year': 2008}
# {'plot': 'Years in the future, a Martian police unit is sent to pick up a '
#          'highly dangerous criminal at a remote mining post. Upon arrival, the '
#          'cops find that the post has become a charnel house.',
#  'title': 'Ghosts of Mars',
#  'year': 2001}
# {'plot': 'An NTSB investigator seeking the cause of an airline disaster meets '
#          'a warrior woman from 1000 years in the future.',
#  'title': 'Millennium',
#  'year': 1989}
# {'plot': 'A man awakens from a coma to discover he has a psychic detective '
#          'ability.',
#  'title': 'The Dead Zone',
#  'year': 1983}
# {'plot': 'Episodic, spiritual and existentialistic look at the state the '
#          'Russia is in in 2017, exactly one hundred years after the '
#          'communist-led Russian Revolution. The future looks gloomy, since the '
#          'world is on the brink of yet another world war.',
#  'title': 'Under Electric Clouds',
#  'year': 2015}
# {'plot': 'In a future mind-controlling game, death row convicts are forced to '
#          "battle in a 'Doom'-type environment. Convict Kable, controlled by "
#          'Simon, a skilled teenage gamer, must survive thirty sessions in '
#          "order to be set free. Or won't he?",
#  'title': 'Gamer',
#  'year': 2009}
# {'plot': 'A college basketball coach is forced to break the rules in order to '
#          'get the players he needs to stay competitive.',
#  'title': 'Blue Chips',
#  'year': 1994}
# {'plot': "A spaceship with three furry aliens lands in a California girl's "
#          'swimming pool, so she makes friends with them.',
#  'title': 'Earth Girls Are Easy',
#  'year': 1988}
# {'plot': "When four high school best friends' lives are dramatically changed "
#          "on the night of a near fatal accident, eighteen years later they're "
#          'reunited, only to discover that a set of past and ...',
#  'title': 'Cru',
#  'year': 2014}
# {'plot': 'A young governess falls in love with her brooding and complex '
#          'master. However, his dark past may destroy their relationship '
#          'forever.',
#  'title': 'Jane Eyre',
#  'year': 2006}
# {'plot': 'Twenty-something Ana, now living in Buenos Aires, returns to her '
#          'native city of Paranè. She meets old school mates, old friends, '
#          'makes new ones, and starts to rethink her life, and perhaps change '
#          'her future.',
#  'title': 'Ana and the Others',
#  'year': 2003}
# {'plot': 'Little pocket thief Wu never got away from the streets like his '
#          "friends did. He realises that he is alone, as his old buddy doesn't "
#          'invite him for his wedding. When he falls in love with a ...',
#  'title': 'Pick Pocket',
#  'year': 1997}
# {'plot': 'The story of 6 or 7 prostitutes, at Pireas harbor.',
#  'title': 'The Red Lanterns',
#  'year': 1963}
# {'plot': 'My iz budushchego, or We Are from the Future, is a movie about time '
#          'travel. Four 21st century treasure seekers are transported back into '
#          "the middle of a WWII battle in Russia. The movie's ...",
#  'title': 'My iz budushchego',
#  'year': 2008}
# {'plot': 'Somewhere in Northern Russia in a small Russian Orthodox monastery '
#          'lives an unusual man whose bizarre conduct confuses his fellow '
#          'monks, while others who visit the island believe that the man has '
#          'the power to heal, exorcise demons and foretell the future.',
#  'title': 'The Island',
#  'year': 2006}
# {'plot': 'A team of international astronauts is sent on a dangerous mission to '
#          'reignite the dying Sun with a nuclear fission bomb in 2057.',
#  'title': 'Sunshine',
#  'year': 2007}
# {'plot': "A Duke's son leads desert warriors against the galactic emperor and "
#          "his father's evil nemesis when they assassinate his father and free "
#          "their desert world from the emperor's rule.",
#  'title': 'Dune',
#  'year': 1984}
# {'plot': 'Based on the comic book by the creator of Ghost in the Shell, a '
#          'young female soldier Deunan and her cyborg partner Briareos survive '
#          'through the post World War 3 apocalyptic New York in ...',
#  'title': 'Appleseed Alpha',
#  'year': 2014}
# {'plot': 'In the near future, the areas between major cities are lawless '
#          'wastelands. Atolladero is a town run with an iron fist by a corrupt '
#          'tyrant named The Judge and his murderous enforcer, Madden....',
#  'title': 'Atolladero',
#  'year': 1995}
# {'plot': 'In the near future, drive-in theatres are turned into concentration '
#          "camps for the undesirable and unemployed. The prisoners don't really "
#          'care to escape because they are fed and they have a ...',
#  'title': 'Dead End Drive-In',
#  'year': 1986}
# {'plot': 'In the post-apocalyptic future, only a few humans are left. No one '
#          'is able to speak; the film contains no dialogue, and characters '
#          'communicate non-verbally. A determined loner befriends a ...',
#  'title': 'Le Dernier Combat (The Last Battle)',
#  'year': 1983}
# {'plot': 'In the not too distant future, a very smoggy and overpopulated Earth '
#          'government makes it illegal to have children for a generation. One '
#          'couple, unsatisfied with their substitute robot baby,...',
#  'title': 'Z.P.G.',
#  'year': 1972}
# {'plot': 'A married couple have dinner and discuss their future, they go to '
#          'bed but soon they realize that someone is in the house. The crisis '
#          'that follows this incident brings the couple closer ...',
#  'title': 'The Break-In',
#  'year': 2015}
# {'plot': 'Deeply ensconced in a top-secret military program, three pilots '
#          'struggle to bring an artificial intelligence program under control '
#          'before it initiates the next world war.',
#  'title': 'Stealth',
#  'year': 2005}
# {'plot': 'In the highlands of Scotland in the 1700s, Rob Roy tries to lead his '
#          'small town to a better future, by borrowing money from the local '
#          'nobility to buy cattle to herd to market. When the ...',
#  'title': 'Rob Roy',
#  'year': 1995}
# {'plot': 'Otsuta is running the geisha house Tsuta in Tokyo. Her business is '
#          "heavily in debt. Her daughter Katsuyo doesn't see any future in her "
#          'mothers trade in the late days of Geisha. But Otsuta ...',
#  'title': 'Flowing',
#  'year': 1956}
# {'plot': 'A complex story of a misaligned man, though good intent, creating a '
#          'nightmarish Dystopian existence.',
#  'title': 'Metropia',
#  'year': 2009}
# {'plot': "In the post-apocalyptic world of 1960s Nevada, a rock 'n' roll "
#          'samurai takes a young boy under his protection.',
#  'title': 'Six-String Samurai',
#  'year': 1998}
# {'plot': 'A futuristic prison movie. Protagonist and wife are nabbed at a '
#          'future US emigration point with an illegal baby during population '
#          'control. The resulting prison experience is the subject of ...',
#  'title': 'Fortress',
#  'year': 1992}
# {'plot': "When God created man, his first try at it wasn't very successful... "
#          'Fantozzi was born, and right from the beginning of time he was '
#          'doomed to be humiliated and laughed at. In a number of ...',
#  'title': 'Superfantozzi',
#  'year': 1986}
# {'plot': "Once there was Disa and Laban and their two kids. But now Disa's "
#          'husband has found a new love, new clothes and a completely new '
#          'future, while Disa is stuck in a life that is put on hold. ...',
#  'title': 'Hallè hallè',
#  'year': 2014}
# {'plot': 'A talent agent summons a young singer to Sao Paulo in order to '
#          'present her to a renowned maestro. While they wait for the day of '
#          'the audition, they stay in a hotel room where, over ...',
#  'title': 'Natimorto',
#  'year': 2009}
# {'plot': 'A selfish, cynical T.V. executive is haunted by three spirits '
#          'bearing lessons on Christmas Eve.',
#  'title': 'Scrooged',
#  'year': 1988}
# {'plot': 'A British lady entomologist travels to a Balkan country to look into '
#          'germ warfare trials using various bugs as carriers.',
#  'title': 'Highly Dangerous',
#  'year': 1950}
# {'plot': 'The poignant yet humor filled story about a single mother of a '
#          'teenager severely impacted by autism, forced to reckon with her '
#          "daughter's future. As her child becomes an adult, what used to...",
#  'title': 'Fly Away',
#  'year': 2011}
# {'plot': 'An exploration of how the actions of individual lives impact one '
#          'another in the past, present and future, as one soul is shaped from '
#          'a killer into a hero, and an act of kindness ripples across '
#          'centuries to inspire a revolution.',
#  'title': 'Cloud Atlas',
#  'year': 2012}
# {'plot': 'A United States Navy destroyer escort participates in a Navy '
#          '"invisibility" experiment that inadvertently sends two sailors 40 '
#          'years into the future.',
#  'title': 'The Philadelphia Experiment',
#  'year': 1984}
# {'plot': "Cleopatra hasn't been on the throne of the pharoahs of Egypt very "
#          'long when Julius Caesar pays a visit. Caesar finds the prospect of '
#          'romance more tempting than he expected, since Cleopatra ...',
#  'title': 'Caesar and Cleopatra',
#  'year': 1945}
# {'plot': 'Kelly, a punk-rocker turned suburban mom, is nostalgic for a life '
#          "she can no longer have and uncertain of a future she doesn't yet fit "
#          'in. Seventeen-year-old Cal is frustrated at his lack ...',
#  'title': 'Kelly & Cal',
#  'year': 2014}
# {'plot': "An animated retelling of Charles Dickens' classic novel about a "
#          'Victorian-era miser taken on a journey of self-redemption, courtesy '
#          'of several mysterious Christmas apparitions.',
#  'title': 'A Christmas Carol',
#  'year': 2009}
# {'plot': 'Albanian teenager, Saimir, emigrates to Italy to start a new life '
#          'with his father. His father tries to make a living transporting '
#          'illegal immigrants. When this fails to make his father any ...',
#  'title': 'Saimir',
#  'year': 2004}
# {'plot': 'Joe and Betty run a fish market and have sunk into a comfortable, if '
#          'somewhat boring life. Enter the drifter Nick, who takes a job in the '
#          'store and a place in their home. He proceeds to ...',
#  'title': 'Caught',
#  'year': 1996}
# {'plot': 'In the distant future, a savage trained only to kill finds a way '
#          'into the community of bored immortals that alone preserves '
#          "humanity's achievements.",
#  'title': 'Zardoz',
#  'year': 1974}
# {'plot': 'As war-ravaged South Sudan claims independence from North Sudan and '
#          'its brutal President, Omar al-Bashir, a tiny, homemade prop plane '
#          'wings in from France. It is piloted by eagle-eyed ...',
#  'title': 'We Come as Friends',
#  'year': 2014}
# {'plot': 'Grace Lee Boggs is an activist and philosopher in Detroit who has '
#          'dedicated her life to the next American Revolution and the '
#          'possibility of a better, more just future for all of humanity. ...',
#  'title': 'American Revolutionary: The Evolution of Grace Lee Boggs',
#  'year': 2013}
# {'plot': 'An Aboriginal boy is torn between his unexpected love of acting and '
#          'the disintegration of his family.',
#  'title': 'Around the Block',
#  'year': 2013}
# {'plot': 'A future archivist looks at old footage from the year 2008 to '
#          'understand why humankind failed to address climate change.',
#  'title': 'The Age of Stupid',
#  'year': 2009}
# {'plot': 'A romantic drama about a Chicago librarian with a gene that causes '
#          'him to involuntarily time travel, and the complications it creates '
#          'for his marriage.',
#  'title': "The Time Traveler's Wife",
#  'year': 2009}
# {'plot': 'The world after the nuclear apocalypse. Pale light lits the scenery '
#          'of total destruction. The surviving humans vegetate in wet cellars '
#          'under the nuclear winter. But somehow human spirit ...',
#  'title': "Dead Man's Letters",
#  'year': 1986}
# {'plot': 'Mel Brooks brings his one-of-a-kind comic touch to the history of '
#          'mankind covering events from the Old Testament to the French '
#          'Revolution in a series of episodic comedy vignettes.',
#  'title': 'History of the World: Part I',
#  'year': 1981}
# {'plot': 'A college freshman encounters new friends, romance, and adventure '
#          'upon her arrival at campus.',
#  'title': 'So Young',
#  'year': 2013}
# {'plot': 'A zombie epidemic spreads throughout a strip club in Nebraska.',
#  'title': 'Zombie Strippers!',
#  'year': 2008}
# {'plot': '"Go Tigers!" is a rare behind-the-scenes chronicling of a remarkable '
#          'season for the Massillon Tigers high school football team, played '
#          'out in a small rustbelt town that draws its identity ...',
#  'title': 'Go Tigers!',
#  'year': 2001}
# {'plot': 'Jason Voorhees returns with a new look, a new machete, and his same '
#          'murderous attitude as he is awakened on a spaceship in the 25th '
#          'century.',
#  'title': 'Jason X',
#  'year': 2001}
# {'plot': 'Nun Sara is on the run in Mexico and is saved from cowboys by Hogan, '
#          'who is preparing for a future mission to capture a French fort. The '
#          'pair become good friends, but Sara never does tell him the true '
#          'reason behind her being outlawed.',
#  'title': 'Two Mules for Sister Sara',
#  'year': 1970}
# {'plot': 'At the NFL Draft, general manager Sonny Weaver has the opportunity '
#          'to rebuild his team when he trades for the number one pick. He must '
#          "decide what he's willing to sacrifice on a life-changing day for a "
#          'few hundred young men with NFL dreams.',
#  'title': 'Draft Day',
#  'year': 2014}
# {'plot': 'A comedy set in the world of European royalty.',
#  'title': 'Palais royal!',
#  'year': 2005}
# {'plot': "Defiant young activists take the women's suffrage movement by storm, "
#          'putting their lives at risk to help American women win the right to '
#          'vote.',
#  'title': 'Iron Jawed Angels',
#  'year': 2004}
# {'plot': 'A fictionalized account of the early life of the American president '
#          'as a young lawyer facing his greatest court case.',
#  'title': 'Young Mr. Lincoln',
#  'year': 1939}
# {'plot': 'Our figurine sized supermen hero embarks on an epic surreal journey '
#          'that will take him across the Ethiopian post apocalyptic landscape '
#          'in search of a way to get on the hovering spacecraft that for years '
#          'has become a landmark in the skies.',
#  'title': 'Crumbs',
#  'year': 2015}
# {'plot': 'The story of Walter L. Shaw, a telecommunications genius, and his '
#          'son Walter T. Shaw, a ruthless jewel thief, is a metaphor and a '
#          'symbol for its time - for the twentieth century and for today.',
#  'title': 'Genius on Hold',
#  'year': 2012}
# {'plot': 'A group of five people working to stay alive in a post-apocalyptic '
#          'future discover what they think is a safe, abandoned farmhouse, but '
#          'they soon find themselves fighting to stay alive as a gang of '
#          'bloodthirsty predators attack.',
#  'title': 'The Day',
#  'year': 2011}
# {'plot': 'After a disastrous debut on the pro circuit, a young golfer finds '
#          'himself unexpectedly stranded in Utopia, Texas and welcomed by an '
#          'eccentric rancher.',
#  'title': 'Seven Days in Utopia',
#  'year': 2011}
# {'plot': 'The film starts in the early evening of a normal day: Sophie, a 20 '
#          'year old girl, is pregnant and wanders through the night to get sure '
#          'about her future life. Does she want to be a mother ...',
#  'title': 'Sophiiiie!',
#  'year': 2002}
# {'plot': 'In the near future, Japan is ruled once more by a monarchy. But, '
#          'rebels opposed to this rule seek to overthrow the government. The '
#          'House of Takemikazuchi, a band of assassins is hired by ...',
#  'title': 'The Princess Blade',
#  'year': 2001}
# {'plot': 'In 2027, in a chaotic world in which women have become somehow '
#          'infertile, a former activist agrees to help transport a miraculously '
#          'pregnant woman to a sanctuary at sea.',
#  'title': 'Children of Men',
#  'year': 2006}
# {'plot': 'In the backdrop of Earths polluted future a female FBI agent removes '
#          'Danner, a pleasure android from an asylum in order to coerce him '
#          'into helping her hunt down the criminal psychopath ...',
#  'title': 'Plughead Rewired: Circuitry Man II',
#  'year': 1994}
# {'plot': 'A warlock flees from the 17th to the 20th century, with a '
#          'witch-hunter in hot pursuit.',
#  'title': 'Warlock',
#  'year': 1989}
# {'plot': 'In 1997, when the US President crashes into Manhattan, now a giant '
#          'maximum security prison, a convicted bank robber is sent in for a '
#          'rescue.',
#  'title': 'Escape from New York',
#  'year': 1981}
# {'plot': "The women who enter a science fiction author's life, over the course "
#          'of a few years, after the author loses the woman he considers his '
#          'one true love.',
#  'title': '2046',
#  'year': 2004}
# {'plot': 'Lone group of teens, led by recently released joyrider and his '
#          'disenchanted Belfast girlfriend, strives to leave their mark on "a '
#          'British city in the near future" while attempting to avoid ...',
#  'title': 'Shopping',
#  'year': 1994}
# {'plot': 'The rise of Peter Marshall, from modest Scottish upbringing, to New '
#          'York seminary, time in Atlanta churches, his marriage, appointment '
#          'as chaplain of the US Senate, and early death at 46. Based on real '
#          'events.',
#  'title': 'A Man Called Peter',
#  'year': 1955}
# {'plot': 'A scheming servant works for a wealthy couple in France during the '
#          'late 19th century.',
#  'title': 'Diary of a Chambermaid',
#  'year': 2015}
# {'plot': 'A couple takes a tense and mysterious road trip through the desolate '
#          'yet hauntingly beautiful landscape of central Florida.',
#  'title': "Sun Don't Shine",
#  'year': 2012}
# {'plot': 'When a college piano prodigy tries to check his mother into rehab, '
#          'he is taken hostage by her drug dealer and swept along on a wild '
#          'adventure.',
#  'title': 'Why Stop Now?',
#  'year': 2012}
# {'plot': '5 years after Pitch Black, the wanted criminal Riddick arrives on a '
#          'planet called Helion Prime, and finds himself up against an invading '
#          'empire called the Necromongers, an army that plans to convert or '
#          'kill all humans in the universe.',
#  'title': 'The Chronicles of Riddick',
#  'year': 2004}
# {'plot': 'A blade runner must pursue and try to terminate four replicants who '
#          'stole a ship in space and have returned to Earth to find their '
#          'creator.',
#  'title': 'Blade Runner',
#  'year': 1982}
# {'plot': 'All Charlotte wants from life is to be cut a slice of the media '
#          "agency she has devoted herself to building. When Charlotte's life "
#          'disintegrates, we follow her on a heart-racing journey of '
#          'self-discovery, atonement and danger.',
#  'title': 'Keeping Rosy',
#  'year': 2014}
# {'plot': 'For two years, director Anne Wivel and her camera followed her '
#          'husband, the prominent Danish politician Svend Auken. The initial '
#          'aim was to portray a modern, idealistic politician with ...',
#  'title': 'Svend',
#  'year': 2011}
# {'plot': 'Set in the near future, an ex-jewel thief receives a gift from his '
#          'son: a robot butler programmed to look after him. But soon the two '
#          'companions try their luck as a heist team.',
#  'title': 'Robot & Frank',
#  'year': 2012}
# {'plot': 'Emilia Clarke stars in this heartfelt coming-of-age story about a '
#          'wannabe rock band in Manchester who hatch a plan to hand-deliver '
#          "their demo tape to their idols, The Stone Roses, at the band's "
#          'impending gig at Spike Island.',
#  'title': 'Spike Island',
#  'year': 2012}
# {'plot': 'A guy challenges himself to say "yes" to everything for an entire '
#          'year.',
#  'title': 'Yes Man',
#  'year': 2008}
# {'plot': "A recently engaged woman's life is thrown into turmoil after "
#          'confessing to her fiancè that she once experimented with bestiality.',
#  'title': 'Sleeping Dogs Lie',
#  'year': 2006}
# {'plot': 'In the future, an alien race uses androids as bombs to attack Earth. '
#          'A government weapons specialist is accused of being one such android '
#          'and sets out to prove his innocence.',
#  'title': 'Impostor',
#  'year': 2001}
# {'plot': 'Four 1950s icons meet in the same hotel room and two of them '
#          'discover more in common between them than they ever anticipated.',
#  'title': 'Insignificance',
#  'year': 1985}
# {'plot': "Manuel's fantasy travel through Time goes from Long Ago (Episode 1 - "
#          'O jardim proibido / Le Jardin interdit) through Now (Episode 2 - O '
#          'pique-nique dos sonhos / Le Pique-nique des rèves), ...',
#  'title': 'Manuel on the Island of Wonders',
#  'year': 1984}
# {'plot': 'A nerdish store owner is revived out of cryostasis into a future '
#          'world to fight an oppressive government.',
#  'title': 'Sleeper',
#  'year': 1973}
# {'plot': 'An English scientist runs away from a research center with an atomic '
#          'bomb. In a letter sent to the British Prime Minister he threatens to '
#          'blow up the center of London if the Government ...',
#  'title': 'Seven Days to Noon',
#  'year': 1950}
# {'plot': 'A sci-fi update of the famous 6th Century poem. In a beseiged land, '
#          'Beowulf must battle against the hideous creature Grendel and his '
#          'vengeance seeking mother.',
#  'title': 'Beowulf',
#  'year': 1999}
# {'plot': 'A mischievous young boy, Tom Sawyer (Jonathan Taylor '
#          'Thomas),witnesses a murder by the deadly Injun Joe. Tom becomes '
#          'friends with Huckleberry Finn (Brad Renfro), a boy with no future '
#          'and no...',
#  'title': 'Tom and Huck',
#  'year': 1995}
# {'plot': 'A mischievous young boy, Tom Sawyer (Jonathan Taylor '
#          'Thomas),witnesses a murder by the deadly Injun Joe. Tom becomes '
#          'friends with Huckleberry Finn (Brad Renfro), a boy with no future '
#          'and no...',
#  'title': 'Tom and Huck',
#  'year': 1995}
# {'plot': 'In a future world ruled by good-looking people, a terrorist group of '
#          'mutants led by Ramon Yarritu kidnap the daughter of Orujo, a rich '
#          'businessman, to claim for the rights of the ugly ...',
#  'title': 'Accièn mutante',
#  'year': 1993}
# {'plot': 'An undercover cop in a not-too-distant future becomes involved with '
#          'a dangerous new drug and begins to lose his own identity as a '
#          'result.',
#  'title': 'A Scanner Darkly',
#  'year': 2006}
# {'plot': 'Two men share an odd friendship while they care for two women who '
#          'are both in deep comas.',
#  'title': 'Talk to Her',
#  'year': 2002}
# {'plot': 'In a future world, young people are increasingly becoming addicted '
#          'to an illegal (and potentially deadly) battle simulation game called '
#          'Avalon. When Ash, a star player, hears of rumors that...',
#  'title': 'Avalon',
#  'year': 2001}
# {'plot': 'Billy Flynn, a former boxing champion, is now horse trainer in '
#          'Hialeah. He makes just enough money to raise his little boy T.J., '
#          'over whom he got custody after his wife Annie left him seven...',
#  'title': 'The Champ',
#  'year': 1979}
# {'plot': 'A global contest reading of the Quran by young Muslim children that '
#          'takes place in Cairo, Egypt annually during Ramadan. A coming of age '
#          'story about Muslim kids in modern times.',
#  'title': 'Koran by Heart',
#  'year': 2011}
# {'plot': 'Life changes in an instant for young Mia Hall after a car accident '
#          'puts her in a coma. During an out-of-body experience, she must '
#          'decide whether to wake up and live a life far different than she had '
#          'imagined. The choice is hers if she can go on.',
#  'title': 'If I Stay',
#  'year': 2014}
# {'plot': 'Wars of the future will be fought over water as they are over oil '
#          'today, as the source of human survival enters the global marketplace '
#          'and political arena. Corporate giants, private ...',
#  'title': 'Blue Gold: World Water Wars',
#  'year': 2008}
# {'plot': "It is 300 years into the future. Earth's environment had been "
#          "devastated by mankind's own foolish plans and humankind is "
# ...
#          "'Chachu' (Dharmendra). Muskaan's childhood friend, Ujaala (...",
#  'title': 'Pyaar Kiya To Darna Kya',
#  'year': 1998}
# {'plot': 'A documentary that follows undercover activists trying to stave off '
#          'a man-made mass extinction.',
#  'title': 'Racing Extinction',
#  'year': 2015}
# {'plot': 'Follows the adventures of Aang, a young successor to a long line of '
#          'Avatars, who must master all four elements and stop the Fire Nation '
#          'from enslaving the Water Tribes and the Earth Kingdom.',
#  'title': 'The Last Airbender',
#  'year': 2010}
# {'plot': 'Leaving her provincial home, teenage Mutsuko arrives in Tokyo by '
#          'train to take a job in a major automotive company but finds that she '
#          'is employed by a small auto repair shop owned by ...',
#  'title': 'Always - Sunset on Third Street',
#  'year': 2005}
# {'plot': 'A group of 1950s high schoolers come of age in a bleak, isolated, '
#          'atrophied West Texas town that is slowly dying, both economically '
#          'and culturally.',
#  'title': 'The Last Picture Show',
#  'year': 1971}
# {'plot': 'George and Gwen Kellerman live in the small, quiet town of Twin '
#          'Oaks, Ohio with their two young children and pet dog. George has a '
#          'strong sense of what is right and wrong, especially as it ...',
#  'title': 'The Out of Towners',
#  'year': 1970}
# {'plot': 'Robert Kearns takes on the Detroit automakers who he claims stole '
#          'his idea for the intermittent windshield wiper.',
#  'title': 'Flash of Genius',
#  'year': 2008}
# {'plot': "Josh 'Skreech' Sandoval, a local skate legend and new father in "
#          "Fullerton, California, has to come to terms with the fact that it's "
#          'time to grow up and be responsible for his son and family.',
#  'title': 'Dragonslayer',
#  'year': 2011}
# {'plot': 'In 1961, a Soviet medical officer is conflicted about his position '
#          'overseeing the health of future cosmonauts.',
#  'title': 'Bumazhnyy soldat',
#  'year': 2008}
# {'plot': 'A drunken Scottish poet, who has not written a word in years, feels '
#          'compelled to regain control of his life and work after meeting a '
#          'beautiful young woman.',
#  'title': 'Reuben, Reuben',
#  'year': 1983}
# {'plot': 'An elite team of Navy SEALs embark on a covert mission to recover a '
#          'kidnapped CIA agent.',
#  'title': 'Act of Valor',
#  'year': 2012}
# {'plot': 'An elite team of Navy SEALs embark on a covert mission to recover a '
#          'kidnapped CIA agent.',
#  'title': 'Act of Valor',
#  'year': 2012}
# {'plot': 'The Power of One is an intriguing story of a young English boy named '
#          'Peekay and his passion for changing the world. Growing up he '
#          'suffered as the only English boy in an Afrikaans school. ...',
#  'title': 'The Power of One',
#  'year': 1992}
# {'plot': 'Two straight, single Brooklyn firefighters pretend to be a gay '
#          'couple in order to receive domestic partner benefits.',
#  'title': 'I Now Pronounce You Chuck & Larry',
#  'year': 2007}
# {'plot': 'In Mexico, two teenage boys and an attractive older woman embark on '
#          'a road trip and learn a thing or two about life, friendship, sex, '
#          'and each other.',
#  'title': 'Y Tu Mamè Tambièn',
#  'year': 2001}
# {'plot': 'Roja lives in a Tamil village, and her sister is about to marry a '
#          'man from the city, who decides to marry Roja instead and gets a job '
#          'assignment in Kashmir, where some militants decide to kidnap them.',
#  'title': 'Roja',
#  'year': 1992}
# {'plot': 'In a violent, futuristic city where the police have the authority to '
#          'act as judge, jury and executioner, a cop teams with a trainee to '
#          'take down a gang that deals the reality-altering drug, SLO-MO.',
#  'title': 'Dredd',
#  'year': 2012}
# {'plot': 'At a turning point in his life, a former tennis pro falls for a '
#          'femme-fatal type who happens to be dating his friend and soon-to-be '
#          'brother-in-law.',
#  'title': 'Match Point',
#  'year': 2005}
# {'plot': 'Linda and Eta, two 14-year-old girls, best of friends, retreat to a '
#          'secluded beach beneath the cliffs of Dubrovnik; the morning after, '
#          'only one of them returns.',
#  'title': 'Cure: The Life of Another',
#  'year': 2014}
# {'plot': 'Unfortunately, the 14th Dalai Lama and the Tibetan people receive '
#          'little political support in their drive to put an end to the Chinese '
#          'brutal regime, as international governments are ...',
#  'title': 'When the Dragon Swallowed the Sun',
#  'year': 2010}
# {'plot': "Third part in Aleksandr Sokurov's quadrilogy of Power, following "
#          'Moloch (1999) and Taurus (2001), focuses on Japanese Emperor '
#          "Hirohito and Japan's defeat in World War II when he is finally "
#          'confronted by General Douglas MacArthur who offers him to accept a '
#          'diplomatic defeat for survival.',
#  'title': 'The Sun',
#  'year': 2005}
# {'plot': 'Two documentary filmmakers accidentally uncover the greatest moon '
#          'secret the world has never known, and the powerful organization '
#          'determined to keep it that way.',
#  'title': 'Lunopolis',
#  'year': 2009}
# {'plot': 'The concurrent sexual lives of best friends Jonathan and Sandy are '
#          'presented, those lives which are affected by the sexual mores of the '
#          'time and their own temperament, especially in ...',
#  'title': 'Carnal Knowledge',
#  'year': 1971}
# {'plot': 'The concurrent sexual lives of best friends Jonathan and Sandy are '
#          'presented, those lives which are affected by the sexual mores of the '
#          'time and their own temperament, especially in ...',
#  'title': 'Carnal Knowledge',
#  'year': 1971}
# {'plot': 'Ten years in the making, ONE LUCKY ELEPHANT follows the poignant '
#          'journey of circus producer David Balding as he tries to find a '
#          'nurturing and permanent home for Flora, the 18-year-old ...',
#  'title': 'One Lucky Elephant',
#  'year': 2010}
# {'plot': 'Father and son run their own two-man furniture business but have '
#          'opposing ideologies on what should guide their craftsmanship, '
#          'quality or commerce.',
#  'title': 'A Simple Curve',
#  'year': 2005}
# {'plot': 'Photographer Robert Kincaid wanders into the life of housewife '
#          'Francesca Johnson, for four days in the 1960s.',
#  'title': 'The Bridges of Madison County',
#  'year': 1995}
# {'plot': 'A regular family living in the outskirts of Lisbon sees the serenity '
#          'of their lives shaken beyond any remedy within a week.',
#  'title': 'Blood of My Blood',
#  'year': 2011}
# {'plot': 'After crash landing near a desert town, an alien enlists the help of '
#          'a local waitress to re-capture a monster that escaped from the '
#          'wreckage of his space ship.',
#  'title': 'Alien Trespass',
#  'year': 2009}
# {'plot': 'Young Danny Flynn is released from prison after 14 years after '
#          '"taking the rap" for the IRA and tries to rebuild his life in his '
#          'old Belfast neighborhood.',
#  'title': 'The Boxer',
#  'year': 1997}
# {'plot': 'Young Danny Flynn is released from prison after 14 years after '
#          '"taking the rap" for the IRA and tries to rebuild his life in his '
#          'old Belfast neighborhood.',
#  'title': 'The Boxer',
#  'year': 1997}
# {'plot': 'The life of a divorced television writer dating a teenage girl is '
#          "further complicated when he falls in love with his best friend's "
#          'mistress.',
#  'title': 'Manhattan',
#  'year': 1979}
# {'plot': "A film adaptation of Steve Martin's novel about a complex love "
#          'triangle between a bored salesgirl, a wealthy businessman and an '
#          'aimless young man.',
#  'title': 'Shopgirl',
#  'year': 2005}
# {'plot': "A young man's peculiar upbringing renders him unable to competently "
#          'cope with the struggle of growing up.',
#  'title': 'Igby Goes Down',
#  'year': 2002}
# {'plot': 'Kaoru dreamily gazes from her bedroom window each morning just '
#          'before dawn. She can see a stretch of the beach in front of her '
#          "parent's house on a hill in Kamakura, but focuses upon the ...",
#  'title': 'Midnight Sun',
#  'year': 2006}
# {'plot': 'INSIDE HANA\'S SUITCASE A Theatrical Documentary Synopsis "Inside '
#          'Hana\'s Suitcase", is the poignant story of two young children who '
#          'grew up in pre-WWII Czechoslovakia and the terrible events...',
#  'title': "Inside Hana's Suitcase",
#  'year': 2009}
# {'plot': 'A manager of an orphanage in India is sent to Copenhagen, Denmark, '
#          'where he discovers a life-altering family secret.',
#  'title': 'After the Wedding',
#  'year': 2006}
# {'plot': 'A small-town detective searching for a missing man has only one '
#          'lead: a connection with a New York prostitute.',
#  'title': 'Klute',
#  'year': 1971}
# {'plot': 'The most popular kid on campus meets a beautiful journalist who '
#          "makes him realize that maybe he's afraid to graduate.",
#  'title': 'Van Wilder: Party Liaison',
#  'year': 2002}
# {'plot': 'This film takes a serious look at the lives of Westernized '
#          'Non-Resident Indians (NRIs) in North America. Whereas Dilwale '
#          'Dulhania Le Jayenge was about NRIs with Indian hearts, Pardes is ...',
#  'title': 'Pardes',
#  'year': 1997}
# {'plot': 'The humorous adventures of a group of American tourists taking a '
#          '18-day guided bus tour of 9 European countries.',
#  'title': "If It's Tuesday, This Must Be Belgium",
#  'year': 1969}
# {'plot': 'In a post-apocalyptic future, a biological warfare program gone '
#          'wrong leaves only four survivors defending themselves from "the '
#          'infected" - mindless killers. As they struggle to survive and make '
#          'sense of what is happening, they find another survivor, intent on '
#          'revealing the truth.',
#  'title': 'Another World',
#  'year': 2015}
# {'plot': "A recently widowed man's son calls a radio talk-show in an attempt "
#          'to find his father a partner.',
#  'title': 'Sleepless in Seattle',
#  'year': 1993}
# {'plot': 'A couple of high school grads spend one final night cruising the '
#          'strip with their buddies before they go off to college.',
#  'title': 'American Graffiti',
#  'year': 1973}
# {'plot': 'Traces the birth and failure of new media company govWorks.com.',
#  'title': 'Startup.com',
#  'year': 2001}
# {'plot': 'Hana Doda, still a girl, escapes from her destiny of being wife and '
#          'servant which is imposed on the women in the inhospitable mountains '
#          'in Albania. She appeals to the old law of the Kanun ...',
#  'title': 'Sworn Virgin',
#  'year': 2015}
# {'plot': 'In the small, predominantly working class town of Inniston, Ontario, '
#          'Marc Hall is a high school senior with a promising future in his '
#          'chosen career as lawyer. He is bright, well liked by ...',
#  'title': 'Prom Queen: The Marc Hall Story',
#  'year': 2004}
# {'plot': 'Stolen Seas presents a chilling exploration of the Somali pirate '
#          'phenomenon and forces you to rethink everything you thought you knew '
#          "about pirates. It's November 8th, 2008 and the CEC ...",
#  'title': 'Stolen Seas',
#  'year': 2012}
# {'plot': 'An older British reporter vies with a young U.S. doctor for the '
#          'affections of a beautiful Vietnamese woman.',
#  'title': 'The Quiet American',
#  'year': 2002}
# {'plot': 'A biography of Chinese Martial Arts Master Huo Yuanjia, who is the '
#          'founder and spiritual guru of the Jin Wu Sports Federation.',
#  'title': 'Fearless',
#  'year': 2006}
# {'plot': 'Spying on her students, a teacher finds an exciting hobby.',
#  'title': 'The Invisible Eye',
#  'year': 2010}
# {'plot': 'In the distant future, a small waste collecting robot inadvertently '
#          'embarks on a space journey that will ultimately decide the fate of '
#          'mankind.',
#  'title': 'WALLèE',
#  'year': 2008}
# {'plot': 'A young man named Amadeo sets off on an unexpected adventure with '
#          'the players of his beloved Foosball game.',
#  'title': 'Underdogs',
#  'year': 2013}
# {'plot': 'Orphaned by smallpox, young Lancashire country lady Fanny Hill '
#          "cheerfully accepts her friend Esther Davies's offer to join the "
#          "London 'working girls' with Mrs. Brown, a madam who recruits ...",
#  'title': 'Fanny Hill',
#  'year': 2007}
# {'plot': 'Nothing will be the same at the end of this summer for Gelsomina and '
#          'her three younger sisters.',
#  'title': 'The Wonders',
#  'year': 2014}
# {'plot': "A woman's journey of self-discovery and the dynamics of her zany "
#          'family.',
#  'title': 'Sleeping with the Fishes',
#  'year': 2013}
# {'plot': 'Five loosely intertwined stories of the emotional issues facing '
#          'individual middle-aged Angelenas are presented. In "This Is Dr. '
#          'Keener", physician Elaine Keener is spending the day taking ...',
#  'title': 'Things You Can Tell Just by Looking at Her',
#  'year': 2000}
# {'plot': "As he struggles with Alzheimer's disease, country-music legend Glen "
#          'Campbell embarks on his farewell tour in the U.S., Australia, and '
#          'Europe.',
#  'title': "Glen Campbell: I'll Be Me",
#  'year': 2014}
# {'plot': 'How will the Germans react to the armistice of the 8th of September '
#          '1943, due to which Italy betrays them and sides with the allied '
#          'forces? This is the distressing questions that a group of...',
#  'title': 'Hotel Meina',
#  'year': 2007}
# {'plot': '1933: An ocean liner belonging to a second-rate German company is '
#          'making a twenty-six day voyage from Veracruz, Mexico to Bremerhaven, '
#          'Germany. Along the way it will stop in Cuba to pick up...',
#  'title': 'Ship of Fools',
#  'year': 1965}
# {'plot': '1935. A group of elderly British women, who the Italians have named '
#          'the Scorpioni, have chosen Italy, specifically Florence, as a place '
#          'to live to blend their proper British sensibilities ...',
#  'title': 'Tea with Mussolini',
#  'year': 1999}
# {'plot': 'The incredible rise of 62-year-old aspiring soul singer Charles '
#          'Bradley, whose debut album rocketed him from a hard life in the '
#          "Brooklyn Housing Projects to Rolling Stone Magazine's top 50 albums "
#          'of 2011.',
#  'title': 'Charles Bradley: Soul of America',
#  'year': 2012}
# {'plot': 'A township near Cape Town. Two young teens, Madiba and Sipho, find a '
#          'gun and a camera. Sipho takes the gun, and Madiba the camera, '
#          'sealing their fate.',
#  'title': 'The Wooden Camera',
#  'year': 2003}
# {'plot': 'An imperial guard and his three traitorous childhood friends ordered '
#          'to hunt him down get accidentally buried and kept frozen in time. '
#          '400 years later passes and they are defrosted continuing the battle '
#          'they left behind.',
#  'title': 'Iceman',
#  'year': 2014}
# {'plot': 'A lawyer sees the chance to salvage his career and self-respect by '
#          'taking a medical malpractice case to trial rather than settling.',
#  'title': 'The Verdict',
#  'year': 1982}
# {'plot': 'Brooklyn, 1975: two brothers looking for a way out of their '
#          'working-class neighborhood make a pact to rob a local theater on the '
#          'night of a Rolling Stones concert.',
#  'title': 'White Irish Drinkers',
#  'year': 2010}
# {'plot': 'The tribes of Israel need to defeat the superior might of the '
#          'Philistines: "Now appoint a king to lead us, such as all the other '
#          'nations have." (I Samuel, 8:5). And so the prophet Samuel ...',
#  'title': 'David',
#  'year': 1997}
# {'plot': 'The true story of Doug Bruce who woke up on Coney Island with total '
#          'amnesia. This documentary follows him as he rediscovers himself and '
#          'the world around him.',
#  'title': 'Unknown White Male',
#  'year': 2005}
# {'plot': 'A movie about the life, work and death of Jesus as we know it from '
#          'the Bible.',
#  'title': 'Jesus',
#  'year': 1999}
# {'plot': 'A movie about the life, work and death of Jesus as we know it from '
#          'the Bible.',
#  'title': 'Jesus',
#  'year': 1999}

# %% [markdown]
# ## Restaurantes
#
# Cargaremos información del json restaurantes que encontraréis en la carpeta.

# %%
import json

restaurantes = []
with open("./data/restaurants.json", "r") as json_file:
    for line in json_file:
        restaurantes.append(json.loads(line))

rest_collection = database.get_collection("restaurantes")
rest_collection.insert_many(restaurantes)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[22], line 9
#       6         restaurantes.append(json.loads(line))
#       8 rest_collection = database.get_collection("restaurantes")
# ----> 9 rest_collection.insert_many(restaurantes)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\collection.py:742, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     740 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     741 blk.ops = list(gen())
# --> 742 blk.execute(write_concern, session, _Op.INSERT)
#     743 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\bulk.py:595, in _Bulk.execute(self, write_concern, session, operation)
#     593         return None
#     594 else:
# --> 595     return self.execute_command(generator, write_concern, session, operation)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\bulk.py:452, in _Bulk.execute_command(self, generator, write_concern, session, operation)
#     441     self._execute_command(
#     442         generator,
#     443         write_concern,
#    (...)
#     448         full_result,
#     449     )
#     451 client = self.collection.database.client
# --> 452 client._retryable_write(
#     453     self.is_retryable,
#     454     retryable_bulk,
#     455     session,
#     456     operation,
#     457     bulk=self,
#     458     operation_id=op_id,
#     459 )
#     461 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#     462     _raise_bulk_write_error(full_result)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1569, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    1555 """Execute an operation with consecutive retries if possible
#    1556
#    1557 Returns func()'s return value on success. On error retries the same
#    (...)
#    1566 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    1567 """
#    1568 with self._tmp_session(session) as s:
# -> 1569     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1455, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1450 # Ensure that the options supports retry_writes and there is a valid session not in
#    1451 # transaction, otherwise, we will not support retry behavior for this txn.
#    1452 retryable = bool(
#    1453     retryable and self.options.retry_writes and session and not session.in_transaction
#    1454 )
# -> 1455 return self._retry_internal(
#    1456     func=func,
#    1457     session=session,
#    1458     bulk=bulk,
#    1459     operation=operation,
#    1460     retryable=retryable,
#    1461     operation_id=operation_id,
#    1462 )
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1501, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1464 @_csot.apply
#    1465 def _retry_internal(
#    1466     self,
#    (...)
#    1475     operation_id: Optional[int] = None,
#    1476 ) -> T:
#    1477     """Internal retryable helper for all client transactions.
#    1478
#    1479     :param func: Callback function we want to retry
#    (...)
#    1488     :return: Output of the calling func()
#    1489     """
#    1490     return _ClientConnectionRetryable(
#    1491         mongo_client=self,
#    1492         func=func,
#    1493         bulk=bulk,
#    1494         operation=operation,
#    1495         is_read=is_read,
#    1496         session=session,
#    1497         read_pref=read_pref,
#    1498         address=address,
#    1499         retryable=retryable,
#    1500         operation_id=operation_id,
# -> 1501     ).run()
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:2347, in _ClientConnectionRetryable.run(self)
#    2345 self._check_last_error(check_csot=True)
#    2346 try:
# -> 2347     return self._read() if self._is_read else self._write()
#    2348 except ServerSelectionTimeoutError:
#    2349     # The application may think the write was never attempted
#    2350     # if we raise ServerSelectionTimeoutError on the retry
#    2351     # attempt. Raise the original exception instead.
#    2352     self._check_last_error()
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:2451, in _ClientConnectionRetryable._write(self)
#    2449 is_mongos = False
#    2450 self._server = self._get_server()
# -> 2451 with self._client._checkout(self._server, self._session) as conn:
#    2452     max_wire_version = conn.max_wire_version
#    2453     sessions_supported = (
#    2454         self._session
#    2455         and self._server.description.retryable_writes_supported
#    2456         and conn.supports_sessions
#    2457     )
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1260, in MongoClient._checkout(self, server, session)
#    1258     yield session._pinned_connection
#    1259     return
# -> 1260 with server.checkout(handler=err_handler) as conn:
#    1261     # Pin this session to the selected server or connection.
#    1262     if (
#    1263         in_txn
#    1264         and session
#    (...)
#    1269         )
#    1270     ):
#    1271         session._pin(server, conn)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:1763, in Pool.checkout(self, handler)
#    1754     if _CONNECTION_LOGGER.isEnabledFor(logging.DEBUG):
#    1755         _debug_log(
#    1756             _CONNECTION_LOGGER,
#    1757             clientId=self._client_id,
#    (...)
#    1760             serverPort=self.address[1],
#    1761         )
# -> 1763 conn = self._get_conn(checkout_started_time, handler=handler)
#    1765 if self.enabled_for_cmap:
#    1766     assert listeners is not None
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:1921, in Pool._get_conn(self, checkout_started_time, handler)
#    1919 else:  # We need to create a new connection
#    1920     try:
# -> 1921         conn = self.connect(handler=handler)
#    1922     finally:
#    1923         with self._max_connecting_cond:
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:1725, in Pool.connect(self, handler)
#    1722     if handler:
#    1723         handler.contribute_socket(conn, completed_handshake=False)
# -> 1725     conn.authenticate()
#    1726 except BaseException:
#    1727     conn.close_conn(ConnectionClosedReason.ERROR)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:1098, in Connection.authenticate(self, reauthenticate)
#    1095 if creds:
#    1096     from pymongo import auth
# -> 1098     auth.authenticate(creds, self, reauthenticate=reauthenticate)
#    1099 self.ready = True
#    1100 if self.enabled_for_cmap:
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\auth.py:656, in authenticate(credentials, conn, reauthenticate)
#     654     _authenticate_oidc(credentials, conn, reauthenticate)
#     655 else:
# --> 656     auth_func(credentials, conn)
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\auth.py:560, in _authenticate_default(credentials, conn)
#     558         return _authenticate_scram(credentials, conn, "SCRAM-SHA-256")
#     559     else:
# --> 560         return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#     561 else:
#     562     return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\auth.py:338, in _authenticate_scram(credentials, conn, mechanism)
#     331 server_sig = standard_b64encode(_hmac(server_key, auth_msg, digestmod).digest())
#     333 cmd = {
#     334     "saslContinue": 1,
#     335     "conversationId": res["conversationId"],
#     336     "payload": Binary(client_final),
#     337 }
# --> 338 res = conn.command(source, cmd)
#     340 parsed = _parse_scram_response(res["payload"])
#     341 if not hmac.compare_digest(parsed[b"v"], server_sig):
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\helpers.py:342, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     339 from pymongo.pool import Connection
#     341 try:
# --> 342     return func(*args, **kwargs)
#     343 except OperationFailure as exc:
#     344     if no_reauth:
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:988, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     986     self._raise_if_not_writable(unacknowledged)
#     987 try:
# --> 988     return command(
#     989         self,
#     990         dbname,
#     991         spec,
#     992         self.is_mongos,
#     993         read_preference,
#     994         codec_options,
#     995         session,
#     996         client,
#     997         check,
#     998         allowable_errors,
#     999         self.address,
#    1000         listeners,
#    1001         self.max_bson_size,
#    1002         read_concern,
#    1003         parse_write_concern_error=parse_write_concern_error,
#    1004         collation=collation,
#    1005         compression_ctx=self.compression_context,
#    1006         use_op_msg=self.op_msg_enabled,
#    1007         unacknowledged=unacknowledged,
#    1008         user_fields=user_fields,
#    1009         exhaust_allowed=exhaust_allowed,
#    1010         write_concern=write_concern,
#    1011     )
#    1012 except (OperationFailure, NotPrimaryError):
#    1013     raise
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\network.py:212, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     210             client._process_response(response_doc, session)
#     211         if check:
# --> 212             helpers._check_command_response(
#     213                 response_doc,
#     214                 conn.max_wire_version,
#     215                 allowable_errors,
#     216                 parse_write_concern_error=parse_write_concern_error,
#     217             )
#     218 except Exception as exc:
#     219     duration = datetime.datetime.now() - start
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\helpers.py:248, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     245 elif code == 43:
#     246     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 248 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: bad auth : authentication failed, full error: {'ok': 0, 'errmsg': 'bad auth : authentication failed', 'code': 8000, 'codeName': 'AtlasError'}

# %% [markdown]
# Acabamos de crear una nueva colección con información de restaurantes.

# %%
rest_collection.count_documents({})
# Out:
# 25359

# %% [markdown]
# Podemos ver qué pinta parecen tener.

# %%
pprint(rest_collection.find_one())
# Out:
# {'_id': ObjectId('666eae8cefae68146ff0ef56'),
#  'address': {'building': '1007',
#              'coord': [-73.856077, 40.848447],
#              'street': 'Morris Park Ave',
#              'zipcode': '10462'},
#  'borough': 'Bronx',
#  'cuisine': 'Bakery',
#  'grades': [{'date': {'$date': 1393804800000}, 'grade': 'A', 'score': 2},
#             {'date': {'$date': 1378857600000}, 'grade': 'A', 'score': 6},
#             {'date': {'$date': 1358985600000}, 'grade': 'A', 'score': 10},
#             {'date': {'$date': 1322006400000}, 'grade': 'A', 'score': 9},
#             {'date': {'$date': 1299715200000}, 'grade': 'B', 'score': 14}],
#  'name': 'Morris Park Bake Shop',
#  'restaurant_id': '30075445'}

# %% [markdown]
# #### ¿Cuantos restaurantes hay en manhattan?

# %% [markdown]
# #### ¿Cuantos de cocina china o japonesa?

# %%
# Aquí va vuestro código

# %% [markdown]
# #### ¿Cuantos restaurantes por distrito?

# %%
# Aquí va vuestro código

# %% [markdown]
# ### Agregaciones
#
# MongoDB permite hacer ciertas agregaciones aunque la sintaxis es un tanto compleja... se conoce como el _pipeline de agregación_.
#
# ![agregacion](./img/aggpipeline.png)

# %% [markdown]
# Tenéis información sobre las distintas etapas y operadores específicos en la documentación oficial: https://www.mongodb.com/docs/languages/python/pymongo-driver/current/aggregation/aggregation-tutorials/

# %% [markdown]
# El operador `$match` hace lo mismo que nuestra función find. Usaremos una segunda etapa con el operador `$limit` para solo mostrar un elemento.

# %%
resultado = rest_collection.aggregate([
    {"$match" : {"borough" : "Manhattan"}},
    {"$limit" : 1}
])

for elemento in resultado:
    pprint(elemento)
# Out:
# {'_id': ObjectId('666eae8cefae68146ff0ef58'),
#  'address': {'building': '351',
#              'coord': [-73.98513559999999, 40.7676919],
#              'street': 'West   57 Street',
#              'zipcode': '10019'},
#  'borough': 'Manhattan',
#  'cuisine': 'Irish',
#  'grades': [{'date': {'$date': 1409961600000}, 'grade': 'A', 'score': 2},
#             {'date': {'$date': 1374451200000}, 'grade': 'A', 'score': 11},
#             {'date': {'$date': 1343692800000}, 'grade': 'A', 'score': 12},
#             {'date': {'$date': 1325116800000}, 'grade': 'A', 'score': 12}],
#  'name': 'Dj Reynolds Pub And Restaurant',
#  'restaurant_id': '30191841'}

# %% [markdown]
# Podemos agregar la información seleccionado un campo a contener el `_id` (sería el campo por el que agrupamos). Para indicar que agruparemos por el valor de un campo usaremos el `$` en este caso sobre el campo.

# %%
resultado = rest_collection.aggregate([ # INTENTAR NO UTILIZAR ESTE COMANDO DE AGREGACIÓN 
    {"$group" : { "_id" : "$borough", "cuantos": {"$sum" : 1}} } # "$borough" TIENE $ PORQUE LO QUE INTERESA ES EL VALOR QUE ALMACENA 
])

for elemento in resultado:
    pprint(elemento)
# Out:
# {'_id': 'Brooklyn', 'cuantos': 6086}
# {'_id': 'Staten Island', 'cuantos': 969}
# {'_id': 'Queens', 'cuantos': 5656}
# {'_id': 'Bronx', 'cuantos': 2338}
# {'_id': 'Missing', 'cuantos': 51}
# {'_id': 'Manhattan', 'cuantos': 10259}

# %% [markdown]
# Agregar la información que esté en un elemento tipo `array` requiere que primero saquemos cada elemento del array a un documento individual. Para ello usaremos el operador `$unwind` en indicaremos el valor de un campo, que se hace empleando el símbolo del dolar (`$`).

# %%
resultado = rest_collection.aggregate([
    {"$match" : {"borough" : "Manhattan"}},
    {"$unwind" : "$grades"},
    {"$limit" : 1}
])

for elemento in resultado:
    pprint(elemento)
# Out:
# {'_id': ObjectId('666eae8cefae68146ff0ef58'),
#  'address': {'building': '351',
#              'coord': [-73.98513559999999, 40.7676919],
#              'street': 'West   57 Street',
#              'zipcode': '10019'},
#  'borough': 'Manhattan',
#  'cuisine': 'Irish',
#  'grades': {'date': {'$date': 1409961600000}, 'grade': 'A', 'score': 2},
#  'name': 'Dj Reynolds Pub And Restaurant',
#  'restaurant_id': '30191841'}

# %% [markdown]
# Y posterior realizar el agrupado y las operaciones de agregación necesarias. Cuando dispongamos de campos anidados usaremos la puntuación `.` como signo de anidamiento (`campo_primer_nivel.campo_segundo_nivel`). Fijaros en el caso de _grades.score_

# %%
resultado = rest_collection.aggregate([
    {"$match" : {"borough" : "Manhattan"}},
    {"$unwind" : "$grades"}, # AVERIGUAR QUE HACE EL OPERADOR "$unwind"  
    {"$group": {"_id": "$name", "nota_promedio" : {"$avg" : "$grades.score"}}}
])

for elemento in resultado:
    pprint(elemento)
# Out:
# {'_id': 'Qi', 'nota_promedio': 11.142857142857142}
# {'_id': 'The Canal Park Playhouse, Inc', 'nota_promedio': 7.5}
# {'_id': 'Ai Zhen Foo Chow Restaurant', 'nota_promedio': 20.333333333333332}
# {'_id': 'Great China', 'nota_promedio': 12.2}
# {'_id': 'Kukaramakara Restaurant', 'nota_promedio': 15.8}
# {'_id': 'Morso', 'nota_promedio': 11.0}
# {'_id': "Lil Frankie'S Pizza", 'nota_promedio': 14.25}
# {'_id': 'Delizia  Ristorante', 'nota_promedio': 11.2}
# {'_id': 'Cafe Gitane', 'nota_promedio': 10.9}
# {'_id': 'Hearst Corporation Edr', 'nota_promedio': 3.6666666666666665}
# {'_id': 'Jaiya Thai Oriental Restaurant', 'nota_promedio': 10.5}
# {'_id': 'Barnes & Noble Booksellers', 'nota_promedio': 8.0}
# {'_id': 'Moonstruck East', 'nota_promedio': 17.285714285714285}
# {'_id': 'The Summit', 'nota_promedio': 14.166666666666666}
# {'_id': 'The Carnegie Cigar Club And Lounge', 'nota_promedio': 11.0}
# {'_id': 'Masala Times', 'nota_promedio': 12.166666666666666}
# {'_id': 'Cafe G', 'nota_promedio': 11.0}
# {'_id': 'Albion', 'nota_promedio': 22.25}
# {'_id': 'Los Bravos', 'nota_promedio': 29.0}
# {'_id': 'Met Life', 'nota_promedio': 8.0}
# {'_id': 'Go Go Thai', 'nota_promedio': 14.0}
# {'_id': 'Va Presto', 'nota_promedio': 11.0}
# {'_id': 'Nancy Whiskey Pub', 'nota_promedio': 14.333333333333334}
# {'_id': 'Grand Cafe', 'nota_promedio': 10.2}
# {'_id': 'Benares', 'nota_promedio': 9.5}
# {'_id': 'Ecuatoriana Restaurant', 'nota_promedio': 13.666666666666666}
# {'_id': 'Xe May', 'nota_promedio': 8.0}
# {'_id': 'Freshday', 'nota_promedio': 20.714285714285715}
# {'_id': 'Al-Dente', 'nota_promedio': 8.2}
# {'_id': 'Tom And Jerry Bar', 'nota_promedio': 11.0}
# {'_id': 'Court Street Grocers', 'nota_promedio': 5.0}
# {'_id': 'Old Homestead', 'nota_promedio': 11.8}
# {'_id': "Mike'S Deli", 'nota_promedio': 10.714285714285714}
# {'_id': "Tgi Friday'S", 'nota_promedio': 11.5}
# {'_id': 'Oaxaca Taquerita', 'nota_promedio': 9.0}
# {'_id': 'Peking Roast Duck', 'nota_promedio': 17.5}
# {'_id': 'The Cornell Center Of New York', 'nota_promedio': 7.6}
# {'_id': 'Jpmc Cafeteria', 'nota_promedio': 6.0}
# {'_id': 'New Broadway Pizzeria And Coffee', 'nota_promedio': 19.0}
# {'_id': "Taco Bell, Dunkin' Donuts", 'nota_promedio': 5.0}
# {'_id': 'Bread Market Cafe', 'nota_promedio': 10.0}
# {'_id': 'Kiosku', 'nota_promedio': 3.5}
# {'_id': 'The Guthrie Inn', 'nota_promedio': 13.333333333333334}
# {'_id': 'Texas Rotisserie', 'nota_promedio': 17.6}
# {'_id': 'Rabbit Club', 'nota_promedio': 5.4}
# {'_id': 'Hot & Crusty Bagels Cafe', 'nota_promedio': 10.2}
# {'_id': 'Mansions Cater', 'nota_promedio': 15.333333333333334}
# {'_id': 'Redemption Grill', 'nota_promedio': 15.714285714285714}
# {'_id': 'Silver Palace', 'nota_promedio': 9.125}
# {'_id': 'The Helen Hayes Theatre', 'nota_promedio': 5.5}
# {'_id': 'Ramen.Co', 'nota_promedio': 19.0}
# {'_id': "Moran'S Chelsea", 'nota_promedio': 11.25}
# {'_id': 'Salud Y Esperanza', 'nota_promedio': 0.0}
# {'_id': 'Bagel Talk', 'nota_promedio': 10.8}
# {'_id': 'Brazilia Cafe', 'nota_promedio': 9.0}
# {'_id': 'Kyochon', 'nota_promedio': 21.4}
# {'_id': "Mojito'S", 'nota_promedio': 19.857142857142858}
# {'_id': 'Off The Wall', 'nota_promedio': 10.142857142857142}
# {'_id': 'Royal Siam Thai & Sushi', 'nota_promedio': 11.666666666666666}
# {'_id': 'Maiden Lane', 'nota_promedio': 6.0}
# {'_id': 'New Roma Pizza', 'nota_promedio': 20.333333333333332}
# {'_id': 'Ann Taylor', 'nota_promedio': 8.75}
# {'_id': 'Anesis Cafe', 'nota_promedio': 6.5}
# {'_id': 'The Harrison', 'nota_promedio': 9.6}
# {'_id': 'Napoli Pizza & Pasta', 'nota_promedio': 8.5}
# {'_id': 'Food Passion Catering', 'nota_promedio': 12.0}
# {'_id': 'Manhattan Elite', 'nota_promedio': 3.0}
# {'_id': 'Ballfields Cafe', 'nota_promedio': 11.0}
# {'_id': 'Soho Grand Hotel', 'nota_promedio': 11.0}
# {'_id': 'Da Noi', 'nota_promedio': 11.333333333333334}
# {'_id': 'Aki Sushi West', 'nota_promedio': 26.0}
# {'_id': 'Au Bon Pain', 'nota_promedio': 9.25287356321839}
# {'_id': "Lenz'S", 'nota_promedio': 15.25}
# {'_id': 'Porteno', 'nota_promedio': 10.6}
# {'_id': 'The Iron Horse', 'nota_promedio': 21.666666666666668}
# {'_id': 'Sirio', 'nota_promedio': 10.8}
# {'_id': 'Tortaria', 'nota_promedio': 11.25}
# {'_id': 'Radio Star', 'nota_promedio': 10.2}
# {'_id': 'Subway Sandwich', 'nota_promedio': 7.666666666666667}
# {'_id': 'Sac Cafe', 'nota_promedio': 6.5}
# {'_id': 'Zibetto Espresso Bar', 'nota_promedio': 9.8}
# {'_id': 'Ben & Jacks Steakhouse', 'nota_promedio': 18.5}
# {'_id': 'Hane Sushi', 'nota_promedio': 12.0}
# {'_id': 'Kava Cafe', 'nota_promedio': 11.125}
# {'_id': 'Chipotle Mexican Grill#1766', 'nota_promedio': 10.0}
# {'_id': 'Thompson Alchemists', 'nota_promedio': 0.6666666666666666}
# {'_id': 'Pizza King', 'nota_promedio': 18.0}
# {'_id': 'Teleon Cafe', 'nota_promedio': 11.666666666666666}
# {'_id': 'Harlem Delight', 'nota_promedio': 10.8}
# {'_id': 'Croton Reservoir Tavern', 'nota_promedio': 10.2}
# {'_id': 'Continental', 'nota_promedio': 12.4}
# {'_id': 'Grill 21', 'nota_promedio': 15.333333333333334}
# {'_id': 'Desmonds Steakhouse And Grill', 'nota_promedio': 21.5}
# {'_id': 'Murray Hill Diner', 'nota_promedio': 12.0}
# {'_id': 'Le Zie Trattoria', 'nota_promedio': 12.833333333333334}
# {'_id': 'Guadalupe Bar And Grill', 'nota_promedio': 10.2}
# {'_id': 'Pick-A-Bagel', 'nota_promedio': 7.375}
# {'_id': 'Double Dragon', 'nota_promedio': 9.666666666666666}
# {'_id': "Grini'S Grill & Restaurant", 'nota_promedio': 14.714285714285714}
# {'_id': 'Bluebird Coffee Shop', 'nota_promedio': 11.6}
# {'_id': 'Jimbos Hamburger Palace', 'nota_promedio': 11.2}
# {'_id': 'Smash Burger', 'nota_promedio': 7.0}
# {'_id': 'Eleven Madison Park', 'nota_promedio': 10.0}
# {'_id': 'Saggio Restaurant', 'nota_promedio': 14.75}
# {'_id': 'Mondrian Soho/ Isola', 'nota_promedio': 6.4}
# {'_id': 'Volare Restaurant', 'nota_promedio': 17.6}
# {'_id': 'Umami Shoppu', 'nota_promedio': 8.0}
# {'_id': 'Nishida Sho-Ten', 'nota_promedio': 17.0}
# {'_id': 'Cabana', 'nota_promedio': 8.833333333333334}
# {'_id': 'Blind Barber', 'nota_promedio': 20.2}
# {'_id': 'Indikitch', 'nota_promedio': 11.0}
# {'_id': 'Dippin Dots', 'nota_promedio': 3.6666666666666665}
# {'_id': 'Kitchen Provance', 'nota_promedio': 13.6}
# {'_id': 'Ginza Sushi', 'nota_promedio': 7.0}
# {'_id': 'Columbo Yogurt/ Taco Bell/ Nathans/ Tim Horton/Pizza Hut',
#  'nota_promedio': 9.5}
# {'_id': 'The Picnic Basket', 'nota_promedio': 10.6}
# {'_id': "Lorelli 'S", 'nota_promedio': 12.333333333333334}
# {'_id': 'Queen Vic', 'nota_promedio': 14.4}
# {'_id': 'The Lite Choice', 'nota_promedio': 9.0}
# {'_id': 'Zoob Zib Thai Noodle / Aura', 'nota_promedio': 14.285714285714286}
# {'_id': 'Mini Express', 'nota_promedio': 8.25}
# {'_id': "Oren'S Daily Roast", 'nota_promedio': 7.2}
# {'_id': 'Krico', 'nota_promedio': 2.0}
# {'_id': 'Marriott Marquis Pastry Shop', 'nota_promedio': 8.75}
# {'_id': 'Katsuhama Restaurant', 'nota_promedio': 14.75}
# {'_id': 'Toto Sushi', 'nota_promedio': 14.8}
# {'_id': 'Effys At The 92Y', 'nota_promedio': 8.333333333333334}
# {'_id': "Moe'S", 'nota_promedio': 9.5}
# {'_id': 'Pick A Bagel', 'nota_promedio': 11.214285714285714}
# {'_id': 'Abace Sushi', 'nota_promedio': 13.0}
# {'_id': 'Nobu Fifty Seven', 'nota_promedio': 9.666666666666666}
# {'_id': 'Sugar Factory', 'nota_promedio': 11.75}
# {'_id': 'Indigo Indian Bistro', 'nota_promedio': 14.4}
# {'_id': "Luzzo'S", 'nota_promedio': 13.4}
# {'_id': 'Liberatos Pizza', 'nota_promedio': 13.8}
# {'_id': 'Peridance Capezio Center Cafe', 'nota_promedio': 6.75}
# {'_id': 'Vu 46', 'nota_promedio': 7.0}
# {'_id': 'The Gin Mill', 'nota_promedio': 10.0}
# {'_id': 'Pier Side Cafe', 'nota_promedio': 10.25}
# {'_id': 'The Horse Box', 'nota_promedio': 8.75}
# {'_id': 'Maru', 'nota_promedio': 22.0}
# {'_id': '14Th Street Pizza Bagel Cafe', 'nota_promedio': 9.5}
# {'_id': 'El Manantial Bakery', 'nota_promedio': 12.8}
# {'_id': 'Ella', 'nota_promedio': 19.666666666666668}
# {'_id': 'Rain Thai Restaurant', 'nota_promedio': 17.166666666666668}
# {'_id': 'Rapha Racing', 'nota_promedio': 12.0}
# {'_id': 'Wise Men', 'nota_promedio': 11.666666666666666}
# {'_id': "Murphy'S Tavern", 'nota_promedio': 14.5}
# {'_id': "Maria'S Mont Blanc Restaurant", 'nota_promedio': 7.25}
# {'_id': "Spitzer'S Corner", 'nota_promedio': 7.5}
# {'_id': 'Thai Angel', 'nota_promedio': 12.0}
# {'_id': 'Supper', 'nota_promedio': 9.714285714285714}
# {'_id': 'Dulce Vida Cafe', 'nota_promedio': 6.833333333333333}
# {'_id': 'Manhattan Center', 'nota_promedio': 21.25}
# {'_id': 'Midtown 1015', 'nota_promedio': 14.25}
# {'_id': '68 Deli Canal Store', 'nota_promedio': 6.0}
# {'_id': 'Nuevo Sabor Restaurant', 'nota_promedio': 12.333333333333334}
# {'_id': 'The Best Of New York Food', 'nota_promedio': 15.0}
# {'_id': "Deacon Brodie'S", 'nota_promedio': 9.8}
# {'_id': 'Savann Restaurant', 'nota_promedio': 8.5}
# {'_id': 'Buongiorno Espresso', 'nota_promedio': 4.75}
# {'_id': 'Marriott Marquis - Main Kitchen', 'nota_promedio': 10.0}
# {'_id': 'La Tarte Flambee', 'nota_promedio': 8.5}
# {'_id': 'Wichcraft Coffee, Espresso & Pastry', 'nota_promedio': 6.0}
# {'_id': "Jim Brady'S Restaurant", 'nota_promedio': 8.4}
# {'_id': 'Azusa Of Japan', 'nota_promedio': 11.0}
# {'_id': 'Sigiri', 'nota_promedio': 11.4}
# {'_id': 'L Q 511', 'nota_promedio': 9.6}
# {'_id': 'Captain Fried Chicken', 'nota_promedio': 9.5}
# {'_id': 'Minus 5 Ice Lounge', 'nota_promedio': 6.0}
# {'_id': 'Evergreen Asian Cuisine', 'nota_promedio': 9.666666666666666}
# {'_id': 'Phebes', 'nota_promedio': 10.2}
# {'_id': 'Ace Bar', 'nota_promedio': 7.0}
# {'_id': 'Sandwich House Italian Restaurant', 'nota_promedio': 9.666666666666666}
# {'_id': 'Sojourn', 'nota_promedio': 12.4}
# {'_id': 'Bank Of New York', 'nota_promedio': 6.666666666666667}
# {'_id': 'Edison Ballroom', 'nota_promedio': 6.0}
# {'_id': 'Cafe Mocha', 'nota_promedio': 13.0}
# {'_id': "Morton'S The Steakhouse", 'nota_promedio': 12.0}
# {'_id': "Fat Sal'S", 'nota_promedio': 21.75}
# {'_id': 'King Bee', 'nota_promedio': 7.0}
# {'_id': "Finnerty'S", 'nota_promedio': 8.75}
# {'_id': 'Maracas Steakhouse', 'nota_promedio': 10.166666666666666}
# {'_id': 'Woodrows', 'nota_promedio': 9.0}
# {'_id': 'Oddfellows Ice Cream', 'nota_promedio': 10.0}
# {'_id': 'Island', 'nota_promedio': 8.6}
# {'_id': 'Chartwells', 'nota_promedio': 6.625}
# {'_id': 'Cafe On 5Th/Sterling Affair', 'nota_promedio': 9.5}
# {'_id': 'Amc Theatres Magic Johnson Harlem 9', 'nota_promedio': 17.2}
# {'_id': "Sarabeth'S/Lord And Taylor 6Th Floor", 'nota_promedio': 11.0}
# {'_id': 'Lexington Pizza Parlour', 'nota_promedio': 13.0}
# {'_id': 'Ilili Box', 'nota_promedio': 2.0}
# {'_id': 'Mountain Bird', 'nota_promedio': 7.0}
# {'_id': 'East 12Th Osteria', 'nota_promedio': 14.0}
# {'_id': 'Jing Fong Restaurant', 'nota_promedio': 11.0}
# {'_id': 'Merrion Square', 'nota_promedio': 13.2}
# {'_id': 'Rustico', 'nota_promedio': 12.0}
# {'_id': 'Dough Boys Pizza', 'nota_promedio': 16.5}
# {'_id': 'Indian Tandoor Oven', 'nota_promedio': 8.0}
# {'_id': 'Trattoria Belverde', 'nota_promedio': 0.0}
# {'_id': 'New Moon Cafe', 'nota_promedio': 8.0}
# {'_id': 'Black Seed Bagels', 'nota_promedio': 2.5}
# {'_id': 'Ing Forman Selz', 'nota_promedio': 7.5}
# {'_id': 'Andanada', 'nota_promedio': 11.2}
# {'_id': 'Rice & Beans Restaurant', 'nota_promedio': 8.875}
# {'_id': 'Best Lexington Pizza', 'nota_promedio': 7.666666666666667}
# {'_id': 'Le Charlot', 'nota_promedio': 10.0}
# {'_id': 'Kinsale Tavern', 'nota_promedio': 10.25}
# {'_id': 'Zucchero E Pomodori', 'nota_promedio': 16.25}
# {'_id': 'Tulcingo Restaurant', 'nota_promedio': 13.8}
# {'_id': 'New Crispy Bamboo', 'nota_promedio': 7.75}
# {'_id': 'Best Fuzhou Restaurant', 'nota_promedio': 9.142857142857142}
# {'_id': 'Saxon & Parole', 'nota_promedio': 11.6}
# {'_id': 'Empellon Cocina', 'nota_promedio': 12.0}
# {'_id': 'Milk Burger Express', 'nota_promedio': 9.0}
# {'_id': 'Cafe Luxembourg', 'nota_promedio': 7.8}
# {'_id': 'Bea', 'nota_promedio': 15.0}
# {'_id': 'Freefoods', 'nota_promedio': 12.166666666666666}
# {'_id': 'Inhabit', 'nota_promedio': 8.75}
# {'_id': "T & G Whitney'S", 'nota_promedio': 8.8}
# {'_id': 'Saturdays Surf', 'nota_promedio': 19.0}
# {'_id': 'Table 71 @ Marriott Cortyard', 'nota_promedio': 13.666666666666666}
# {'_id': 'Sake Bar Satsko', 'nota_promedio': 10.0}
# {'_id': 'Flavors Cafe', 'nota_promedio': 6.0}
# {'_id': 'American Bar', 'nota_promedio': 15.75}
# {'_id': 'Starbucks Coffee Company', 'nota_promedio': 5.444444444444445}
# {'_id': 'Ubs Cafe (27 Fl.)', 'nota_promedio': 8.75}
# {'_id': "Blythe Ann'S", 'nota_promedio': 10.0}
# {'_id': 'Roadside', 'nota_promedio': 2.0}
# {'_id': 'La Ripaille Restaurant', 'nota_promedio': 10.666666666666666}
# {'_id': '39 Coffee Shop', 'nota_promedio': 7.75}
# {'_id': 'Cafe 57', 'nota_promedio': 7.75}
# {'_id': 'Kaffe 1668', 'nota_promedio': 9.777777777777779}
# {'_id': 'Cucina And Co.', 'nota_promedio': 10.75}
# {'_id': 'Paris Restaurant', 'nota_promedio': 14.4}
# {'_id': 'Pizza 33', 'nota_promedio': 10.666666666666666}
# {'_id': "Zucker'S Bagels And Smoked Fish", 'nota_promedio': 8.8}
# {'_id': 'El Azteca Mexican Restaurant', 'nota_promedio': 20.666666666666668}
# {'_id': 'Cafe Riazor', 'nota_promedio': 13.0}
# {'_id': 'Il Violino', 'nota_promedio': 11.0}
# {'_id': 'The Coffee House', 'nota_promedio': 5.2}
# {'_id': 'Hawa Smoothie', 'nota_promedio': 8.5}
# {'_id': 'Gmt Tavern', 'nota_promedio': 10.8}
# {'_id': 'Dons Bogam', 'nota_promedio': 10.8}
# {'_id': 'Racines Nyc Llc', 'nota_promedio': 8.0}
# {'_id': 'Tal Bagels', 'nota_promedio': 9.833333333333334}
# {'_id': 'Freemans', 'nota_promedio': 9.2}
# {'_id': 'Cucina & Company', 'nota_promedio': 13.2}
# {'_id': 'Frankies 570 Spuntino', 'nota_promedio': 9.5}
# {'_id': 'Uptown', 'nota_promedio': 13.4}
# {'_id': 'Cong Ly Restaurant', 'nota_promedio': 14.8}
# {'_id': 'Morning Star Restaurant', 'nota_promedio': 9.5}
# {'_id': 'Grand Appetito', 'nota_promedio': 10.666666666666666}
# {'_id': 'Stumptown Coffee Roasters', 'nota_promedio': 3.5}
# {'_id': "P.J. Clarke'S", 'nota_promedio': 11.25}
# {'_id': 'La Vie En Szechuan Restaurant', 'nota_promedio': 21.25}
# {'_id': 'Luxor Cafe', 'nota_promedio': 10.0}
# {'_id': 'Mana', 'nota_promedio': 11.25}
# {'_id': 'Revision', 'nota_promedio': 2.0}
# {'_id': 'Ruchi Indian Cuisine', 'nota_promedio': 18.333333333333332}
# {'_id': 'The Press Box', 'nota_promedio': 11.75}
# {'_id': 'Gregory Coffee', 'nota_promedio': 12.0}
# {'_id': 'Golden Fung Wong Bakery', 'nota_promedio': 11.4}
# {'_id': 'Hot Fresh Pizza', 'nota_promedio': 5.0}
# {'_id': 'Favela Cubana', 'nota_promedio': 14.75}
# {'_id': 'Lexington Restaurant', 'nota_promedio': 24.4}
# {'_id': 'Ipanema Restaurant', 'nota_promedio': 11.0}
# {'_id': 'Doughnut Plant', 'nota_promedio': 10.2}
# {'_id': 'Rose Bakery', 'nota_promedio': 12.5}
# {'_id': "King'S Chef Chinese Restaurant", 'nota_promedio': 16.0}
# {'_id': 'Kuma Inn', 'nota_promedio': 15.0}
# {'_id': 'The Wright', 'nota_promedio': 8.25}
# {'_id': 'Central Cafe', 'nota_promedio': 20.166666666666668}
# {'_id': 'Conrad New York', 'nota_promedio': 8.666666666666666}
# {'_id': 'Lit Lounge Nyc', 'nota_promedio': 15.4}
# {'_id': 'Sisters Cuisine', 'nota_promedio': 9.8}
# {'_id': 'Umi Sushi Japanese Cuisine', 'nota_promedio': 12.0}
# {'_id': 'Mariott Marquis/Crossroads Bar', 'nota_promedio': 8.0}
# {'_id': 'Maggies Place', 'nota_promedio': 11.5}
# {'_id': 'Nios Restaurant', 'nota_promedio': 32.42857142857143}
# {'_id': 'Via Quadronno', 'nota_promedio': 9.142857142857142}
# {'_id': 'Rafina Greek Cuisine', 'nota_promedio': 11.166666666666666}
# {'_id': 'Time Warner Executive Dining Room',
#  'nota_promedio': 3.6666666666666665}
# {'_id': 'Cagen', 'nota_promedio': 11.0}
# {'_id': 'C.U.N.Y Cafe', 'nota_promedio': 9.8}
# {'_id': 'Healthy Oasis', 'nota_promedio': 9.0}
# {'_id': 'Soom Soom', 'nota_promedio': 10.75}
# {'_id': 'Kung Fu Little Stemed Buns Ramen Inc', 'nota_promedio': 9.0}
# {'_id': "The Frog'S Crown Bakery", 'nota_promedio': 10.0}
# {'_id': 'Trump Soho Main Kitchen Cafeteria', 'nota_promedio': 11.0}
# {'_id': 'Industry', 'nota_promedio': 9.0}
# {'_id': 'Alibaba', 'nota_promedio': 6.75}
# {'_id': 'Gezunte Bagel', 'nota_promedio': 11.75}
# {'_id': 'Wild Ginger Vegetarian Kitchen', 'nota_promedio': 20.4}
# {'_id': 'Little Box', 'nota_promedio': 7.0}
# {'_id': 'Apple Restaurant & Bom Bar', 'nota_promedio': 11.6}
# {'_id': 'Morgenstern Finest Ice Cream', 'nota_promedio': 3.0}
# {'_id': 'Holey Cream', 'nota_promedio': 11.4}
# {'_id': 'Kobe Sushi', 'nota_promedio': 25.333333333333332}
# {'_id': "Yankee'S Sk Pizza", 'nota_promedio': 11.0}
# {'_id': 'Machiavelli', 'nota_promedio': 14.2}
# {'_id': 'Corner Cafe And Bakery', 'nota_promedio': 15.333333333333334}
# {'_id': "Paddy'S Reilly'S Bar", 'nota_promedio': 10.75}
# {'_id': 'Yuva Frontier Indian Grill', 'nota_promedio': 11.6}
# {'_id': 'Orso', 'nota_promedio': 7.666666666666667}
# {'_id': "Swifty'S", 'nota_promedio': 15.5}
# {'_id': 'New Tu Do Restaurant', 'nota_promedio': 11.833333333333334}
# {'_id': 'Strokos Gourmet Deli', 'nota_promedio': 12.8}
# {'_id': 'Totoya', 'nota_promedio': 9.0}
# {'_id': 'Butter  Restaurant', 'nota_promedio': 14.0}
# {'_id': 'Bodrum', 'nota_promedio': 12.2}
# {'_id': 'Royale', 'nota_promedio': 15.8}
# {'_id': 'Latin American Restaurant', 'nota_promedio': 9.4}
# {'_id': 'Blossom', 'nota_promedio': 17.4}
# {'_id': 'The Original Soupman', 'nota_promedio': 6.333333333333333}
# {'_id': 'Belgium Beer Cafe', 'nota_promedio': 12.0}
# {'_id': 'Sushi Seki', 'nota_promedio': 12.333333333333334}
# {'_id': 'Trump Cafe & Grill', 'nota_promedio': 14.0}
# {'_id': 'The Cafe @ Greene St', 'nota_promedio': 7.0}
# {'_id': 'Nbc-Ge', 'nota_promedio': 8.333333333333334}
# {'_id': 'Tir Na Nog Bar And Grill', 'nota_promedio': 4.0}
# {'_id': 'Citi Cafe/Rohatyn Room', 'nota_promedio': 13.0}
# {'_id': 'Paris Baguette Cafe', 'nota_promedio': 9.0}
# {'_id': 'Fishtag', 'nota_promedio': 12.0}
# {'_id': 'Bar Prima', 'nota_promedio': 11.0}
# {'_id': 'Kodama Sushi', 'nota_promedio': 22.0}
# {'_id': 'Nanoosh', 'nota_promedio': 8.384615384615385}
# {'_id': 'T49 Cafe', 'nota_promedio': 2.6666666666666665}
# {'_id': 'Lafayette', 'nota_promedio': 9.333333333333334}
# {'_id': 'Grandma Pizza', 'nota_promedio': 14.666666666666666}
# {'_id': "Tiny'S And The Bar Upstairs", 'nota_promedio': 10.4}
# {'_id': 'Mad River Bar & Grille', 'nota_promedio': 11.5}
# {'_id': 'Artisanal', 'nota_promedio': 12.4}
# {'_id': "Mighty Quinn'S Barbeque", 'nota_promedio': 9.666666666666666}
# {'_id': 'Gotham Bar & Grill', 'nota_promedio': 9.2}
# {'_id': 'Teavana #22994', 'nota_promedio': 12.0}
# {'_id': 'Amelie', 'nota_promedio': 12.4}
# {'_id': 'Joy Curry & Tandoor', 'nota_promedio': 9.2}
# {'_id': '38Th Street Diner', 'nota_promedio': 21.5}
# {'_id': 'Wcou Radio / Tile Bar', 'nota_promedio': 15.0}
# {'_id': 'Cosi Downtown', 'nota_promedio': 10.272727272727273}
# {'_id': 'La Crosta Restaurant', 'nota_promedio': 11.0}
# {'_id': 'News Bar', 'nota_promedio': 11.4}
# {'_id': 'Courtside Cafe', 'nota_promedio': 10.0}
# {'_id': 'Local Thyme', 'nota_promedio': 8.0}
# {'_id': 'Jw Marriot Essex House', 'nota_promedio': 14.0}
# {'_id': 'The Half Pint', 'nota_promedio': 13.5}
# {'_id': 'Good Health Natural Cafe', 'nota_promedio': 10.4}
# {'_id': 'Ninja Restaurant', 'nota_promedio': 14.6}
# {'_id': 'Off The Rails', 'nota_promedio': 12.25}
# {'_id': 'Irving Farm', 'nota_promedio': 7.666666666666667}
# {'_id': 'Zhang Qun Empire Inc', 'nota_promedio': 8.0}
# {'_id': "John'S Pizzeria", 'nota_promedio': 11.0}
# {'_id': 'Reuters Executive Dining Room', 'nota_promedio': 3.75}
# {'_id': 'Johns Cafe & Resturant', 'nota_promedio': 13.142857142857142}
# {'_id': 'Aureole', 'nota_promedio': 8.0}
# {'_id': 'Corner Cafe & Bakery', 'nota_promedio': 13.6}
# {'_id': '3 Deli & Grill', 'nota_promedio': 9.666666666666666}
# {'_id': "Claudia'S Coffee Shop", 'nota_promedio': 9.75}
# {'_id': 'Bar Six', 'nota_promedio': 8.8}
# {'_id': '502 Hudson Bagel Corp', 'nota_promedio': 7.0}
# {'_id': 'Taqueria Guadalupe', 'nota_promedio': 17.0}
# {'_id': 'Dunkin Donuts, Baskin Robbins', 'nota_promedio': 8.8}
# {'_id': 'Dunkin Donuts Baskin Robbins', 'nota_promedio': 8.166666666666666}
# {'_id': 'Il Gnocchi Restaurant', 'nota_promedio': 12.5}
# {'_id': 'Ubs', 'nota_promedio': 4.5}
# {'_id': 'The Green Room', 'nota_promedio': 7.222222222222222}
# {'_id': 'Imperial Pizzeria Restaurant', 'nota_promedio': 20.2}
# {'_id': 'Cucina Gourmet', 'nota_promedio': 9.666666666666666}
# {'_id': 'Taqueria San Pedro', 'nota_promedio': 19.0}
# {'_id': 'Cafeteria', 'nota_promedio': 13.0}
# {'_id': 'Tribeca Treats', 'nota_promedio': 7.0}
# {'_id': "Tom'S Restaurant", 'nota_promedio': 11.6}
# {'_id': 'Arata Japanese Restaurant', 'nota_promedio': 12.5}
# {'_id': 'Fika Espresso Bar', 'nota_promedio': 15.5}
# {'_id': 'Il Piccolo Bufalo', 'nota_promedio': 8.4}
# {'_id': 'Aaa Ichiban Sushi', 'nota_promedio': 10.857142857142858}
# {'_id': "Tj Byrne'S Bar", 'nota_promedio': 12.8}
# {'_id': "Earl'S Beer & Cheese", 'nota_promedio': 8.0}
# {'_id': "L'Express", 'nota_promedio': 7.75}
# {'_id': 'M & J Asian Restaurant', 'nota_promedio': 35.0}
# {'_id': 'Cafe Clementine', 'nota_promedio': 9.4}
# {'_id': 'Barnes And Noble Cafe', 'nota_promedio': 10.25}
# {'_id': "Virgil'S Bbq", 'nota_promedio': 10.5}
# {'_id': 'The Counter', 'nota_promedio': 8.6}
# {'_id': "Ruby Foo'S Times Square", 'nota_promedio': 9.333333333333334}
# {'_id': 'Culture Club', 'nota_promedio': 11.666666666666666}
# {'_id': 'Ellen Deli & Grocery', 'nota_promedio': 10.0}
# {'_id': 'Cheesy Pizza', 'nota_promedio': 10.5}
# {'_id': "Tiny'S Giant Sandwich Shop", 'nota_promedio': 15.5}
# {'_id': 'Taki Sushi', 'nota_promedio': 17.25}
# {'_id': 'Bonnie Vee', 'nota_promedio': 8.0}
# {'_id': 'Aaa Burrito Mariachi', 'nota_promedio': 5.0}
# {'_id': 'Matryoshka', 'nota_promedio': 12.6}
# {'_id': 'Garden Market 2', 'nota_promedio': 0.0}
# {'_id': 'On The Rocks', 'nota_promedio': 15.8}
# {'_id': 'Cipriani Dolci', 'nota_promedio': 9.4}
# {'_id': 'Tio Pepe', 'nota_promedio': 10.75}
# {'_id': 'Manhattan Proper', 'nota_promedio': 10.666666666666666}
# {'_id': 'Pure Thai Restaurant', 'nota_promedio': 13.0}
# {'_id': "Haven'S Kitchen", 'nota_promedio': 14.5}
# {'_id': 'Roy Rogers', 'nota_promedio': 7.0}
# {'_id': 'Brod Kitchen', 'nota_promedio': 18.75}
# {'_id': "Paesano'S", 'nota_promedio': 10.25}
# {'_id': "Zoie'S Cafe And Delicatessen", 'nota_promedio': 5.5}
# {'_id': 'Cinnabon World Famous Cinnamon Rolls/Carvel', 'nota_promedio': 11.0}
# {'_id': 'Regional', 'nota_promedio': 9.5}
# {'_id': 'Beauty And Essex', 'nota_promedio': 11.142857142857142}
# {'_id': 'Hampton Inn-Herald Square', 'nota_promedio': 9.75}
# {'_id': 'Blt Bar & Grill', 'nota_promedio': 12.4}
# {'_id': 'Akira Japanese Cuisine', 'nota_promedio': 12.0}
# {'_id': 'Philly Chessestake', 'nota_promedio': 11.0}
# {'_id': 'Little Poland Restaurant', 'nota_promedio': 14.0}
# {'_id': 'El Aguila', 'nota_promedio': 14.642857142857142}
# {'_id': 'Brassierie 1605/Broadway 49 Bar & Lounge (Main Kitchen)',
#  'nota_promedio': 11.333333333333334}
# {'_id': 'Floridita Bakery', 'nota_promedio': 9.0}
# {'_id': 'Vitae', 'nota_promedio': 11.333333333333334}
# {'_id': "Applebaum'S", 'nota_promedio': 12.166666666666666}
# {'_id': 'Aperitivo Di Palma', 'nota_promedio': 4.0}
# {'_id': 'Society Billards And Bar', 'nota_promedio': 7.0}
# {'_id': 'Antika Pizzeria', 'nota_promedio': 7.333333333333333}
# {'_id': 'White Castle', 'nota_promedio': 6.5}
# {'_id': "Claw Daddy'S", 'nota_promedio': 6.0}
# {'_id': 'Baohaus', 'nota_promedio': 18.5}
# {'_id': "Dunkin' Donuts", 'nota_promedio': 7.941860465116279}
# {'_id': "New York Sal'S Pizzeria", 'nota_promedio': 9.5}
# {'_id': "Otto'S Tacos", 'nota_promedio': 12.0}
# {'_id': 'Breads Bakery', 'nota_promedio': 10.5}
# {'_id': 'Jubilee', 'nota_promedio': 12.75}
# {'_id': 'Primo Coffee Cart', 'nota_promedio': 7.8}
# {'_id': 'Serafina', 'nota_promedio': 13.25}
# {'_id': 'Cafe Angelique', 'nota_promedio': 13.384615384615385}
# {'_id': 'Seattle Cafe', 'nota_promedio': 14.833333333333334}
# {'_id': 'Cafe Twist', 'nota_promedio': 15.333333333333334}
# {'_id': "Welcome To The Johnson'S", 'nota_promedio': 10.5}
# {'_id': 'The Wayfarer', 'nota_promedio': 10.0}
# {'_id': 'Teodora', 'nota_promedio': 8.833333333333334}
# {'_id': "Touch Of Dee'S", 'nota_promedio': 10.0}
# {'_id': "Waldy'S Wood Fired Pizza & Penne", 'nota_promedio': 9.2}
# {'_id': 'Dairy Queen Grill And Chill', 'nota_promedio': 13.0}
# {'_id': 'Gradisca Restaurant', 'nota_promedio': 13.0}
# {'_id': 'Pietros', 'nota_promedio': 10.333333333333334}
# {'_id': "Zaro'S Bakery", 'nota_promedio': 14.0}
# {'_id': "Jack'S Stir Brew Coffee", 'nota_promedio': 9.285714285714286}
# {'_id': 'Il Palazzo', 'nota_promedio': 16.2}
# {'_id': 'Bella Vita', 'nota_promedio': 29.285714285714285}
# {'_id': "Alice'S Int'L Cafe", 'nota_promedio': 9.333333333333334}
# {'_id': 'Bengal Tiger Indian Food', 'nota_promedio': 7.0}
# {'_id': "Hamilton'S Soda Fountain", 'nota_promedio': 31.0}
# {'_id': 'Cipriani 42Nd Street', 'nota_promedio': 9.666666666666666}
# {'_id': 'Zabb City', 'nota_promedio': 13.333333333333334}
# {'_id': 'Yi Zhang Fishball', 'nota_promedio': 8.25}
# {'_id': 'Cafe Atelier (Art Students League)', 'nota_promedio': 10.8}
# {'_id': 'Soho Fried Chicken & Pizzeria', 'nota_promedio': 8.5}
# {'_id': 'Galanga Thai Cooking', 'nota_promedio': 12.571428571428571}
# {'_id': 'Rosa Mexicano', 'nota_promedio': 10.333333333333334}
# {'_id': 'Taverna Di Bacco', 'nota_promedio': 10.2}
# {'_id': 'Pauls Da Burger Joint', 'nota_promedio': 13.6}
# {'_id': 'Sushi Samba #7', 'nota_promedio': 11.8}
# {'_id': 'Salud Soho', 'nota_promedio': 11.0}
# {'_id': 'Meridian 23', 'nota_promedio': 7.0}
# {'_id': 'Cheese Grille', 'nota_promedio': 7.0}
# {'_id': 'Bangal Curry', 'nota_promedio': 10.833333333333334}
# {'_id': "Teresa'S Gourmet", 'nota_promedio': 12.5}
# {'_id': 'Subway/Uno Express', 'nota_promedio': 7.0}
# {'_id': 'Biny', 'nota_promedio': 12.0}
# {'_id': 'Sprinkles Ice Cream', 'nota_promedio': 4.0}
# {'_id': 'Manchu Wok', 'nota_promedio': 11.2}
# {'_id': 'Taj Ii', 'nota_promedio': 13.5}
# {'_id': 'Room Service Kitchen', 'nota_promedio': 8.5}
# {'_id': 'Red Bubble', 'nota_promedio': 4.0}
# {'_id': 'Tgi Fridays', 'nota_promedio': 19.0}
# {'_id': '7 Green & Grain', 'nota_promedio': 17.0}
# {'_id': 'Hot & Crusty', 'nota_promedio': 16.0}
# {'_id': 'New York Law School', 'nota_promedio': 9.5}
# {'_id': 'Audrey At St. Giles Hotel', 'nota_promedio': 10.6}
# {'_id': 'Little Italy Pizza', 'nota_promedio': 12.025}
# {'_id': "Hillstone'S", 'nota_promedio': 10.0}
# {'_id': 'Reggae Sun Delights Natural Juice Bar',
#  'nota_promedio': 10.333333333333334}
# {'_id': 'Pinche Taqueria', 'nota_promedio': 12.285714285714286}
# {'_id': 'Metro Grill', 'nota_promedio': 10.0}
# {'_id': 'Piora', 'nota_promedio': 10.5}
# {'_id': 'Sin Bin', 'nota_promedio': 10.0}
# {'_id': 'Time Warner Conference Center', 'nota_promedio': 7.0}
# {'_id': 'Panada Restaurant', 'nota_promedio': 9.0}
# {'_id': 'Playwright Tavern', 'nota_promedio': 11.8}
# {'_id': 'Indus Valley', 'nota_promedio': 11.8}
# {'_id': 'Broadway Lounge', 'nota_promedio': 8.25}
# {'_id': 'Previti Pizza', 'nota_promedio': 13.0}
# {'_id': 'Studio', 'nota_promedio': 8.0}
# {'_id': 'Barn Joo', 'nota_promedio': 10.0}
# {'_id': 'Grand Banks', 'nota_promedio': 7.0}
# {'_id': 'Goggan', 'nota_promedio': 10.0}
# {'_id': 'Bali Nusa Indonesian Restaurant', 'nota_promedio': 13.2}
# {'_id': 'Bally Total Fitness', 'nota_promedio': 8.8}
# {'_id': 'Mole', 'nota_promedio': 9.4}
# {'_id': 'University Market Place', 'nota_promedio': 12.833333333333334}
# {'_id': 'Simpson Thacher And Bartlet Cafe', 'nota_promedio': 7.75}
# {'_id': 'Twins Pub', 'nota_promedio': 10.8}
# {'_id': 'A Taste Of Sea Food', 'nota_promedio': 13.75}
# {'_id': 'East Broadway Restaurant', 'nota_promedio': 19.666666666666668}
# {'_id': "Somethin' Jazz Club", 'nota_promedio': 8.25}
# {'_id': 'El Vez', 'nota_promedio': 5.0}
# {'_id': 'Hardware Bar', 'nota_promedio': 7.5}
# {'_id': 'Gustorganics', 'nota_promedio': 12.714285714285714}
# {'_id': 'World Pizza Champion', 'nota_promedio': 15.6}
# {'_id': 'Ess-A-Bagel 1', 'nota_promedio': 18.75}
# {'_id': 'One And One', 'nota_promedio': 14.0}
# {'_id': 'Epicerie Bouloud', 'nota_promedio': 10.0}
# {'_id': 'Market Cafe', 'nota_promedio': 9.4}
# {'_id': 'Franchia', 'nota_promedio': 10.25}
# {'_id': "Tj'S Coffee World", 'nota_promedio': 6.666666666666667}
# {'_id': 'New York Times Cafe', 'nota_promedio': 9.0}
# {'_id': 'Lair', 'nota_promedio': 9.6}
# {'_id': 'Nixtamalito', 'nota_promedio': 12.0}
# {'_id': 'Big Booty Bread', 'nota_promedio': 9.2}
# {'_id': 'Abc Cocina', 'nota_promedio': 14.75}
# {'_id': "Phil'S Pizza West Village", 'nota_promedio': 7.6}
# {'_id': 'Starbucks Coffee (Store 17478)', 'nota_promedio': 5.666666666666667}
# {'_id': 'Lupita Restaurant', 'nota_promedio': 10.5}
# {'_id': 'Disiac Lounge', 'nota_promedio': 7.2}
# {'_id': 'Tartina', 'nota_promedio': 14.0}
# {'_id': 'Bagels And Co', 'nota_promedio': 10.25}
# {'_id': 'Benjamin Steak House', 'nota_promedio': 8.8}
# {'_id': 'Barking Dog', 'nota_promedio': 10.428571428571429}
# {'_id': 'Anjappar Chettinad South Indian Cuisine', 'nota_promedio': 9.5}
# {'_id': 'American Cut', 'nota_promedio': 12.0}
# {'_id': 'Jamba Juice', 'nota_promedio': 12.738095238095237}
# {'_id': 'Sams Famous Pizza', 'nota_promedio': 10.2}
# {'_id': 'Karaoke Boho', 'nota_promedio': 9.333333333333334}
# {'_id': 'Refinery Lobby Bar', 'nota_promedio': 7.0}
# {'_id': "Gaetana'S Cucina Italiana", 'nota_promedio': 14.2}
# {'_id': 'Elevate Restaurant', 'nota_promedio': 11.0}
# {'_id': 'Homewood Suites By Hilton New York Midtown Manhattan Times Square',
#  'nota_promedio': 52.0}
# {'_id': "Harry'S Burrito Junction", 'nota_promedio': 15.714285714285714}
# {'_id': 'Knish Nosh (Conservatory Water)', 'nota_promedio': 10.6}
# {'_id': "Norman'S Cay", 'nota_promedio': 7.0}
# {'_id': 'Cafe Trend', 'nota_promedio': 9.2}
# {'_id': 'Candle 79 Restaurant', 'nota_promedio': 9.25}
# {'_id': 'Quantum Leap', 'nota_promedio': 9.0}
# {'_id': 'Indian Road Cafe', 'nota_promedio': 9.0}
# {'_id': 'East Of Eighth', 'nota_promedio': 14.6}
# {'_id': 'Heights Tavern', 'nota_promedio': 6.0}
# {'_id': 'Hilton New  York Hilton Banquet Hall',
#  'nota_promedio': 10.333333333333334}
# {'_id': 'Provocateur Night Club', 'nota_promedio': 13.25}
# {'_id': 'New Bo Ky Restaurant', 'nota_promedio': 18.571428571428573}
# {'_id': 'Euros El Tina Restaurant Lounge And Billiards',
#  'nota_promedio': 6.333333333333333}
# {'_id': "Lily'S Bar @ Roger Smith Hotel", 'nota_promedio': 19.2}
# {'_id': 'Kurant', 'nota_promedio': 8.5}
# {'_id': 'Kobeyaki', 'nota_promedio': 8.428571428571429}
# {'_id': 'Patrick Conways', 'nota_promedio': 8.0}
# {'_id': 'Little Collins', 'nota_promedio': 9.5}
# {'_id': 'Sushi-Teria', 'nota_promedio': 6.25}
# {'_id': 'Anchor Winebar Llc', 'nota_promedio': 8.0}
# {'_id': 'Al Horno Lean Mexican', 'nota_promedio': 22.0}
# {'_id': 'Tette Club', 'nota_promedio': 8.666666666666666}
# {'_id': 'New China King Restaurant', 'nota_promedio': 8.75}
# {'_id': 'Happy Garden Palace', 'nota_promedio': 14.75}
# {'_id': 'Rodeo Grill', 'nota_promedio': 10.2}
# {'_id': 'New Dragon Town Of Manhattan', 'nota_promedio': 9.6}
# {'_id': "Lobby Lounge And Trouble'S Trust @ The Palace Hotel",
#  'nota_promedio': 12.0}
# {'_id': 'Donut Pub', 'nota_promedio': 11.5}
# {'_id': "Pizza Pete'S", 'nota_promedio': 13.75}
# {'_id': 'Tropical 128', 'nota_promedio': 11.75}
# {'_id': 'Phoenix Park', 'nota_promedio': 12.666666666666666}
# {'_id': 'Queen Bakery Ii', 'nota_promedio': 10.75}
# {'_id': "Bo'S Kitchen & Bar Room", 'nota_promedio': 7.0}
# {'_id': 'Voga Lounge & Grill', 'nota_promedio': 9.0}
# {'_id': 'S. Wan Cafe', 'nota_promedio': 9.833333333333334}
# {'_id': 'Gan Asia', 'nota_promedio': 12.833333333333334}
# {'_id': 'Mcgees Pub', 'nota_promedio': 11.333333333333334}
# {'_id': 'Eurest Dining Service (American Express)',
#  'nota_promedio': 12.571428571428571}
# {'_id': 'Bermudez Bakery', 'nota_promedio': 12.666666666666666}
# {'_id': 'Hughes Tavern', 'nota_promedio': 10.75}
# {'_id': 'Sazon', 'nota_promedio': 13.8}
# {'_id': 'The Bluebell Cafe', 'nota_promedio': 9.75}
# {'_id': 'Garden Kebab House', 'nota_promedio': 19.5}
# {'_id': 'The Bistro (Courtyard By Marriot)', 'nota_promedio': 12.5}
# {'_id': "Wolfgang'S Steak House", 'nota_promedio': 8.8}
# {'_id': 'The Black Duck Restaurant', 'nota_promedio': 11.6}
# {'_id': "Chef'S Secret", 'nota_promedio': 16.166666666666668}
# {'_id': 'Manchester Pub', 'nota_promedio': 18.142857142857142}
# {'_id': 'Union Club Of City Of New York', 'nota_promedio': 6.25}
# {'_id': 'Yasha Raman', 'nota_promedio': 11.666666666666666}
# {'_id': '7 Grams Caffe', 'nota_promedio': 3.0}
# {'_id': 'Lenfest Cafe - Jerome Green Hall', 'nota_promedio': 5.0}
# {'_id': 'Dafni', 'nota_promedio': 11.0}
# {'_id': 'Chinatown Restaurant', 'nota_promedio': 11.0}
# {'_id': "D'Milton Restaurant", 'nota_promedio': 10.0}
# {'_id': 'Mini Cafe', 'nota_promedio': 8.25}
# {'_id': 'Hamilton', 'nota_promedio': 9.0}
# {'_id': "Grini'S Bakery", 'nota_promedio': 0.0}
# {'_id': 'Kmr', 'nota_promedio': 9.25}
# {'_id': 'Momofuku Ssam Bar', 'nota_promedio': 10.6}
# {'_id': 'China House Chinese Restaurant', 'nota_promedio': 10.5}
# {'_id': 'La Bella Vita', 'nota_promedio': 11.0}
# {'_id': 'New Fresh Wok', 'nota_promedio': 28.0}
# {'_id': 'W Hotel', 'nota_promedio': 23.5}
# {'_id': 'E.A.T. Cafe', 'nota_promedio': 11.714285714285714}
# {'_id': '2A', 'nota_promedio': 7.75}
# {'_id': 'Grand Great Wall Restaurant Inc', 'nota_promedio': 10.8}
# {'_id': 'Fresh Salt', 'nota_promedio': 15.0}
# {'_id': 'Destination', 'nota_promedio': 11.333333333333334}
# {'_id': 'Muzzarella Pizza', 'nota_promedio': 13.833333333333334}
# {'_id': 'Piada', 'nota_promedio': 10.4}
# {'_id': 'Marumi', 'nota_promedio': 16.0}
# {'_id': 'Spaha Soul', 'nota_promedio': 0.0}
# {'_id': "Sob'S", 'nota_promedio': 12.2}
# {'_id': 'Tarallucci E Vino', 'nota_promedio': 10.466666666666667}
# {'_id': 'El Panadero Bakery', 'nota_promedio': 7.75}
# {'_id': 'La Nueva Victoria Restaurant', 'nota_promedio': 9.571428571428571}
# {'_id': 'Sidley Austin Cafeteria', 'nota_promedio': 4.25}
# {'_id': 'Zoe Cafe', 'nota_promedio': 14.5}
# {'_id': 'Harlem  Gourmet Cafe', 'nota_promedio': 7.666666666666667}
# {'_id': 'Diwan-E- Khaas', 'nota_promedio': 4.75}
# {'_id': "Josie'S Bar", 'nota_promedio': 8.0}
# {'_id': 'Exchange Bar And Grill', 'nota_promedio': 11.857142857142858}
# {'_id': 'Quatorze Bistro', 'nota_promedio': 10.6}
# {'_id': 'New Kim Tong', 'nota_promedio': 15.0}
# {'_id': 'Le Baratin', 'nota_promedio': 11.5}
# {'_id': 'Birdbath Spring', 'nota_promedio': 9.0}
# {'_id': 'The Redhead', 'nota_promedio': 10.2}
# {'_id': 'Naya Mezze & Grill', 'nota_promedio': 8.4}
# {'_id': 'American Express', 'nota_promedio': 5.75}
# {'_id': 'O Cafe', 'nota_promedio': 10.75}
# {'_id': 'Shanghai Cafe Deluxe', 'nota_promedio': 20.857142857142858}
# {'_id': 'Tao Restaurant', 'nota_promedio': 9.0}
# {'_id': 'Black Ant', 'nota_promedio': 14.666666666666666}
# {'_id': 'Circle Line Brooklyn', 'nota_promedio': 8.0}
# {'_id': 'Carino On Second', 'nota_promedio': 7.0}
# {'_id': 'Promenade Bar Grill Sushi', 'nota_promedio': 10.5}
# {'_id': 'Session House', 'nota_promedio': 8.8}
# {'_id': 'Guzan Japanese Cuisine & Bar', 'nota_promedio': 13.6}
# {'_id': 'Momofuko Milk Bar Uws', 'nota_promedio': 5.75}
# {'_id': 'Tous Les Jours', 'nota_promedio': 12.333333333333334}
# {'_id': 'Aa Ichiban Sushi', 'nota_promedio': 11.666666666666666}
# {'_id': 'Xian Famous Foods', 'nota_promedio': 7.0}
# {'_id': "Ben & Jerry'S", 'nota_promedio': 8.6}
# {'_id': 'Il Brigante', 'nota_promedio': 7.25}
# {'_id': 'The Randolph At Broome', 'nota_promedio': 17.0}
# {'_id': 'Awash Ethiopian Restaurant', 'nota_promedio': 9.8}
# {'_id': 'Bondurants', 'nota_promedio': 9.0}
# {'_id': 'Pizza Italia', 'nota_promedio': 12.0}
# {'_id': 'Sushi Damo', 'nota_promedio': 24.333333333333332}
# {'_id': 'Epistrophy Cafe', 'nota_promedio': 12.5}
# {'_id': 'Garage', 'nota_promedio': 11.285714285714286}
# {'_id': 'Atami Japanese Fusion', 'nota_promedio': 6.25}
# {'_id': 'El Coco', 'nota_promedio': 26.0}
# {'_id': 'Nespresso', 'nota_promedio': 8.777777777777779}
# {'_id': 'Toledo', 'nota_promedio': 7.75}
# {'_id': 'Zen Palate', 'nota_promedio': 32.5}
# {'_id': "Sal'S Family Pizza", 'nota_promedio': 13.5}
# {'_id': 'Patisserie Des Ambassades', 'nota_promedio': 14.571428571428571}
# {'_id': 'Creative Juice', 'nota_promedio': 7.45}
# {'_id': 'Chicken Festival', 'nota_promedio': 17.0}
# {'_id': 'Aromas Boutique Bakery & Cafe', 'nota_promedio': 6.5}
# {'_id': 'Prime One 16', 'nota_promedio': 11.0}
# {'_id': 'Rhong-Tiam Thai', 'nota_promedio': 13.0}
# {'_id': 'Employee Feeding', 'nota_promedio': 0.0}
# {'_id': 'Underline Coffee', 'nota_promedio': 12.0}
# {'_id': 'Pizza Stop', 'nota_promedio': 8.4}
# {'_id': 'St George Tower', 'nota_promedio': 37.0}
# {'_id': 'Choux Factory', 'nota_promedio': 14.5}
# {'_id': 'N.Y. Academy Of Science', 'nota_promedio': 7.0}
# {'_id': 'The Grey Dog', 'nota_promedio': 9.833333333333334}
# {'_id': 'Fujiyama', 'nota_promedio': 14.166666666666666}
# {'_id': 'Fb9110 Hot Dog Concession', 'nota_promedio': 1.0}
# {'_id': 'Box Car Lounge', 'nota_promedio': 12.5}
# {'_id': "Pinky'S Jamaican And American Restaurant", 'nota_promedio': 12.0}
# {'_id': 'Marm Cafe', 'nota_promedio': 12.0}
# {'_id': 'La Linea Lounge', 'nota_promedio': 6.5}
# {'_id': 'My Bubbly Tea', 'nota_promedio': 9.6}
# {'_id': 'Emmetts', 'nota_promedio': 21.5}
# {'_id': 'Tataki Japanese Restaurant', 'nota_promedio': 15.666666666666666}
# {'_id': 'Roastown', 'nota_promedio': 19.714285714285715}
# {'_id': 'Lan Larb Soho', 'nota_promedio': 19.0}
# {'_id': 'Regency Whist Club', 'nota_promedio': 12.0}
# {'_id': 'Campagnola Restaurant', 'nota_promedio': 12.5}
# {'_id': 'Sakagura', 'nota_promedio': 10.666666666666666}
# {'_id': 'Pizza Shack', 'nota_promedio': 8.25}
# {'_id': 'Hair Of The Dog', 'nota_promedio': 9.666666666666666}
# {'_id': 'Hungarian Pastry Shop', 'nota_promedio': 9.6}
# {'_id': 'Pink Elephant', 'nota_promedio': 24.5}
# {'_id': 'Kambi Ramen', 'nota_promedio': 8.6}
# {'_id': "Lili'S 57", 'nota_promedio': 13.6}
# {'_id': 'Cafe Oliviero', 'nota_promedio': 13.0}
# {'_id': 'Villagio On The Park', 'nota_promedio': 13.0}
# {'_id': 'Colony Club', 'nota_promedio': 9.0}
# {'_id': 'Happy Star Bakery', 'nota_promedio': 11.857142857142858}
# {'_id': 'Casa Nonna', 'nota_promedio': 7.125}
# {'_id': 'Rare Bar & Grill', 'nota_promedio': 12.333333333333334}
# {'_id': 'Astor Center', 'nota_promedio': 14.0}
# {'_id': 'Terra Blues', 'nota_promedio': 9.25}
# {'_id': 'Amc Theatres 19Th Street East', 'nota_promedio': 6.5}
# {'_id': 'Leche Y Miel Restaurant', 'nota_promedio': 9.0}
# {'_id': "Arturo'S", 'nota_promedio': 13.6}
# {'_id': 'Saffron Garden', 'nota_promedio': 13.2}
# {'_id': 'Royal Pizza', 'nota_promedio': 8.8}
# {'_id': 'Mark Joseph Cakes', 'nota_promedio': 3.0}
# {'_id': 'CafÉ Gusto', 'nota_promedio': 10.666666666666666}
# {'_id': 'Food King Chinese Restaurant', 'nota_promedio': 11.333333333333334}
# {'_id': 'United Fried Chicken', 'nota_promedio': 19.142857142857142}
# {'_id': 'Dbgb Kitchen & Bar', 'nota_promedio': 8.6}
# {'_id': 'Khe-Yo', 'nota_promedio': 8.0}
# {'_id': 'New Lucky Star Kitchen', 'nota_promedio': 5.5}
# {'_id': 'Bluestone Lane Coffee', 'nota_promedio': 14.2}
# {'_id': "Quinn'S Bar & Grill", 'nota_promedio': 11.5}
# {'_id': "Auntie Anne'S Pretzels", 'nota_promedio': 11.909090909090908}
# {'_id': 'Sky Terrace Bar', 'nota_promedio': 12.0}
# {'_id': "Mom'S Pizza", 'nota_promedio': 20.0}
# {'_id': 'Insomnia  Cooklies', 'nota_promedio': 10.0}
# {'_id': 'Heermance Farm Purveyors', 'nota_promedio': 10.0}
# {'_id': 'The River Club', 'nota_promedio': 18.0}
# {'_id': "Pete'S Tavern", 'nota_promedio': 9.8}
# {'_id': "Fluffy'S Cafe & Bakery", 'nota_promedio': 8.5}
# {'_id': 'Swagat', 'nota_promedio': 12.8}
# {'_id': "Mihoko'S 21 Grams", 'nota_promedio': 7.0}
# {'_id': 'Karizma Lounge', 'nota_promedio': 12.75}
# {'_id': 'Edi & The Wolf', 'nota_promedio': 21.0}
# {'_id': 'La Dinastia', 'nota_promedio': 14.4}
# {'_id': 'Xe Lua Restaurant', 'nota_promedio': 18.5}
# {'_id': 'Scarab Lounge', 'nota_promedio': 7.333333333333333}
# {'_id': 'Blacksmith Cafe & Delicatessen', 'nota_promedio': 15.75}
# {'_id': 'China Place', 'nota_promedio': 13.0}
# {'_id': 'Cafe 71', 'nota_promedio': 14.0}
# {'_id': 'Walter Kerr Theatre', 'nota_promedio': 10.333333333333334}
# {'_id': 'B Flat', 'nota_promedio': 11.25}
# {'_id': 'Morgan Stanley Cafeteria', 'nota_promedio': 4.25}
# {'_id': 'Blarney Stone Pub', 'nota_promedio': 15.166666666666666}
# {'_id': 'John Jay Dining Hall', 'nota_promedio': 11.666666666666666}
# {'_id': 'Seoul Garden', 'nota_promedio': 11.714285714285714}
# {'_id': 'Lips Restaurant', 'nota_promedio': 9.75}
# {'_id': 'Cafe Nunez', 'nota_promedio': 14.666666666666666}
# {'_id': "John Sullivan'S Pub", 'nota_promedio': 12.0}
# {'_id': 'Riverbank Grill', 'nota_promedio': 11.6}
# {'_id': 'Marlin Bar At Tommy Bahama And Tommy Bahama Restaurant And B',
#  'nota_promedio': 10.666666666666666}
# {'_id': 'Kirakuya Sake Bar', 'nota_promedio': 9.0}
# {'_id': 'Starbucks Coffee (Bank Of America Building)', 'nota_promedio': 4.0}
# {'_id': "Harriet'S Kitchen", 'nota_promedio': 10.666666666666666}
# {'_id': 'The Famous Chicken Place', 'nota_promedio': 12.0}
# {'_id': 'Simply Sliders', 'nota_promedio': 10.5}
# {'_id': "Mozzarelli'S", 'nota_promedio': 9.6}
# {'_id': 'Havana Ny', 'nota_promedio': 15.6}
# {'_id': 'Alliance Capital', 'nota_promedio': 9.5}
# {'_id': 'Calliope', 'nota_promedio': 12.0}
# {'_id': 'Solas', 'nota_promedio': 11.714285714285714}
# {'_id': 'Yuji Ramen', 'nota_promedio': 12.0}
# {'_id': 'Girello', 'nota_promedio': 9.333333333333334}
# {'_id': 'Sapphire Indian Cuisine', 'nota_promedio': 18.5}
# {'_id': 'Nai Tapas Bar', 'nota_promedio': 12.2}
# {'_id': 'Restaurant Riki', 'nota_promedio': 16.5}
# {'_id': 'Sanctuary T', 'nota_promedio': 13.8}
# {'_id': 'Pearl & Ash', 'nota_promedio': 9.0}
# {'_id': 'Black Seed', 'nota_promedio': 12.0}
# {'_id': 'Spot', 'nota_promedio': 10.8}
# {'_id': 'New York Stock Exchange', 'nota_promedio': 9.25}
# {'_id': 'El Toro Blanco', 'nota_promedio': 9.333333333333334}
# {'_id': 'Blake And Todd', 'nota_promedio': 10.75}
# {'_id': 'The Simone', 'nota_promedio': 10.0}
# {'_id': 'Lexler Deli', 'nota_promedio': 4.6}
# {'_id': 'Amity Hall', 'nota_promedio': 6.8}
# {'_id': "Murray'S Bagels", 'nota_promedio': 12.454545454545455}
# {'_id': 'Mama Ghanoush', 'nota_promedio': 12.0}
# {'_id': 'Chokolat Patisserie', 'nota_promedio': 9.666666666666666}
# {'_id': 'Hot Sichuan', 'nota_promedio': 27.0}
# {'_id': 'Tribeca Pizzeria', 'nota_promedio': 10.8}
# {'_id': 'Capri Restaurant', 'nota_promedio': 12.0}
# {'_id': 'Lady M Confections', 'nota_promedio': 9.25}
# {'_id': 'Il Melograno', 'nota_promedio': 9.75}
# {'_id': 'Jackson Hole', 'nota_promedio': 9.166666666666666}
# {'_id': "Sunberry'S", 'nota_promedio': 9.4}
# {'_id': 'Times Deli & Cafe', 'nota_promedio': 23.571428571428573}
# {'_id': 'Altus Cafe', 'nota_promedio': 16.4}
# {'_id': "Davey'S Ice Cream", 'nota_promedio': 8.0}
# {'_id': 'Mon Petit Cafe', 'nota_promedio': 7.75}
# {'_id': 'New University Deli', 'nota_promedio': 24.5}
# {'_id': 'Molly Wee Pub', 'nota_promedio': 10.833333333333334}
# {'_id': 'Sundaes And Cones', 'nota_promedio': 6.333333333333333}
# {'_id': 'Thai Select', 'nota_promedio': 14.75}
# {'_id': 'East Seafood Inc', 'nota_promedio': 23.0}
# {'_id': 'Brushstroke (30 Hudson St)', 'nota_promedio': 11.8}
# {'_id': 'Victory Garden', 'nota_promedio': 8.5}
# {'_id': 'Il Tinello Ristorante', 'nota_promedio': 9.4}
# {'_id': 'Barbes', 'nota_promedio': 13.6}
# {'_id': 'Regency Hotel', 'nota_promedio': 10.0}
# {'_id': 'Hu Kitchen', 'nota_promedio': 8.333333333333334}
# {'_id': 'The Lexington Social', 'nota_promedio': 10.5}
# {'_id': 'Google Chelsea Market', 'nota_promedio': 7.5}
# {'_id': 'Bombonada', 'nota_promedio': 12.0}
# {'_id': 'El Rancho Vegano', 'nota_promedio': 9.0}
# {'_id': "Tower'S Cafe", 'nota_promedio': 14.333333333333334}
# {'_id': 'Aux Epices', 'nota_promedio': 11.25}
# {'_id': 'The Grisly Pear', 'nota_promedio': 16.2}
# {'_id': 'West New Malaysia Restaurant', 'nota_promedio': 12.0}
# {'_id': 'Juke Box Juice & Salad', 'nota_promedio': 7.5}
# {'_id': 'Root & Bone', 'nota_promedio': 9.0}
# {'_id': "Gila'S Nosh", 'nota_promedio': 7.666666666666667}
# {'_id': '876 Market Deli', 'nota_promedio': 8.2}
# {'_id': 'Sushi Nakazawa', 'nota_promedio': 10.5}
# {'_id': 'City College Cafeteria', 'nota_promedio': 15.333333333333334}
# {'_id': 'Golden Manna Bakery', 'nota_promedio': 14.0}
# {'_id': 'New Shun Hing Chinese Restaurant', 'nota_promedio': 12.0}
# {'_id': 'Primo Cappuccino', 'nota_promedio': 5.75}
# {'_id': 'El Rincon Del Sabor', 'nota_promedio': 12.0}
# {'_id': 'Hibachi Dumpling', 'nota_promedio': 2.0}
# {'_id': 'Evelyn', 'nota_promedio': 11.0}
# {'_id': "Tequila Chito'S Mexican Grill", 'nota_promedio': 15.8}
# {'_id': 'La Preciosa China Restaurant', 'nota_promedio': 22.571428571428573}
# {'_id': 'Sugarcane Vietnamese Cooking', 'nota_promedio': 11.5}
# {'_id': 'Hells Kitchen Cafe/Hk Lounge', 'nota_promedio': 18.333333333333332}
# {'_id': 'Randolph Beer', 'nota_promedio': 11.0}
# {'_id': 'Bikinis', 'nota_promedio': 8.0}
# {'_id': 'New York University - Kimmel Student Center Cafeteria',
#  'nota_promedio': 3.75}
# {'_id': 'Restivo Ristorante', 'nota_promedio': 15.571428571428571}
# {'_id': 'Punjabi Tadka & Kebab', 'nota_promedio': 13.833333333333334}
# {'_id': 'Bluespoon Coffee', 'nota_promedio': 12.0}
# {'_id': 'Deluxe', 'nota_promedio': 9.0}
# {'_id': 'New Nyc Yoan Ming Garden', 'nota_promedio': 18.0}
# {'_id': 'Cafe Centro', 'nota_promedio': 19.0}
# {'_id': 'Lederhosen Restaurant', 'nota_promedio': 10.25}
# {'_id': 'Water Taxi Beach', 'nota_promedio': 8.75}
# {'_id': "Mcdonald'S (Macy'S 7Th Fl)", 'nota_promedio': 11.75}
# {'_id': "Bunga'S Den", 'nota_promedio': 13.333333333333334}
# {'_id': "Billie'S Black Bar Lounge And Restaurant",
#  'nota_promedio': 13.333333333333334}
# {'_id': 'Westside Brewhouse', 'nota_promedio': 10.4}
# {'_id': 'Haus', 'nota_promedio': 16.0}
# {'_id': 'Hua Du Dumpling Shop', 'nota_promedio': 18.285714285714285}
# {'_id': 'Catch', 'nota_promedio': 14.2}
# {'_id': "Eleni'S New York", 'nota_promedio': 11.0}
# {'_id': 'Elsa La Reina Del Chicharron', 'nota_promedio': 8.0}
# {'_id': 'Fanelli Cafe', 'nota_promedio': 7.5}
# {'_id': 'Pronto Pizza', 'nota_promedio': 13.333333333333334}
# {'_id': 'Bistecca Fiorentina Steak', 'nota_promedio': 10.0}
# {'_id': 'Baraonda', 'nota_promedio': 12.25}
# {'_id': "Joe'S Crab Shack", 'nota_promedio': 22.666666666666668}
# {'_id': 'Metropolitan Food Service', 'nota_promedio': 9.25}
# {'_id': 'Amaze', 'nota_promedio': 25.2}
# {'_id': 'Safe Horizon', 'nota_promedio': 4.666666666666667}
# {'_id': 'La Margarita', 'nota_promedio': 7.0}
# {'_id': 'Cd8010 Hamburger Concession', 'nota_promedio': 0.0}
# {'_id': 'Corsino Cantina', 'nota_promedio': 12.8}
# {'_id': 'The Burger Bistro', 'nota_promedio': 13.0}
# {'_id': "Berger'S On The Go", 'nota_promedio': 11.714285714285714}
# {'_id': 'Sheraton Tribeca New York Hotel', 'nota_promedio': 17.5}
# {'_id': 'Apt. 78', 'nota_promedio': 20.0}
# {'_id': "The Grey Dog'S Coffee", 'nota_promedio': 9.25}
# {'_id': 'Treehaus', 'nota_promedio': 13.25}
# {'_id': 'Three Tarts', 'nota_promedio': 6.333333333333333}
# {'_id': 'Max Fish', 'nota_promedio': 9.0}
# {'_id': 'Garden Pub', 'nota_promedio': 0.6666666666666666}
# {'_id': 'The Spot Karaoke Lounge', 'nota_promedio': 15.0}
# {'_id': 'Marilu & Deysi Restaurant', 'nota_promedio': 12.0}
# {'_id': 'New Ocean', 'nota_promedio': 22.25}
# {'_id': 'Garden Cafe', 'nota_promedio': 10.833333333333334}
# {'_id': 'Evolve', 'nota_promedio': 14.166666666666666}
# {'_id': 'Flight 151', 'nota_promedio': 9.2}
# {'_id': "E'S Bar", 'nota_promedio': 12.0}
# {'_id': 'Enthaice', 'nota_promedio': 15.166666666666666}
# {'_id': 'The Stairs Bar And Lounge', 'nota_promedio': 11.0}
# {'_id': 'Aarons Chinese & Thai Restaurant', 'nota_promedio': 17.25}
# {'_id': "Mickie'S Ice Cream", 'nota_promedio': 9.666666666666666}
# {'_id': 'Accra Restaurant', 'nota_promedio': 12.5}
# {'_id': 'Julliard & S.A.B. Cafeteria', 'nota_promedio': 2.6666666666666665}
# {'_id': 'Aleo', 'nota_promedio': 15.6}
# {'_id': 'The Sixth Ward', 'nota_promedio': 13.5}
# {'_id': 'Center Bar', 'nota_promedio': 10.333333333333334}
# {'_id': 'Tribeca Grill', 'nota_promedio': 12.0}
# {'_id': 'Gourmet Bagel', 'nota_promedio': 12.75}
# {'_id': '456 Restaurant', 'nota_promedio': 21.0}
# {'_id': '218 Restaurant', 'nota_promedio': 27.166666666666668}
# {'_id': 'American Legion Veterans Post', 'nota_promedio': 12.0}
# {'_id': '49 Grove', 'nota_promedio': 4.75}
# {'_id': 'Rosens Cafe', 'nota_promedio': 9.285714285714286}
# {'_id': 'Le Glacier', 'nota_promedio': 11.166666666666666}
# {'_id': 'Brown Brothers Cafeteria', 'nota_promedio': 8.5}
# {'_id': 'Il Riccio Restaurant', 'nota_promedio': 14.166666666666666}
# {'_id': '510 11St Bar', 'nota_promedio': 7.25}
# {'_id': 'Moca Bar & Lounge', 'nota_promedio': 13.5}
# {'_id': 'Bistro Les Amis', 'nota_promedio': 9.0}
# {'_id': 'Go Go Curry Usa', 'nota_promedio': 10.25}
# {'_id': "Juicy Lucy'S", 'nota_promedio': 4.5}
# {'_id': "Omar'S Kitchen & Bakery", 'nota_promedio': 8.75}
# {'_id': 'Bread', 'nota_promedio': 15.555555555555555}
# {'_id': 'Raspberry Deli & Grocery', 'nota_promedio': 9.2}
# {'_id': 'Hawkers', 'nota_promedio': 14.4}
# {'_id': 'Hunan Manor Restaurant', 'nota_promedio': 18.0}
# {'_id': 'Evr', 'nota_promedio': 24.0}
# {'_id': 'Cochinita Dos', 'nota_promedio': 12.0}
# {'_id': 'Tasty Deli', 'nota_promedio': 13.666666666666666}
# {'_id': 'Kokum', 'nota_promedio': 10.333333333333334}
# ...
# {'_id': 'The Squeeze', 'nota_promedio': 7.0}
# {'_id': "Saluggi'S", 'nota_promedio': 17.4}
# {'_id': "La Esquina ''The Corner''", 'nota_promedio': 12.0}
# {'_id': 'Chelsea Deli & Pizza', 'nota_promedio': 13.666666666666666}
# {'_id': 'El Quinto Pino', 'nota_promedio': 8.2}
# {'_id': 'Wo Hop City', 'nota_promedio': 20.857142857142858}
# {'_id': "Beecher'S Handmade Cheese", 'nota_promedio': 10.0}
# {'_id': "Bayard'S Alehouse", 'nota_promedio': 9.6}
# {'_id': 'Willow Road', 'nota_promedio': 7.666666666666667}
# {'_id': 'Sl Green Realty', 'nota_promedio': 10.333333333333334}
# {'_id': 'Super Taste', 'nota_promedio': 9.0}
# {'_id': 'Saigon Vietnamese Sandwich', 'nota_promedio': 8.2}
# {'_id': 'Florian Cafe Tattoria & Bar', 'nota_promedio': 12.0}
# {'_id': 'Aki 39 Japanese Cuisine', 'nota_promedio': 11.0}
# {'_id': 'Legends Nyc', 'nota_promedio': 19.333333333333332}
# {'_id': 'Amcook Fusion Sushi & Asian Cuisine', 'nota_promedio': 12.75}
# {'_id': "Fiore'S Pizza", 'nota_promedio': 11.833333333333334}
# {'_id': 'The Growler', 'nota_promedio': 14.25}
# {'_id': 'Ken & Cook', 'nota_promedio': 16.333333333333332}
# {'_id': 'Toon Thai Cafe', 'nota_promedio': 13.333333333333334}
# {'_id': 'Grand Central Star Cafe', 'nota_promedio': 10.833333333333334}
# {'_id': 'Nargila Grill', 'nota_promedio': 9.6}
# {'_id': 'Hi-Collar', 'nota_promedio': 5.0}
# {'_id': 'Bangkok House', 'nota_promedio': 17.666666666666668}
# {'_id': 'Queen Of Sheba Ethiopian Restaurant',
#  'nota_promedio': 11.666666666666666}
# {'_id': 'Cold Stone Creamery/Tim Hortons', 'nota_promedio': 4.0}
# {'_id': 'Global Kitchen', 'nota_promedio': 23.0}
# {'_id': 'Kentucky Fried Chicken/ Island Cuisine', 'nota_promedio': 8.25}
# {'_id': '99 Cent Best Pizza 5Ave Inc', 'nota_promedio': 2.0}
# {'_id': 'La Dulzura Restaurant', 'nota_promedio': 11.333333333333334}
# {'_id': 'Hop Won Express', 'nota_promedio': 26.5}
# {'_id': 'Hunter College Proudly Brew Starbucks', 'nota_promedio': 8.75}
# {'_id': 'Salumeria Rosi Parmacotto', 'nota_promedio': 14.333333333333334}
# {'_id': 'Food World', 'nota_promedio': 14.666666666666666}
# {'_id': 'Johnny Utahs', 'nota_promedio': 18.0}
# {'_id': 'Tout Va Bien', 'nota_promedio': 21.5}
# {'_id': 'Morningstar Restaurant', 'nota_promedio': 10.285714285714286}
# {'_id': 'Back Forty', 'nota_promedio': 14.25}
# {'_id': '1 Oak', 'nota_promedio': 9.666666666666666}
# {'_id': 'Pampano', 'nota_promedio': 15.833333333333334}
# {'_id': 'Bombay Deli Pizza & Tandoori Restaurant', 'nota_promedio': 10.5}
# {'_id': '5 Boro Burger', 'nota_promedio': 10.571428571428571}
# {'_id': 'Wine Bar', 'nota_promedio': 9.5}
# {'_id': 'Amarone Restaurant', 'nota_promedio': 7.0}
# {'_id': 'Butterfield Catering', 'nota_promedio': 12.75}
# {'_id': 'Falanghina', 'nota_promedio': 8.0}
# {'_id': 'Trestle On Tenth', 'nota_promedio': 10.2}
# {'_id': 'Billiards', 'nota_promedio': 11.5}
# {'_id': 'Sonnier & Castle Food', 'nota_promedio': 11.4}
# {'_id': 'Nice One Bakery', 'nota_promedio': 11.25}
# {'_id': 'A Slice Of New York', 'nota_promedio': 19.0}
# {'_id': 'Alphabet Lounge', 'nota_promedio': 11.6}
# {'_id': "Dunkin' Donuts/Baskin Robbins", 'nota_promedio': 8.8125}
# {'_id': 'Megu Midtown', 'nota_promedio': 12.75}
# {'_id': 'Le Cafe Coffee', 'nota_promedio': 8.5}
# {'_id': "Judy'S Spanish Restaurant", 'nota_promedio': 5.0}
# {'_id': 'Everyday Gourmet Deli', 'nota_promedio': 25.666666666666668}
# {'_id': 'City Swiggers', 'nota_promedio': 4.0}
# {'_id': "Sotheby'S Cafe", 'nota_promedio': 6.0}
# {'_id': "Balducci'S", 'nota_promedio': 12.0}
# {'_id': 'Grand Street Deli & Mini Market', 'nota_promedio': 12.571428571428571}
# {'_id': "Biddy'S Pub", 'nota_promedio': 12.6}
# {'_id': 'V Bar', 'nota_promedio': 11.8}
# {'_id': 'Dd Maru Sushi', 'nota_promedio': 8.2}
# {'_id': 'Boston Market', 'nota_promedio': 10.11111111111111}
# {'_id': 'Lincoln Fried Chicken', 'nota_promedio': 9.75}
# {'_id': 'Simply Food', 'nota_promedio': 6.0}
# {'_id': 'Robusta  Espresso Bar', 'nota_promedio': 4.0}
# {'_id': "Lin'S Gourmet", 'nota_promedio': 10.25}
# {'_id': 'Empire Hotel Bar', 'nota_promedio': 8.5}
# {'_id': 'Jaiya Thai & Oriental Restaurant', 'nota_promedio': 11.5}
# {'_id': '374 Deli', 'nota_promedio': 22.0}
# {'_id': 'Pie', 'nota_promedio': 3.3333333333333335}
# {'_id': 'The Bubble Lounge', 'nota_promedio': 9.0}
# {'_id': 'Royalton Hotel', 'nota_promedio': 11.666666666666666}
# {'_id': 'Cafe Bravo', 'nota_promedio': 14.857142857142858}
# {'_id': 'Polash Indian Cuisine Restaurant', 'nota_promedio': 9.5}
# {'_id': 'Bagels & Co.', 'nota_promedio': 30.333333333333332}
# {'_id': 'Liberty View Chinese Restaurant', 'nota_promedio': 11.166666666666666}
# {'_id': 'The Tap Room', 'nota_promedio': 10.5}
# {'_id': 'Bourgeois Pig North', 'nota_promedio': 9.2}
# {'_id': 'King Wok', 'nota_promedio': 9.5}
# {'_id': 'Snafu 28', 'nota_promedio': 11.0}
# {'_id': 'Gagopa Music Studio', 'nota_promedio': 6.0}
# {'_id': 'Tai Pan Bakery', 'nota_promedio': 13.142857142857142}
# {'_id': 'Thai Plus', 'nota_promedio': 15.333333333333334}
# {'_id': 'Palace Deli', 'nota_promedio': 10.0}
# {'_id': 'Tenzan', 'nota_promedio': 12.6}
# {'_id': "J. Gumbo'S", 'nota_promedio': 12.0}
# {'_id': 'New York Rifle Club', 'nota_promedio': 12.5}
# {'_id': 'Atlas Social Club', 'nota_promedio': 5.0}
# {'_id': 'Fpb  Bakery', 'nota_promedio': 9.0}
# {'_id': 'Shamas Deli', 'nota_promedio': 10.4}
# {'_id': 'Da Umberto Restaurant', 'nota_promedio': 11.0}
# {'_id': 'Hotel Pierre-Banquet Kitchen', 'nota_promedio': 11.666666666666666}
# {'_id': 'Delicatessen Macbar', 'nota_promedio': 11.833333333333334}
# {'_id': 'The Westway', 'nota_promedio': 7.666666666666667}
# {'_id': 'Mudville Saloon', 'nota_promedio': 9.25}
# {'_id': 'Red House Restaurant', 'nota_promedio': 17.333333333333332}
# {'_id': 'American Table Cafe And Bar', 'nota_promedio': 8.0}
# {'_id': 'Hide Chan Ramen', 'nota_promedio': 9.6}
# {'_id': 'Pig Heaven', 'nota_promedio': 12.0}
# {'_id': 'Bloomberg', 'nota_promedio': 5.0}
# {'_id': 'Burrito Box', 'nota_promedio': 10.0}
# {'_id': 'Minar Indian Restaurant', 'nota_promedio': 17.0}
# {'_id': 'D Napoli Pizza', 'nota_promedio': 11.75}
# {'_id': 'Nicky Ii Inc', 'nota_promedio': 10.0}
# {'_id': 'Amazing 66 Restaurant', 'nota_promedio': 13.375}
# {'_id': 'Majestic Pizza', 'nota_promedio': 11.571428571428571}
# {'_id': 'Restaurant San Cristobal', 'nota_promedio': 9.666666666666666}
# {'_id': 'East Side Billard', 'nota_promedio': 17.333333333333332}
# {'_id': "Cleopatra'S Needle", 'nota_promedio': 10.8}
# {'_id': 'My Cooking Party', 'nota_promedio': 8.0}
# {'_id': '42Nd Street Pizza Diner', 'nota_promedio': 8.0}
# {'_id': 'Black Shack', 'nota_promedio': 8.25}
# {'_id': 'Cold Cut City Bunny Deli 2', 'nota_promedio': 24.0}
# {'_id': 'The Sea Fire Grill', 'nota_promedio': 15.0}
# {'_id': 'Bibble And Sip', 'nota_promedio': 3.0}
# {'_id': "Ben'S Deli", 'nota_promedio': 8.6}
# {'_id': 'Nosh! - Courtyard By Marriott', 'nota_promedio': 9.25}
# {'_id': 'Goloka Juice Bar', 'nota_promedio': 9.666666666666666}
# {'_id': 'Good To Go', 'nota_promedio': 8.333333333333334}
# {'_id': 'Shubert Theater', 'nota_promedio': 10.4}
# {'_id': 'Nassau Bar', 'nota_promedio': 9.25}
# {'_id': 'Fat Baby', 'nota_promedio': 22.75}
# {'_id': "Bally'S Sport Club", 'nota_promedio': 11.0}
# {'_id': 'Via Della Pace', 'nota_promedio': 20.4}
# {'_id': 'Golden Steamer', 'nota_promedio': 17.5}
# {'_id': 'Greenwich Treehouse', 'nota_promedio': 8.75}
# {'_id': "Sofia'S", 'nota_promedio': 12.0}
# {'_id': 'Madison Garden Beer Pub', 'nota_promedio': 0.0}
# {'_id': 'Motivo', 'nota_promedio': 11.0}
# {'_id': 'Up Town Swirl', 'nota_promedio': 9.5}
# {'_id': 'Oyster Bar', 'nota_promedio': 15.0}
# {'_id': 'Swerve Fitness', 'nota_promedio': 6.0}
# {'_id': 'The Kingside', 'nota_promedio': 9.0}
# {'_id': 'En Japanese Brasserie', 'nota_promedio': 10.0}
# {'_id': 'Little Atlas Cafe', 'nota_promedio': 12.5}
# {'_id': 'Juice Press 12', 'nota_promedio': 0.0}
# {'_id': 'Ra At Barclays', 'nota_promedio': 8.0}
# {'_id': 'Original Puglia Ristorante Italiano', 'nota_promedio': 15.5}
# {'_id': 'The Green Table(Chelsea Market)', 'nota_promedio': 8.6}
# {'_id': 'La Posada Mexican Food', 'nota_promedio': 11.0}
# {'_id': 'Bacchanal', 'nota_promedio': 9.0}
# {'_id': 'Amigos', 'nota_promedio': 11.4}
# {'_id': 'Anyway Cafe', 'nota_promedio': 10.4}
# {'_id': 'B.B. Kings', 'nota_promedio': 28.428571428571427}
# {'_id': 'Lotos Club Grill Room', 'nota_promedio': 11.5}
# {'_id': '2Nd Avenue Deli', 'nota_promedio': 10.125}
# {'_id': "Brady'S Bar", 'nota_promedio': 11.333333333333334}
# {'_id': 'Iron Sushi', 'nota_promedio': 14.555555555555555}
# {'_id': 'Teavana#22632', 'nota_promedio': 10.0}
# {'_id': 'City Gourmet', 'nota_promedio': 12.666666666666666}
# {'_id': 'Diwan-E-Khaas', 'nota_promedio': 2.5}
# {'_id': 'Mthai', 'nota_promedio': 9.0}
# {'_id': 'Sheshe Pizzeria', 'nota_promedio': 12.0}
# {'_id': 'Dichter Pharmacy', 'nota_promedio': 9.5}
# {'_id': 'Stanton Social', 'nota_promedio': 9.0}
# {'_id': 'Glass House Tavern', 'nota_promedio': 11.75}
# {'_id': 'Golden Krust Caribbean Bakery & Grill',
#  'nota_promedio': 10.956521739130435}
# {'_id': 'Bistro Le Steak', 'nota_promedio': 7.8}
# {'_id': "Rae'S Deli", 'nota_promedio': 18.75}
# {'_id': 'Rpm', 'nota_promedio': 10.0}
# {'_id': 'The Wheeltapper', 'nota_promedio': 10.5}
# {'_id': 'Karahi Indian Cuisine', 'nota_promedio': 8.4}
# {'_id': 'Atwood Kitchen & Bar', 'nota_promedio': 24.0}
# {'_id': 'Beautique', 'nota_promedio': 5.0}
# {'_id': 'Taormina Ristorante', 'nota_promedio': 10.166666666666666}
# {'_id': 'Great Hong Kong Inc', 'nota_promedio': 3.0}
# {'_id': 'B4 Nyc', 'nota_promedio': 10.5}
# {'_id': 'Daryl Roth Theatre', 'nota_promedio': 8.5}
# {'_id': 'Tim Hortons', 'nota_promedio': 7.25}
# {'_id': 'Five Guys Burgers  And  Fries', 'nota_promedio': 5.666666666666667}
# {'_id': 'Maguro Sushi', 'nota_promedio': 11.0}
# {'_id': 'King Dragon', 'nota_promedio': 9.333333333333334}
# {'_id': 'Briciola', 'nota_promedio': 12.5}
# {'_id': 'Deli Plus ( Inside Port Authority Station)', 'nota_promedio': 10.4}
# {'_id': 'Andrews Coffee Shop', 'nota_promedio': 10.833333333333334}
# {'_id': "Bubby'S", 'nota_promedio': 10.0}
# {'_id': 'Tisserie', 'nota_promedio': 11.25}
# {'_id': 'Clarkson', 'nota_promedio': 20.666666666666668}
# {'_id': 'Don Panchito Restaurant', 'nota_promedio': 16.5}
# {'_id': 'Bristle And Creme', 'nota_promedio': 4.0}
# {'_id': 'Kpmg Cafe', 'nota_promedio': 6.0}
# {'_id': 'Wondee Siam V', 'nota_promedio': 11.0}
# {'_id': "Kennedy'S Chicken Sandwiches", 'nota_promedio': 16.25}
# {'_id': '810 Deli & Cafe', 'nota_promedio': 12.0}
# {'_id': "D'Vida Health Bar", 'nota_promedio': 10.3}
# {'_id': 'Graffitti Me', 'nota_promedio': 7.0}
# {'_id': 'Sushiya Japanese Restaurant', 'nota_promedio': 7.0}
# {'_id': 'Gardenia Grocery & Deli', 'nota_promedio': 12.285714285714286}
# {'_id': 'The Cupping Room', 'nota_promedio': 12.666666666666666}
# {'_id': 'U Like Chinese Take Out', 'nota_promedio': 20.0}
# {'_id': 'Bistro 61', 'nota_promedio': 11.8}
# {'_id': 'Parlor Club Nyc', 'nota_promedio': 14.25}
# {'_id': 'Morgan Cafe', 'nota_promedio': 12.333333333333334}
# {'_id': 'La Giara', 'nota_promedio': 9.0}
# {'_id': "Danny'S Deli", 'nota_promedio': 13.5}
# {'_id': 'Rendezvous (Pier 81)', 'nota_promedio': 12.666666666666666}
# {'_id': 'Brk', 'nota_promedio': 12.0}
# {'_id': 'Gaia Italian Cafe', 'nota_promedio': 9.75}
# {'_id': 'Thunder Jacksons Urban Roadhouse', 'nota_promedio': 13.333333333333334}
# {'_id': "Maryann'S", 'nota_promedio': 22.333333333333332}
# {'_id': 'Crave Sandwiches', 'nota_promedio': 6.571428571428571}
# {'_id': 'Cata', 'nota_promedio': 17.333333333333332}
# {'_id': "Mama'S Bar", 'nota_promedio': 11.0}
# {'_id': 'Bcd Tofu House', 'nota_promedio': 15.5}
# {'_id': "D'Lili Bakery", 'nota_promedio': 4.0}
# {'_id': 'Peacock Alley Restaurant And Bar', 'nota_promedio': 17.333333333333332}
# {'_id': 'D-Lish Pita', 'nota_promedio': 10.0}
# {'_id': 'Lura', 'nota_promedio': 12.0}
# {'_id': 'Sutton Pizza & Gyro', 'nota_promedio': 13.4}
# {'_id': 'Sriracha', 'nota_promedio': 12.5}
# {'_id': 'Carvel Ice Cream', 'nota_promedio': 21.0}
# {'_id': 'The Milton', 'nota_promedio': 10.0}
# {'_id': 'Starbucks Coffee # 15440', 'nota_promedio': 3.5}
# {'_id': 'Cafe Noir', 'nota_promedio': 10.0}
# {'_id': 'Teqa', 'nota_promedio': 10.8}
# {'_id': 'Aa Jing', 'nota_promedio': 23.333333333333332}
# {'_id': 'La Nueva Espana', 'nota_promedio': 16.6}
# {'_id': 'Mexican Festival', 'nota_promedio': 2.0}
# {'_id': 'Novecento', 'nota_promedio': 11.5}
# {'_id': "Lillie'S Restaurant", 'nota_promedio': 13.0}
# {'_id': 'Las Americas Bakery', 'nota_promedio': 14.166666666666666}
# {'_id': 'The Met Grill/Double Tree Hotel', 'nota_promedio': 17.428571428571427}
# {'_id': 'Greenwich Village Bistro', 'nota_promedio': 25.833333333333332}
# {'_id': 'Ai Fiori', 'nota_promedio': 8.75}
# {'_id': 'The Library', 'nota_promedio': 15.666666666666666}
# {'_id': 'Abc Kitchen', 'nota_promedio': 11.5}
# {'_id': 'Yogurtland', 'nota_promedio': 8.875}
# {'_id': 'Bumble & Bumble Cafe', 'nota_promedio': 6.25}
# {'_id': 'Mikes Pizza', 'nota_promedio': 11.4}
# {'_id': 'Paquitos', 'nota_promedio': 16.333333333333332}
# {'_id': 'Do Hwa', 'nota_promedio': 10.0}
# {'_id': 'Spin New York', 'nota_promedio': 13.0}
# {'_id': 'Amura Japanese Restaurant', 'nota_promedio': 11.25}
# {'_id': 'Great N.Y. Noodletown', 'nota_promedio': 13.0}
# {'_id': 'Chickpea/Red Mango', 'nota_promedio': 11.0}
# {'_id': 'Apotheke', 'nota_promedio': 10.666666666666666}
# {'_id': 'District 12', 'nota_promedio': 12.0}
# {'_id': 'World Yacht Princess', 'nota_promedio': 7.666666666666667}
# {'_id': 'The Park View', 'nota_promedio': 25.0}
# {'_id': 'Market Table', 'nota_promedio': 8.8}
# {'_id': 'Pizza Beach', 'nota_promedio': 2.0}
# {'_id': '99C Fresh Pizza', 'nota_promedio': 10.5}
# {'_id': 'Betel Party Supply Bakery', 'nota_promedio': 10.5}
# {'_id': 'Ho Yip Restaurant', 'nota_promedio': 17.833333333333332}
# {'_id': 'Asian Time Eatery', 'nota_promedio': 2.0}
# {'_id': 'Residence Inn Times Square', 'nota_promedio': 9.0}
# {'_id': 'Blue Ribbon Sushi Bar & Grill', 'nota_promedio': 11.25}
# {'_id': 'Radicchio', 'nota_promedio': 17.2}
# {'_id': 'Sea Grill', 'nota_promedio': 10.2}
# {'_id': 'Aba Asian Fusion Cuisine Ave', 'nota_promedio': 11.5}
# {'_id': 'Sfoglia Restaurant', 'nota_promedio': 11.4}
# {'_id': 'Suger Flower Cake Shop', 'nota_promedio': 3.5}
# {'_id': 'Taco Bell', 'nota_promedio': 7.0}
# {'_id': 'Bibi Winecellar', 'nota_promedio': 5.0}
# {'_id': 'Famous Bagel Buffet', 'nota_promedio': 12.0}
# {'_id': "Manny'S On Second", 'nota_promedio': 14.0}
# {'_id': "Uncle Mario'S", 'nota_promedio': 11.4}
# {'_id': 'Pinche Taquiera', 'nota_promedio': 10.5}
# {'_id': 'Refresh Cafe', 'nota_promedio': 9.0}
# {'_id': 'Wharf Bar & Grill', 'nota_promedio': 10.75}
# {'_id': 'The Room', 'nota_promedio': 7.0}
# {'_id': 'Rohm Thai', 'nota_promedio': 18.166666666666668}
# {'_id': 'Perkins', 'nota_promedio': 13.0}
# {'_id': 'Nocciola Ristorante', 'nota_promedio': 12.0}
# {'_id': 'Hayaty', 'nota_promedio': 16.2}
# {'_id': 'Third Floor Cafe', 'nota_promedio': 13.666666666666666}
# {'_id': 'La Paloma Restaurant', 'nota_promedio': 9.8}
# {'_id': 'The Comfort Diner', 'nota_promedio': 13.166666666666666}
# {'_id': "Lucy'S Whey", 'nota_promedio': 8.5}
# {'_id': 'Buddha B Beeq', 'nota_promedio': 12.0}
# {'_id': 'Texas De Brazil Churrascaria', 'nota_promedio': 34.0}
# {'_id': 'The Hallmark Of Battery Park City- Dining Room', 'nota_promedio': 12.0}
# {'_id': 'Playwright Celtic Pub', 'nota_promedio': 12.3}
# {'_id': 'Yong Sheng Restaurant', 'nota_promedio': 11.75}
# {'_id': "Mary Ann'S", 'nota_promedio': 19.0}
# {'_id': 'Raymi', 'nota_promedio': 23.0}
# {'_id': 'Hunan House', 'nota_promedio': 8.0}
# {'_id': 'Cafe Frida', 'nota_promedio': 8.8}
# {'_id': 'Panini & Co', 'nota_promedio': 14.833333333333334}
# {'_id': 'The Heights Bar & Grill', 'nota_promedio': 17.5}
# {'_id': 'Healthy Bite', 'nota_promedio': 10.0}
# {'_id': "Ted'S Montana Grill", 'nota_promedio': 15.0}
# {'_id': 'Kushi Q', 'nota_promedio': 8.75}
# {'_id': 'Pizza Boss', 'nota_promedio': 12.0}
# {'_id': 'Il Buco Restaurant', 'nota_promedio': 9.0}
# {'_id': 'M2M Mart', 'nota_promedio': 14.833333333333334}
# {'_id': 'Anglers Club Of New York', 'nota_promedio': 8.25}
# {'_id': 'Millenium Hilton', 'nota_promedio': 8.0}
# {'_id': 'Fb9090 Hot Dog Concession', 'nota_promedio': 0.0}
# {'_id': 'Il Principe', 'nota_promedio': 10.0}
# {'_id': 'Taszo Coffee', 'nota_promedio': 8.5}
# {'_id': 'Argotea', 'nota_promedio': 2.3333333333333335}
# {'_id': 'Village Yogurt', 'nota_promedio': 11.333333333333334}

# %% [markdown]
# Y podemos ordenar los resultados empleando el operador `$sort`.

# %%
resultado = rest_collection.aggregate([
    {"$match" : {"borough" : "Manhattan"}},
    {"$unwind" : "$grades"},
    {"$group": {"_id": "$name", "nota_promedio" : {"$avg" : "$grades.score"}}},
    {"$sort": {"nota_promedio": -1}}, # "-1" INDICA QUE SE DEBE ORDENAR EN ORDEN DESCENDENTE  
    {"$limit": 10}
])

for elemento in resultado:
    pprint(elemento)
# Out:
# {'_id': 'Ivory D O S  Inc', 'nota_promedio': 60.0}
# {'_id': 'Matcha Cafe Wabi', 'nota_promedio': 56.0}
# {'_id': 'Espace', 'nota_promedio': 56.0}
# {'_id': 'Savour Sichuan', 'nota_promedio': 56.0}
# {'_id': 'Kikka At Whole Foods Chelsea', 'nota_promedio': 56.0}
# {'_id': 'Savory', 'nota_promedio': 54.0}
# {'_id': 'Homewood Suites By Hilton New York Midtown Manhattan Times Square',
#  'nota_promedio': 52.0}
# {'_id': "Luzzo'S La Mtp", 'nota_promedio': 47.0}
# {'_id': 'The Derby', 'nota_promedio': 47.0}
# {'_id': 'Cheri', 'nota_promedio': 46.0}

# %% [markdown]
# ### Indices
#
# Existen dos índices especialmente útiles en MongoDB. Los índices textuales que nos permiten búsquedas semánticas sobre el texto y las geo-espaciales que no permiten preguntas del tipo _cerca de mi_.

# %%
rest_collection.create_index({ "$**" : "text"})
# Out:
# '$**_text'

# %%
query = { "$text": { "$search": "cafe" } }
proyeccion = {"_id": 0, "name" : True, "cuisine": 1}

for elemento in rest_collection.find(query, proyeccion):
    pprint(elemento)
# Out:
# {'cuisine': 'Café/Coffee/Tea', 'name': 'A Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Locus Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Zoni Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Brompton Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Off To Start Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Burly Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Bruffin Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Grumpy'}
# {'cuisine': 'Café/Coffee/Tea', 'name': '19 Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Harmony Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Edna'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Grumpy'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Bene'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Jax'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Oval Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Currant Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Creffle Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Fafa Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Iconic Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': "Alice'S Cafe"}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Ost Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Swallow Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'The Path Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Paulette'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Infinitea Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Ap Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Biba'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Propeller Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Comma Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'The Cafe Grind'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Blank Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe 101'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Pashtriku'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Kava Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Jubilee Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Serie A Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Sac Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Boulis'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe G'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Buunni'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Agnanti Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': "Shervin'S Cafe"}
# {'cuisine': 'Café/Coffee/Tea', 'name': "Lundy'S Cafe"}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Onassis Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Y'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Primrose Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': "Reggi'S Cafe"}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe  Sicily'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Integral'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Tarantin'}
# {'cuisine': 'Café/Coffee/Tea', 'name': "Sandy'S Cafe"}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Madeline'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Lucid Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Mee Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Regular'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Milan'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Caffe Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Couleur Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Rieu Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Kava Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Pause Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Piccolo Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Fao Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Lucid Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Macaron Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Corner Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Martin'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cascade Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Piccolo Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Breadbox Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Courtside Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Alembi Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Your House Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': "Tee'S Cafe"}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Gabriella Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Green'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Thirstea Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Caggiano'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Variety Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Mocha'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Europa'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Ost Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Refresh Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Gales Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Europan Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Macaron Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Atlas Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Hook Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Pod Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Zaiya'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Parisienne Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Europan Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Simple Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Uro Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Tuscany Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Grumpy'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe 71'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Metro'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Fulton Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Zaiya'}
# {'cuisine': 'Café/Coffee/Tea', 'name': "Sotheby'S Cafe"}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Shqiperia Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Grumpy'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Kpmg Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Postmark Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Angelique'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Regular'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Keko Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'European Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Mila Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Trend'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Angelique'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Gurra Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Olympic Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Oxford Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Portofino Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Sunflower Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe 101'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Madison'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Culinart Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Europa Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Lalo'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Capri'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Terrace Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Topos Bookstore Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'New Forest Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Spincity Billiard & Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Bay Ridge Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'The Little Sweet Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Eyes On Hudson Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Matcha Cafe Wabi'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Red Pipe Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'J + B Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe 1 Of A Kind'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Mania Llc'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Astor Row Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Full Moon Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Boca Ciega'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'New Moon Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': '15 St Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Muse Cafe & Tea'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Blue Dog Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': '7Th Floor Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'The Civil Service Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Black Cat Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Silk Road Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Mrs. Claus Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Barclay Street Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Pelham Bay Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'La Luna Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Hester Street Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Sweet Island Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'K Bagel Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Renaissance Java Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Milk & Honey Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Con Amor'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Milk & Pull Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Aunt Chels Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Tip Of The Tongue Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Home Plate Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Tea Cup Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Bread And Butter Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Caffeine Fix Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Tripp & Cooper Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Tin Cup Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Crespella Cafe And Bakery'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'The Little Fox Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe De Cupping'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Big Apple Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'The Little Sweet Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Table Green Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': '9 & 8 Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Checkpoint Ben Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Barnes & Noble Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Vine Tree Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Barnes & Noble Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Le Moulin A Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Ny Dc Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Barnes And Noble Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Central Cafe Brooklyn'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Argo Tea Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Clinton Park Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Argo Tea Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Via Expresso'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Penny House Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Juan Valdez Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Argo Tea Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Angelique Express'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Krave Cafe  And Grill'}
# {'cuisine': 'Café/Coffee/Tea', 'name': "C'Est Bon Cafe"}
# {'cuisine': 'Café/Coffee/Tea', 'name': "L'Aroma Deli Cafe"}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Box Kite Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Barnes & Noble Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Mcnally Jackson Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Inatesso Cafe Casano'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Con Leche'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Via Quadronno Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Root Hill Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Aunt Butchies Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Marina House Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Juan Valdez Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': "Ero'S Cafe Bar"}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'E Squared Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': "Lily'S Cafe Restaurant"}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Prospect Perk Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cupcake Cafe Casa'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Little Atlas Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': '11 Street Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Bar Navruz'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Hidden City Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Bumble & Bumble Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': "Zoie'S Cafe And Delicatessen"}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Sports Center Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': "Fluffy'S Cafe & Bakery"}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Manon Cafe / Leonidas'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Barnes & Noble Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'City Chow Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Barnes & Noble Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Barre Cafe At Steps'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Ole Usa'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Barnes & Noble Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'World Cup Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'West Side Cafe Ii'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Maglia Rosa Bike Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Petite Blue Dog Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Carmen Cafe ( Carmen Hall)'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Lavazza Cafe Per Wes'}
# {'cuisine': 'Café/Coffee/Tea', 'name': "Chock Full O'Nuts Cafe"}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Barnes & Noble Cafe At Baruch'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Herald Square Cafe (Starbucks)'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Noi Espresso Bar'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Grumpy Les Llc'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'American Table Cafe And Bar'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'S & P Internet Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Peridance Capezio Center Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Istanbul Cafe Of White Plains'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'The Swallow Cafe & Espresso Bar'}
# {'cuisine': 'Café/Coffee/Tea', 'name': "Bob'S Discount Furniture Cafe"}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'City Tech Bookstore & Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe East - Uris Hall'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe Panino Mucho Gusto'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'New Line Internet Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Mn Scorpion Cafe Club'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Ubs Cafe (27 Fl.)'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Bluestockings Womens Bookstore Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Food For Thought Library Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'New Wave Cafe & Restaurant'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Gotham Stadium Tennis Center Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Au Bon Pain / Cih Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'La Casita Yarn Shop Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': "St John'S University Library Cafe"}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cafe East - Alfred Lerner Hall'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Jour Et Nuit Cafe And Restaurant'}
# {'cuisine': 'Café/Coffee/Tea',
#  'name': 'Long Island University - Blackbird Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'City Chow Cafe V (Equinox)'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Lenfest Cafe - Jerome Green Hall'}
# {'cuisine': 'Café/Coffee/Tea',
#  'name': 'Hungry Ghost Coffee Bar And Cafe At Bric'}
# {'cuisine': 'Café/Coffee/Tea',
#  'name': 'Suny Maritime University (S And E Cafe)'}
# {'cuisine': 'Café/Coffee/Tea',
#  'name': 'La Boulangerie Lopez Baked Goods & Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'New York University - Law School Cafe'}
# {'cuisine': 'Café/Coffee/Tea',
#  'name': 'Cafe 212/Columbia Catering Kitchen - Alfred Lerner Hall'}
# {'cuisine': 'Café/Coffee/Tea',
#  'name': 'Center Plate- Concourse Cafe-Jacob K Javits Convention Center'}
# {'cuisine': 'Delicatessen', 'name': 'Breadsoul Cafe/ Lincoln Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Cafe Habana/Cafe Habana To Go'}
# {'cuisine': 'American', 'name': 'Cafe Kitchen (Centerplate Cafe And Kitchen)'}
# {'cuisine': 'American', 'name': 'Noumura Cafe ( 5Th Floor Noumura Cafe)'}
# {'cuisine': 'Caribbean', 'name': 'A Cafe'}
# {'cuisine': 'Chinese', 'name': 'Him & Her Cafe'}
# {'cuisine': 'American',
#  'name': 'New York Botanical Gardens Terrace Cafe ( Garden Cafe )'}
# {'cuisine': 'American',
#  'name': "Brooklyn Children'S Museum Cafe/Forest City Ratner Cafe"}
# {'cuisine': 'Other', 'name': 'Ciminna Cafe'}
# {'cuisine': 'Other', 'name': 'Cafe Bari'}
# {'cuisine': 'American', 'name': "''W'' Cafe"}
# {'cuisine': 'Other', 'name': 'Cafe R'}
# {'cuisine': 'Japanese', 'name': 'Maid Cafe'}
# {'cuisine': 'Other', 'name': 'Cafe Clover'}
# {'cuisine': 'Other', 'name': 'Cafe Wha'}
# {'cuisine': 'American', 'name': 'Cafe Islan'}
# {'cuisine': 'Other', 'name': 'Ny Cafe'}
# {'cuisine': 'Japanese', 'name': 'Ogawa Cafe'}
# {'cuisine': 'American', 'name': "Isadora'S Cafe"}
# {'cuisine': 'Donuts', 'name': 'Bruffin Cafe'}
# {'cuisine': 'American', 'name': "Lucky'S Cafe"}
# {'cuisine': 'Caribbean', 'name': 'Vivid Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Forte'}
# {'cuisine': 'Middle Eastern', 'name': 'Gyro Cafe'}
# {'cuisine': 'Chinese', 'name': 'Cielo Cafe'}
# {'cuisine': 'American', 'name': "Cafe Rockaway'S"}
# {'cuisine': 'Other', 'name': 'Cafe 11231'}
# {'cuisine': 'Other', 'name': 'Cafe 55'}
# {'cuisine': 'American', 'name': 'Cafe Plus'}
# {'cuisine': 'Spanish', 'name': 'Vanilla Cafe'}
# {'cuisine': 'Other', 'name': 'Cafe Devocion'}
# {'cuisine': 'Pizza', 'name': "Andy'S Cafe"}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Redstone Cafe'}
# {'cuisine': 'Spanish', 'name': 'Cafe Sahara'}
# {'cuisine': 'Bottled beverages, including water, sodas, juices, etc.',
#  'name': 'Cleopatra Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': "Morrito'S Cafe"}
# {'cuisine': 'American', 'name': 'Tost Cafe'}
# {'cuisine': 'Other', 'name': "Capelli'S Cafe"}
# {'cuisine': 'Other', 'name': 'Ok Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Cafe Ruquetta'}
# {'cuisine': 'Juice, Smoothies, Fruit Salads', 'name': 'Veggies Cafe'}
# {'cuisine': 'American', 'name': 'Anthony Cafe'}
# {'cuisine': 'American', 'name': 'Corner Cafe'}
# {'cuisine': 'Vegetarian', 'name': 'Jungle Cafe'}
# {'cuisine': 'American', 'name': 'Amici Cafe'}
# {'cuisine': 'Ice Cream, Gelato, Yogurt, Ices', 'name': 'Gantry Cafe'}
# {'cuisine': 'Vegetarian', 'name': 'Orchard Cafe'}
# {'cuisine': 'Ice Cream, Gelato, Yogurt, Ices', 'name': 'Microchip Cafe'}
# {'cuisine': 'American', 'name': 'Tcr Cafe'}
# {'cuisine': 'Tapas', 'name': 'Cafe Noir'}
# {'cuisine': 'Chinese', 'name': 'Yes Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Southside Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Corner Cafe'}
# {'cuisine': 'American', 'name': 'Cafe By The Bay'}
# {'cuisine': 'Sandwiches', 'name': 'The Falls Cafe'}
# {'cuisine': 'American', 'name': 'Marm Cafe'}
# {'cuisine': 'American', 'name': "Sharkey'S Cafe"}
# {'cuisine': 'Chinese', 'name': 'Kato Cafe'}
# {'cuisine': 'Ice Cream, Gelato, Yogurt, Ices', 'name': 'Maxie Cafe'}
# {'cuisine': 'Russian', 'name': 'Cafe Edelweiss'}
# {'cuisine': 'Bagels/Pretzels', 'name': 'Bagel Cafe'}
# {'cuisine': 'Eastern European', 'name': 'Cafe Kiev'}
# {'cuisine': 'Other', 'name': 'Brazilia Cafe'}
# {'cuisine': 'Armenian', 'name': "Fatty'S Cafe"}
# {'cuisine': 'Jewish/Kosher', 'name': 'Cafe Paris'}
# {'cuisine': 'Thai', 'name': 'Thailand Cafe'}
# {'cuisine': 'Chinese', 'name': 'Cafe China'}
# {'cuisine': 'American', 'name': 'Europan Cafe'}
# {'cuisine': 'American', 'name': 'Grace Cafe'}
# {'cuisine': 'American', 'name': 'Press Cafe'}
# {'cuisine': 'American', 'name': 'Seattle Cafe'}
# {'cuisine': 'American', 'name': 'Cafe 2'}
# {'cuisine': 'Ethiopian', 'name': 'Bunna Cafe'}
# {'cuisine': 'Italian', 'name': 'Arco Cafe'}
# {'cuisine': 'American', 'name': 'Epice Cafe'}
# {'cuisine': 'Other', 'name': 'Cellar Cafe'}
# {'cuisine': 'Other', 'name': 'Gratitude Cafe'}
# {'cuisine': 'Mediterranean', 'name': 'Layaly Cafe'}
# {'cuisine': 'Chinese', 'name': 'Maikley Cafe'}
# {'cuisine': 'Asian', 'name': 'Benton Cafe'}
# {'cuisine': 'Mediterranean', 'name': 'Effys Cafe'}
# {'cuisine': 'Sandwiches', 'name': 'Cycle Cafe'}
# {'cuisine': 'American', 'name': "Camila'S Cafe"}
# {'cuisine': 'Mediterranean', 'name': "Effy'S Cafe"}
# {'cuisine': 'Turkish', 'name': 'Sofra Cafe'}
# {'cuisine': 'Eastern European', 'name': 'Zair Cafe'}
# {'cuisine': 'Thai', 'name': 'Thai Cafe'}
# {'cuisine': 'Asian', 'name': 'Amarin Cafe'}
# {'cuisine': 'Spanish', 'name': 'Arepas Cafe'}
# {'cuisine': 'Russian', 'name': 'Cafe Euphoria'}
# {'cuisine': 'French', 'name': 'Francis Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Cafe 11'}
# {'cuisine': 'American', 'name': 'Madison Cafe'}
# {'cuisine': 'Juice, Smoothies, Fruit Salads', 'name': 'Reconnect Cafe'}
# {'cuisine': 'Asian', 'name': 'Panda Cafe'}
# {'cuisine': 'Juice, Smoothies, Fruit Salads', 'name': 'Cofi Cafe'}
# {'cuisine': 'American', 'name': 'Cafe 86'}
# {'cuisine': 'Mediterranean', 'name': 'Firdos Cafe'}
# {'cuisine': 'American', 'name': 'Canteen Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Concon Cafe'}
# {'cuisine': 'Eastern European', 'name': 'No Name Cafe'}
# {'cuisine': 'American', 'name': 'The Mug Cafe'}
# {'cuisine': 'Bakery', 'name': 'Hudson Cafe'}
# {'cuisine': 'Asian', 'name': 'Hit Cafe'}
# {'cuisine': 'Other', 'name': "Valle'S Cafe"}
# {'cuisine': 'American', 'name': 'Cyclone Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Picco'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': "Gabriel'S Cafe"}
# {'cuisine': 'Other', 'name': 'Destiny Cafe'}
# {'cuisine': 'Spanish', 'name': 'Cafe Iguana'}
# {'cuisine': 'American', 'name': 'Tuscan Cafe'}
# {'cuisine': 'Japanese', 'name': 'Nomura Cafe'}
# {'cuisine': 'Chinese', 'name': '88 Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Hestia'}
# {'cuisine': 'Chinese', 'name': 'Joyful Cafe'}
# {'cuisine': 'American', 'name': 'Broadway Cafe'}
# {'cuisine': 'American', 'name': 'Tosca Cafe'}
# {'cuisine': 'Middle Eastern', 'name': 'Parlay Cafe'}
# {'cuisine': 'American', 'name': 'Butterfield Cafe'}
# {'cuisine': 'American', 'name': 'Cafe 285'}
# {'cuisine': 'American', 'name': 'Malesia Cafe'}
# {'cuisine': 'Russian', 'name': 'Darina Cafe'}
# {'cuisine': 'Chinese', 'name': 'C2 Cafe'}
# {'cuisine': 'American', 'name': 'Primavera Cafe'}
# {'cuisine': 'Middle Eastern', 'name': 'Cafe Nadery'}
# {'cuisine': 'Chinese', 'name': 'Quickly Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'Cafe Twist'}
# {'cuisine': 'Spanish', 'name': 'Doras Cafe'}
# {'cuisine': 'Korean', 'name': 'Cafe Bene'}
# {'cuisine': 'Sandwiches', 'name': 'Subway Cafe'}
# {'cuisine': 'American', 'name': 'Dunhill Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Elite Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Cafe Mofongo'}
# {'cuisine': 'American', 'name': 'Euro Cafe'}
# {'cuisine': 'Egyptian', 'name': 'Zoe Cafe'}
# {'cuisine': 'American', 'name': "Logan'S Cafe"}
# {'cuisine': 'Jewish/Kosher', 'name': 'Palace Cafe'}
# {'cuisine': 'Italian', 'name': 'Ottomanelli Cafe'}
# {'cuisine': 'Italian', 'name': 'Cammareri Cafe'}
# {'cuisine': 'Korean', 'name': 'Cafe Originale'}
# {'cuisine': 'American', 'name': 'Cafe 45'}
# {'cuisine': 'American', 'name': 'Bloom Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Today'}
# {'cuisine': 'American', 'name': 'Rockaway Cafe'}
# {'cuisine': 'Mediterranean', 'name': 'Cafe Gallery'}
# {'cuisine': 'Japanese', 'name': 'Benton Cafe'}
# {'cuisine': 'Seafood', 'name': 'Fishnet Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'Kappock Cafe'}
# {'cuisine': 'American', 'name': 'Green Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Cd'}
# {'cuisine': 'American', 'name': "Cj'S Cafe"}
# {'cuisine': 'American', 'name': 'Aviation Cafe'}
# {'cuisine': 'American', 'name': 'T49 Cafe'}
# {'cuisine': 'American', 'name': 'The Eagle Cafe'}
# {'cuisine': 'American', 'name': 'Crc Cafe'}
# {'cuisine': 'Bakery', 'name': 'Noisette Cafe'}
# {'cuisine': 'American', 'name': 'Grand Cafe'}
# {'cuisine': 'Chinese', 'name': 'Cafe Evergreen'}
# {'cuisine': 'American', 'name': "Pete'S Cafe"}
# {'cuisine': 'Mediterranean', 'name': 'Cafe Latte'}
# {'cuisine': 'American', 'name': 'Cafe 58'}
# {'cuisine': 'American', 'name': 'Pulse Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Fresco'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Kabila Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Kosher Cafe'}
# {'cuisine': 'American', 'name': "Lucky'S Cafe"}
# {'cuisine': 'Chinese', 'name': 'Munchies Cafe'}
# {'cuisine': 'Delicatessen', 'name': "Nikki'S Cafe"}
# {'cuisine': 'American', 'name': 'Oxford Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Oliviero'}
# {'cuisine': 'American', 'name': "Jj'S Cafe"}
# {'cuisine': 'American', 'name': 'Puff Cafe'}
# {'cuisine': 'American', 'name': 'Cafe To Go'}
# {'cuisine': 'French', 'name': 'Cafe Dada'}
# {'cuisine': 'American', 'name': 'Bocado Cafe'}
# {'cuisine': 'Ice Cream, Gelato, Yogurt, Ices', 'name': 'Breeze Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': "Terry'S Cafe"}
# {'cuisine': 'Delicatessen', 'name': 'The Spot Cafe'}
# {'cuisine': 'Chinese', 'name': 'Metro Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Dancer'}
# {'cuisine': 'French', 'name': 'Piccolo Cafe'}
# {'cuisine': 'American', 'name': 'Gigi Cafe'}
# {'cuisine': 'American', 'name': 'Rosens Cafe'}
# {'cuisine': 'Spanish', 'name': 'Sugar Cafe'}
# {'cuisine': 'American', 'name': 'Packard  Cafe'}
# {'cuisine': 'Asian', 'name': 'Nam Cafe'}
# {'cuisine': 'Middle Eastern', 'name': 'Cafe Mogador'}
# {'cuisine': 'Bakery', 'name': 'Chiqui Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Jerusalem Cafe'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Liberty Cafe'}
# {'cuisine': 'Chinese', 'name': 'Cafe Bakery'}
# {'cuisine': 'Vegetarian', 'name': 'Cafe Blossom'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Turnpike Cafe'}
# {'cuisine': 'American', 'name': 'Cafe 47'}
# {'cuisine': 'Juice, Smoothies, Fruit Salads', 'name': 'Crepe Cafe'}
# {'cuisine': 'Chinese', 'name': 'Asian Cafe'}
# {'cuisine': 'Middle Eastern', 'name': 'Cafe Rokhat'}
# {'cuisine': 'Delicatessen', 'name': 'Gotham Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'City Cafe'}
# {'cuisine': 'Spanish', 'name': 'Warma Cafe'}
# {'cuisine': 'Spanish', 'name': 'Andiamo Cafe'}
# {'cuisine': 'American', 'name': 'Commons Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Acuario Cafe'}
# {'cuisine': 'Eastern European', 'name': 'Cafe Gourmand'}
# {'cuisine': 'American', 'name': 'Worth Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Aka'}
# {'cuisine': 'American', 'name': 'Cafe Bench'}
# {'cuisine': 'Chinese', 'name': 'Kissena Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Elisa Cafe'}
# {'cuisine': 'Japanese', 'name': 'Hana Cafe'}
# {'cuisine': 'Mexican', 'name': "Yola'S Cafe"}
# {'cuisine': 'American', 'name': 'Premier Cafe'}
# {'cuisine': 'Spanish', 'name': 'Mamajuana Cafe'}
# {'cuisine': 'Thai', 'name': 'Mythai Cafe'}
# {'cuisine': 'Caribbean', 'name': 'Reggae Cafe'}
# {'cuisine': 'Korean', 'name': 'Hanra Cafe'}
# {'cuisine': 'American', 'name': 'Mars Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Havana Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Tallulah'}
# {'cuisine': 'Italian', 'name': 'Cafe Lore'}
# {'cuisine': 'American', 'name': "Mila'S Cafe"}
# {'cuisine': 'Italian', 'name': 'Cafe On The Hill'}
# {'cuisine': 'American', 'name': "Daniela'S Cafe"}
# {'cuisine': 'Asian', 'name': 'Y Cafe'}
# {'cuisine': 'American', 'name': "Zanny'S Cafe"}
# {'cuisine': 'American', 'name': 'Cafe 1853'}
# {'cuisine': 'American', 'name': 'Brooklyn  Cafe'}
# {'cuisine': 'American', 'name': 'Cornerstone Cafe'}
# {'cuisine': 'American', 'name': "Cc'S Cafe"}
# {'cuisine': 'Eastern European', 'name': 'Cafe Afsona'}
# {'cuisine': 'American', 'name': 'Bareplanet Cafe'}
# {'cuisine': 'Indian', 'name': 'India Cafe'}
# {'cuisine': 'American', 'name': 'Silo Cafe'}
# {'cuisine': 'Italian', 'name': 'Piccolo Cafe'}
# {'cuisine': 'American', 'name': 'Cafe R'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Cafe Clementine'}
# {'cuisine': 'Delicatessen', 'name': 'Cafe 37'}
# {'cuisine': 'American', 'name': 'Windsor Cafe'}
# {'cuisine': 'American', 'name': "Michael'S Cafe"}
# {'cuisine': 'American', 'name': 'Independence Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Ghia'}
# {'cuisine': 'Spanish', 'name': "Mela'S Cafe"}
# {'cuisine': 'American', 'name': 'Cafe Hanover'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Flavors Cafe'}
# {'cuisine': 'French', 'name': 'Cafe Jolie'}
# {'cuisine': 'American', 'name': "Maybelle'S Cafe"}
# {'cuisine': 'Korean', 'name': 'Cafe 232'}
# {'cuisine': 'American', 'name': 'Exo Cafe'}
# {'cuisine': 'American', 'name': "Shane'S Cafe"}
# {'cuisine': 'Turkish', 'name': 'Gyro Cafe'}
# {'cuisine': 'Mediterranean', 'name': 'Mtskheta Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Hestia'}
# {'cuisine': 'American', 'name': 'O Cafe'}
# {'cuisine': 'American', 'name': 'Bagel Cafe'}
# {'cuisine': 'Russian', 'name': 'Cafe Euroasia'}
# {'cuisine': 'American', 'name': 'Tower Cafe'}
# {'cuisine': 'American', 'name': 'Harvest Cafe'}
# {'cuisine': 'American', 'name': 'Fresh To You Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Havana Cafe'}
# {'cuisine': 'Mediterranean', 'name': 'Bedawi Cafe'}
# {'cuisine': 'American', 'name': 'The West Cafe'}
# {'cuisine': 'Middle Eastern', 'name': 'Gulf Cafe'}
# {'cuisine': 'American', 'name': 'Tost Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Maggio'}
# {'cuisine': 'American', 'name': 'Dorian Cafe'}
# {'cuisine': 'American', 'name': 'Station Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'Cafe Lafayette'}
# {'cuisine': 'Eastern European', 'name': 'Cafe Budovice'}
# {'cuisine': 'American', 'name': 'The Proper Cafe'}
# {'cuisine': 'American', 'name': 'Toasties Cafe'}
# {'cuisine': 'Italian', 'name': 'Fiat Cafe'}
# {'cuisine': 'Russian', 'name': 'Cafe Tabu'}
# {'cuisine': 'Delicatessen', 'name': "The Cafe At Bob'S"}
# {'cuisine': 'Eastern European', 'name': 'Cafe Prague'}
# {'cuisine': 'American', 'name': "Rae'S Cafe"}
# {'cuisine': 'Continental', 'name': 'Banc Cafe'}
# {'cuisine': 'Egyptian', 'name': 'On The Nile Cafe'}
# {'cuisine': 'Russian', 'name': 'Kashkar Cafe'}
# {'cuisine': 'American', 'name': 'Mustang Cafe'}
# {'cuisine': 'Japanese', 'name': 'Ogawa Cafe'}
# {'cuisine': 'Continental', 'name': 'The Bluebell Cafe'}
# {'cuisine': 'American', 'name': "Ariel'S Cafe"}
# {'cuisine': 'Italian', 'name': 'Cafe Minerva'}
# {'cuisine': 'American', 'name': 'Benvenuto Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'Gourmet Cafe'}
# {'cuisine': 'American', 'name': '101 Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Cafe Argentino'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Savor Cafe'}
# {'cuisine': 'American', 'name': 'Morgan Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Cubana Cafe'}
# {'cuisine': 'American', 'name': 'Taz Cafe'}
# {'cuisine': 'American', 'name': 'Love Cafe'}
# {'cuisine': 'American', 'name': 'Green Cafe'}
# {'cuisine': 'French', 'name': 'Cafe Gitane'}
# {'cuisine': 'American', 'name': 'Westside Cafe'}
# {'cuisine': 'American', 'name': "Brad'S Cafe"}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Altus Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'Cafe Tomato'}
# {'cuisine': 'American', 'name': 'Milos Cafe'}
# {'cuisine': 'Caribbean', 'name': 'Impulse Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'Green Cafe'}
# {'cuisine': 'Italian', 'name': 'Provini Cafe'}
# {'cuisine': 'Italian', 'name': "Edgar'S Cafe"}
# {'cuisine': 'Sandwiches', 'name': 'Tasty Cafe'}
# {'cuisine': 'American', 'name': 'Green Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Bistro'}
# {'cuisine': 'American', 'name': 'Cafe Grumpy'}
# {'cuisine': 'American', 'name': "Burgandy'S Cafe"}
# {'cuisine': 'Jewish/Kosher', 'name': 'Cafe 11'}
# {'cuisine': 'Asian', 'name': 'Cafe Himalaya'}
# {'cuisine': 'Russian', 'name': 'Oasis Cafe'}
# {'cuisine': 'American', 'name': 'Towers Cafe'}
# {'cuisine': 'American', 'name': 'Towers Cafe'}
# {'cuisine': 'American', 'name': 'Cafe 27'}
# {'cuisine': 'American', 'name': 'Cafe Pedlar'}
# {'cuisine': 'American', 'name': 'Cafe Olympia'}
# {'cuisine': 'American', 'name': 'Island Cafe'}
# {'cuisine': 'American', 'name': 'Cancun Cafe'}
# {'cuisine': 'American', 'name': 'Cafe 23'}
# {'cuisine': 'American', 'name': "Daddy'S Cafe"}
# {'cuisine': 'American', 'name': 'Woodside Cafe'}
# {'cuisine': 'Other', 'name': 'Cemi Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Wha?'}
# {'cuisine': 'American', 'name': 'Boulevard Cafe'}
# {'cuisine': 'French', 'name': 'B Cafe'}
# {'cuisine': 'Delicatessen', 'name': "Isadora'S Cafe"}
# {'cuisine': 'American', 'name': 'The Jackpot Cafe'}
# {'cuisine': 'Mexican', 'name': 'Cafe 104'}
# {'cuisine': 'Other', 'name': 'Away Cafe'}
# {'cuisine': 'Bakery', 'name': 'Vanilla Cafe'}
# {'cuisine': 'French', 'name': 'Cafe Cambodge'}
# {'cuisine': 'Middle Eastern', 'name': 'Sultana Cafe'}
# {'cuisine': 'American', 'name': 'Silo Cafe'}
# {'cuisine': 'Mediterranean', 'name': 'Cafe Petisco'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Metro Cafe'}
# {'cuisine': 'Korean', 'name': 'Room Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Colador Cafe'}
# {'cuisine': 'Chinese', 'name': 'City Cafe'}
# {'cuisine': 'American', 'name': 'Briarwood Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'Studebaker Cafe'}
# {'cuisine': 'American', 'name': 'Prime Cafe'}
# {'cuisine': 'Eastern European', 'name': 'Cafe Select'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Cafe Rubio'}
# {'cuisine': 'American', 'name': 'Cafe Restaurant'}
# {'cuisine': 'American', 'name': 'Alor Cafe'}
# {'cuisine': 'Polish', 'name': "Johnny'S Cafe"}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Europa Cafe'}
# {'cuisine': 'American', 'name': 'Seattle Cafe'}
# {'cuisine': 'American', 'name': 'Variety Cafe'}
# {'cuisine': 'Sandwiches', 'name': 'Ashbox Cafe'}
# {'cuisine': 'American', 'name': 'Soho Cafe'}
# {'cuisine': 'American', 'name': 'Crossroads Cafe'}
# {'cuisine': 'American', 'name': 'Cranberry Cafe'}
# {'cuisine': 'Vegetarian', 'name': 'Jivamuktea Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Empanadas Cafe'}
# {'cuisine': 'American', 'name': 'Green Cafe'}
# {'cuisine': 'Eastern European', 'name': 'Cafe Katja'}
# {'cuisine': 'Delicatessen', 'name': 'Cafe 42'}
# {'cuisine': 'American', 'name': 'Rosens Cafe'}
# {'cuisine': 'American', 'name': 'Wateredge Cafe'}
# {'cuisine': 'Eastern European', 'name': 'Nargis Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'Cafe Fresco'}
# {'cuisine': 'American', 'name': 'Pier I Cafe'}
# {'cuisine': 'American', 'name': 'Tasty Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Cafe Cortadito'}
# {'cuisine': 'Vegetarian', 'name': 'The Wellness Cafe'}
# {'cuisine': 'American', 'name': 'Circles Cafe'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Europa Cafe'}
# {'cuisine': 'American', 'name': 'Boardwalk Cafe'}
# {'cuisine': 'Mediterranean', 'name': 'Artopolis Cafe'}
# {'cuisine': 'American', 'name': 'Willburg Cafe'}
# {'cuisine': 'Thai', 'name': 'Cafe Chili'}
# {'cuisine': 'French', 'name': 'Cafe Triskell'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Avenue Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Colette'}
# {'cuisine': 'Chinese', 'name': 'Kowloon Cafe'}
# {'cuisine': 'American', 'name': "Tower'S Cafe"}
# {'cuisine': 'American', 'name': 'Telegraphe Cafe'}
# {'cuisine': 'Italian', 'name': 'Cafe Minto'}
# {'cuisine': 'American', 'name': 'Cafe Amrita'}
# {'cuisine': 'American', 'name': 'Flowers Cafe'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Europa Cafe'}
# {'cuisine': 'American', 'name': 'Gigi Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Cubana Cafe'}
# {'cuisine': 'American', 'name': "Moe'S Cafe"}
# {'cuisine': 'American', 'name': "Moe'S Cafe"}
# {'cuisine': 'Jewish/Kosher', 'name': 'Cafe Venezia'}
# {'cuisine': 'American', 'name': 'Beach Cafe'}
# {'cuisine': 'American', 'name': 'Mac Cafe'}
# {'cuisine': 'Other', 'name': 'B Cafe'}
# {'cuisine': 'French', 'name': 'Cafe Cluny'}
# {'cuisine': 'American', 'name': "Ricky'S Cafe"}
# {'cuisine': 'Bakery', 'name': 'Vanilla Cafe'}
# {'cuisine': 'Caribbean', 'name': 'Mingles Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Lincoln'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Carro Cafe'}
# {'cuisine': 'American', 'name': 'Park Cafe'}
# {'cuisine': 'Italian', 'name': 'Vintner Cafe'}
# {'cuisine': 'American', 'name': 'CafÉ Gusto'}
# {'cuisine': 'Vietnamese/Cambodian/Malaysia', 'name': 'Lan Cafe'}
# {'cuisine': 'American', 'name': 'Figs Cafe'}
# {'cuisine': 'American', 'name': 'Cafe 57'}
# {'cuisine': 'American', 'name': 'Beanocchios Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Muscat Cafe'}
# {'cuisine': 'Mediterranean', 'name': 'Horus Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'Cafe Water'}
# {'cuisine': 'French', 'name': 'Cafe Condesa'}
# {'cuisine': 'American', 'name': 'Teleon Cafe'}
# {'cuisine': 'American', 'name': 'Beach Cafe'}
# {'cuisine': 'Caribbean', 'name': "Delroy'S Cafe"}
# {'cuisine': 'Delicatessen', 'name': 'Cafe Duke'}
# {'cuisine': 'Bagels/Pretzels', 'name': 'What A Bagel Cafe'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Europa Cafe'}
# {'cuisine': 'French', 'name': "Cafe D'Alsace"}
# {'cuisine': 'Eastern European', 'name': 'Ukus Cafe'}
# {'cuisine': 'American', 'name': 'Martinique Cafe'}
# {'cuisine': 'American', 'name': 'Museum Cafe'}
# {'cuisine': 'Spanish', 'name': "Rosa'S Cafe"}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Mamajuana Cafe'}
# {'cuisine': 'American', 'name': 'Market Cafe'}
# {'cuisine': 'French', 'name': 'Cafe Lafayette'}
# {'cuisine': 'Italian', 'name': 'Epistrophy Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Cafe Hadar'}
# {'cuisine': 'Eastern European', 'name': "Andre'S Cafe"}
# {'cuisine': 'Greek', 'name': 'Grand Cafe'}
# {'cuisine': 'American', 'name': 'Cafe 101'}
# {'cuisine': 'Bakery', 'name': 'Cafe Riviera'}
# {'cuisine': 'Caribbean', 'name': 'Footprints Cafe'}
# {'cuisine': 'American', 'name': 'Gigi Cafe'}
# {'cuisine': 'Middle Eastern', 'name': 'Luxor Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Metro'}
# {'cuisine': 'Caribbean', 'name': 'Bajan Cafe'}
# {'cuisine': 'American', 'name': "Gracie'S Cafe"}
# {'cuisine': 'American', 'name': "Cc'S Cafe"}
# {'cuisine': 'American', 'name': 'Sugar Cafe'}
# {'cuisine': 'American', 'name': "Gotte'S Cafe"}
# {'cuisine': 'Middle Eastern', 'name': 'Tarboosh Cafe'}
# {'cuisine': 'American', 'name': 'The Brothers Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Metro'}
# {'cuisine': 'Middle Eastern', 'name': 'Cozy Cafe'}
# {'cuisine': 'American', 'name': 'Garden Cafe'}
# {'cuisine': 'French', 'name': 'Hill Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Manhattan'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Cafe Nunez'}
# {'cuisine': 'American', 'name': 'Green Cafe'}
# {'cuisine': 'American', 'name': 'Bxl Cafe'}
# {'cuisine': 'American', 'name': 'Park Cafe'}
# {'cuisine': 'Vietnamese/Cambodian/Malaysia', 'name': 'Viet Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'Oxford Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Jennifer Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Exchange'}
# {'cuisine': 'American', 'name': 'Fanelli Cafe'}
# {'cuisine': 'American', 'name': 'Favorite Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Pick Me Up'}
# {'cuisine': 'Chinese', 'name': "Sai'S Cafe"}
# {'cuisine': 'Soups & Sandwiches', 'name': 'Cafe Metro'}
# {'cuisine': 'French', 'name': 'Cafe Henri'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': "Bicheiro'S Cafe"}
# {'cuisine': 'American', 'name': "Captain'S Cafe"}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Europan Cafe'}
# {'cuisine': 'Russian', 'name': 'Anyway Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'Corte Cafe'}
# {'cuisine': 'Spanish', 'name': 'Cafe Espanol'}
# {'cuisine': 'American', 'name': 'Europan Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Cafe K'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Cafe Classico'}
# {'cuisine': 'American', 'name': 'Cafe 101'}
# {'cuisine': 'American', 'name': 'Cafe Metro'}
# {'cuisine': 'American', 'name': 'Libero Cafe'}
# {'cuisine': 'American', 'name': 'Flavors Cafe'}
# {'cuisine': 'Italian', 'name': "Sambuca'S Cafe"}
# {'cuisine': 'Mexican', 'name': 'Macumba Cafe'}
# {'cuisine': 'American', 'name': 'Cafe 28'}
# {'cuisine': 'Asian', 'name': 'Cafe Mingala'}
# {'cuisine': 'American', 'name': 'Le Cafe'}
# {'cuisine': 'American', 'name': 'Liberty Cafe'}
# {'cuisine': 'Bakery', 'name': "Tong'S Cafe"}
# {'cuisine': 'American', 'name': 'Eastside Cafe'}
# {'cuisine': 'American', 'name': 'Theater Cafe'}
# {'cuisine': 'Pizza', 'name': 'Cafe Viva'}
# {'cuisine': 'American', 'name': 'Cafe Duke'}
# {'cuisine': 'Italian', 'name': 'Cafe Milano'}
# {'cuisine': 'American', 'name': 'Farragut Cafe'}
# {'cuisine': 'American', 'name': 'Eastchester Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Centro'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Europa Cafe'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Europa Cafe'}
# {'cuisine': 'American', 'name': 'Gigi Cafe'}
# {'cuisine': 'American', 'name': 'Max  Cafe'}
# {'cuisine': 'Soul Food', 'name': 'Cafe 22'}
# {'cuisine': 'Delicatessen', 'name': 'Cafe Alice'}
# {'cuisine': 'American', 'name': 'Grand Cafe'}
# {'cuisine': 'Japanese', 'name': 'Jikji Cafe'}
# {'cuisine': 'American', 'name': "Cafe O'"}
# {'cuisine': 'American', 'name': 'Cafe Metro'}
# {'cuisine': 'American', 'name': 'Viand Cafe'}
# {'cuisine': 'Greek', 'name': 'Avenue Cafe'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Europa Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Cafe K'}
# {'cuisine': 'American', 'name': "Teddy'S Cafe"}
# {'cuisine': 'Italian', 'name': 'Cafe Luna'}
# {'cuisine': 'Fruits/Vegetables', 'name': 'Mini Cafe'}
# {'cuisine': 'American', 'name': 'Europa Cafe'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Cosi Cafe'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Cafe Metro'}
# {'cuisine': 'Bakery', 'name': 'Cafe Colombia'}
# {'cuisine': 'Bagels/Pretzels', 'name': 'Liberty Cafe'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Europa Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Amazon Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Bonjour'}
# {'cuisine': 'Japanese', 'name': 'Cafe Zaiya'}
# {'cuisine': 'French', 'name': 'Cafe Angus'}
# {'cuisine': 'American', 'name': 'Belvedere Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Luluc'}
# {'cuisine': 'German', 'name': 'Cafe Sabarsky'}
# {'cuisine': 'Eastern European', 'name': 'Cafe Steinhof'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Cafe Renaissance'}
# {'cuisine': 'Tapas', 'name': 'Cafe Ronda'}
# {'cuisine': 'American', 'name': 'Plymouth Cafe'}
# {'cuisine': 'Indian', 'name': 'Cafe Spice'}
# {'cuisine': 'Indian', 'name': 'Taj Cafe'}
# {'cuisine': 'Caribbean', 'name': 'Footprints Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Duke'}
# {'cuisine': 'American', 'name': 'Cafe Metro'}
# {'cuisine': 'Mexican', 'name': 'Cafe Frida'}
# {'cuisine': 'American', 'name': 'Cafe Luka'}
# {'cuisine': 'American', 'name': 'Ballfields Cafe'}
# {'cuisine': 'American', 'name': 'Intermisson Cafe'}
# {'cuisine': 'Pizza', 'name': "Junior'S Cafe"}
# {'cuisine': 'American', 'name': 'Cafe Orlin'}
# {'cuisine': 'American', 'name': 'Nations Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Cafe K'}
# {'cuisine': 'French', 'name': 'Cafe Joul'}
# {'cuisine': 'American', 'name': 'Stir Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'Central Cafe'}
# {'cuisine': 'Indian', 'name': 'Ghandi Cafe'}
# {'cuisine': 'American', 'name': 'The Country Cafe'}
# {'cuisine': 'Polish', 'name': 'I.O. Cafe'}
# {'cuisine': 'American', 'name': 'Europa Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Express'}
# {'cuisine': 'Indian', 'name': 'Ayurveda Cafe'}
# {'cuisine': 'American', 'name': "Showman'S Cafe"}
# {'cuisine': 'American', 'name': 'Webster Cafe'}
# {'cuisine': 'Moroccan', 'name': 'Cafe Mogador'}
# {'cuisine': 'American', 'name': "Rick'S Cafe"}
# {'cuisine': 'Mediterranean', 'name': 'Cafe Rakka'}
# {'cuisine': 'Delicatessen', 'name': "Bono'S Cafe"}
# {'cuisine': 'American', 'name': "Anna'S Cafe"}
# {'cuisine': 'American', 'name': 'Paris Cafe'}
# {'cuisine': 'American', 'name': "Cafe Lou'S"}
# {'cuisine': 'Mediterranean', 'name': 'Cafe Bar'}
# {'cuisine': 'Mediterranean', 'name': 'Omonia Cafe'}
# {'cuisine': 'American', 'name': 'Cafe 31'}
# {'cuisine': 'American', 'name': 'Anesis Cafe'}
# {'cuisine': 'Italian', 'name': 'Portobello Cafe'}
# {'cuisine': 'Continental', 'name': 'Cafe Champignon'}
# {'cuisine': 'French', 'name': "Jacque'S Cafe"}
# {'cuisine': 'American', 'name': 'Cafe Bravo'}
# {'cuisine': 'Russian', 'name': 'Anyway Cafe'}
# {'cuisine': 'Italian', 'name': 'Arte Cafe'}
# {'cuisine': 'American', 'name': 'Woodlawn Cafe'}
# {'cuisine': 'Thai', 'name': 'Cafe Asean'}
# {'cuisine': 'American', 'name': 'Cravath Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Metro'}
# {'cuisine': 'Spanish', 'name': "Nelly'S Cafe"}
# {'cuisine': 'American', 'name': 'Heights Cafe'}
# {'cuisine': 'Russian', 'name': 'Cafe Volna'}
# {'cuisine': 'Irish', 'name': 'The Scratcher Cafe'}
# {'cuisine': 'Russian', 'name': 'Cafe Paris'}
# {'cuisine': 'American', 'name': 'Gramercy Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Beyond'}
# {'cuisine': 'French', 'name': 'Cafe Gitane'}
# {'cuisine': 'Vegetarian', 'name': 'Candle Cafe'}
# {'cuisine': 'Italian', 'name': 'Enzo Cafe'}
# {'cuisine': 'American', 'name': 'Market Cafe'}
# {'cuisine': 'French', 'name': 'Cafe Loup'}
# {'cuisine': 'American', 'name': 'Europa Cafe'}
# {'cuisine': 'Italian', 'name': 'Cafe Cardini'}
# {'cuisine': 'Greek', 'name': 'Oasis Cafe'}
# {'cuisine': 'American', 'name': 'Metrostar Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Azuri Cafe'}
# {'cuisine': 'American', 'name': "Gleason'S Cafe"}
# {'cuisine': 'American', 'name': 'Belaire Cafe'}
# {'cuisine': 'Egyptian', 'name': 'Kabab Cafe'}
# {'cuisine': 'Italian', 'name': 'Cafe Luna'}
# {'cuisine': 'Delicatessen', 'name': 'Bagel Cafe'}
# {'cuisine': 'American', 'name': 'Cloister Cafe'}
# {'cuisine': 'Italian', 'name': "Carol'S Cafe"}
# {'cuisine': 'American', 'name': 'Cappuccino Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Edison'}
# {'cuisine': 'French', 'name': 'Cafe Luxembourg'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': "Victor'S Cafe"}
# {'cuisine': 'Greek', 'name': 'Omonia Cafe'}
# {'cuisine': 'Italian', 'name': 'Marina Cafe'}
# {'cuisine': 'Spanish', 'name': 'Cafe Espanol'}
# {'cuisine': 'American', 'name': 'Viand Cafe'}
# {'cuisine': 'American', 'name': 'The River Cafe'}
# {'cuisine': 'Spanish', 'name': 'Cafe Riazor'}
# {'cuisine': 'American', 'name': 'The Riviera Cafe'}
# {'cuisine': 'American', 'name': 'Palace Cafe'}
# {'cuisine': 'American', 'name': 'Towne Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Metro'}
# {'cuisine': 'Turkish', 'name': 'The Country Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'La Baguette Shop'}
# {'cuisine': 'Other', 'name': 'River Dock Cafe'}
# {'cuisine': 'Other', 'name': '12 Chairs Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Fika'}
# {'cuisine': 'Other', 'name': 'Sweet Fox Cafe'}
# {'cuisine': 'Other', 'name': 'Bricktown Bagels & Cafe'}
# {'cuisine': 'Other', 'name': 'Pastabar Cafe Corp'}
# {'cuisine': 'Other', 'name': "Li'L Jays Cafe"}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Bushwick Public House'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Starbucks Coffee'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Space Gabi ( Pink By Ele)'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Teaffee'}
# {'cuisine': 'Other', 'name': 'Red And Black Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Frisson Espresso'}
# {'cuisine': 'Ethiopian', 'name': 'Tsion Cafe & Bakery'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Little Cupcake Bakeshop'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Little Skips'}
# {'cuisine': 'Other', 'name': 'Truva Cafe Grill'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Gregory Coffee'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Beautiful Memory Desserts'}
# {'cuisine': 'American', 'name': 'Cafe De Novo'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'The Dessert Club'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Fab Cup'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'K & D Internet Inc'}
# {'cuisine': 'Other', 'name': "Ziemek'S Cafe Llc"}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Starbucks Coffee #23267'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Your House'}
# {'cuisine': 'Other', 'name': 'Alba Bar Cafe'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Cocohodo'}
# {'cuisine': 'Café/Coffee/Tea', 'name': 'Doughnut Plant'}
# ...
# {'cuisine': 'Delicatessen', 'name': 'A Le Baguette/ Cafe Olympia'}
# {'cuisine': 'Pizza', 'name': "Ray'S Pizza Bagel Cafe"}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Pratt-Higgins Hall Cafe'}
# {'cuisine': 'Juice, Smoothies, Fruit Salads',
#  'name': '301 Cafe Juice And Smoothies'}
# {'cuisine': 'American', 'name': 'Aig 31St Floor Cafe'}
# {'cuisine': 'Spanish', 'name': "Dylan'S Brooklyn Cafe & Restaurant"}
# {'cuisine': 'Seafood', 'name': 'Oyster Cafe Of New York'}
# {'cuisine': 'Spanish', 'name': 'Aroma De Cafe Bakery'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Church Cafe Wine Bar'}
# {'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#  'name': 'Scoops Ice Cream And Cafe'}
# {'cuisine': 'American', 'name': 'Desert Rose Cafe & Lounge'}
# {'cuisine': 'Bagels/Pretzels', 'name': 'Bread Brothers Bagel Cafe'}
# {'cuisine': 'Chinese', 'name': 'Min Jiang Mini Cafe'}
# {'cuisine': 'Vegetarian', 'name': 'Earth Wellness Cafe Yoga'}
# {'cuisine': 'Spanish', 'name': 'Bocaito Cafe & Wine Bar'}
# {'cuisine': 'Spanish', 'name': "Ray'S Cafe And Restaurant Inc"}
# {'cuisine': 'Indian', 'name': 'Red Chilli Indian Cafe'}
# {'cuisine': 'American', 'name': 'Citi Cafe/Rohatyn Room'}
# {'cuisine': 'American', 'name': 'Marymount College Nugents Cafe'}
# {'cuisine': 'French', 'name': 'Georges-Andre Vintage Cafe'}
# {'cuisine': 'Chinese', 'name': 'Pie Pie Q Cafe'}
# {'cuisine': 'Spanish', 'name': 'El Viejo Gran Cafe'}
# {'cuisine': 'American', 'name': 'N Rico Cafe Restaurant'}
# {'cuisine': 'Mexican', 'name': 'Riky & Sepi Sport Cafe'}
# {'cuisine': 'American', 'name': 'Bread Brothers Bagel Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Mamajuana Cafe / Fiesta Club'}
# {'cuisine': 'American', 'name': 'Lite Bites Cafe And Grill'}
# {'cuisine': 'Delicatessen', 'name': "Water'S Edge Cafe & Convenience"}
# {'cuisine': 'Bakery', 'name': 'Sweets First Bakeshoppe & Cafe'}
# {'cuisine': 'Chinese', 'name': 'New Bay Pkwy Cafe'}
# {'cuisine': 'Pizza', 'name': 'Francisca Pizzeria Bagel Cafe'}
# {'cuisine': 'Italian', 'name': 'Sofia Wine Bar & Cafe'}
# {'cuisine': 'American', 'name': 'F&M Cafe & Restaurant'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Long Island Bagel Cafe'}
# {'cuisine': 'American', 'name': 'Simplicity Wine Bar & Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Chai Pizza & Sushi Cafe'}
# {'cuisine': 'Russian', 'name': '5 Star Village Cafe'}
# {'cuisine': 'Bakery', 'name': 'Aromas Boutique Bakery & Cafe'}
# {'cuisine': 'American', 'name': 'City College Marshak Cafe'}
# {'cuisine': 'Middle Eastern', 'name': 'Blow Hookah Lounge & Cafe'}
# {'cuisine': 'American', 'name': 'Archway Cafe (Unit 114)'}
# {'cuisine': 'Bakery', 'name': 'Fay Wong Cafe Bakery'}
# {'cuisine': 'Delicatessen', 'name': 'Oh Hot Bagels & Cafe'}
# {'cuisine': 'Sandwiches', 'name': 'Saigon 9 West Cafe'}
# {'cuisine': 'Tex-Mex', 'name': 'El Mexicano Restaurante & Cafe'}
# {'cuisine': 'American', 'name': 'Havana Cafe (Section 5)'}
# {'cuisine': 'American', 'name': 'Havana Cafe (Section 10)'}
# {'cuisine': 'Delicatessen', 'name': 'Howard Beach Bagel Cafe'}
# {'cuisine': 'Bakery', 'name': 'Sweets Boutique  Bakery & Cafe'}
# {'cuisine': 'Chinese', 'name': 'Holland Cafe Chinese Restaurant'}
# {'cuisine': 'Bagels/Pretzels', 'name': 'East Side Bagel Cafe'}
# {'cuisine': 'Bakery', 'name': 'New York Bakery Cafe'}
# {'cuisine': 'Russian', 'name': 'Cafe Kafeneja Jone Lounge'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Saint Anns Cafe Restaurant'}
# {'cuisine': 'Juice, Smoothies, Fruit Salads',
#  'name': 'Green Power Cafe @Equinox'}
# {'cuisine': 'Bakery', 'name': 'New Qq Cafe And Bakery'}
# {'cuisine': 'Caribbean', 'name': 'N.Y. Tracks Cafe'}
# {'cuisine': 'Mexican', 'name': 'La Canela Restaurant & Cafe'}
# {'cuisine': 'Bakery', 'name': 'Plenty Cafe Bakery Catering'}
# {'cuisine': 'Juice, Smoothies, Fruit Salads',
#  'name': 'Juice Generation Cafe Group'}
# {'cuisine': 'American', 'name': 'Juice Generation Cafe Group'}
# {'cuisine': 'Spanish', 'name': 'Paradise Cafe Ny Restaurant'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Sabor Colombiano Cafe Restaurant'}
# {'cuisine': 'American', 'name': 'Cafe On 5Th/Sterling Affair'}
# {'cuisine': 'Caribbean', 'name': 'Cafe Soul Jamaican Restaurant'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'La Isla Cafe Restaurant'}
# {'cuisine': 'Delicatessen', 'name': 'Jireh Hot Bagel & Cafe'}
# {'cuisine': 'American', 'name': 'Google Water Tower Cafe'}
# {'cuisine': 'American', 'name': 'Pace University - Cafe 101'}
# {'cuisine': 'Brazilian', 'name': 'Villa Brazil Cafe Grill'}
# {'cuisine': 'American', 'name': 'Ruby Falls Nightlife Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Tierra Ny Cafe Restaurante'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Ice Cream Center & Cafe'}
# {'cuisine': 'American', 'name': 'Fordham University Cosi Cafe'}
# {'cuisine': 'American', 'name': 'Day Break Cafe Restaurant'}
# {'cuisine': 'Russian', 'name': 'Cafe Glechik Of Sheepshead Bay'}
# {'cuisine': 'American', 'name': 'Grand Central Star Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Marine Cafe  Shop Restaurant'}
# {'cuisine': 'Spanish', 'name': 'Que Sabor Bakery Cafe'}
# {'cuisine': 'American', 'name': 'Grand Cafe (Metropolitan Hospital)'}
# {'cuisine': 'French', 'name': 'Cafe Boulud/Bar Pleiades'}
# {'cuisine': 'American', 'name': "Katie'S Cafe In Skating Rink"}
# {'cuisine': 'Turkish', 'name': 'Aksaray Turkish Cafe And Restaurant'}
# {'cuisine': 'Middle Eastern', 'name': 'El-Rawsheh Cafe & Restaurant'}
# {'cuisine': 'Asian', 'name': "King'S Bar Cafe(Class)"}
# {'cuisine': 'Continental', 'name': 'Q Cafe (Queens College)'}
# {'cuisine': 'American', 'name': 'Jewish Guild For The Blind Cafe'}
# {'cuisine': 'Bakery', 'name': 'Red Lotus Bakery & Cafe'}
# {'cuisine': 'Vegetarian', 'name': 'Wild Ginger Vegan Cafe'}
# {'cuisine': 'American', 'name': 'Two 80 Cafe And Lounge'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Cafe Colonial Restaurant & Grill'}
# {'cuisine': 'Caribbean', 'name': 'Cafe Omar/Patty Palace'}
# {'cuisine': 'American', 'name': 'Rmr Cafe (Bowling Alley)'}
# {'cuisine': 'American', 'name': 'Stop Inn Restaurant & Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Cafe El Puente Restaurant'}
# {'cuisine': 'Chinese', 'name': '5Th Avenue Empire Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': '27 Sports Bar & Cafe'}
# {'cuisine': 'Bottled beverages, including water, sodas, juices, etc.',
#  'name': 'Ayza Cafe & Wine Bar'}
# {'cuisine': 'American', 'name': 'Casellula Cheese & Wine Cafe'}
# {'cuisine': 'Middle Eastern', 'name': 'Huka Tel Aviv Cafe'}
# {'cuisine': 'American', 'name': 'New York Times Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': '556 El Cafe International'}
# {'cuisine': 'Eastern European', 'name': 'Hush Cafe Lounge & Garden'}
# {'cuisine': 'Italian', 'name': 'Italianissimo Restaurant Cafe Bar'}
# {'cuisine': 'American', 'name': 'South 4Th Bar & Cafe'}
# {'cuisine': 'Bakery', 'name': 'Morrone Pastry Shop & Cafe'}
# {'cuisine': 'Bagels/Pretzels', 'name': '5Th Avenue Bageltique Cafe'}
# {'cuisine': 'Bakery', 'name': 'Cafe Con Pan Bakery'}
# {'cuisine': 'American', 'name': "Harry'S Cafe/Harry'S Steak"}
# {'cuisine': 'American', 'name': 'Wine And Roses Bar And Cafe'}
# {'cuisine': 'Bakery', 'name': 'Cafe Y Algo Mas'}
# {'cuisine': 'Bakery', 'name': 'Royal Crown Bakery Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Bonjour Deli & Pizza'}
# {'cuisine': 'Mexican', 'name': 'El Sonador Cafe Restaurant'}
# {'cuisine': 'American', 'name': 'Everything Goes Book Cafe'}
# {'cuisine': 'American', 'name': '44 1/2 Cafe'}
# {'cuisine': 'American', 'name': 'Hudson News/Euro Cafe'}
# {'cuisine': 'American', 'name': 'Spin City Cafe & Billards'}
# {'cuisine': 'Asian', 'name': 'Good Health Natural Cafe'}
# {'cuisine': 'Pizza/Italian', 'name': 'Cafe Daniellos Pizzeria Restaurant'}
# {'cuisine': 'Pizza', 'name': "Little Tonino'S Pizza & Cafe"}
# {'cuisine': 'American', 'name': 'Star On 18Th Diner Cafe'}
# {'cuisine': 'American', 'name': "V.I.P.'S Cafe"}
# {'cuisine': 'Bagels/Pretzels', 'name': 'Mill Basin Bagel Cafe'}
# {'cuisine': 'Spanish', 'name': 'Cafe La Morena & Deli'}
# {'cuisine': 'American', 'name': 'Staten Island Zoo Cafe'}
# {'cuisine': 'Bagels/Pretzels', 'name': 'The Liberty Cafe (S.I. Newhouse)'}
# {'cuisine': 'Greek', 'name': 'Igloo Ice Cream Cafe'}
# {'cuisine': 'American', 'name': "Manny'S Cafe Family Restaurant"}
# {'cuisine': 'Mexican', 'name': 'La Flor Bakery Cafe'}
# {'cuisine': 'American', 'name': 'Hanson Gourmet Deli & Cafe'}
# {'cuisine': 'American', 'name': 'Morrell Wine Bar & Cafe'}
# {'cuisine': 'American', 'name': 'Amerada Hess Express Cafe'}
# {'cuisine': 'Italian', 'name': 'Il Fornetto Trattoria Cafe'}
# {'cuisine': 'Pizza', 'name': '10Th Avenue Pizza & Cafe'}
# {'cuisine': 'Greek', 'name': 'Fresco Bar Cafe Restaurant'}
# {'cuisine': 'Bagels/Pretzels', 'name': 'Hot & Crusty Bagels Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'El Nuevo Cafe Latino'}
# {'cuisine': 'American', 'name': "Nora'S Park Bench Cafe"}
# {'cuisine': 'American', 'name': 'Bank Of New York Cafe'}
# {'cuisine': 'American', 'name': 'Simpson Thacher And Bartlet Cafe'}
# {'cuisine': 'Bakery', 'name': 'Fortunato Bros Cafe & Bakery'}
# {'cuisine': 'American', 'name': 'Fifth Ave Cafe /Diner'}
# {'cuisine': 'American', 'name': 'Weiss Cafe Rockefeller University'}
# {'cuisine': 'Bakery', 'name': "Cousin John'S Cafe And Bakery"}
# {'cuisine': 'French', 'name': 'Cafe Un Deux Trois'}
# {'cuisine': 'American', 'name': 'African Market (Baboon Cafe)'}
# {'cuisine': 'American', 'name': 'Terminal Cafe/Yankee Clipper'}
# {'cuisine': 'Other', 'name': '1380 Bronx River Cafe Corp'}
# {'cuisine': 'Turkish', 'name': 'Tsob-Tsobe Cafe Lounge Bar'}
# {'cuisine': 'Bakery', 'name': 'Green Leaf Cafe & Bakery Inc'}
# {'cuisine': 'Bakery', 'name': "Georgia&Aliou'S Tiny Treats Cafe"}
# {'cuisine': 'Creole', 'name': 'Cafe Creole Restaurant N Bakery'}
# {'cuisine': 'American', 'name': 'Antique Cafe & Bakery Iii Inc'}
# {'cuisine': 'American', 'name': 'Figaro Cafe Bistro Bar & Grill'}
# {'cuisine': 'American', 'name': 'New York Film Academy Cafe'}
# {'cuisine': 'Chinese', 'name': 'Hong Kong Cafe Chinese Restaurant'}
# {'cuisine': 'Spanish', 'name': 'Big Apple Restaurant Deli Cafe'}
# {'cuisine': 'Korean', 'name': 'New York Spa & Sauna Cafe'}
# {'cuisine': 'Pizza/Italian', 'name': 'Italian Passion Cafe & Pizza Restaurant'}
# {'cuisine': 'American', 'name': 'Fasst Cafe (Second Stage Theatre)'}
# {'cuisine': 'American', 'name': 'Cafe (At The Museum Of The City Of New York)'}
# {'cuisine': 'Juice, Smoothies, Fruit Salads',
#  'name': 'Force Fusion Juice Bar  & Cafe'}
# {'cuisine': 'Steak', 'name': 'Alex Steak House Bar & Cafe'}
# {'cuisine': 'American', 'name': 'Cones Cafe And Watermark Bar & Lounge'}
# {'cuisine': 'American', 'name': '14Th Street Pizza Bagel Cafe'}
# {'cuisine': 'Bakery', 'name': 'Aroma Cafe Bakery & Coffee Shop'}
# {'cuisine': 'Other', 'name': 'Hungry Ghost Coffee Bar And Cafe'}
# {'cuisine': 'Spanish', 'name': 'Cana Y Cafe Bar Restaurant'}
# {'cuisine': 'American', 'name': 'Skylight Cafe (Medgar Evers College)'}
# {'cuisine': 'Bakery', 'name': 'La Toulousaine Boulangerie Patisserie Cafe'}
# {'cuisine': 'American', 'name': 'The Everett Cafe/Starbucks-Teachers College'}
# {'cuisine': 'American', 'name': "Miss K'S Italian Eatery & Cafe"}
# {'cuisine': 'Chinese', 'name': 'Jin Jin Hong Kong Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'The Original Dream Cafe Comida Latina'}
# {'cuisine': 'Turkish', 'name': 'Pierre Loti Cafe & Wine Bar'}
# {'cuisine': 'American', 'name': 'Science Building - Naked Pear Cafe'}
# {'cuisine': 'Sandwiches', 'name': 'Movable Feast Cafe (At The Picnic House)'}
# {'cuisine': 'Bakery', 'name': 'Cafe Con Pan Bakery Ii'}
# {'cuisine': 'American', 'name': 'Starbucks Coffee,Limited Brands Cafe'}
# {'cuisine': 'American', 'name': 'Employee Cafeteria/Cloister Trie Cafe'}
# {'cuisine': 'American', 'name': 'Teachers College/ Grace Dodge Cafe'}
# {'cuisine': 'American', 'name': 'Radisson Jfk- Cafe One Forty'}
# {'cuisine': 'American', 'name': 'Credit Suisse B-2= Cafe'}
# {'cuisine': 'Tapas', 'name': 'Pierre Loti Cafe Wine Bar'}
# {'cuisine': 'Caribbean', 'name': 'Guy R Cafe Snack Corner'}
# {'cuisine': 'Bagels/Pretzels', 'name': 'Bagels Cafe/Gowanus Yacht Club'}
# {'cuisine': 'American', 'name': 'Hells Kitchen Cafe/Hk Lounge'}
# {'cuisine': 'American', 'name': 'B.A.M. Cafe/Great Performances'}
# {'cuisine': 'American', 'name': "Saidy'S Cafe/Deepdale Gardens Community"}
# {'cuisine': 'American', 'name': 'Whaler Bar, Cafe Buon Giorno'}
# {'cuisine': 'French', 'name': 'Le Train Bleu & B Cafe'}
# {'cuisine': 'American', 'name': 'Dancing Crane Cafe (Bx Zoo)'}
# {'cuisine': 'Greek', 'name': 'The Greek Kitchen  Clinton Bakery Cafe'}
# {'cuisine': 'American', 'name': 'C.U.N.Y Cafe'}
# {'cuisine': 'American', 'name': 'New York University - Courtyard Cafe'}
# {'cuisine': 'American', 'name': 'Gotham Cafe (Inside Holiday Inn)'}
# {'cuisine': 'American', 'name': 'Metropolitan Food Cafe Of Brooklyn College'}
# {'cuisine': 'American', 'name': 'P.S. Gourmet (Cafe On 8)'}
# {'cuisine': 'American', 'name': 'Cafe 101 16Th Floor Cafeteria'}
# {'cuisine': 'American', 'name': 'B.Q.E. Cafe Billiards'}
# {'cuisine': 'American',
#  'name': 'Science Cafe (Queensborough  Community College)'}
# {'cuisine': 'American', 'name': 'Olive Tree Cafe & Comedy Cellar'}
# {'cuisine': 'American', 'name': 'Cafe Atelier (Art Students League)'}
# {'cuisine': 'Other',
#  'name': 'Columbia University Medical Center Bookstore Cafe'}
# {'cuisine': 'Juice, Smoothies, Fruit Salads',
#  'name': 'Snatch & Go Internet Cafe & Juice Bar'}
# {'cuisine': 'Other', 'name': 'New Sun Cafe Japanese Cuisine Inc'}
# {'cuisine': 'Jewish/Kosher', 'name': 'J Ii 13Th Avenue Pizza Cafe'}
# {'cuisine': 'Pizza', 'name': '99 Cent Fresh Pizza Villa Cafe'}
# {'cuisine': 'American', 'name': 'Grand Oaks Country Club/Boxwood Cafe'}
# {'cuisine': 'American', 'name': 'Metropolitan Museum Roof Top Garden Cafe'}
# {'cuisine': 'Juice, Smoothies, Fruit Salads',
#  'name': 'Fountain Of Youth Juice Bar And Cafe Inc.'}
# {'cuisine': 'American', 'name': 'Pier 79/Ny Waterway Seattle Cafe'}
# {'cuisine': 'Sandwiches', 'name': 'Take Away Cafe In Rebecca Rehab Center'}
# {'cuisine': 'Juice, Smoothies, Fruit Salads',
#  'name': 'Green Power Cafe At Equinox Fitness Club'}
# {'cuisine': 'American', 'name': 'Fresh To You Cafe (Home Depot Parking Lot)'}
# {'cuisine': 'American', 'name': 'Cafe Bravo/ Pomodoro Pizza/Planet Gyro'}
# {'cuisine': 'American', 'name': 'Blue Cafe/3 In 1 Deli Restaurant'}
# {'cuisine': 'American', 'name': 'Nrgize Life Style Cafe (La Fitness)'}
# {'cuisine': 'Pizza', 'name': 'Ny Pizza Cafe & Spanish Food Restaurant'}
# {'cuisine': 'Caribbean', 'name': "Gem & Joe Indian'S Eat And Drink Cafe"}
# {'cuisine': 'Bagels/Pretzels',
#  'name': 'The Liberty Cafe  (On The Guy V. Molinari Ferry)'}
# {'cuisine': 'American', 'name': 'West 79Th Street Boat Basin Cafe'}
# {'cuisine': 'American',
#  'name': 'Greenhouse Cafe (557 Broaday) Scholastic Building'}
# {'cuisine': 'Italian', 'name': "Cha Cha'S Backyard Garden Bar & Cafe"}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet',
#  'name': 'Cafe1 & Cafe 4 (American Museum Of Natural History)'}
# {'cuisine': 'American',
#  'name': 'New York Botanical Garden Visitors Center Cafe'}
# {'cuisine': 'American', 'name': 'Chop-N-Toss Cafe Bar/Red Mango'}
# {'cuisine': 'American', 'name': 'Forbell Cafe (U.S. Post Office Cafeteria)'}
# {'cuisine': 'American', 'name': 'New York University- Hall Cafe/ Burger Studio'}
# {'cuisine': 'American',
#  'name': 'Tigin Irish Pub,Peets Coffee&Tea,Panopolis Bakery&Cafe'}
# {'cuisine': 'American',
#  'name': 'Buffalo Wild Wings,Peets Coofee &Tea, Panopolis Bakery & Cafe'}
# {'cuisine': 'Chinese',
#  'name': 'Hong Kong Cafe / Fresh Sandwich Bakery (Basement Food Court '
#          'Restaurant & 1St Fl Bakery)'}

# %%
query = { "$text": { "$search": "cafe -tea" } } # QUE NO CONTENGA LA PALABRA "tea" 
proyeccion = {"_id": 0, "name" : True, "cuisine": 1}

for elemento in rest_collection.find(query, proyeccion):
    pprint(elemento)
# Out:
# {'cuisine': 'Delicatessen', 'name': 'Breadsoul Cafe/ Lincoln Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Cafe Habana/Cafe Habana To Go'}
# {'cuisine': 'American', 'name': 'Cafe Kitchen (Centerplate Cafe And Kitchen)'}
# {'cuisine': 'American', 'name': 'Noumura Cafe ( 5Th Floor Noumura Cafe)'}
# {'cuisine': 'Caribbean', 'name': 'A Cafe'}
# {'cuisine': 'Chinese', 'name': 'Him & Her Cafe'}
# {'cuisine': 'American',
#  'name': 'New York Botanical Gardens Terrace Cafe ( Garden Cafe )'}
# {'cuisine': 'American',
#  'name': "Brooklyn Children'S Museum Cafe/Forest City Ratner Cafe"}
# {'cuisine': 'Other', 'name': 'Ciminna Cafe'}
# {'cuisine': 'Other', 'name': 'Cafe Bari'}
# {'cuisine': 'American', 'name': "''W'' Cafe"}
# {'cuisine': 'Other', 'name': 'Cafe R'}
# {'cuisine': 'Japanese', 'name': 'Maid Cafe'}
# {'cuisine': 'Other', 'name': 'Cafe Clover'}
# {'cuisine': 'Other', 'name': 'Cafe Wha'}
# {'cuisine': 'American', 'name': 'Cafe Islan'}
# {'cuisine': 'Other', 'name': 'Ny Cafe'}
# {'cuisine': 'Japanese', 'name': 'Ogawa Cafe'}
# {'cuisine': 'American', 'name': "Isadora'S Cafe"}
# {'cuisine': 'Donuts', 'name': 'Bruffin Cafe'}
# {'cuisine': 'American', 'name': "Lucky'S Cafe"}
# {'cuisine': 'Caribbean', 'name': 'Vivid Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Forte'}
# {'cuisine': 'Middle Eastern', 'name': 'Gyro Cafe'}
# {'cuisine': 'Chinese', 'name': 'Cielo Cafe'}
# {'cuisine': 'American', 'name': "Cafe Rockaway'S"}
# {'cuisine': 'Other', 'name': 'Cafe 11231'}
# {'cuisine': 'Other', 'name': 'Cafe 55'}
# {'cuisine': 'American', 'name': 'Cafe Plus'}
# {'cuisine': 'Spanish', 'name': 'Vanilla Cafe'}
# {'cuisine': 'Other', 'name': 'Cafe Devocion'}
# {'cuisine': 'Pizza', 'name': "Andy'S Cafe"}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Redstone Cafe'}
# {'cuisine': 'Spanish', 'name': 'Cafe Sahara'}
# {'cuisine': 'Bottled beverages, including water, sodas, juices, etc.',
#  'name': 'Cleopatra Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': "Morrito'S Cafe"}
# {'cuisine': 'American', 'name': 'Tost Cafe'}
# {'cuisine': 'Other', 'name': "Capelli'S Cafe"}
# {'cuisine': 'Other', 'name': 'Ok Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Cafe Ruquetta'}
# {'cuisine': 'Juice, Smoothies, Fruit Salads', 'name': 'Veggies Cafe'}
# {'cuisine': 'American', 'name': 'Anthony Cafe'}
# {'cuisine': 'American', 'name': 'Corner Cafe'}
# {'cuisine': 'Vegetarian', 'name': 'Jungle Cafe'}
# {'cuisine': 'American', 'name': 'Amici Cafe'}
# {'cuisine': 'Ice Cream, Gelato, Yogurt, Ices', 'name': 'Gantry Cafe'}
# {'cuisine': 'Vegetarian', 'name': 'Orchard Cafe'}
# {'cuisine': 'Ice Cream, Gelato, Yogurt, Ices', 'name': 'Microchip Cafe'}
# {'cuisine': 'American', 'name': 'Tcr Cafe'}
# {'cuisine': 'Tapas', 'name': 'Cafe Noir'}
# {'cuisine': 'Chinese', 'name': 'Yes Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Southside Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Corner Cafe'}
# {'cuisine': 'American', 'name': 'Cafe By The Bay'}
# {'cuisine': 'Sandwiches', 'name': 'The Falls Cafe'}
# {'cuisine': 'American', 'name': 'Marm Cafe'}
# {'cuisine': 'American', 'name': "Sharkey'S Cafe"}
# {'cuisine': 'Chinese', 'name': 'Kato Cafe'}
# {'cuisine': 'Ice Cream, Gelato, Yogurt, Ices', 'name': 'Maxie Cafe'}
# {'cuisine': 'Russian', 'name': 'Cafe Edelweiss'}
# {'cuisine': 'Bagels/Pretzels', 'name': 'Bagel Cafe'}
# {'cuisine': 'Eastern European', 'name': 'Cafe Kiev'}
# {'cuisine': 'Other', 'name': 'Brazilia Cafe'}
# {'cuisine': 'Armenian', 'name': "Fatty'S Cafe"}
# {'cuisine': 'Jewish/Kosher', 'name': 'Cafe Paris'}
# {'cuisine': 'Thai', 'name': 'Thailand Cafe'}
# {'cuisine': 'Chinese', 'name': 'Cafe China'}
# {'cuisine': 'American', 'name': 'Europan Cafe'}
# {'cuisine': 'American', 'name': 'Grace Cafe'}
# {'cuisine': 'American', 'name': 'Press Cafe'}
# {'cuisine': 'American', 'name': 'Seattle Cafe'}
# {'cuisine': 'American', 'name': 'Cafe 2'}
# {'cuisine': 'Ethiopian', 'name': 'Bunna Cafe'}
# {'cuisine': 'Italian', 'name': 'Arco Cafe'}
# {'cuisine': 'American', 'name': 'Epice Cafe'}
# {'cuisine': 'Other', 'name': 'Cellar Cafe'}
# {'cuisine': 'Other', 'name': 'Gratitude Cafe'}
# {'cuisine': 'Mediterranean', 'name': 'Layaly Cafe'}
# {'cuisine': 'Chinese', 'name': 'Maikley Cafe'}
# {'cuisine': 'Asian', 'name': 'Benton Cafe'}
# {'cuisine': 'Mediterranean', 'name': 'Effys Cafe'}
# {'cuisine': 'Sandwiches', 'name': 'Cycle Cafe'}
# {'cuisine': 'American', 'name': "Camila'S Cafe"}
# {'cuisine': 'Mediterranean', 'name': "Effy'S Cafe"}
# {'cuisine': 'Turkish', 'name': 'Sofra Cafe'}
# {'cuisine': 'Eastern European', 'name': 'Zair Cafe'}
# {'cuisine': 'Thai', 'name': 'Thai Cafe'}
# {'cuisine': 'Asian', 'name': 'Amarin Cafe'}
# {'cuisine': 'Spanish', 'name': 'Arepas Cafe'}
# {'cuisine': 'Russian', 'name': 'Cafe Euphoria'}
# {'cuisine': 'French', 'name': 'Francis Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Cafe 11'}
# {'cuisine': 'American', 'name': 'Madison Cafe'}
# {'cuisine': 'Juice, Smoothies, Fruit Salads', 'name': 'Reconnect Cafe'}
# {'cuisine': 'Asian', 'name': 'Panda Cafe'}
# {'cuisine': 'Juice, Smoothies, Fruit Salads', 'name': 'Cofi Cafe'}
# {'cuisine': 'American', 'name': 'Cafe 86'}
# {'cuisine': 'Mediterranean', 'name': 'Firdos Cafe'}
# {'cuisine': 'American', 'name': 'Canteen Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Concon Cafe'}
# {'cuisine': 'Eastern European', 'name': 'No Name Cafe'}
# {'cuisine': 'American', 'name': 'The Mug Cafe'}
# {'cuisine': 'Bakery', 'name': 'Hudson Cafe'}
# {'cuisine': 'Asian', 'name': 'Hit Cafe'}
# {'cuisine': 'Other', 'name': "Valle'S Cafe"}
# {'cuisine': 'American', 'name': 'Cyclone Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Picco'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': "Gabriel'S Cafe"}
# {'cuisine': 'Other', 'name': 'Destiny Cafe'}
# {'cuisine': 'Spanish', 'name': 'Cafe Iguana'}
# {'cuisine': 'American', 'name': 'Tuscan Cafe'}
# {'cuisine': 'Japanese', 'name': 'Nomura Cafe'}
# {'cuisine': 'Chinese', 'name': '88 Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Hestia'}
# {'cuisine': 'Chinese', 'name': 'Joyful Cafe'}
# {'cuisine': 'American', 'name': 'Broadway Cafe'}
# {'cuisine': 'American', 'name': 'Tosca Cafe'}
# {'cuisine': 'Middle Eastern', 'name': 'Parlay Cafe'}
# {'cuisine': 'American', 'name': 'Butterfield Cafe'}
# {'cuisine': 'American', 'name': 'Cafe 285'}
# {'cuisine': 'American', 'name': 'Malesia Cafe'}
# {'cuisine': 'Russian', 'name': 'Darina Cafe'}
# {'cuisine': 'Chinese', 'name': 'C2 Cafe'}
# {'cuisine': 'American', 'name': 'Primavera Cafe'}
# {'cuisine': 'Middle Eastern', 'name': 'Cafe Nadery'}
# {'cuisine': 'Chinese', 'name': 'Quickly Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'Cafe Twist'}
# {'cuisine': 'Spanish', 'name': 'Doras Cafe'}
# {'cuisine': 'Korean', 'name': 'Cafe Bene'}
# {'cuisine': 'Sandwiches', 'name': 'Subway Cafe'}
# {'cuisine': 'American', 'name': 'Dunhill Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Elite Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Cafe Mofongo'}
# {'cuisine': 'American', 'name': 'Euro Cafe'}
# {'cuisine': 'Egyptian', 'name': 'Zoe Cafe'}
# {'cuisine': 'American', 'name': "Logan'S Cafe"}
# {'cuisine': 'Jewish/Kosher', 'name': 'Palace Cafe'}
# {'cuisine': 'Italian', 'name': 'Ottomanelli Cafe'}
# {'cuisine': 'Italian', 'name': 'Cammareri Cafe'}
# {'cuisine': 'Korean', 'name': 'Cafe Originale'}
# {'cuisine': 'American', 'name': 'Cafe 45'}
# {'cuisine': 'American', 'name': 'Bloom Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Today'}
# {'cuisine': 'American', 'name': 'Rockaway Cafe'}
# {'cuisine': 'Mediterranean', 'name': 'Cafe Gallery'}
# {'cuisine': 'Japanese', 'name': 'Benton Cafe'}
# {'cuisine': 'Seafood', 'name': 'Fishnet Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'Kappock Cafe'}
# {'cuisine': 'American', 'name': 'Green Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Cd'}
# {'cuisine': 'American', 'name': "Cj'S Cafe"}
# {'cuisine': 'American', 'name': 'Aviation Cafe'}
# {'cuisine': 'American', 'name': 'T49 Cafe'}
# {'cuisine': 'American', 'name': 'The Eagle Cafe'}
# {'cuisine': 'American', 'name': 'Crc Cafe'}
# {'cuisine': 'Bakery', 'name': 'Noisette Cafe'}
# {'cuisine': 'American', 'name': 'Grand Cafe'}
# {'cuisine': 'Chinese', 'name': 'Cafe Evergreen'}
# {'cuisine': 'American', 'name': "Pete'S Cafe"}
# {'cuisine': 'Mediterranean', 'name': 'Cafe Latte'}
# {'cuisine': 'American', 'name': 'Cafe 58'}
# {'cuisine': 'American', 'name': 'Pulse Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Fresco'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Kabila Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Kosher Cafe'}
# {'cuisine': 'American', 'name': "Lucky'S Cafe"}
# {'cuisine': 'Chinese', 'name': 'Munchies Cafe'}
# {'cuisine': 'Delicatessen', 'name': "Nikki'S Cafe"}
# {'cuisine': 'American', 'name': 'Oxford Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Oliviero'}
# {'cuisine': 'American', 'name': "Jj'S Cafe"}
# {'cuisine': 'American', 'name': 'Puff Cafe'}
# {'cuisine': 'American', 'name': 'Cafe To Go'}
# {'cuisine': 'French', 'name': 'Cafe Dada'}
# {'cuisine': 'American', 'name': 'Bocado Cafe'}
# {'cuisine': 'Ice Cream, Gelato, Yogurt, Ices', 'name': 'Breeze Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': "Terry'S Cafe"}
# {'cuisine': 'Delicatessen', 'name': 'The Spot Cafe'}
# {'cuisine': 'Chinese', 'name': 'Metro Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Dancer'}
# {'cuisine': 'French', 'name': 'Piccolo Cafe'}
# {'cuisine': 'American', 'name': 'Gigi Cafe'}
# {'cuisine': 'American', 'name': 'Rosens Cafe'}
# {'cuisine': 'Spanish', 'name': 'Sugar Cafe'}
# {'cuisine': 'American', 'name': 'Packard  Cafe'}
# {'cuisine': 'Asian', 'name': 'Nam Cafe'}
# {'cuisine': 'Middle Eastern', 'name': 'Cafe Mogador'}
# {'cuisine': 'Bakery', 'name': 'Chiqui Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Jerusalem Cafe'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Liberty Cafe'}
# {'cuisine': 'Chinese', 'name': 'Cafe Bakery'}
# {'cuisine': 'Vegetarian', 'name': 'Cafe Blossom'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Turnpike Cafe'}
# {'cuisine': 'American', 'name': 'Cafe 47'}
# {'cuisine': 'Juice, Smoothies, Fruit Salads', 'name': 'Crepe Cafe'}
# {'cuisine': 'Chinese', 'name': 'Asian Cafe'}
# {'cuisine': 'Middle Eastern', 'name': 'Cafe Rokhat'}
# {'cuisine': 'Delicatessen', 'name': 'Gotham Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'City Cafe'}
# {'cuisine': 'Spanish', 'name': 'Warma Cafe'}
# {'cuisine': 'Spanish', 'name': 'Andiamo Cafe'}
# {'cuisine': 'American', 'name': 'Commons Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Acuario Cafe'}
# {'cuisine': 'Eastern European', 'name': 'Cafe Gourmand'}
# {'cuisine': 'American', 'name': 'Worth Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Aka'}
# {'cuisine': 'American', 'name': 'Cafe Bench'}
# {'cuisine': 'Chinese', 'name': 'Kissena Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Elisa Cafe'}
# {'cuisine': 'Japanese', 'name': 'Hana Cafe'}
# {'cuisine': 'Mexican', 'name': "Yola'S Cafe"}
# {'cuisine': 'American', 'name': 'Premier Cafe'}
# {'cuisine': 'Spanish', 'name': 'Mamajuana Cafe'}
# {'cuisine': 'Thai', 'name': 'Mythai Cafe'}
# {'cuisine': 'Caribbean', 'name': 'Reggae Cafe'}
# {'cuisine': 'Korean', 'name': 'Hanra Cafe'}
# {'cuisine': 'American', 'name': 'Mars Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Havana Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Tallulah'}
# {'cuisine': 'Italian', 'name': 'Cafe Lore'}
# {'cuisine': 'American', 'name': "Mila'S Cafe"}
# {'cuisine': 'Italian', 'name': 'Cafe On The Hill'}
# {'cuisine': 'American', 'name': "Daniela'S Cafe"}
# {'cuisine': 'Asian', 'name': 'Y Cafe'}
# {'cuisine': 'American', 'name': "Zanny'S Cafe"}
# {'cuisine': 'American', 'name': 'Cafe 1853'}
# {'cuisine': 'American', 'name': 'Brooklyn  Cafe'}
# {'cuisine': 'American', 'name': 'Cornerstone Cafe'}
# {'cuisine': 'American', 'name': "Cc'S Cafe"}
# {'cuisine': 'Eastern European', 'name': 'Cafe Afsona'}
# {'cuisine': 'American', 'name': 'Bareplanet Cafe'}
# {'cuisine': 'Indian', 'name': 'India Cafe'}
# {'cuisine': 'American', 'name': 'Silo Cafe'}
# {'cuisine': 'Italian', 'name': 'Piccolo Cafe'}
# {'cuisine': 'American', 'name': 'Cafe R'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Cafe Clementine'}
# {'cuisine': 'Delicatessen', 'name': 'Cafe 37'}
# {'cuisine': 'American', 'name': 'Windsor Cafe'}
# {'cuisine': 'American', 'name': "Michael'S Cafe"}
# {'cuisine': 'American', 'name': 'Independence Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Ghia'}
# {'cuisine': 'Spanish', 'name': "Mela'S Cafe"}
# {'cuisine': 'American', 'name': 'Cafe Hanover'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Flavors Cafe'}
# {'cuisine': 'French', 'name': 'Cafe Jolie'}
# {'cuisine': 'American', 'name': "Maybelle'S Cafe"}
# {'cuisine': 'Korean', 'name': 'Cafe 232'}
# {'cuisine': 'American', 'name': 'Exo Cafe'}
# {'cuisine': 'American', 'name': "Shane'S Cafe"}
# {'cuisine': 'Turkish', 'name': 'Gyro Cafe'}
# {'cuisine': 'Mediterranean', 'name': 'Mtskheta Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Hestia'}
# {'cuisine': 'American', 'name': 'O Cafe'}
# {'cuisine': 'American', 'name': 'Bagel Cafe'}
# {'cuisine': 'Russian', 'name': 'Cafe Euroasia'}
# {'cuisine': 'American', 'name': 'Tower Cafe'}
# {'cuisine': 'American', 'name': 'Harvest Cafe'}
# {'cuisine': 'American', 'name': 'Fresh To You Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Havana Cafe'}
# {'cuisine': 'Mediterranean', 'name': 'Bedawi Cafe'}
# {'cuisine': 'American', 'name': 'The West Cafe'}
# {'cuisine': 'Middle Eastern', 'name': 'Gulf Cafe'}
# {'cuisine': 'American', 'name': 'Tost Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Maggio'}
# {'cuisine': 'American', 'name': 'Dorian Cafe'}
# {'cuisine': 'American', 'name': 'Station Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'Cafe Lafayette'}
# {'cuisine': 'Eastern European', 'name': 'Cafe Budovice'}
# {'cuisine': 'American', 'name': 'The Proper Cafe'}
# {'cuisine': 'American', 'name': 'Toasties Cafe'}
# {'cuisine': 'Italian', 'name': 'Fiat Cafe'}
# {'cuisine': 'Russian', 'name': 'Cafe Tabu'}
# {'cuisine': 'Delicatessen', 'name': "The Cafe At Bob'S"}
# {'cuisine': 'Eastern European', 'name': 'Cafe Prague'}
# {'cuisine': 'American', 'name': "Rae'S Cafe"}
# {'cuisine': 'Continental', 'name': 'Banc Cafe'}
# {'cuisine': 'Egyptian', 'name': 'On The Nile Cafe'}
# {'cuisine': 'Russian', 'name': 'Kashkar Cafe'}
# {'cuisine': 'American', 'name': 'Mustang Cafe'}
# {'cuisine': 'Japanese', 'name': 'Ogawa Cafe'}
# {'cuisine': 'Continental', 'name': 'The Bluebell Cafe'}
# {'cuisine': 'American', 'name': "Ariel'S Cafe"}
# {'cuisine': 'Italian', 'name': 'Cafe Minerva'}
# {'cuisine': 'American', 'name': 'Benvenuto Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'Gourmet Cafe'}
# {'cuisine': 'American', 'name': '101 Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Cafe Argentino'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Savor Cafe'}
# {'cuisine': 'American', 'name': 'Morgan Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Cubana Cafe'}
# {'cuisine': 'American', 'name': 'Taz Cafe'}
# {'cuisine': 'American', 'name': 'Love Cafe'}
# {'cuisine': 'American', 'name': 'Green Cafe'}
# {'cuisine': 'French', 'name': 'Cafe Gitane'}
# {'cuisine': 'American', 'name': 'Westside Cafe'}
# {'cuisine': 'American', 'name': "Brad'S Cafe"}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Altus Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'Cafe Tomato'}
# {'cuisine': 'American', 'name': 'Milos Cafe'}
# {'cuisine': 'Caribbean', 'name': 'Impulse Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'Green Cafe'}
# {'cuisine': 'Italian', 'name': 'Provini Cafe'}
# {'cuisine': 'Italian', 'name': "Edgar'S Cafe"}
# {'cuisine': 'Sandwiches', 'name': 'Tasty Cafe'}
# {'cuisine': 'American', 'name': 'Green Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Bistro'}
# {'cuisine': 'American', 'name': 'Cafe Grumpy'}
# {'cuisine': 'American', 'name': "Burgandy'S Cafe"}
# {'cuisine': 'Jewish/Kosher', 'name': 'Cafe 11'}
# {'cuisine': 'Asian', 'name': 'Cafe Himalaya'}
# {'cuisine': 'Russian', 'name': 'Oasis Cafe'}
# {'cuisine': 'American', 'name': 'Towers Cafe'}
# {'cuisine': 'American', 'name': 'Towers Cafe'}
# {'cuisine': 'American', 'name': 'Cafe 27'}
# {'cuisine': 'American', 'name': 'Cafe Pedlar'}
# {'cuisine': 'American', 'name': 'Cafe Olympia'}
# {'cuisine': 'American', 'name': 'Island Cafe'}
# {'cuisine': 'American', 'name': 'Cancun Cafe'}
# {'cuisine': 'American', 'name': 'Cafe 23'}
# {'cuisine': 'American', 'name': "Daddy'S Cafe"}
# {'cuisine': 'American', 'name': 'Woodside Cafe'}
# {'cuisine': 'Other', 'name': 'Cemi Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Wha?'}
# {'cuisine': 'American', 'name': 'Boulevard Cafe'}
# {'cuisine': 'French', 'name': 'B Cafe'}
# {'cuisine': 'Delicatessen', 'name': "Isadora'S Cafe"}
# {'cuisine': 'American', 'name': 'The Jackpot Cafe'}
# {'cuisine': 'Mexican', 'name': 'Cafe 104'}
# {'cuisine': 'Other', 'name': 'Away Cafe'}
# {'cuisine': 'Bakery', 'name': 'Vanilla Cafe'}
# {'cuisine': 'French', 'name': 'Cafe Cambodge'}
# {'cuisine': 'Middle Eastern', 'name': 'Sultana Cafe'}
# {'cuisine': 'American', 'name': 'Silo Cafe'}
# {'cuisine': 'Mediterranean', 'name': 'Cafe Petisco'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Metro Cafe'}
# {'cuisine': 'Korean', 'name': 'Room Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Colador Cafe'}
# {'cuisine': 'Chinese', 'name': 'City Cafe'}
# {'cuisine': 'American', 'name': 'Briarwood Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'Studebaker Cafe'}
# {'cuisine': 'American', 'name': 'Prime Cafe'}
# {'cuisine': 'Eastern European', 'name': 'Cafe Select'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Cafe Rubio'}
# {'cuisine': 'American', 'name': 'Cafe Restaurant'}
# {'cuisine': 'American', 'name': 'Alor Cafe'}
# {'cuisine': 'Polish', 'name': "Johnny'S Cafe"}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Europa Cafe'}
# {'cuisine': 'American', 'name': 'Seattle Cafe'}
# {'cuisine': 'American', 'name': 'Variety Cafe'}
# {'cuisine': 'Sandwiches', 'name': 'Ashbox Cafe'}
# {'cuisine': 'American', 'name': 'Soho Cafe'}
# {'cuisine': 'American', 'name': 'Crossroads Cafe'}
# {'cuisine': 'American', 'name': 'Cranberry Cafe'}
# {'cuisine': 'Vegetarian', 'name': 'Jivamuktea Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Empanadas Cafe'}
# {'cuisine': 'American', 'name': 'Green Cafe'}
# {'cuisine': 'Eastern European', 'name': 'Cafe Katja'}
# {'cuisine': 'Delicatessen', 'name': 'Cafe 42'}
# {'cuisine': 'American', 'name': 'Rosens Cafe'}
# {'cuisine': 'American', 'name': 'Wateredge Cafe'}
# {'cuisine': 'Eastern European', 'name': 'Nargis Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'Cafe Fresco'}
# {'cuisine': 'American', 'name': 'Pier I Cafe'}
# {'cuisine': 'American', 'name': 'Tasty Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Cafe Cortadito'}
# {'cuisine': 'Vegetarian', 'name': 'The Wellness Cafe'}
# {'cuisine': 'American', 'name': 'Circles Cafe'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Europa Cafe'}
# {'cuisine': 'American', 'name': 'Boardwalk Cafe'}
# {'cuisine': 'Mediterranean', 'name': 'Artopolis Cafe'}
# {'cuisine': 'American', 'name': 'Willburg Cafe'}
# {'cuisine': 'Thai', 'name': 'Cafe Chili'}
# {'cuisine': 'French', 'name': 'Cafe Triskell'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Avenue Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Colette'}
# {'cuisine': 'Chinese', 'name': 'Kowloon Cafe'}
# {'cuisine': 'American', 'name': "Tower'S Cafe"}
# {'cuisine': 'American', 'name': 'Telegraphe Cafe'}
# {'cuisine': 'Italian', 'name': 'Cafe Minto'}
# {'cuisine': 'American', 'name': 'Cafe Amrita'}
# {'cuisine': 'American', 'name': 'Flowers Cafe'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Europa Cafe'}
# {'cuisine': 'American', 'name': 'Gigi Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Cubana Cafe'}
# {'cuisine': 'American', 'name': "Moe'S Cafe"}
# {'cuisine': 'American', 'name': "Moe'S Cafe"}
# {'cuisine': 'Jewish/Kosher', 'name': 'Cafe Venezia'}
# {'cuisine': 'American', 'name': 'Beach Cafe'}
# {'cuisine': 'American', 'name': 'Mac Cafe'}
# {'cuisine': 'Other', 'name': 'B Cafe'}
# {'cuisine': 'French', 'name': 'Cafe Cluny'}
# {'cuisine': 'American', 'name': "Ricky'S Cafe"}
# {'cuisine': 'Bakery', 'name': 'Vanilla Cafe'}
# {'cuisine': 'Caribbean', 'name': 'Mingles Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Lincoln'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Carro Cafe'}
# {'cuisine': 'American', 'name': 'Park Cafe'}
# {'cuisine': 'Italian', 'name': 'Vintner Cafe'}
# {'cuisine': 'American', 'name': 'CafÉ Gusto'}
# {'cuisine': 'Vietnamese/Cambodian/Malaysia', 'name': 'Lan Cafe'}
# {'cuisine': 'American', 'name': 'Figs Cafe'}
# {'cuisine': 'American', 'name': 'Cafe 57'}
# {'cuisine': 'American', 'name': 'Beanocchios Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Muscat Cafe'}
# {'cuisine': 'Mediterranean', 'name': 'Horus Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'Cafe Water'}
# {'cuisine': 'French', 'name': 'Cafe Condesa'}
# {'cuisine': 'American', 'name': 'Teleon Cafe'}
# {'cuisine': 'American', 'name': 'Beach Cafe'}
# {'cuisine': 'Caribbean', 'name': "Delroy'S Cafe"}
# {'cuisine': 'Delicatessen', 'name': 'Cafe Duke'}
# {'cuisine': 'Bagels/Pretzels', 'name': 'What A Bagel Cafe'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Europa Cafe'}
# {'cuisine': 'French', 'name': "Cafe D'Alsace"}
# {'cuisine': 'Eastern European', 'name': 'Ukus Cafe'}
# {'cuisine': 'American', 'name': 'Martinique Cafe'}
# {'cuisine': 'American', 'name': 'Museum Cafe'}
# {'cuisine': 'Spanish', 'name': "Rosa'S Cafe"}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Mamajuana Cafe'}
# {'cuisine': 'American', 'name': 'Market Cafe'}
# {'cuisine': 'French', 'name': 'Cafe Lafayette'}
# {'cuisine': 'Italian', 'name': 'Epistrophy Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Cafe Hadar'}
# {'cuisine': 'Eastern European', 'name': "Andre'S Cafe"}
# {'cuisine': 'Greek', 'name': 'Grand Cafe'}
# {'cuisine': 'American', 'name': 'Cafe 101'}
# {'cuisine': 'Bakery', 'name': 'Cafe Riviera'}
# {'cuisine': 'Caribbean', 'name': 'Footprints Cafe'}
# {'cuisine': 'American', 'name': 'Gigi Cafe'}
# {'cuisine': 'Middle Eastern', 'name': 'Luxor Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Metro'}
# {'cuisine': 'Caribbean', 'name': 'Bajan Cafe'}
# {'cuisine': 'American', 'name': "Gracie'S Cafe"}
# {'cuisine': 'American', 'name': "Cc'S Cafe"}
# {'cuisine': 'American', 'name': 'Sugar Cafe'}
# {'cuisine': 'American', 'name': "Gotte'S Cafe"}
# {'cuisine': 'Middle Eastern', 'name': 'Tarboosh Cafe'}
# {'cuisine': 'American', 'name': 'The Brothers Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Metro'}
# {'cuisine': 'Middle Eastern', 'name': 'Cozy Cafe'}
# {'cuisine': 'American', 'name': 'Garden Cafe'}
# {'cuisine': 'French', 'name': 'Hill Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Manhattan'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Cafe Nunez'}
# {'cuisine': 'American', 'name': 'Green Cafe'}
# {'cuisine': 'American', 'name': 'Bxl Cafe'}
# {'cuisine': 'American', 'name': 'Park Cafe'}
# {'cuisine': 'Vietnamese/Cambodian/Malaysia', 'name': 'Viet Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'Oxford Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Jennifer Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Exchange'}
# {'cuisine': 'American', 'name': 'Fanelli Cafe'}
# {'cuisine': 'American', 'name': 'Favorite Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Pick Me Up'}
# {'cuisine': 'Chinese', 'name': "Sai'S Cafe"}
# {'cuisine': 'Soups & Sandwiches', 'name': 'Cafe Metro'}
# {'cuisine': 'French', 'name': 'Cafe Henri'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': "Bicheiro'S Cafe"}
# {'cuisine': 'American', 'name': "Captain'S Cafe"}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Europan Cafe'}
# {'cuisine': 'Russian', 'name': 'Anyway Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'Corte Cafe'}
# {'cuisine': 'Spanish', 'name': 'Cafe Espanol'}
# {'cuisine': 'American', 'name': 'Europan Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Cafe K'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Cafe Classico'}
# {'cuisine': 'American', 'name': 'Cafe 101'}
# {'cuisine': 'American', 'name': 'Cafe Metro'}
# {'cuisine': 'American', 'name': 'Libero Cafe'}
# {'cuisine': 'American', 'name': 'Flavors Cafe'}
# {'cuisine': 'Italian', 'name': "Sambuca'S Cafe"}
# {'cuisine': 'Mexican', 'name': 'Macumba Cafe'}
# {'cuisine': 'American', 'name': 'Cafe 28'}
# {'cuisine': 'Asian', 'name': 'Cafe Mingala'}
# {'cuisine': 'American', 'name': 'Le Cafe'}
# {'cuisine': 'American', 'name': 'Liberty Cafe'}
# {'cuisine': 'Bakery', 'name': "Tong'S Cafe"}
# {'cuisine': 'American', 'name': 'Eastside Cafe'}
# {'cuisine': 'American', 'name': 'Theater Cafe'}
# {'cuisine': 'Pizza', 'name': 'Cafe Viva'}
# {'cuisine': 'American', 'name': 'Cafe Duke'}
# {'cuisine': 'Italian', 'name': 'Cafe Milano'}
# {'cuisine': 'American', 'name': 'Farragut Cafe'}
# {'cuisine': 'American', 'name': 'Eastchester Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Centro'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Europa Cafe'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Europa Cafe'}
# {'cuisine': 'American', 'name': 'Gigi Cafe'}
# {'cuisine': 'American', 'name': 'Max  Cafe'}
# {'cuisine': 'Soul Food', 'name': 'Cafe 22'}
# {'cuisine': 'Delicatessen', 'name': 'Cafe Alice'}
# {'cuisine': 'American', 'name': 'Grand Cafe'}
# {'cuisine': 'Japanese', 'name': 'Jikji Cafe'}
# {'cuisine': 'American', 'name': "Cafe O'"}
# {'cuisine': 'American', 'name': 'Cafe Metro'}
# {'cuisine': 'American', 'name': 'Viand Cafe'}
# {'cuisine': 'Greek', 'name': 'Avenue Cafe'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Europa Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Cafe K'}
# {'cuisine': 'American', 'name': "Teddy'S Cafe"}
# {'cuisine': 'Italian', 'name': 'Cafe Luna'}
# {'cuisine': 'Fruits/Vegetables', 'name': 'Mini Cafe'}
# {'cuisine': 'American', 'name': 'Europa Cafe'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Cosi Cafe'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Cafe Metro'}
# {'cuisine': 'Bakery', 'name': 'Cafe Colombia'}
# {'cuisine': 'Bagels/Pretzels', 'name': 'Liberty Cafe'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Europa Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Amazon Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Bonjour'}
# {'cuisine': 'Japanese', 'name': 'Cafe Zaiya'}
# {'cuisine': 'French', 'name': 'Cafe Angus'}
# {'cuisine': 'American', 'name': 'Belvedere Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Luluc'}
# {'cuisine': 'German', 'name': 'Cafe Sabarsky'}
# {'cuisine': 'Eastern European', 'name': 'Cafe Steinhof'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Cafe Renaissance'}
# {'cuisine': 'Tapas', 'name': 'Cafe Ronda'}
# {'cuisine': 'American', 'name': 'Plymouth Cafe'}
# {'cuisine': 'Indian', 'name': 'Cafe Spice'}
# {'cuisine': 'Indian', 'name': 'Taj Cafe'}
# {'cuisine': 'Caribbean', 'name': 'Footprints Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Duke'}
# {'cuisine': 'American', 'name': 'Cafe Metro'}
# {'cuisine': 'Mexican', 'name': 'Cafe Frida'}
# {'cuisine': 'American', 'name': 'Cafe Luka'}
# {'cuisine': 'American', 'name': 'Ballfields Cafe'}
# {'cuisine': 'American', 'name': 'Intermisson Cafe'}
# {'cuisine': 'Pizza', 'name': "Junior'S Cafe"}
# {'cuisine': 'American', 'name': 'Cafe Orlin'}
# {'cuisine': 'American', 'name': 'Nations Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Cafe K'}
# {'cuisine': 'French', 'name': 'Cafe Joul'}
# {'cuisine': 'American', 'name': 'Stir Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'Central Cafe'}
# {'cuisine': 'Indian', 'name': 'Ghandi Cafe'}
# {'cuisine': 'American', 'name': 'The Country Cafe'}
# {'cuisine': 'Polish', 'name': 'I.O. Cafe'}
# {'cuisine': 'American', 'name': 'Europa Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Express'}
# {'cuisine': 'Indian', 'name': 'Ayurveda Cafe'}
# {'cuisine': 'American', 'name': "Showman'S Cafe"}
# {'cuisine': 'American', 'name': 'Webster Cafe'}
# {'cuisine': 'Moroccan', 'name': 'Cafe Mogador'}
# {'cuisine': 'American', 'name': "Rick'S Cafe"}
# {'cuisine': 'Mediterranean', 'name': 'Cafe Rakka'}
# {'cuisine': 'Delicatessen', 'name': "Bono'S Cafe"}
# {'cuisine': 'American', 'name': "Anna'S Cafe"}
# {'cuisine': 'American', 'name': 'Paris Cafe'}
# {'cuisine': 'American', 'name': "Cafe Lou'S"}
# {'cuisine': 'Mediterranean', 'name': 'Cafe Bar'}
# {'cuisine': 'Mediterranean', 'name': 'Omonia Cafe'}
# {'cuisine': 'American', 'name': 'Cafe 31'}
# {'cuisine': 'American', 'name': 'Anesis Cafe'}
# {'cuisine': 'Italian', 'name': 'Portobello Cafe'}
# {'cuisine': 'Continental', 'name': 'Cafe Champignon'}
# {'cuisine': 'French', 'name': "Jacque'S Cafe"}
# {'cuisine': 'American', 'name': 'Cafe Bravo'}
# {'cuisine': 'Russian', 'name': 'Anyway Cafe'}
# {'cuisine': 'Italian', 'name': 'Arte Cafe'}
# {'cuisine': 'American', 'name': 'Woodlawn Cafe'}
# {'cuisine': 'Thai', 'name': 'Cafe Asean'}
# {'cuisine': 'American', 'name': 'Cravath Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Metro'}
# {'cuisine': 'Spanish', 'name': "Nelly'S Cafe"}
# {'cuisine': 'American', 'name': 'Heights Cafe'}
# {'cuisine': 'Russian', 'name': 'Cafe Volna'}
# {'cuisine': 'Irish', 'name': 'The Scratcher Cafe'}
# {'cuisine': 'Russian', 'name': 'Cafe Paris'}
# {'cuisine': 'American', 'name': 'Gramercy Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Beyond'}
# {'cuisine': 'French', 'name': 'Cafe Gitane'}
# {'cuisine': 'Vegetarian', 'name': 'Candle Cafe'}
# {'cuisine': 'Italian', 'name': 'Enzo Cafe'}
# {'cuisine': 'American', 'name': 'Market Cafe'}
# {'cuisine': 'French', 'name': 'Cafe Loup'}
# {'cuisine': 'American', 'name': 'Europa Cafe'}
# {'cuisine': 'Italian', 'name': 'Cafe Cardini'}
# {'cuisine': 'Greek', 'name': 'Oasis Cafe'}
# {'cuisine': 'American', 'name': 'Metrostar Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Azuri Cafe'}
# {'cuisine': 'American', 'name': "Gleason'S Cafe"}
# {'cuisine': 'American', 'name': 'Belaire Cafe'}
# {'cuisine': 'Egyptian', 'name': 'Kabab Cafe'}
# {'cuisine': 'Italian', 'name': 'Cafe Luna'}
# {'cuisine': 'Delicatessen', 'name': 'Bagel Cafe'}
# {'cuisine': 'American', 'name': 'Cloister Cafe'}
# {'cuisine': 'Italian', 'name': "Carol'S Cafe"}
# {'cuisine': 'American', 'name': 'Cappuccino Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Edison'}
# {'cuisine': 'French', 'name': 'Cafe Luxembourg'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': "Victor'S Cafe"}
# {'cuisine': 'Greek', 'name': 'Omonia Cafe'}
# {'cuisine': 'Italian', 'name': 'Marina Cafe'}
# {'cuisine': 'Spanish', 'name': 'Cafe Espanol'}
# {'cuisine': 'American', 'name': 'Viand Cafe'}
# {'cuisine': 'American', 'name': 'The River Cafe'}
# {'cuisine': 'Spanish', 'name': 'Cafe Riazor'}
# {'cuisine': 'American', 'name': 'The Riviera Cafe'}
# {'cuisine': 'American', 'name': 'Palace Cafe'}
# {'cuisine': 'American', 'name': 'Towne Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Metro'}
# {'cuisine': 'Turkish', 'name': 'The Country Cafe'}
# {'cuisine': 'Other', 'name': 'River Dock Cafe'}
# {'cuisine': 'Other', 'name': '12 Chairs Cafe'}
# {'cuisine': 'Other', 'name': 'Sweet Fox Cafe'}
# {'cuisine': 'Other', 'name': 'Bricktown Bagels & Cafe'}
# {'cuisine': 'Other', 'name': 'Pastabar Cafe Corp'}
# {'cuisine': 'Other', 'name': "Li'L Jays Cafe"}
# {'cuisine': 'Other', 'name': 'Red And Black Cafe'}
# {'cuisine': 'Ethiopian', 'name': 'Tsion Cafe & Bakery'}
# {'cuisine': 'Other', 'name': 'Truva Cafe Grill'}
# {'cuisine': 'American', 'name': 'Cafe De Novo'}
# {'cuisine': 'Other', 'name': "Ziemek'S Cafe Llc"}
# {'cuisine': 'Other', 'name': 'Alba Bar Cafe'}
# {'cuisine': 'Soul Food', 'name': 'East Broadway Cafe'}
# {'cuisine': 'Other', 'name': 'Ipot Cafe Inc.'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Hudson/Euro Cafe'}
# {'cuisine': 'Soul Food', 'name': 'New Soul Cafe'}
# {'cuisine': 'American', 'name': 'Soho Cafe & Grill'}
# {'cuisine': 'American', 'name': 'Lucky Pizzeria & Cafe'}
# {'cuisine': 'Bakery', 'name': 'Pecoshitas Cafe Bakery'}
# {'cuisine': 'Other', 'name': "Li'L Jay'S Cafe"}
# {'cuisine': 'Other', 'name': 'Cafe Restaurant Corp'}
# {'cuisine': 'Other', 'name': 'Bryant Park Cafe'}
# {'cuisine': 'Chinese', 'name': 'D & L Cafe'}
# {'cuisine': 'Caribbean', 'name': 'Soursop Tree Cafe'}
# {'cuisine': 'American', 'name': 'Rivals Boardgame Cafe'}
# {'cuisine': 'Russian', 'name': 'Cafe Shirin Corp.'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Raw Juice Cafe'}
# {'cuisine': 'American', 'name': 'Antique  Bakery & Cafe'}
# {'cuisine': 'Chinese', 'name': 'Taste Buddy Cafe'}
# {'cuisine': 'Spanish', 'name': 'Apple Garden Cafe'}
# {'cuisine': 'Caribbean', 'name': 'Breadfruit Tree Cafe'}
# {'cuisine': 'Chinese/Japanese', 'name': 'Oriental Cafe / Sunny'}
# {'cuisine': 'American', 'name': 'Corona Park Cafe'}
# {'cuisine': 'Chinese', 'name': 'Prince Noodle And Cafe'}
# {'cuisine': 'Chicken', 'name': 'City Wings  Cafe'}
# {'cuisine': 'Pizza', 'name': 'Retro Pizza Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Cafe Au Lee'}
# {'cuisine': 'French', 'name': 'Millefeuille Bakery Cafe'}
# {'cuisine': 'Other', 'name': "Benny'S Bridge Cafe"}
# {'cuisine': 'Bakery', 'name': 'Rainbow Bakery And Cafe'}
# {'cuisine': 'American', 'name': 'Aurora Cafe & Grill'}
# {'cuisine': 'American', 'name': 'Brooklyn Cafe 1'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Bella Caracas Cafe'}
# {'cuisine': 'Tex-Mex', 'name': 'Savoy Cafe & Grill'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Cana Y Cafe'}
# {'cuisine': 'American', 'name': 'Russ & Daughters Cafe'}
# {'cuisine': 'Mexican', 'name': 'Cafe El Presidente'}
# {'cuisine': 'American', 'name': 'Knapp Bagel Cafe'}
# {'cuisine': 'Other', 'name': 'Nrgize Lifestye Cafe'}
# {'cuisine': 'Asian', 'name': 'Saigon Internet Cafe'}
# {'cuisine': 'American', 'name': "Uncle Arthur'S Cafe"}
# {'cuisine': 'American', 'name': 'Cafe De Broadway'}
# {'cuisine': 'Asian', 'name': 'Tibetan Dumpling Cafe'}
# {'cuisine': 'American', 'name': '241St Cafe Restaurant'}
# {'cuisine': 'French', 'name': 'Paris Baguette Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Cafe Tabaco & Ron'}
# {'cuisine': 'Chinese', 'name': 'Happy Express Cafe'}
# {'cuisine': 'Pizza', 'name': 'Salad Garden Cafe'}
# {'cuisine': 'American', 'name': 'University Center Cafe'}
# {'cuisine': 'Korean', 'name': 'Black Hole Cafe'}
# {'cuisine': 'American', 'name': 'Bluestone Lakeside Cafe'}
# {'cuisine': 'American', 'name': 'Griddle Cafe Deli'}
# {'cuisine': 'Mediterranean', 'name': 'Rocca Cafe & Lounge'}
# {'cuisine': 'American', 'name': 'Market Place Cafe'}
# {'cuisine': 'Other', 'name': '66 Hope Cafe'}
# {'cuisine': 'Armenian', 'name': 'Five Town Cafe'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'The Cafe @ Greene St'}
# {'cuisine': 'Japanese', 'name': 'Tokyo Tapas Cafe'}
# {'cuisine': 'Other', 'name': '85 Broad Cafe'}
# {'cuisine': 'Bakery', 'name': '51St Bakery And Cafe'}
# {'cuisine': 'Bakery', 'name': 'Bakery On 3Rd Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Panini La Cafe'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Panini Tost Cafe'}
# {'cuisine': 'American', 'name': 'Cafe 52 Restaurant'}
# {'cuisine': 'Pizza/Italian', 'name': 'Bedford Pizza Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'Dad Deli & Cafe'}
# {'cuisine': 'Pizza/Italian', 'name': "Mario'S Pizza Cafe"}
# {'cuisine': 'Barbecue', 'name': "Ms. Dahlia'S Cafe"}
# {'cuisine': 'American', 'name': 'Le Cafe Coffee'}
# {'cuisine': 'Caribbean', 'name': 'Footprints Cafe Express'}
# {'cuisine': 'Caribbean', 'name': 'Island Cz Cafe'}
# {'cuisine': 'Bakery', 'name': '80 Riverside Cafe'}
# {'cuisine': 'American', 'name': 'La Lampara Cafe'}
# {'cuisine': 'Middle Eastern', 'name': 'Aziza 7 Cafe'}
# {'cuisine': 'Bakery', 'name': 'Audrey Bakery & Cafe'}
# {'cuisine': 'Seafood', 'name': 'Cea-Lo Cafe'}
# {'cuisine': 'American', 'name': 'Kwik Stop Cafe'}
# {'cuisine': 'American', 'name': 'Cypress Inn Cafe'}
# {'cuisine': 'Chinese', 'name': 'Good Century Cafe'}
# {'cuisine': 'Bakery', 'name': 'Kamboat Bakery & Cafe'}
# {'cuisine': 'American', 'name': '4Th Floor Cafe'}
# {'cuisine': 'American', 'name': 'The Park West Cafe'}
# {'cuisine': 'American', 'name': "Cafe B'Way 46"}
# {'cuisine': 'Caribbean', 'name': 'Farafina Cafe And Lounge'}
# {'cuisine': 'Bakery', 'name': 'Koryodang Bakery & Cafe'}
# {'cuisine': 'Bakery', 'name': "Ana'S Bakery & Cafe"}
# {'cuisine': 'French', 'name': 'Belgium Beer Cafe'}
# {'cuisine': 'Caribbean', 'name': 'Milk River Cafe'}
# {'cuisine': 'Spanish', 'name': "Claudio'S Cafe Ii"}
# {'cuisine': 'American', 'name': 'Fresh & Pure Cafe'}
# {'cuisine': 'American', 'name': "Mara'S Cafe & Bakery"}
# {'cuisine': 'Pizza', 'name': 'Beverley Pizza & Cafe'}
# {'cuisine': 'Chinese', 'name': 'Cafe Hong Kong'}
# {'cuisine': 'American', 'name': 'Olympic Pier Cafe'}
# {'cuisine': 'Thai', 'name': 'Fulton Thai Cafe'}
# {'cuisine': 'Korean', 'name': 'Cosmos Room Cafe'}
# {'cuisine': 'Mediterranean', 'name': 'Paninico Cafe Inc'}
# {'cuisine': 'American', 'name': 'Cafe Rue Dix'}
# {'cuisine': 'Spanish', 'name': 'Iguazu Cafe & Grill'}
# {'cuisine': 'Spanish', 'name': 'Cafe Ole Restaurant'}
# {'cuisine': 'American', 'name': 'Harlem  Gourmet Cafe'}
# {'cuisine': 'American', 'name': 'Energy Fuel Cafe'}
# {'cuisine': 'Chinese', 'name': 'Starry Bakery & Cafe'}
# {'cuisine': 'Bakery', 'name': "Veyta'S Bakery Cafe"}
# {'cuisine': 'American', 'name': 'Cafe Zona Sur'}
# {'cuisine': 'Vegetarian', 'name': 'Peacefood Cafe Downtown'}
# {'cuisine': 'Bakery', 'name': "Amy'S Cafe And Bakery"}
# {'cuisine': 'Bakery', 'name': 'Cake Boss Cafe'}
# {'cuisine': 'Spanish', 'name': 'La Villa Cafe'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Pfizer Broadway Cafe'}
# {'cuisine': 'Greek', 'name': 'Gold Mine Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Sfa Nyc'}
# {'cuisine': 'American', 'name': 'Stars & Stripes Cafe'}
# {'cuisine': 'Mediterranean', 'name': 'La Sultana Cafe'}
# {'cuisine': 'American', 'name': 'Alex Cafe & Deli'}
# {'cuisine': 'Spanish', 'name': 'Blue Aroma Cafe'}
# {'cuisine': 'Bakery', 'name': 'Koryodang Bakery And Cafe'}
# {'cuisine': 'Bakery', 'name': "D' Postre Cafe"}
# {'cuisine': 'American', 'name': 'City Tech Cafe'}
# {'cuisine': 'Chinese', 'name': 'Ta 40 Cafe'}
# {'cuisine': 'Spanish', 'name': "Spiro'S Cafe & Pizza"}
# {'cuisine': 'American', 'name': 'Friends Corner Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Cafe Cousina Restaurant'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': "Jessie'S Express Cafe"}
# {'cuisine': 'Japanese', 'name': 'Tomo Japanese Cafe'}
# {'cuisine': 'Indian', 'name': 'Sonali Cafe & Restaurant'}
# {'cuisine': 'Italian', 'name': 'Cafe Del Mondo'}
# {'cuisine': 'American', 'name': 'Panini Tost Cafe'}
# {'cuisine': 'Armenian', 'name': 'Cafe Guy & Gallard'}
# {'cuisine': 'American', 'name': 'Union Square Cafe'}
# {'cuisine': 'Chinese', 'name': 'Im Star Cafe'}
# {'cuisine': 'American', 'name': 'Lotus Cafe & Bagels'}
# {'cuisine': 'Turkish', 'name': 'Opera Cafe Lounge'}
# {'cuisine': 'French', 'name': 'Lange Noir Cafe'}
# {'cuisine': 'French', 'name': 'French Cafe Gourmand'}
# {'cuisine': 'Russian', 'name': 'Ocean View Cafe'}
# {'cuisine': 'Vegetarian', 'name': 'Candle Cafe West'}
# {'cuisine': 'Middle Eastern', 'name': 'Yemen Alsaed Cafe'}
# {'cuisine': 'Bakery', 'name': 'Richol Cafe & Bakery'}
# {'cuisine': 'American', 'name': '120 Bay Cafe'}
# {'cuisine': 'Bakery', 'name': 'Cafe Margot Patisserie'}
# {'cuisine': 'American', 'name': 'Signature Cafe And Bar'}
# {'cuisine': 'American', 'name': 'Blu Cafe By Tavalon'}
# {'cuisine': 'Indian', 'name': 'Majlis Lounge & Cafe'}
# {'cuisine': 'Turkish', 'name': 'Gulluoglu Baklava & Cafe'}
# {'cuisine': 'Indian', 'name': 'Woodside Cafe Restaurant'}
# {'cuisine': 'Caribbean', 'name': "Elsie'S Caribbean Cafe"}
# {'cuisine': 'Jewish/Kosher', 'name': 'Pizza World Cafe'}
# {'cuisine': 'American', 'name': "Lil Bite'S Cafe"}
# {'cuisine': 'Chinese', 'name': 'Lian Won Cafe'}
# {'cuisine': 'Bakery', 'name': 'My Ny Bakery Cafe'}
# {'cuisine': 'Turkish', 'name': "L' Chaim Cafe"}
# {'cuisine': 'Chinese', 'name': 'Shui Mei Cafe'}
# {'cuisine': 'Indian', 'name': "Humro Bhim'S Cafe,"}
# {'cuisine': 'Middle Eastern', 'name': 'Mocha Hookah Cafe'}
# {'cuisine': 'Spanish', 'name': 'Riquisimo Cafe Bakery'}
# {'cuisine': 'American', 'name': 'Nfl-Huddle Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': "Gruenebaum'S Bakery &Cafe"}
# {'cuisine': 'Chinese', 'name': 'Hong Bao Cafe'}
# {'cuisine': 'Pizza/Italian', 'name': "Fratelli'S Pizza & Cafe"}
# {'cuisine': 'American', 'name': 'Triple Crown Cafe'}
# {'cuisine': 'Thai', 'name': 'Sri Thai Cafe'}
# {'cuisine': 'Bagels/Pretzels', 'name': 'Flatiron Green Cafe'}
# {'cuisine': 'Asian', 'name': 'Bedford Fusion Cafe'}
# {'cuisine': 'Irish', 'name': "Ryan'S Daughter Cafe"}
# {'cuisine': 'American', 'name': 'Epicure Cafe & Caterers'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Hudson River Cafe'}
# {'cuisine': 'Bakery', 'name': 'Palombo Bakery Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Lox At Cafe Weissman'}
# {'cuisine': 'French', 'name': 'Mon Petit Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'Cafe Del Sol'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Cafe Con Leche'}
# {'cuisine': 'Bakery', 'name': 'Monteleone Bakery Cafe'}
# {'cuisine': 'Middle Eastern', 'name': 'Water Falls Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'The Corner Cafe & Bakery'}
# {'cuisine': 'American', 'name': 'Caracas Beach Cafe'}
# {'cuisine': 'Bakery', 'name': 'Millefeuille Bakery Cafe'}
# {'cuisine': 'Italian', 'name': 'Bella Donna Cafe'}
# {'cuisine': 'Thai', 'name': 'Mini Thai Cafe'}
# {'cuisine': 'Bakery', 'name': 'Cafe Grumpy Bakery'}
# {'cuisine': 'Middle Eastern', 'name': 'Tutt Heights Cafe'}
# {'cuisine': 'Bakery', 'name': 'Golden Sands Cafe'}
# {'cuisine': 'Russian', 'name': "Tatiana'S Cafe & Grill"}
# {'cuisine': 'Mediterranean', 'name': 'Wine Garden Cafe'}
# {'cuisine': 'Greek', 'name': 'Cozy Diner & Cafe'}
# {'cuisine': 'American', 'name': 'Ceo Ktv & Cafe'}
# {'cuisine': 'Chinese', 'name': 'Lp 28 Cafe'}
# {'cuisine': 'American', 'name': 'The Lutheran Halal Cafe'}
# {'cuisine': 'American', 'name': 'Jacobi Towers Cafe'}
# {'cuisine': 'American', 'name': "Juju'S Bagels Cafe"}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Dulce Vida Cafe'}
# {'cuisine': 'American', 'name': 'Berkli Parc Cafe'}
# {'cuisine': 'American', 'name': '55 Thomas Cafe'}
# {'cuisine': 'Italian', 'name': 'Gaia Italian Cafe'}
# {'cuisine': 'Delicatessen', 'name': "John'S Cafe Deli"}
# {'cuisine': 'American', 'name': 'New Star Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Nu Cafe 47'}
# {'cuisine': 'Eastern European', 'name': 'Cafe Two Way'}
# {'cuisine': 'American', 'name': 'Majestic Delicatessen Cafe'}
# {'cuisine': 'Bakery', 'name': 'Sunshine Bakery & Cafe'}
# {'cuisine': 'Chinese', 'name': 'Shanghai Cafe Deluxe'}
# {'cuisine': 'Vietnamese/Cambodian/Malaysia', 'name': 'V-Nam Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'Elim Deli Cafe'}
# {'cuisine': 'Russian', 'name': 'New Cafe Minutka'}
# {'cuisine': 'American', 'name': 'Barnes & Noble Cafe'}
# {'cuisine': 'Caribbean', 'name': 'Blue Flame Cafe'}
# {'cuisine': 'Chinese', 'name': 'Lee Chung Cafe'}
# {'cuisine': 'American', 'name': 'Soho Cafe & Grill'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Jou Jou Cafe'}
# {'cuisine': 'Chinese', 'name': '388 Cafe & Deli'}
# {'cuisine': 'Pizza/Italian', 'name': "Regina'S Cafe & Pizzeria"}
# {'cuisine': 'American', 'name': 'Take Away & Cafe'}
# {'cuisine': 'Cajun', 'name': 'Cajun Cafe & Grill'}
# {'cuisine': 'American', 'name': 'Arome Cafe Ii'}
# {'cuisine': 'Pizza', 'name': 'Perizia Cafe  And  Pizza'}
# {'cuisine': 'Middle Eastern', 'name': 'Yemen Cafe & Restaurant'}
# {'cuisine': 'American', 'name': 'Bagel Maven Cafe'}
# {'cuisine': 'Pizza', 'name': 'Bistro 175 Cafe'}
# {'cuisine': 'Mexican', 'name': "Rjc Family'S Cafe"}
# {'cuisine': 'American', 'name': 'Green Kitchen Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Bora Bora'}
# {'cuisine': 'Bakery', 'name': 'Paris Baguette & Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Blue Dish Cafe'}
# {'cuisine': 'American', 'name': 'Taste Of Cafe (Potamkin)'}
# {'cuisine': 'Pizza', 'name': 'Europan Pizza Cafe'}
# {'cuisine': 'American', 'name': 'Veranda Restaurant-Cafe'}
# {'cuisine': 'American', 'name': 'Chelsea Bagel & Cafe'}
# {'cuisine': 'American', 'name': 'Corner Cafe & Bakery'}
# {'cuisine': 'American', 'name': '1001 Nights Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'The Point Cafe & Grill'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Pizza Palace Cafe'}
# {'cuisine': 'Mexican', 'name': 'El Parador Cafe'}
# {'cuisine': 'American', 'name': 'Jou Jou Cafe'}
# {'cuisine': 'American', 'name': "Dominick'S Bakery & Cafe"}
# {'cuisine': 'American', 'name': 'Moxie Works Cafe'}
# {'cuisine': 'American', 'name': 'Ground Support Cafe'}
# {'cuisine': 'Italian', 'name': 'Tonelli Cafe Bar'}
# {'cuisine': 'Russian', 'name': 'Coffee Spot Cafe'}
# {'cuisine': 'Thai', 'name': 'Toon Thai Cafe'}
# {'cuisine': 'American', 'name': "George'S Diner-Cafe"}
# {'cuisine': 'Turkish', 'name': 'Gulluoglu Baklava & Cafe'}
# {'cuisine': 'Korean', 'name': 'Third Floor Cafe'}
# {'cuisine': 'Bakery', 'name': "Veyta'S Bakery Cafe"}
# {'cuisine': 'American', 'name': 'Peace Food Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Oh! Bagel Cafe'}
# {'cuisine': 'American', 'name': 'Hard Rock Cafe'}
# {'cuisine': 'Pizza', 'name': "Mama'S Pizza Cafe"}
# {'cuisine': 'American', 'name': 'Ge Financial Cafe'}
# {'cuisine': 'American', 'name': 'World Ice Cafe'}
# {'cuisine': 'Vegetarian', 'name': 'The Green Bean Cafe'}
# {'cuisine': 'American', 'name': 'Dancing Crane Cafe'}
# {'cuisine': 'American', 'name': 'Local Cafe & Cocktails'}
# {'cuisine': 'Mexican', 'name': 'Mexican Cafe & Restaurant'}
# {'cuisine': 'American', 'name': 'Hermes Billiards & Cafe'}
# {'cuisine': 'Soul Food', 'name': 'New Soul Cafe'}
# {'cuisine': 'American', 'name': 'Pier Side Cafe'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet',
#  'name': "Brownie'S Cafe At Columbia"}
# {'cuisine': 'Bakery', 'name': 'Horizon Bakery Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'Blacksmith Cafe & Delicatessen'}
# {'cuisine': 'Delicatessen', 'name': 'Oh Bagel Cafe'}
# {'cuisine': 'American', 'name': 'East Harlem Cafe'}
# {'cuisine': 'American', 'name': 'Indian Road Cafe'}
# {'cuisine': 'American', 'name': 'Ice House Cafe'}
# {'cuisine': 'Asian', 'name': 'Top Cafe Tibet'}
# {'cuisine': 'Mediterranean', 'name': "Cafe Jonny'S Lounge"}
# {'cuisine': 'Bakery', 'name': 'Paris Baguette Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'Delissimo Deli & Cafe'}
# {'cuisine': 'American', 'name': 'Bank Of America Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Nano Billiard Cafe'}
# {'cuisine': 'Japanese', 'name': 'Metro Sushi Cafe'}
# {'cuisine': 'Bakery', 'name': 'Mario Bakery And Cafe'}
# {'cuisine': 'Spanish', 'name': 'Cafe Los Arcos'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Fiesta Cafe Bar'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Europan Bakery Cafe'}
# {'cuisine': 'American', 'name': 'Gramercy Star Cafe'}
# {'cuisine': 'Chinese', 'name': 'L & U Cafe'}
# {'cuisine': 'American', 'name': 'Tanto Dulce Cafe'}
# {'cuisine': 'American', 'name': 'North Star Cafe'}
# {'cuisine': 'Mediterranean', 'name': 'Melody Cafe & Restaurant'}
# {'cuisine': 'American', 'name': 'Juan Valdez Cafe'}
# {'cuisine': 'Turkish', 'name': 'Masal Cafe & Lounge'}
# {'cuisine': 'Spanish', 'name': 'Cafe Salamanca Restaurant'}
# {'cuisine': 'Other', 'name': 'Markt Cafe Restaurant'}
# {'cuisine': 'Pizza', 'name': 'Cafe Roma Pizzeria'}
# {'cuisine': 'American', 'name': 'Route 66 Cafe'}
# {'cuisine': 'American', 'name': 'Coco Moka Cafe'}
# {'cuisine': 'Spanish', 'name': 'Cafe 2000 Corona'}
# {'cuisine': 'American', 'name': 'Lincoln Towers Cafe'}
# {'cuisine': 'American', 'name': 'Ropes & Gray Cafe'}
# {'cuisine': 'Korean', 'name': 'Cosmos Room Cafe'}
# {'cuisine': 'American', 'name': 'Wow Bridge Cafe'}
# {'cuisine': 'American', 'name': "Alice'S Int'L Cafe"}
# {'cuisine': 'Bakery', 'name': 'Cafe Savoy Bakery'}
# {'cuisine': 'Chinese', 'name': 'S. Wan Cafe'}
# {'cuisine': 'American', 'name': 'Sea Level Cafe'}
# {'cuisine': 'American', 'name': 'East Village Cafe'}
# ...
# {'cuisine': 'American', 'name': 'Cafe Frederick Harlem Parlor'}
# {'cuisine': 'Korean', 'name': 'Pine Tree Cafe & Restaurant'}
# {'cuisine': 'Australian', 'name': 'Bluestone Lane Collective Cafe'}
# {'cuisine': 'Delicatessen', 'name': 'A Le Baguette/ Cafe Olympia'}
# {'cuisine': 'Pizza', 'name': "Ray'S Pizza Bagel Cafe"}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Pratt-Higgins Hall Cafe'}
# {'cuisine': 'Juice, Smoothies, Fruit Salads',
#  'name': '301 Cafe Juice And Smoothies'}
# {'cuisine': 'American', 'name': 'Aig 31St Floor Cafe'}
# {'cuisine': 'Spanish', 'name': "Dylan'S Brooklyn Cafe & Restaurant"}
# {'cuisine': 'Seafood', 'name': 'Oyster Cafe Of New York'}
# {'cuisine': 'Spanish', 'name': 'Aroma De Cafe Bakery'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Church Cafe Wine Bar'}
# {'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#  'name': 'Scoops Ice Cream And Cafe'}
# {'cuisine': 'American', 'name': 'Desert Rose Cafe & Lounge'}
# {'cuisine': 'Bagels/Pretzels', 'name': 'Bread Brothers Bagel Cafe'}
# {'cuisine': 'Chinese', 'name': 'Min Jiang Mini Cafe'}
# {'cuisine': 'Vegetarian', 'name': 'Earth Wellness Cafe Yoga'}
# {'cuisine': 'Spanish', 'name': 'Bocaito Cafe & Wine Bar'}
# {'cuisine': 'Spanish', 'name': "Ray'S Cafe And Restaurant Inc"}
# {'cuisine': 'Indian', 'name': 'Red Chilli Indian Cafe'}
# {'cuisine': 'American', 'name': 'Citi Cafe/Rohatyn Room'}
# {'cuisine': 'American', 'name': 'Marymount College Nugents Cafe'}
# {'cuisine': 'French', 'name': 'Georges-Andre Vintage Cafe'}
# {'cuisine': 'Chinese', 'name': 'Pie Pie Q Cafe'}
# {'cuisine': 'Spanish', 'name': 'El Viejo Gran Cafe'}
# {'cuisine': 'American', 'name': 'N Rico Cafe Restaurant'}
# {'cuisine': 'Mexican', 'name': 'Riky & Sepi Sport Cafe'}
# {'cuisine': 'American', 'name': 'Bread Brothers Bagel Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Mamajuana Cafe / Fiesta Club'}
# {'cuisine': 'American', 'name': 'Lite Bites Cafe And Grill'}
# {'cuisine': 'Delicatessen', 'name': "Water'S Edge Cafe & Convenience"}
# {'cuisine': 'Bakery', 'name': 'Sweets First Bakeshoppe & Cafe'}
# {'cuisine': 'Chinese', 'name': 'New Bay Pkwy Cafe'}
# {'cuisine': 'Pizza', 'name': 'Francisca Pizzeria Bagel Cafe'}
# {'cuisine': 'Italian', 'name': 'Sofia Wine Bar & Cafe'}
# {'cuisine': 'American', 'name': 'F&M Cafe & Restaurant'}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet', 'name': 'Long Island Bagel Cafe'}
# {'cuisine': 'American', 'name': 'Simplicity Wine Bar & Cafe'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Chai Pizza & Sushi Cafe'}
# {'cuisine': 'Russian', 'name': '5 Star Village Cafe'}
# {'cuisine': 'Bakery', 'name': 'Aromas Boutique Bakery & Cafe'}
# {'cuisine': 'American', 'name': 'City College Marshak Cafe'}
# {'cuisine': 'Middle Eastern', 'name': 'Blow Hookah Lounge & Cafe'}
# {'cuisine': 'American', 'name': 'Archway Cafe (Unit 114)'}
# {'cuisine': 'Bakery', 'name': 'Fay Wong Cafe Bakery'}
# {'cuisine': 'Delicatessen', 'name': 'Oh Hot Bagels & Cafe'}
# {'cuisine': 'Sandwiches', 'name': 'Saigon 9 West Cafe'}
# {'cuisine': 'Tex-Mex', 'name': 'El Mexicano Restaurante & Cafe'}
# {'cuisine': 'American', 'name': 'Havana Cafe (Section 5)'}
# {'cuisine': 'American', 'name': 'Havana Cafe (Section 10)'}
# {'cuisine': 'Delicatessen', 'name': 'Howard Beach Bagel Cafe'}
# {'cuisine': 'Bakery', 'name': 'Sweets Boutique  Bakery & Cafe'}
# {'cuisine': 'Chinese', 'name': 'Holland Cafe Chinese Restaurant'}
# {'cuisine': 'Bagels/Pretzels', 'name': 'East Side Bagel Cafe'}
# {'cuisine': 'Bakery', 'name': 'New York Bakery Cafe'}
# {'cuisine': 'Russian', 'name': 'Cafe Kafeneja Jone Lounge'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Saint Anns Cafe Restaurant'}
# {'cuisine': 'Juice, Smoothies, Fruit Salads',
#  'name': 'Green Power Cafe @Equinox'}
# {'cuisine': 'Bakery', 'name': 'New Qq Cafe And Bakery'}
# {'cuisine': 'Caribbean', 'name': 'N.Y. Tracks Cafe'}
# {'cuisine': 'Mexican', 'name': 'La Canela Restaurant & Cafe'}
# {'cuisine': 'Bakery', 'name': 'Plenty Cafe Bakery Catering'}
# {'cuisine': 'Juice, Smoothies, Fruit Salads',
#  'name': 'Juice Generation Cafe Group'}
# {'cuisine': 'American', 'name': 'Juice Generation Cafe Group'}
# {'cuisine': 'Spanish', 'name': 'Paradise Cafe Ny Restaurant'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Sabor Colombiano Cafe Restaurant'}
# {'cuisine': 'American', 'name': 'Cafe On 5Th/Sterling Affair'}
# {'cuisine': 'Caribbean', 'name': 'Cafe Soul Jamaican Restaurant'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'La Isla Cafe Restaurant'}
# {'cuisine': 'Delicatessen', 'name': 'Jireh Hot Bagel & Cafe'}
# {'cuisine': 'American', 'name': 'Google Water Tower Cafe'}
# {'cuisine': 'American', 'name': 'Pace University - Cafe 101'}
# {'cuisine': 'Brazilian', 'name': 'Villa Brazil Cafe Grill'}
# {'cuisine': 'American', 'name': 'Ruby Falls Nightlife Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Tierra Ny Cafe Restaurante'}
# {'cuisine': 'Jewish/Kosher', 'name': 'Ice Cream Center & Cafe'}
# {'cuisine': 'American', 'name': 'Fordham University Cosi Cafe'}
# {'cuisine': 'American', 'name': 'Day Break Cafe Restaurant'}
# {'cuisine': 'Russian', 'name': 'Cafe Glechik Of Sheepshead Bay'}
# {'cuisine': 'American', 'name': 'Grand Central Star Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Marine Cafe  Shop Restaurant'}
# {'cuisine': 'Spanish', 'name': 'Que Sabor Bakery Cafe'}
# {'cuisine': 'American', 'name': 'Grand Cafe (Metropolitan Hospital)'}
# {'cuisine': 'French', 'name': 'Cafe Boulud/Bar Pleiades'}
# {'cuisine': 'American', 'name': "Katie'S Cafe In Skating Rink"}
# {'cuisine': 'Turkish', 'name': 'Aksaray Turkish Cafe And Restaurant'}
# {'cuisine': 'Middle Eastern', 'name': 'El-Rawsheh Cafe & Restaurant'}
# {'cuisine': 'Asian', 'name': "King'S Bar Cafe(Class)"}
# {'cuisine': 'Continental', 'name': 'Q Cafe (Queens College)'}
# {'cuisine': 'American', 'name': 'Jewish Guild For The Blind Cafe'}
# {'cuisine': 'Bakery', 'name': 'Red Lotus Bakery & Cafe'}
# {'cuisine': 'Vegetarian', 'name': 'Wild Ginger Vegan Cafe'}
# {'cuisine': 'American', 'name': 'Two 80 Cafe And Lounge'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Cafe Colonial Restaurant & Grill'}
# {'cuisine': 'Caribbean', 'name': 'Cafe Omar/Patty Palace'}
# {'cuisine': 'American', 'name': 'Rmr Cafe (Bowling Alley)'}
# {'cuisine': 'American', 'name': 'Stop Inn Restaurant & Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'Cafe El Puente Restaurant'}
# {'cuisine': 'Chinese', 'name': '5Th Avenue Empire Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': '27 Sports Bar & Cafe'}
# {'cuisine': 'Bottled beverages, including water, sodas, juices, etc.',
#  'name': 'Ayza Cafe & Wine Bar'}
# {'cuisine': 'American', 'name': 'Casellula Cheese & Wine Cafe'}
# {'cuisine': 'Middle Eastern', 'name': 'Huka Tel Aviv Cafe'}
# {'cuisine': 'American', 'name': 'New York Times Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': '556 El Cafe International'}
# {'cuisine': 'Eastern European', 'name': 'Hush Cafe Lounge & Garden'}
# {'cuisine': 'Italian', 'name': 'Italianissimo Restaurant Cafe Bar'}
# {'cuisine': 'American', 'name': 'South 4Th Bar & Cafe'}
# {'cuisine': 'Bakery', 'name': 'Morrone Pastry Shop & Cafe'}
# {'cuisine': 'Bagels/Pretzels', 'name': '5Th Avenue Bageltique Cafe'}
# {'cuisine': 'Bakery', 'name': 'Cafe Con Pan Bakery'}
# {'cuisine': 'American', 'name': "Harry'S Cafe/Harry'S Steak"}
# {'cuisine': 'American', 'name': 'Wine And Roses Bar And Cafe'}
# {'cuisine': 'Bakery', 'name': 'Cafe Y Algo Mas'}
# {'cuisine': 'Bakery', 'name': 'Royal Crown Bakery Cafe'}
# {'cuisine': 'American', 'name': 'Cafe Bonjour Deli & Pizza'}
# {'cuisine': 'Mexican', 'name': 'El Sonador Cafe Restaurant'}
# {'cuisine': 'American', 'name': 'Everything Goes Book Cafe'}
# {'cuisine': 'American', 'name': '44 1/2 Cafe'}
# {'cuisine': 'American', 'name': 'Hudson News/Euro Cafe'}
# {'cuisine': 'American', 'name': 'Spin City Cafe & Billards'}
# {'cuisine': 'Asian', 'name': 'Good Health Natural Cafe'}
# {'cuisine': 'Pizza/Italian', 'name': 'Cafe Daniellos Pizzeria Restaurant'}
# {'cuisine': 'Pizza', 'name': "Little Tonino'S Pizza & Cafe"}
# {'cuisine': 'American', 'name': 'Star On 18Th Diner Cafe'}
# {'cuisine': 'American', 'name': "V.I.P.'S Cafe"}
# {'cuisine': 'Bagels/Pretzels', 'name': 'Mill Basin Bagel Cafe'}
# {'cuisine': 'Spanish', 'name': 'Cafe La Morena & Deli'}
# {'cuisine': 'American', 'name': 'Staten Island Zoo Cafe'}
# {'cuisine': 'Bagels/Pretzels', 'name': 'The Liberty Cafe (S.I. Newhouse)'}
# {'cuisine': 'Greek', 'name': 'Igloo Ice Cream Cafe'}
# {'cuisine': 'American', 'name': "Manny'S Cafe Family Restaurant"}
# {'cuisine': 'Mexican', 'name': 'La Flor Bakery Cafe'}
# {'cuisine': 'American', 'name': 'Hanson Gourmet Deli & Cafe'}
# {'cuisine': 'American', 'name': 'Morrell Wine Bar & Cafe'}
# {'cuisine': 'American', 'name': 'Amerada Hess Express Cafe'}
# {'cuisine': 'Italian', 'name': 'Il Fornetto Trattoria Cafe'}
# {'cuisine': 'Pizza', 'name': '10Th Avenue Pizza & Cafe'}
# {'cuisine': 'Greek', 'name': 'Fresco Bar Cafe Restaurant'}
# {'cuisine': 'Bagels/Pretzels', 'name': 'Hot & Crusty Bagels Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'El Nuevo Cafe Latino'}
# {'cuisine': 'American', 'name': "Nora'S Park Bench Cafe"}
# {'cuisine': 'American', 'name': 'Bank Of New York Cafe'}
# {'cuisine': 'American', 'name': 'Simpson Thacher And Bartlet Cafe'}
# {'cuisine': 'Bakery', 'name': 'Fortunato Bros Cafe & Bakery'}
# {'cuisine': 'American', 'name': 'Fifth Ave Cafe /Diner'}
# {'cuisine': 'American', 'name': 'Weiss Cafe Rockefeller University'}
# {'cuisine': 'Bakery', 'name': "Cousin John'S Cafe And Bakery"}
# {'cuisine': 'French', 'name': 'Cafe Un Deux Trois'}
# {'cuisine': 'American', 'name': 'African Market (Baboon Cafe)'}
# {'cuisine': 'American', 'name': 'Terminal Cafe/Yankee Clipper'}
# {'cuisine': 'Other', 'name': '1380 Bronx River Cafe Corp'}
# {'cuisine': 'Turkish', 'name': 'Tsob-Tsobe Cafe Lounge Bar'}
# {'cuisine': 'Bakery', 'name': 'Green Leaf Cafe & Bakery Inc'}
# {'cuisine': 'Bakery', 'name': "Georgia&Aliou'S Tiny Treats Cafe"}
# {'cuisine': 'Creole', 'name': 'Cafe Creole Restaurant N Bakery'}
# {'cuisine': 'American', 'name': 'Antique Cafe & Bakery Iii Inc'}
# {'cuisine': 'American', 'name': 'Figaro Cafe Bistro Bar & Grill'}
# {'cuisine': 'American', 'name': 'New York Film Academy Cafe'}
# {'cuisine': 'Chinese', 'name': 'Hong Kong Cafe Chinese Restaurant'}
# {'cuisine': 'Spanish', 'name': 'Big Apple Restaurant Deli Cafe'}
# {'cuisine': 'Korean', 'name': 'New York Spa & Sauna Cafe'}
# {'cuisine': 'Pizza/Italian', 'name': 'Italian Passion Cafe & Pizza Restaurant'}
# {'cuisine': 'American', 'name': 'Fasst Cafe (Second Stage Theatre)'}
# {'cuisine': 'American', 'name': 'Cafe (At The Museum Of The City Of New York)'}
# {'cuisine': 'Juice, Smoothies, Fruit Salads',
#  'name': 'Force Fusion Juice Bar  & Cafe'}
# {'cuisine': 'Steak', 'name': 'Alex Steak House Bar & Cafe'}
# {'cuisine': 'American', 'name': 'Cones Cafe And Watermark Bar & Lounge'}
# {'cuisine': 'American', 'name': '14Th Street Pizza Bagel Cafe'}
# {'cuisine': 'Bakery', 'name': 'Aroma Cafe Bakery & Coffee Shop'}
# {'cuisine': 'Other', 'name': 'Hungry Ghost Coffee Bar And Cafe'}
# {'cuisine': 'Spanish', 'name': 'Cana Y Cafe Bar Restaurant'}
# {'cuisine': 'American', 'name': 'Skylight Cafe (Medgar Evers College)'}
# {'cuisine': 'Bakery', 'name': 'La Toulousaine Boulangerie Patisserie Cafe'}
# {'cuisine': 'American', 'name': 'The Everett Cafe/Starbucks-Teachers College'}
# {'cuisine': 'American', 'name': "Miss K'S Italian Eatery & Cafe"}
# {'cuisine': 'Chinese', 'name': 'Jin Jin Hong Kong Cafe'}
# {'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'name': 'The Original Dream Cafe Comida Latina'}
# {'cuisine': 'Turkish', 'name': 'Pierre Loti Cafe & Wine Bar'}
# {'cuisine': 'American', 'name': 'Science Building - Naked Pear Cafe'}
# {'cuisine': 'Sandwiches', 'name': 'Movable Feast Cafe (At The Picnic House)'}
# {'cuisine': 'Bakery', 'name': 'Cafe Con Pan Bakery Ii'}
# {'cuisine': 'American', 'name': 'Starbucks Coffee,Limited Brands Cafe'}
# {'cuisine': 'American', 'name': 'Employee Cafeteria/Cloister Trie Cafe'}
# {'cuisine': 'American', 'name': 'Teachers College/ Grace Dodge Cafe'}
# {'cuisine': 'American', 'name': 'Radisson Jfk- Cafe One Forty'}
# {'cuisine': 'American', 'name': 'Credit Suisse B-2= Cafe'}
# {'cuisine': 'Tapas', 'name': 'Pierre Loti Cafe Wine Bar'}
# {'cuisine': 'Caribbean', 'name': 'Guy R Cafe Snack Corner'}
# {'cuisine': 'Bagels/Pretzels', 'name': 'Bagels Cafe/Gowanus Yacht Club'}
# {'cuisine': 'American', 'name': 'Hells Kitchen Cafe/Hk Lounge'}
# {'cuisine': 'American', 'name': 'B.A.M. Cafe/Great Performances'}
# {'cuisine': 'American', 'name': "Saidy'S Cafe/Deepdale Gardens Community"}
# {'cuisine': 'American', 'name': 'Whaler Bar, Cafe Buon Giorno'}
# {'cuisine': 'French', 'name': 'Le Train Bleu & B Cafe'}
# {'cuisine': 'American', 'name': 'Dancing Crane Cafe (Bx Zoo)'}
# {'cuisine': 'Greek', 'name': 'The Greek Kitchen  Clinton Bakery Cafe'}
# {'cuisine': 'American', 'name': 'C.U.N.Y Cafe'}
# {'cuisine': 'American', 'name': 'New York University - Courtyard Cafe'}
# {'cuisine': 'American', 'name': 'Gotham Cafe (Inside Holiday Inn)'}
# {'cuisine': 'American', 'name': 'Metropolitan Food Cafe Of Brooklyn College'}
# {'cuisine': 'American', 'name': 'P.S. Gourmet (Cafe On 8)'}
# {'cuisine': 'American', 'name': 'Cafe 101 16Th Floor Cafeteria'}
# {'cuisine': 'American', 'name': 'B.Q.E. Cafe Billiards'}
# {'cuisine': 'American',
#  'name': 'Science Cafe (Queensborough  Community College)'}
# {'cuisine': 'American', 'name': 'Olive Tree Cafe & Comedy Cellar'}
# {'cuisine': 'American', 'name': 'Cafe Atelier (Art Students League)'}
# {'cuisine': 'Other',
#  'name': 'Columbia University Medical Center Bookstore Cafe'}
# {'cuisine': 'Juice, Smoothies, Fruit Salads',
#  'name': 'Snatch & Go Internet Cafe & Juice Bar'}
# {'cuisine': 'Other', 'name': 'New Sun Cafe Japanese Cuisine Inc'}
# {'cuisine': 'Jewish/Kosher', 'name': 'J Ii 13Th Avenue Pizza Cafe'}
# {'cuisine': 'Pizza', 'name': '99 Cent Fresh Pizza Villa Cafe'}
# {'cuisine': 'American', 'name': 'Grand Oaks Country Club/Boxwood Cafe'}
# {'cuisine': 'American', 'name': 'Metropolitan Museum Roof Top Garden Cafe'}
# {'cuisine': 'Juice, Smoothies, Fruit Salads',
#  'name': 'Fountain Of Youth Juice Bar And Cafe Inc.'}
# {'cuisine': 'American', 'name': 'Pier 79/Ny Waterway Seattle Cafe'}
# {'cuisine': 'Sandwiches', 'name': 'Take Away Cafe In Rebecca Rehab Center'}
# {'cuisine': 'Juice, Smoothies, Fruit Salads',
#  'name': 'Green Power Cafe At Equinox Fitness Club'}
# {'cuisine': 'American', 'name': 'Fresh To You Cafe (Home Depot Parking Lot)'}
# {'cuisine': 'American', 'name': 'Cafe Bravo/ Pomodoro Pizza/Planet Gyro'}
# {'cuisine': 'American', 'name': 'Blue Cafe/3 In 1 Deli Restaurant'}
# {'cuisine': 'American', 'name': 'Nrgize Life Style Cafe (La Fitness)'}
# {'cuisine': 'Pizza', 'name': 'Ny Pizza Cafe & Spanish Food Restaurant'}
# {'cuisine': 'Caribbean', 'name': "Gem & Joe Indian'S Eat And Drink Cafe"}
# {'cuisine': 'Bagels/Pretzels',
#  'name': 'The Liberty Cafe  (On The Guy V. Molinari Ferry)'}
# {'cuisine': 'American', 'name': 'West 79Th Street Boat Basin Cafe'}
# {'cuisine': 'American',
#  'name': 'Greenhouse Cafe (557 Broaday) Scholastic Building'}
# {'cuisine': 'Italian', 'name': "Cha Cha'S Backyard Garden Bar & Cafe"}
# {'cuisine': 'Sandwiches/Salads/Mixed Buffet',
#  'name': 'Cafe1 & Cafe 4 (American Museum Of Natural History)'}
# {'cuisine': 'American',
#  'name': 'New York Botanical Garden Visitors Center Cafe'}
# {'cuisine': 'American', 'name': 'Chop-N-Toss Cafe Bar/Red Mango'}
# {'cuisine': 'American', 'name': 'Forbell Cafe (U.S. Post Office Cafeteria)'}
# {'cuisine': 'American', 'name': 'New York University- Hall Cafe/ Burger Studio'}
# {'cuisine': 'Chinese',
#  'name': 'Hong Kong Cafe / Fresh Sandwich Bakery (Basement Food Court '
#          'Restaurant & 1St Fl Bakery)'}

# %%
rest_collection.create_index({ "address.coord" : "2d" })
# Out:
# 'address.coord_2d'

# %%
import folium

mi_ubicación = [40.74, -74]

my_map = folium.Map(location=mi_ubicación,
                 zoom_start=14,
                 control_scale=True)

# add marker to map
folium.Marker(mi_ubicación,
             popup = "You are here",
             tooltip = 'click').add_to(my_map)

# display map
display(my_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_664518afe2f7a2eef96cfe641c6862a7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_664518afe2f7a2eef96cfe641c6862a7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_664518afe2f7a2eef96cfe641c6862a7 = L.map(
#                 &quot;map_664518afe2f7a2eef96cfe641c6862a7&quot;,
#                 {
#                     center: [40.74, -74.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_664518afe2f7a2eef96cfe641c6862a7);
#
#
#
#
#
#             var tile_layer_7b24b5f678546652b919fc6a9b4f9a30 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7b24b5f678546652b919fc6a9b4f9a30.addTo(map_664518afe2f7a2eef96cfe641c6862a7);
#
#
#             var marker_a047e1445a6c27ad4145dcaf434221bf = L.marker(
#                 [40.74, -74.0],
#                 {}
#             ).addTo(map_664518afe2f7a2eef96cfe641c6862a7);
#
#
#         var popup_c25d11d13faeeb69f6bbfc5a08598d55 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d7d09f241347d4f81400eabd167ef059 = $(`&lt;div id=&quot;html_d7d09f241347d4f81400eabd167ef059&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;You are here&lt;/div&gt;`)[0];
#                 popup_c25d11d13faeeb69f6bbfc5a08598d55.setContent(html_d7d09f241347d4f81400eabd167ef059);
#
#
#
#         marker_a047e1445a6c27ad4145dcaf434221bf.bindPopup(popup_c25d11d13faeeb69f6bbfc5a08598d55)
#         ;
#
#
#
#
#             marker_a047e1445a6c27ad4145dcaf434221bf.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# NOTA: En este caso la información de latitud y longitud está invertida

# "$and" INDICA QUE SE DEBEN CUMPLIR DOS CONDICIONES  

query = {"$and" : [
    { "address.coord" : { "$geoWithin" : { "$center" : [ [mi_ubicación[1], mi_ubicación[0]] , 0.01 ] } } }, 
    { "$text": { "$search": "cafe -tea" } }
]}

proyeccion = {"name" : True, "_id" : 0, "address.coord" : True}

restaurantes_cerca = []
for elemento in rest_collection.find(query, proyeccion):
    restaurantes_cerca.append(elemento)

# %%
elemento
# Out:
# {'address': {'coord': [-74.00057799999999, 40.730204]},
#  'name': 'Olive Tree Cafe & Comedy Cellar'}

# %%
folium.Marker(elemento["address"]["coord"][::-1], tooltip = 'click', icon=folium.Icon(color='green'), popup=elemento["name"]).add_to(my_map)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_664518afe2f7a2eef96cfe641c6862a7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_664518afe2f7a2eef96cfe641c6862a7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_664518afe2f7a2eef96cfe641c6862a7 = L.map(
#                 &quot;map_664518afe2f7a2eef96cfe641c6862a7&quot;,
#                 {
#                     center: [40.74, -74.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_664518afe2f7a2eef96cfe641c6862a7);
#
#
#
#
#
#             var tile_layer_7b24b5f678546652b919fc6a9b4f9a30 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7b24b5f678546652b919fc6a9b4f9a30.addTo(map_664518afe2f7a2eef96cfe641c6862a7);
#
#
#             var marker_a047e1445a6c27ad4145dcaf434221bf = L.marker(
#                 [40.74, -74.0],
#                 {}
#             ).addTo(map_664518afe2f7a2eef96cfe641c6862a7);
#
#
#         var popup_c25d11d13faeeb69f6bbfc5a08598d55 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d7d09f241347d4f81400eabd167ef059 = $(`&lt;div id=&quot;html_d7d09f241347d4f81400eabd167ef059&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;You are here&lt;/div&gt;`)[0];
#                 popup_c25d11d13faeeb69f6bbfc5a08598d55.setContent(html_d7d09f241347d4f81400eabd167ef059);
#
#
#
#         marker_a047e1445a6c27ad4145dcaf434221bf.bindPopup(popup_c25d11d13faeeb69f6bbfc5a08598d55)
#         ;
#
#
#
#
#             marker_a047e1445a6c27ad4145dcaf434221bf.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_7b24b5f678546652b919fc6a9b4f9a30.addTo(map_664518afe2f7a2eef96cfe641c6862a7);
#
#
#             var marker_8cc511d75a096b472b6ab4e88115b5ab = L.marker(
#                 [40.730204, -74.00057799999999],
#                 {}
#             ).addTo(map_664518afe2f7a2eef96cfe641c6862a7);
#
#
#             var icon_1213b97c7d23887d2b25417e0bd4c77e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8cc511d75a096b472b6ab4e88115b5ab.setIcon(icon_1213b97c7d23887d2b25417e0bd4c77e);
#
#
#         var popup_73396b5d5e1fd6574c7183f1e73e7ea5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c89b0b4d98d332cb112bdd5119a94b89 = $(`&lt;div id=&quot;html_c89b0b4d98d332cb112bdd5119a94b89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Olive Tree Cafe &amp; Comedy Cellar&lt;/div&gt;`)[0];
#                 popup_73396b5d5e1fd6574c7183f1e73e7ea5.setContent(html_c89b0b4d98d332cb112bdd5119a94b89);
#
#
#
#         marker_8cc511d75a096b472b6ab4e88115b5ab.bindPopup(popup_73396b5d5e1fd6574c7183f1e73e7ea5)
#         ;
#
#
#
#
#             marker_8cc511d75a096b472b6ab4e88115b5ab.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
icon = folium.Icon(color='green')

feature_group = folium.FeatureGroup("Locations")

for rest in restaurantes_cerca:
    feature_group.add_child(folium.Marker(location=rest["address"]["coord"][::-1], icon=folium.Icon(color='green'), tooltip = 'click', popup=rest["name"]))

my_map.add_child(feature_group)

# display map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_664518afe2f7a2eef96cfe641c6862a7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_664518afe2f7a2eef96cfe641c6862a7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_664518afe2f7a2eef96cfe641c6862a7 = L.map(
#                 &quot;map_664518afe2f7a2eef96cfe641c6862a7&quot;,
#                 {
#                     center: [40.74, -74.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_664518afe2f7a2eef96cfe641c6862a7);
#
#
#
#
#
#             var tile_layer_7b24b5f678546652b919fc6a9b4f9a30 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7b24b5f678546652b919fc6a9b4f9a30.addTo(map_664518afe2f7a2eef96cfe641c6862a7);
#
#
#             var marker_a047e1445a6c27ad4145dcaf434221bf = L.marker(
#                 [40.74, -74.0],
#                 {}
#             ).addTo(map_664518afe2f7a2eef96cfe641c6862a7);
#
#
#         var popup_c25d11d13faeeb69f6bbfc5a08598d55 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d7d09f241347d4f81400eabd167ef059 = $(`&lt;div id=&quot;html_d7d09f241347d4f81400eabd167ef059&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;You are here&lt;/div&gt;`)[0];
#                 popup_c25d11d13faeeb69f6bbfc5a08598d55.setContent(html_d7d09f241347d4f81400eabd167ef059);
#
#
#
#         marker_a047e1445a6c27ad4145dcaf434221bf.bindPopup(popup_c25d11d13faeeb69f6bbfc5a08598d55)
#         ;
#
#
#
#
#             marker_a047e1445a6c27ad4145dcaf434221bf.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_7b24b5f678546652b919fc6a9b4f9a30.addTo(map_664518afe2f7a2eef96cfe641c6862a7);
#
#
#             var marker_8cc511d75a096b472b6ab4e88115b5ab = L.marker(
#                 [40.730204, -74.00057799999999],
#                 {}
#             ).addTo(map_664518afe2f7a2eef96cfe641c6862a7);
#
#
#             var icon_1213b97c7d23887d2b25417e0bd4c77e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8cc511d75a096b472b6ab4e88115b5ab.setIcon(icon_1213b97c7d23887d2b25417e0bd4c77e);
#
#
#         var popup_73396b5d5e1fd6574c7183f1e73e7ea5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c89b0b4d98d332cb112bdd5119a94b89 = $(`&lt;div id=&quot;html_c89b0b4d98d332cb112bdd5119a94b89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Olive Tree Cafe &amp; Comedy Cellar&lt;/div&gt;`)[0];
#                 popup_73396b5d5e1fd6574c7183f1e73e7ea5.setContent(html_c89b0b4d98d332cb112bdd5119a94b89);
#
#
#
#         marker_8cc511d75a096b472b6ab4e88115b5ab.bindPopup(popup_73396b5d5e1fd6574c7183f1e73e7ea5)
#         ;
#
#
#
#
#             marker_8cc511d75a096b472b6ab4e88115b5ab.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_7b24b5f678546652b919fc6a9b4f9a30.addTo(map_664518afe2f7a2eef96cfe641c6862a7);
#
#
#             var feature_group_4a3c49cf4ff501b700db847a604d0207 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_89f816239098281fa226bb2aafe11cf3 = L.marker(
#                 [40.7301659, -74.000664],
#                 {}
#             ).addTo(feature_group_4a3c49cf4ff501b700db847a604d0207);
#
#
#             var icon_679d2a9bf46be03688e8d8fdf3e8b2d2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_89f816239098281fa226bb2aafe11cf3.setIcon(icon_679d2a9bf46be03688e8d8fdf3e8b2d2);
#
#
#         var popup_d79edf030abb46d69b7735aef0618417 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_88a7236a7bf574336b13618b2bc49081 = $(`&lt;div id=&quot;html_88a7236a7bf574336b13618b2bc49081&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cafe Wha&lt;/div&gt;`)[0];
#                 popup_d79edf030abb46d69b7735aef0618417.setContent(html_88a7236a7bf574336b13618b2bc49081);
#
#
#
#         marker_89f816239098281fa226bb2aafe11cf3.bindPopup(popup_d79edf030abb46d69b7735aef0618417)
#         ;

# %%
map.save(outfile = "test.html")

# %% [markdown]
# ¿Seríais capaces de encontrar los restaurantes Chinos o Japoneses cerca de mi?

# %%
# Aquí va vuestro código

# %% [markdown]
# Finalmente podremos cerrar la conexión.

# %%
client.close()
